# %% [markdown]
# ## Library

# %%
import math
import random

import numpy as np
import matplotlib.pyplot as plt

import squigglepy as sq
from squigglepy import bayes
from squigglepy.numbers import K, M, B, T

from copy import copy, deepcopy
from scipy import stats
from pprint import pprint
print('Loaded 1')

exec(open('utils.py').read())
print('Loaded 2')

exec(open('/Users/peterhurford/dev/forecastflow/library.py').read()) # TODO: Package?
print('Loaded 3')
# Out:
# Loaded 1
# Loaded 2
# Loaded 3

# %% [markdown]
# ## Variables (customize these)

# %%
# Customize these!!!

# Global variables - probably don't want to change these but you could.
RUNS = 10000                                      # Number of runs to do (default 1000)
CURRENT_YEAR = 2023                               # What year to start the run on? (default: 2023)
MAX_YEAR = 2123                                   # What year to end the run on? (default: 2123)
USE_NUMBERS = 'Wildeford'                         # Which variable set (see below) to use?
GRAPH_P = 50                                      # What percentile to graph on the graphs below? (default: 50)
VARIABLE_SETS = {}


VARIABLE_SETS['Cotra2020'] = {
    'initial_gdp': 23*T,                  # GDP in `CURRENT_YEAR` of country that will develop TAI (default: 23 trillion)
    'tai_flop_size': sq.sample(load_cache_file='caches/cotra_2020'),  # Cache generated in "Anchors" notebook
    # 90% CI, it takes 10^X FLOPs to run a transformative AI at inference.
    # Note: A petaflop/s-day (pfs-day) consists of performing 10^15 neural net operations per second for one day,
    # or a total of about 10^20 operations
    'algo_doubling_rate_max': 3.5,        # 90% CI, algorithms get twice as efficient every X years (maximum)
    'algo_doubling_rate_min': 2,          # 90% CI, algorithms get twice as efficient every X years (minimum)
    'min_reduction': 2,                   # 90% CI, the minimum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'max_reduction': 5,                   # 90% CI, the maximum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'initial_flops_per_dollar': 17,       # 90% CI, as of today, we can buy 10^X FLOPs per $
    'flops_halving_rate': 2.5,            # 90% CI, the cost of FLOPs per $ halves every X years
    'max_flops_per_dollar': 24,           # 90% CI, the cheapest FLOPs will get is 10^X FLOPs per $
    'initial_pay': 8.7,                   # 90% CI, as of today the maximum we would pay for TAI is $10^X
    'gdp_growth': 1.03,                   # 90% CI, GDP will increase by a factor of X each year
    'max_gdp_frac': 0.01,                 # 90% CI, the maximum % of GDP that would be spent on TAI is $10^X
    'spend_doubling_time': 2.5            # 90% CI, our willingness to spend on TAI doubles every X years
}


VARIABLE_SETS['Cotra2022'] = deepcopy(VARIABLE_SETS['Cotra2020'])
VARIABLE_SETS['Cotra2022']['tai_flop_size'] = sq.sample(load_cache_file='caches/cotra_2022')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Cotra2022']['initial_flops_per_dollar'] = sq.const(18)


def wildeford_max_gdp_frac():
    small_project = sq.lognorm(1 / (250*K), 1 / (3*K))
    modern_megaproject = sq.lognorm(1/K, 1/600)
    old_form_megaproject = sq.lognorm(1/500, 1/150)
    gigaproject = sq.lognorm(1/150, 1/50)
    
    r_ = random.random()
    if r_ < 0.1:
        gdp_frac = small_project
        percent_spent_on_compute = sq.lognorm(0.2,0.6, lclip=0.1, rclip=0.9)
    elif r_ < 0.8:
        gdp_frac = modern_megaproject
        percent_spent_on_compute = sq.lognorm(0.4,0.7, lclip=0.1, rclip=0.9)
    elif r_ < 0.95:
        gdp_frac = old_form_megaproject
        percent_spent_on_compute = sq.lognorm(0.5,0.9, lclip=0.1, rclip=0.9)
    else:
        gdp_frac = gigaproject
        percent_spent_on_compute = sq.lognorm(0.6,0.9, lclip=0.1, rclip=0.9)

    return ~gdp_frac * ~percent_spent_on_compute

VARIABLE_SETS['Wildeford'] = deepcopy(VARIABLE_SETS['Cotra2022'])
VARIABLE_SETS['Wildeford']['tai_flop_size'] = sq.sample(load_cache_file='caches/meta_anchor')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Wildeford']['flops_halving_rate'] = sq.lognorm(2, 5)
VARIABLE_SETS['Wildeford']['initial_pay'] = sq.mixture([[0.8, sq.const(7.1)],
                                                        [0.2, sq.lognorm(7.1,9, lclip=7.1)]]) #NEW
VARIABLE_SETS['Wildeford']['gdp_growth'] = sq.lognorm(1.015, 1.035) #NEW
VARIABLE_SETS['Wildeford']['max_gdp_frac'] = wildeford_max_gdp_frac #NEW
VARIABLE_SETS['Wildeford']['spend_doubling_time'] = sq.mixture([[0.8, sq.lognorm(3,6)],
                                                                [0.2, sq.lognorm(1,2, lclip=1)]]) #NEW
# TODO: Willingness to spend connected to commercialization
VARIABLE_SETS['Wildeford']['initial_chance_of_nonscaling_issue'] = 0.95 #NEW
VARIABLE_SETS['Wildeford']['final_chance_of_nonscaling_issue'] = 0.3 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_issue_bottom_year'] = 2050 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_delay'] = sq.mixture([[0.7, sq.lognorm(2,10)],
                                                             [0.3, sq.lognorm(5,40)]]) #NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_max'] = sq.norm(1,3) # NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_min'] = sq.norm(1,2) # NEW
VARIABLE_SETS['Wildeford']['min_reduction'] = 2 # TODO: Connect to efficiency within tai_flop_size / should correlate with tai_flop_size
VARIABLE_SETS['Wildeford']['max_reduction'] = 5


# These equations define how variables change over time or in relationship to other variables.
def gdp(initial_gdp, gdp_growth, year):
    return initial_gdp * (gdp_growth ** year)


def willingness_to_pay(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac, year):
    gdp_ = gdp(initial_gdp=initial_gdp, gdp_growth=gdp_growth, year=year)
    x = (np.log(2) / spend_doubling_time) * year
    if x < 650:
        y = math.log10(initial_pay) + math.log10(math.exp(x)) - math.log10(1 + initial_pay / (gdp_ * max_gdp_frac) * math.exp(x))
        if y > 300:
            y = int(y) # Handle overflow errors
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_pay) + (year/spend_doubling_time)/3.3)
    

def algo_halving_fn(min_speed, max_speed, tai_flop_size):
    if max_speed < min_speed:
        max_speed = min_speed
    if min_speed > max_speed:
        min_speed = max_speed
    return min(max(max_speed - (round((tai_flop_size - 29) / 2) / 2), min_speed), max_speed)


def flops_needed(initial_flops, possible_reduction, doubling_rate, year):
    x = (np.log(2) / doubling_rate) * year
    if x < 650:
        y = (math.log10(initial_flops) - max(math.log10(math.exp(x)) - math.log10(1 + (1/possible_reduction) * math.exp(x)), 0))
        if y > 300:
            y = int(y) # Handle overflow errors        
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops) - (1/possible_reduction))

    
def flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, halving_rate, year):
    x = (np.log(2) / halving_rate) * year
    if x < 650:
        y = (math.log10(initial_flops_per_dollar) + math.log10(math.exp(x)) - math.log10(1 + initial_flops_per_dollar / max_flops_per_dollar * math.exp(x)))
        if y > 300:
            y = int(y) # Handle overflow errors                
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops_per_dollar) + (year/halving_rate)/3.3)

    
def cost_of_tai(initial_flops, possible_reduction, algo_doubling_rate, initial_flops_per_dollar, max_flops_per_dollar,
                flops_halving_rate, year):
    return (flops_needed(initial_flops, possible_reduction, algo_doubling_rate, year) /
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def flops_at_max(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac,
                 initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year):
    return (willingness_to_pay(initial_gdp=initial_gdp,
                               gdp_growth=gdp_growth,
                               initial_pay=initial_pay,
                               spend_doubling_time=spend_doubling_time,
                               max_gdp_frac=max_gdp_frac,
                               year=year) *
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def possible_algo_reduction_fn(min_reduction, max_reduction, tai_flop_size):
    if max_reduction < min_reduction:
        max_reduction = min_reduction
    if min_reduction > max_reduction:
        min_reduction = max_reduction
    return min(max(min_reduction + round((tai_flop_size - 32) / 4), min_reduction), max_reduction)


# NEW
def p_nonscaling_delay(initial_p, final_p, year, max_year):
    return generalized_logistic_curve(x=year - CURRENT_YEAR,
                                      slope=0.3,
                                      shift=3 * (max_year - CURRENT_YEAR),
                                      push=1,
                                      maximum=final_p,
                                      minimum=initial_p)
    

# ------------- Ignore below here ------------
years = list(range(CURRENT_YEAR, MAX_YEAR))
variables = VARIABLE_SETS[USE_NUMBERS]
print('Loaded')
# Out:
# Loaded

# %%
initial_flop_size_s = variables['tai_flop_size']
initial_flops_p = sq.get_percentiles(initial_flop_size_s)
plt.hist(initial_flop_size_s, bins = 200)
pprint(initial_flops_p)
# Out:
# {1: 19.63724923334467,
#  5: 24.075237899269318,
#  10: 25.256382971267474,
#  20: 26.89483425563567,
#  30: 28.67435022348726,
#  40: 30.658979466450262,
#  50: 32.465619190623535,
#  60: 34.42396366962843,
#  70: 36.61065628850712,
#  80: 39.269776073581944,
#  90: 42.94780946266621,
#  95: 45.92494809894404,
#  99: 51.977890800303854}

# %%
min_reduction_p = sq.get_percentiles(sq.sample(variables['min_reduction'], n=1000))
min_reduction_p
# Out:
# {1: 2.0,
#  5: 2.0,
#  10: 2.0,
#  20: 2.0,
#  30: 2.0,
#  40: 2.0,
#  50: 2.0,
#  60: 2.0,
#  70: 2.0,
#  80: 2.0,
#  90: 2.0,
#  95: 2.0,
#  99: 2.0}

# %%
max_reduction_p = sq.get_percentiles(sq.sample(variables['max_reduction'], n=1000), reverse=True)
max_reduction_p
# Out:
# {99: 5.0,
#  95: 5.0,
#  90: 5.0,
#  80: 5.0,
#  70: 5.0,
#  60: 5.0,
#  50: 5.0,
#  40: 5.0,
#  30: 5.0,
#  20: 5.0,
#  10: 5.0,
#  5: 5.0,
#  1: 5.0}

# %%
algo_doubling_rate_min_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_min'], n=1000), reverse=True)
algo_doubling_rate_min_p
# Out:
# {99: 0.7473901172902102,
#  95: 0.9682820204157396,
#  90: 1.0991705676073544,
#  80: 1.2348346886548083,
#  70: 1.3194383676694168,
#  60: 1.4095187612564284,
#  50: 1.4855671643247885,
#  40: 1.5759786954149564,
#  30: 1.6455399295236386,
#  20: 1.7466959441534602,
#  10: 1.881225368826084,
#  5: 2.0078447184903223,
#  1: 2.1783897326442365}

# %%
algo_doubling_rate_max_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_max'], n=1000), reverse=True)
algo_doubling_rate_max_p
# Out:
# {99: 0.6987156059401414,
#  95: 1.0362945695361678,
#  90: 1.207570991218175,
#  80: 1.4896476085114259,
#  70: 1.6950768728296775,
#  60: 1.8627368031487612,
#  50: 2.0276876069971594,
#  40: 2.186794670152668,
#  30: 2.3278116758408562,
#  20: 2.523357320981274,
#  10: 2.7388511595785694,
#  5: 2.9336926429059758,
#  1: 3.4095455585526397}

# %%
initial_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['initial_flops_per_dollar'], n=1000))
initial_flops_per_dollar_p
# Out:
# {1: 18.0,
#  5: 18.0,
#  10: 18.0,
#  20: 18.0,
#  30: 18.0,
#  40: 18.0,
#  50: 18.0,
#  60: 18.0,
#  70: 18.0,
#  80: 18.0,
#  90: 18.0,
#  95: 18.0,
#  99: 18.0}

# %%
flops_halving_rate_p = sq.get_percentiles(sq.sample(variables['flops_halving_rate'], n=1000), reverse=True)
flops_halving_rate_p
# Out:
# {99: 1.6879013675131727,
#  95: 2.0326319438830343,
#  90: 2.2146801016725384,
#  80: 2.4951103115481086,
#  70: 2.7122376535984856,
#  60: 2.92022505745295,
#  50: 3.1469116595210593,
#  40: 3.406648158765616,
#  30: 3.66064309335217,
#  20: 3.954873212106176,
#  10: 4.509391655605442,
#  5: 4.909276574950523,
#  1: 6.010770429922193}

# %%
max_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['max_flops_per_dollar'], n=1000))
max_flops_per_dollar_p
# Out:
# {1: 24.0,
#  5: 24.0,
#  10: 24.0,
#  20: 24.0,
#  30: 24.0,
#  40: 24.0,
#  50: 24.0,
#  60: 24.0,
#  70: 24.0,
#  80: 24.0,
#  90: 24.0,
#  95: 24.0,
#  99: 24.0}

# %%
initial_pay_p = sq.get_percentiles(sq.sample(variables['initial_pay'], n=1000))
initial_pay_p
# Out:
# {1: 7.1,
#  5: 7.1,
#  10: 7.1,
#  20: 7.1,
#  30: 7.1,
#  40: 7.1,
#  50: 7.1,
#  60: 7.1,
#  70: 7.1,
#  80: 7.1,
#  90: 8.024861725852782,
#  95: 8.366195811508236,
#  99: 9.06788909445532}

# %%
gdp_growth_p = sq.get_percentiles(sq.sample(variables['gdp_growth'], n=1000))
gdp_growth_p
# Out:
# {1: 1.0106045177201843,
#  5: 1.0153235983857318,
#  10: 1.0170887687876977,
#  20: 1.0198522864246793,
#  30: 1.0217058622229203,
#  40: 1.0236195686762244,
#  50: 1.0249790080016608,
#  60: 1.0265349340064371,
#  70: 1.0281037012840917,
#  80: 1.0300256944358697,
#  90: 1.033262559949535,
#  95: 1.0350185618436554,
#  99: 1.0393781593423508}

# %%
max_gdp_frac_p = sq.get_percentiles(sq.sample(variables['max_gdp_frac'], n=1000))
max_gdp_frac_p
# Out:
# {1: 3.4753577957957215e-06,
#  5: 1.9465709441180994e-05,
#  10: 0.0004300925910888125,
#  20: 0.000540546848363479,
#  30: 0.000605580564763549,
#  40: 0.0006598675985490062,
#  50: 0.000735973501192771,
#  60: 0.0008045162107753118,
#  70: 0.0009312882676594987,
#  80: 0.0015777152433662856,
#  90: 0.003071893956106004,
#  95: 0.005258119407521895,
#  99: 0.011837672593549788}

# %%
willingness_ramp = variables.get('willingness_ramp', 0)
if willingness_ramp != 0:
    willingness_ramp_p = sq.get_percentiles(sq.sample(willingness_ramp), n=1000)
    pprint(willingness_ramp_p)
else:
    print(0)
# Out:
# 0

# %%
spend_doubling_time_p = sq.get_percentiles(sq.sample(variables['spend_doubling_time'], n=1000), reverse=True)
spend_doubling_time_p
# Out:
# {99: 1.0015034463171575,
#  95: 1.2677560809450419,
#  90: 1.5368552232273194,
#  80: 3.0375723199724156,
#  70: 3.5076239784747116,
#  60: 3.804099562551874,
#  50: 4.040084551101762,
#  40: 4.302102762623102,
#  30: 4.607555345261555,
#  20: 4.947008290855615,
#  10: 5.394828897977846,
#  5: 5.828892183627507,
#  1: 6.381252795067913}

# %%
nonscaling_delay = variables.get('nonscaling_delay', 0)
if nonscaling_delay != 0:
    nonscaling_delay_p = sq.get_percentiles(np.ceil(sq.sample(nonscaling_delay, n=1000)), reverse=True)
    pprint(nonscaling_delay_p)
else:
    print(0)
# Out:
# {1: 46.00999999999999,
#  5: 27.049999999999955,
#  10: 19.0,
#  20: 12.200000000000045,
#  30: 9.0,
#  40: 7.0,
#  50: 6.0,
#  60: 5.0,
#  70: 5.0,
#  80: 4.0,
#  90: 3.0,
#  95: 3.0,
#  99: 2.0}

# %%
willingness_spend_horizon = variables.get('willingness_spend_horizon', 1)
if willingness_spend_horizon != 1:
    willingness_spend_horizon_p = sq.get_percentiles(sq.sample(willingness_spend_horizon, n=1000))
    pprint(willingness_spend_horizon_p)
else:
    print(1)
# Out:
# 1

# %% [markdown]
# ## GDP Over Time

# %%
gdp_ = np.array([gdp(initial_gdp=variables['initial_gdp'],
                     gdp_growth=gdp_growth_p[GRAPH_P],
                     year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(gdp_))
plt.ylabel('log GDP')
# Out:
# Text(0, 0.5, 'log GDP')

# %%
for y in years:
    print('Year: {} - GDP log 2022$USD {} (~{})'.format(y,
                                                        np.round(np.log10(gdp_[y - CURRENT_YEAR]), 1),
                                                        numerize(gdp_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - GDP log 2022$USD 13.4 (~23 trillion)
# Year: 2024 - GDP log 2022$USD 13.4 (~24 trillion)
# Year: 2025 - GDP log 2022$USD 13.4 (~24 trillion)
# Year: 2026 - GDP log 2022$USD 13.4 (~25 trillion)
# Year: 2027 - GDP log 2022$USD 13.4 (~25 trillion)
# Year: 2028 - GDP log 2022$USD 13.4 (~26 trillion)
# Year: 2029 - GDP log 2022$USD 13.4 (~27 trillion)
# Year: 2030 - GDP log 2022$USD 13.4 (~27 trillion)
# Year: 2031 - GDP log 2022$USD 13.4 (~28 trillion)
# Year: 2032 - GDP log 2022$USD 13.5 (~29 trillion)
# Year: 2033 - GDP log 2022$USD 13.5 (~29 trillion)
# Year: 2034 - GDP log 2022$USD 13.5 (~30 trillion)
# Year: 2035 - GDP log 2022$USD 13.5 (~31 trillion)
# Year: 2036 - GDP log 2022$USD 13.5 (~32 trillion)
# Year: 2037 - GDP log 2022$USD 13.5 (~32 trillion)
# Year: 2038 - GDP log 2022$USD 13.5 (~33 trillion)
# Year: 2039 - GDP log 2022$USD 13.5 (~34 trillion)
# Year: 2040 - GDP log 2022$USD 13.5 (~35 trillion)
# Year: 2041 - GDP log 2022$USD 13.6 (~36 trillion)
# Year: 2042 - GDP log 2022$USD 13.6 (~37 trillion)
# Year: 2043 - GDP log 2022$USD 13.6 (~38 trillion)
# Year: 2044 - GDP log 2022$USD 13.6 (~39 trillion)
# Year: 2045 - GDP log 2022$USD 13.6 (~40 trillion)
# Year: 2046 - GDP log 2022$USD 13.6 (~41 trillion)
# Year: 2047 - GDP log 2022$USD 13.6 (~42 trillion)
# Year: 2048 - GDP log 2022$USD 13.6 (~43 trillion)
# Year: 2049 - GDP log 2022$USD 13.6 (~44 trillion)
# Year: 2050 - GDP log 2022$USD 13.7 (~45 trillion)
# Year: 2051 - GDP log 2022$USD 13.7 (~46 trillion)
# Year: 2052 - GDP log 2022$USD 13.7 (~47 trillion)
# Year: 2053 - GDP log 2022$USD 13.7 (~48 trillion)
# Year: 2054 - GDP log 2022$USD 13.7 (~49 trillion)
# Year: 2055 - GDP log 2022$USD 13.7 (~51 trillion)
# Year: 2056 - GDP log 2022$USD 13.7 (~52 trillion)
# Year: 2057 - GDP log 2022$USD 13.7 (~53 trillion)
# Year: 2058 - GDP log 2022$USD 13.7 (~55 trillion)
# Year: 2059 - GDP log 2022$USD 13.7 (~56 trillion)
# Year: 2060 - GDP log 2022$USD 13.8 (~57 trillion)
# Year: 2061 - GDP log 2022$USD 13.8 (~59 trillion)
# Year: 2062 - GDP log 2022$USD 13.8 (~60 trillion)
# Year: 2063 - GDP log 2022$USD 13.8 (~62 trillion)
# Year: 2064 - GDP log 2022$USD 13.8 (~63 trillion)
# Year: 2065 - GDP log 2022$USD 13.8 (~65 trillion)
# Year: 2066 - GDP log 2022$USD 13.8 (~66 trillion)
# Year: 2067 - GDP log 2022$USD 13.8 (~68 trillion)
# Year: 2068 - GDP log 2022$USD 13.8 (~70 trillion)
# Year: 2069 - GDP log 2022$USD 13.9 (~72 trillion)
# Year: 2070 - GDP log 2022$USD 13.9 (~73 trillion)
# Year: 2071 - GDP log 2022$USD 13.9 (~75 trillion)
# Year: 2072 - GDP log 2022$USD 13.9 (~77 trillion)
# Year: 2073 - GDP log 2022$USD 13.9 (~79 trillion)
# Year: 2074 - GDP log 2022$USD 13.9 (~81 trillion)
# Year: 2075 - GDP log 2022$USD 13.9 (~83 trillion)
# Year: 2076 - GDP log 2022$USD 13.9 (~85 trillion)
# Year: 2077 - GDP log 2022$USD 13.9 (~87 trillion)
# Year: 2078 - GDP log 2022$USD 14.0 (~89 trillion)
# Year: 2079 - GDP log 2022$USD 14.0 (~92 trillion)
# Year: 2080 - GDP log 2022$USD 14.0 (~94 trillion)
# Year: 2081 - GDP log 2022$USD 14.0 (~96 trillion)
# Year: 2082 - GDP log 2022$USD 14.0 (~99 trillion)
# Year: 2083 - GDP log 2022$USD 14.0 (~101 trillion)
# Year: 2084 - GDP log 2022$USD 14.0 (~104 trillion)
# Year: 2085 - GDP log 2022$USD 14.0 (~106 trillion)
# Year: 2086 - GDP log 2022$USD 14.0 (~109 trillion)
# Year: 2087 - GDP log 2022$USD 14.0 (~112 trillion)
# Year: 2088 - GDP log 2022$USD 14.1 (~114 trillion)
# Year: 2089 - GDP log 2022$USD 14.1 (~117 trillion)
# Year: 2090 - GDP log 2022$USD 14.1 (~120 trillion)
# Year: 2091 - GDP log 2022$USD 14.1 (~123 trillion)
# Year: 2092 - GDP log 2022$USD 14.1 (~126 trillion)
# Year: 2093 - GDP log 2022$USD 14.1 (~129 trillion)
# Year: 2094 - GDP log 2022$USD 14.1 (~133 trillion)
# Year: 2095 - GDP log 2022$USD 14.1 (~136 trillion)
# Year: 2096 - GDP log 2022$USD 14.1 (~139 trillion)
# Year: 2097 - GDP log 2022$USD 14.2 (~143 trillion)
# Year: 2098 - GDP log 2022$USD 14.2 (~146 trillion)
# Year: 2099 - GDP log 2022$USD 14.2 (~150 trillion)
# Year: 2100 - GDP log 2022$USD 14.2 (~154 trillion)
# Year: 2101 - GDP log 2022$USD 14.2 (~158 trillion)
# Year: 2102 - GDP log 2022$USD 14.2 (~162 trillion)
# Year: 2103 - GDP log 2022$USD 14.2 (~166 trillion)
# Year: 2104 - GDP log 2022$USD 14.2 (~170 trillion)
# Year: 2105 - GDP log 2022$USD 14.2 (~174 trillion)
# Year: 2106 - GDP log 2022$USD 14.3 (~178 trillion)
# Year: 2107 - GDP log 2022$USD 14.3 (~183 trillion)
# Year: 2108 - GDP log 2022$USD 14.3 (~187 trillion)
# Year: 2109 - GDP log 2022$USD 14.3 (~192 trillion)
# Year: 2110 - GDP log 2022$USD 14.3 (~197 trillion)
# Year: 2111 - GDP log 2022$USD 14.3 (~202 trillion)
# Year: 2112 - GDP log 2022$USD 14.3 (~207 trillion)
# Year: 2113 - GDP log 2022$USD 14.3 (~212 trillion)
# Year: 2114 - GDP log 2022$USD 14.3 (~217 trillion)
# Year: 2115 - GDP log 2022$USD 14.3 (~223 trillion)
# Year: 2116 - GDP log 2022$USD 14.4 (~228 trillion)
# Year: 2117 - GDP log 2022$USD 14.4 (~234 trillion)
# Year: 2118 - GDP log 2022$USD 14.4 (~240 trillion)
# Year: 2119 - GDP log 2022$USD 14.4 (~246 trillion)
# Year: 2120 - GDP log 2022$USD 14.4 (~252 trillion)
# Year: 2121 - GDP log 2022$USD 14.4 (~258 trillion)
# Year: 2122 - GDP log 2022$USD 14.4 (~265 trillion)

# %% [markdown]
# ## Willingness to Pay Over Time

# %%
for p in [20, 50, 80]:
    print('-')
    print('-')
    print('## {} ##'.format(p))
    willingness = np.array([willingness_to_pay(initial_gdp=variables['initial_gdp'],
                                               gdp_growth=gdp_growth_p[p],
                                               initial_pay=10 ** initial_pay_p[p],
                                               spend_doubling_time=spend_doubling_time_p[p],
                                               max_gdp_frac=max_gdp_frac_p[p],
                                               year=(y - CURRENT_YEAR)) for y in years])
    for y in years:
        print('Year: {} - willingness log 2022$USD per year {} (~{})'.format(y,
                                                                             np.round(np.log10(willingness[y - CURRENT_YEAR]), 1),
                                                                             numerize(willingness[y - CURRENT_YEAR])))


    plt.plot(years, np.log10(willingness))
plt.ylabel('log 2022$USD/yr willing to spend on TAI')
plt.show()
# Out:
# -
# -
# ## 20 ##
# Year: 2023 - willingness log 2022$USD per year 7.1 (~13 million)
# Year: 2024 - willingness log 2022$USD per year 7.2 (~14 million)
# Year: 2025 - willingness log 2022$USD per year 7.2 (~17 million)
# Year: 2026 - willingness log 2022$USD per year 7.3 (~19 million)
# Year: 2027 - willingness log 2022$USD per year 7.3 (~22 million)
# Year: 2028 - willingness log 2022$USD per year 7.4 (~25 million)
# Year: 2029 - willingness log 2022$USD per year 7.5 (~29 million)
# Year: 2030 - willingness log 2022$USD per year 7.5 (~33 million)
# Year: 2031 - willingness log 2022$USD per year 7.6 (~39 million)
# Year: 2032 - willingness log 2022$USD per year 7.6 (~44 million)
# Year: 2033 - willingness log 2022$USD per year 7.7 (~51 million)
# Year: 2034 - willingness log 2022$USD per year 7.8 (~59 million)
# Year: 2035 - willingness log 2022$USD per year 7.8 (~67 million)
# Year: 2036 - willingness log 2022$USD per year 7.9 (~77 million)
# Year: 2037 - willingness log 2022$USD per year 7.9 (~89 million)
# Year: 2038 - willingness log 2022$USD per year 8.0 (~102 million)
# Year: 2039 - willingness log 2022$USD per year 8.1 (~118 million)
# Year: 2040 - willingness log 2022$USD per year 8.1 (~135 million)
# Year: 2041 - willingness log 2022$USD per year 8.2 (~155 million)
# Year: 2042 - willingness log 2022$USD per year 8.3 (~179 million)
# Year: 2043 - willingness log 2022$USD per year 8.3 (~205 million)
# Year: 2044 - willingness log 2022$USD per year 8.4 (~236 million)
# Year: 2045 - willingness log 2022$USD per year 8.4 (~271 million)
# Year: 2046 - willingness log 2022$USD per year 8.5 (~311 million)
# Year: 2047 - willingness log 2022$USD per year 8.6 (~357 million)
# Year: 2048 - willingness log 2022$USD per year 8.6 (~410 million)
# Year: 2049 - willingness log 2022$USD per year 8.7 (~470 million)
# Year: 2050 - willingness log 2022$USD per year 8.7 (~539 million)
# Year: 2051 - willingness log 2022$USD per year 8.8 (~618 million)
# Year: 2052 - willingness log 2022$USD per year 8.9 (~709 million)
# Year: 2053 - willingness log 2022$USD per year 8.9 (~812 million)
# Year: 2054 - willingness log 2022$USD per year 9.0 (~930 million)
# Year: 2055 - willingness log 2022$USD per year 9.0 (~1 billion)
# Year: 2056 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2057 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2058 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2059 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2060 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2061 - willingness log 2022$USD per year 9.4 (~2 billion)
# Year: 2062 - willingness log 2022$USD per year 9.4 (~3 billion)
# Year: 2063 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2064 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2065 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2066 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2067 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2068 - willingness log 2022$USD per year 9.7 (~6 billion)
# Year: 2069 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2070 - willingness log 2022$USD per year 9.8 (~7 billion)
# Year: 2071 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2072 - willingness log 2022$USD per year 9.9 (~9 billion)
# Year: 2073 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2074 - willingness log 2022$USD per year 10.0 (~11 billion)
# Year: 2075 - willingness log 2022$USD per year 10.1 (~12 billion)
# Year: 2076 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2077 - willingness log 2022$USD per year 10.2 (~15 billion)
# Year: 2078 - willingness log 2022$USD per year 10.2 (~16 billion)
# Year: 2079 - willingness log 2022$USD per year 10.2 (~17 billion)
# Year: 2080 - willingness log 2022$USD per year 10.3 (~19 billion)
# Year: 2081 - willingness log 2022$USD per year 10.3 (~20 billion)
# Year: 2082 - willingness log 2022$USD per year 10.3 (~22 billion)
# Year: 2083 - willingness log 2022$USD per year 10.4 (~24 billion)
# Year: 2084 - willingness log 2022$USD per year 10.4 (~25 billion)
# Year: 2085 - willingness log 2022$USD per year 10.4 (~27 billion)
# Year: 2086 - willingness log 2022$USD per year 10.5 (~29 billion)
# Year: 2087 - willingness log 2022$USD per year 10.5 (~30 billion)
# Year: 2088 - willingness log 2022$USD per year 10.5 (~32 billion)
# Year: 2089 - willingness log 2022$USD per year 10.5 (~34 billion)
# Year: 2090 - willingness log 2022$USD per year 10.5 (~35 billion)
# Year: 2091 - willingness log 2022$USD per year 10.6 (~37 billion)
# Year: 2092 - willingness log 2022$USD per year 10.6 (~39 billion)
# Year: 2093 - willingness log 2022$USD per year 10.6 (~41 billion)
# Year: 2094 - willingness log 2022$USD per year 10.6 (~42 billion)
# Year: 2095 - willingness log 2022$USD per year 10.6 (~44 billion)
# Year: 2096 - willingness log 2022$USD per year 10.7 (~45 billion)
# Year: 2097 - willingness log 2022$USD per year 10.7 (~47 billion)
# Year: 2098 - willingness log 2022$USD per year 10.7 (~49 billion)
# Year: 2099 - willingness log 2022$USD per year 10.7 (~50 billion)
# Year: 2100 - willingness log 2022$USD per year 10.7 (~52 billion)
# Year: 2101 - willingness log 2022$USD per year 10.7 (~53 billion)
# Year: 2102 - willingness log 2022$USD per year 10.7 (~55 billion)
# Year: 2103 - willingness log 2022$USD per year 10.8 (~56 billion)
# Year: 2104 - willingness log 2022$USD per year 10.8 (~58 billion)
# Year: 2105 - willingness log 2022$USD per year 10.8 (~59 billion)
# Year: 2106 - willingness log 2022$USD per year 10.8 (~61 billion)
# Year: 2107 - willingness log 2022$USD per year 10.8 (~62 billion)
# Year: 2108 - willingness log 2022$USD per year 10.8 (~64 billion)
# Year: 2109 - willingness log 2022$USD per year 10.8 (~65 billion)
# Year: 2110 - willingness log 2022$USD per year 10.8 (~67 billion)
# Year: 2111 - willingness log 2022$USD per year 10.8 (~68 billion)
# Year: 2112 - willingness log 2022$USD per year 10.8 (~70 billion)
# Year: 2113 - willingness log 2022$USD per year 10.9 (~72 billion)
# Year: 2114 - willingness log 2022$USD per year 10.9 (~73 billion)
# Year: 2115 - willingness log 2022$USD per year 10.9 (~75 billion)
# Year: 2116 - willingness log 2022$USD per year 10.9 (~76 billion)
# Year: 2117 - willingness log 2022$USD per year 10.9 (~78 billion)
# Year: 2118 - willingness log 2022$USD per year 10.9 (~80 billion)
# Year: 2119 - willingness log 2022$USD per year 10.9 (~81 billion)
# Year: 2120 - willingness log 2022$USD per year 10.9 (~83 billion)
# Year: 2121 - willingness log 2022$USD per year 10.9 (~85 billion)
# Year: 2122 - willingness log 2022$USD per year 10.9 (~86 billion)
# -
# -
# ## 50 ##
# Year: 2023 - willingness log 2022$USD per year 7.1 (~13 million)
# Year: 2024 - willingness log 2022$USD per year 7.2 (~15 million)
# Year: 2025 - willingness log 2022$USD per year 7.2 (~18 million)
# Year: 2026 - willingness log 2022$USD per year 7.3 (~21 million)
# Year: 2027 - willingness log 2022$USD per year 7.4 (~25 million)
# Year: 2028 - willingness log 2022$USD per year 7.5 (~30 million)
# Year: 2029 - willingness log 2022$USD per year 7.5 (~35 million)
# Year: 2030 - willingness log 2022$USD per year 7.6 (~42 million)
# Year: 2031 - willingness log 2022$USD per year 7.7 (~50 million)
# Year: 2032 - willingness log 2022$USD per year 7.8 (~59 million)
# Year: 2033 - willingness log 2022$USD per year 7.8 (~70 million)
# Year: 2034 - willingness log 2022$USD per year 7.9 (~83 million)
# Year: 2035 - willingness log 2022$USD per year 8.0 (~98 million)
# Year: 2036 - willingness log 2022$USD per year 8.1 (~117 million)
# Year: 2037 - willingness log 2022$USD per year 8.1 (~138 million)
# Year: 2038 - willingness log 2022$USD per year 8.2 (~164 million)
# Year: 2039 - willingness log 2022$USD per year 8.3 (~194 million)
# Year: 2040 - willingness log 2022$USD per year 8.4 (~231 million)
# Year: 2041 - willingness log 2022$USD per year 8.4 (~273 million)
# Year: 2042 - willingness log 2022$USD per year 8.5 (~324 million)
# Year: 2043 - willingness log 2022$USD per year 8.6 (~384 million)
# Year: 2044 - willingness log 2022$USD per year 8.7 (~455 million)
# Year: 2045 - willingness log 2022$USD per year 8.7 (~538 million)
# Year: 2046 - willingness log 2022$USD per year 8.8 (~637 million)
# Year: 2047 - willingness log 2022$USD per year 8.9 (~754 million)
# Year: 2048 - willingness log 2022$USD per year 9.0 (~892 million)
# Year: 2049 - willingness log 2022$USD per year 9.0 (~1 billion)
# Year: 2050 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2051 - willingness log 2022$USD per year 9.2 (~1 billion)
# Year: 2052 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2053 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2054 - willingness log 2022$USD per year 9.4 (~2 billion)
# Year: 2055 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2056 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2057 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2058 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2059 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2060 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2061 - willingness log 2022$USD per year 9.9 (~7 billion)
# Year: 2062 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2063 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2064 - willingness log 2022$USD per year 10.0 (~11 billion)
# Year: 2065 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2066 - willingness log 2022$USD per year 10.2 (~14 billion)
# Year: 2067 - willingness log 2022$USD per year 10.2 (~16 billion)
# Year: 2068 - willingness log 2022$USD per year 10.3 (~18 billion)
# Year: 2069 - willingness log 2022$USD per year 10.3 (~21 billion)
# Year: 2070 - willingness log 2022$USD per year 10.4 (~23 billion)
# Year: 2071 - willingness log 2022$USD per year 10.4 (~26 billion)
# Year: 2072 - willingness log 2022$USD per year 10.5 (~28 billion)
# Year: 2073 - willingness log 2022$USD per year 10.5 (~31 billion)
# Year: 2074 - willingness log 2022$USD per year 10.5 (~34 billion)
# Year: 2075 - willingness log 2022$USD per year 10.6 (~37 billion)
# Year: 2076 - willingness log 2022$USD per year 10.6 (~40 billion)
# Year: 2077 - willingness log 2022$USD per year 10.6 (~43 billion)
# Year: 2078 - willingness log 2022$USD per year 10.7 (~46 billion)
# Year: 2079 - willingness log 2022$USD per year 10.7 (~50 billion)
# Year: 2080 - willingness log 2022$USD per year 10.7 (~53 billion)
# Year: 2081 - willingness log 2022$USD per year 10.7 (~56 billion)
# Year: 2082 - willingness log 2022$USD per year 10.8 (~59 billion)
# Year: 2083 - willingness log 2022$USD per year 10.8 (~62 billion)
# Year: 2084 - willingness log 2022$USD per year 10.8 (~65 billion)
# Year: 2085 - willingness log 2022$USD per year 10.8 (~68 billion)
# Year: 2086 - willingness log 2022$USD per year 10.9 (~71 billion)
# Year: 2087 - willingness log 2022$USD per year 10.9 (~74 billion)
# Year: 2088 - willingness log 2022$USD per year 10.9 (~77 billion)
# Year: 2089 - willingness log 2022$USD per year 10.9 (~80 billion)
# Year: 2090 - willingness log 2022$USD per year 10.9 (~83 billion)
# Year: 2091 - willingness log 2022$USD per year 10.9 (~85 billion)
# Year: 2092 - willingness log 2022$USD per year 10.9 (~88 billion)
# Year: 2093 - willingness log 2022$USD per year 11.0 (~91 billion)
# Year: 2094 - willingness log 2022$USD per year 11.0 (~94 billion)
# Year: 2095 - willingness log 2022$USD per year 11.0 (~97 billion)
# Year: 2096 - willingness log 2022$USD per year 11.0 (~100 billion)
# Year: 2097 - willingness log 2022$USD per year 11.0 (~102 billion)
# Year: 2098 - willingness log 2022$USD per year 11.0 (~105 billion)
# Year: 2099 - willingness log 2022$USD per year 11.0 (~108 billion)
# Year: 2100 - willingness log 2022$USD per year 11.0 (~111 billion)
# Year: 2101 - willingness log 2022$USD per year 11.1 (~114 billion)
# Year: 2102 - willingness log 2022$USD per year 11.1 (~117 billion)
# Year: 2103 - willingness log 2022$USD per year 11.1 (~121 billion)
# Year: 2104 - willingness log 2022$USD per year 11.1 (~124 billion)
# Year: 2105 - willingness log 2022$USD per year 11.1 (~127 billion)
# Year: 2106 - willingness log 2022$USD per year 11.1 (~130 billion)
# Year: 2107 - willingness log 2022$USD per year 11.1 (~134 billion)
# Year: 2108 - willingness log 2022$USD per year 11.1 (~137 billion)
# Year: 2109 - willingness log 2022$USD per year 11.1 (~141 billion)
# Year: 2110 - willingness log 2022$USD per year 11.2 (~144 billion)
# Year: 2111 - willingness log 2022$USD per year 11.2 (~148 billion)
# Year: 2112 - willingness log 2022$USD per year 11.2 (~152 billion)
# Year: 2113 - willingness log 2022$USD per year 11.2 (~156 billion)
# Year: 2114 - willingness log 2022$USD per year 11.2 (~159 billion)
# Year: 2115 - willingness log 2022$USD per year 11.2 (~164 billion)
# Year: 2116 - willingness log 2022$USD per year 11.2 (~168 billion)
# Year: 2117 - willingness log 2022$USD per year 11.2 (~172 billion)
# Year: 2118 - willingness log 2022$USD per year 11.2 (~176 billion)
# Year: 2119 - willingness log 2022$USD per year 11.3 (~181 billion)
# Year: 2120 - willingness log 2022$USD per year 11.3 (~185 billion)
# Year: 2121 - willingness log 2022$USD per year 11.3 (~190 billion)
# Year: 2122 - willingness log 2022$USD per year 11.3 (~195 billion)
# -
# -
# ## 80 ##
# Year: 2023 - willingness log 2022$USD per year 7.1 (~13 million)
# Year: 2024 - willingness log 2022$USD per year 7.2 (~16 million)
# Year: 2025 - willingness log 2022$USD per year 7.3 (~20 million)
# Year: 2026 - willingness log 2022$USD per year 7.4 (~25 million)
# Year: 2027 - willingness log 2022$USD per year 7.5 (~31 million)
# Year: 2028 - willingness log 2022$USD per year 7.6 (~39 million)
# Year: 2029 - willingness log 2022$USD per year 7.7 (~49 million)
# Year: 2030 - willingness log 2022$USD per year 7.8 (~62 million)
# Year: 2031 - willingness log 2022$USD per year 7.9 (~78 million)
# Year: 2032 - willingness log 2022$USD per year 8.0 (~98 million)
# Year: 2033 - willingness log 2022$USD per year 8.1 (~123 million)
# Year: 2034 - willingness log 2022$USD per year 8.2 (~154 million)
# Year: 2035 - willingness log 2022$USD per year 8.3 (~194 million)
# Year: 2036 - willingness log 2022$USD per year 8.4 (~243 million)
# Year: 2037 - willingness log 2022$USD per year 8.5 (~305 million)
# Year: 2038 - willingness log 2022$USD per year 8.6 (~383 million)
# Year: 2039 - willingness log 2022$USD per year 8.7 (~481 million)
# Year: 2040 - willingness log 2022$USD per year 8.8 (~603 million)
# Year: 2041 - willingness log 2022$USD per year 8.9 (~756 million)
# Year: 2042 - willingness log 2022$USD per year 9.0 (~947 million)
# Year: 2043 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2044 - willingness log 2022$USD per year 9.2 (~1 billion)
# Year: 2045 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2046 - willingness log 2022$USD per year 9.4 (~2 billion)
# Year: 2047 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2048 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2049 - willingness log 2022$USD per year 9.7 (~4 billion)
# Year: 2050 - willingness log 2022$USD per year 9.7 (~6 billion)
# Year: 2051 - willingness log 2022$USD per year 9.8 (~7 billion)
# Year: 2052 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2053 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2054 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2055 - willingness log 2022$USD per year 10.2 (~16 billion)
# Year: 2056 - willingness log 2022$USD per year 10.3 (~19 billion)
# Year: 2057 - willingness log 2022$USD per year 10.4 (~23 billion)
# Year: 2058 - willingness log 2022$USD per year 10.4 (~27 billion)
# Year: 2059 - willingness log 2022$USD per year 10.5 (~32 billion)
# Year: 2060 - willingness log 2022$USD per year 10.6 (~38 billion)
# Year: 2061 - willingness log 2022$USD per year 10.6 (~44 billion)
# Year: 2062 - willingness log 2022$USD per year 10.7 (~51 billion)
# Year: 2063 - willingness log 2022$USD per year 10.8 (~59 billion)
# Year: 2064 - willingness log 2022$USD per year 10.8 (~66 billion)
# Year: 2065 - willingness log 2022$USD per year 10.9 (~75 billion)
# Year: 2066 - willingness log 2022$USD per year 10.9 (~83 billion)
# Year: 2067 - willingness log 2022$USD per year 11.0 (~91 billion)
# Year: 2068 - willingness log 2022$USD per year 11.0 (~100 billion)
# Year: 2069 - willingness log 2022$USD per year 11.0 (~108 billion)
# Year: 2070 - willingness log 2022$USD per year 11.1 (~116 billion)
# Year: 2071 - willingness log 2022$USD per year 11.1 (~124 billion)
# Year: 2072 - willingness log 2022$USD per year 11.1 (~132 billion)
# Year: 2073 - willingness log 2022$USD per year 11.1 (~140 billion)
# Year: 2074 - willingness log 2022$USD per year 11.2 (~147 billion)
# Year: 2075 - willingness log 2022$USD per year 11.2 (~154 billion)
# Year: 2076 - willingness log 2022$USD per year 11.2 (~162 billion)
# Year: 2077 - willingness log 2022$USD per year 11.2 (~169 billion)
# Year: 2078 - willingness log 2022$USD per year 11.2 (~176 billion)
# Year: 2079 - willingness log 2022$USD per year 11.3 (~182 billion)
# Year: 2080 - willingness log 2022$USD per year 11.3 (~189 billion)
# Year: 2081 - willingness log 2022$USD per year 11.3 (~196 billion)
# Year: 2082 - willingness log 2022$USD per year 11.3 (~203 billion)
# Year: 2083 - willingness log 2022$USD per year 11.3 (~210 billion)
# Year: 2084 - willingness log 2022$USD per year 11.3 (~217 billion)
# Year: 2085 - willingness log 2022$USD per year 11.4 (~224 billion)
# Year: 2086 - willingness log 2022$USD per year 11.4 (~232 billion)
# Year: 2087 - willingness log 2022$USD per year 11.4 (~239 billion)
# Year: 2088 - willingness log 2022$USD per year 11.4 (~246 billion)
# Year: 2089 - willingness log 2022$USD per year 11.4 (~254 billion)
# Year: 2090 - willingness log 2022$USD per year 11.4 (~262 billion)
# Year: 2091 - willingness log 2022$USD per year 11.4 (~270 billion)
# Year: 2092 - willingness log 2022$USD per year 11.4 (~279 billion)
# Year: 2093 - willingness log 2022$USD per year 11.5 (~287 billion)
# Year: 2094 - willingness log 2022$USD per year 11.5 (~296 billion)
# Year: 2095 - willingness log 2022$USD per year 11.5 (~305 billion)
# Year: 2096 - willingness log 2022$USD per year 11.5 (~314 billion)
# Year: 2097 - willingness log 2022$USD per year 11.5 (~324 billion)
# Year: 2098 - willingness log 2022$USD per year 11.5 (~333 billion)
# Year: 2099 - willingness log 2022$USD per year 11.5 (~343 billion)
# Year: 2100 - willingness log 2022$USD per year 11.5 (~354 billion)
# Year: 2101 - willingness log 2022$USD per year 11.6 (~364 billion)
# Year: 2102 - willingness log 2022$USD per year 11.6 (~375 billion)
# Year: 2103 - willingness log 2022$USD per year 11.6 (~387 billion)
# Year: 2104 - willingness log 2022$USD per year 11.6 (~398 billion)
# Year: 2105 - willingness log 2022$USD per year 11.6 (~410 billion)
# Year: 2106 - willingness log 2022$USD per year 11.6 (~423 billion)
# Year: 2107 - willingness log 2022$USD per year 11.6 (~435 billion)
# Year: 2108 - willingness log 2022$USD per year 11.7 (~449 billion)
# Year: 2109 - willingness log 2022$USD per year 11.7 (~462 billion)
# Year: 2110 - willingness log 2022$USD per year 11.7 (~476 billion)
# Year: 2111 - willingness log 2022$USD per year 11.7 (~490 billion)
# Year: 2112 - willingness log 2022$USD per year 11.7 (~505 billion)
# Year: 2113 - willingness log 2022$USD per year 11.7 (~520 billion)
# Year: 2114 - willingness log 2022$USD per year 11.7 (~536 billion)
# Year: 2115 - willingness log 2022$USD per year 11.7 (~552 billion)
# Year: 2116 - willingness log 2022$USD per year 11.8 (~568 billion)
# Year: 2117 - willingness log 2022$USD per year 11.8 (~585 billion)
# Year: 2118 - willingness log 2022$USD per year 11.8 (~603 billion)
# Year: 2119 - willingness log 2022$USD per year 11.8 (~621 billion)
# Year: 2120 - willingness log 2022$USD per year 11.8 (~640 billion)
# Year: 2121 - willingness log 2022$USD per year 11.8 (~659 billion)
# Year: 2122 - willingness log 2022$USD per year 11.8 (~679 billion)

# %% [markdown]
# ## FLOPs Needed to Make TAI (Given Algorithmic Progress)

# %%
flops_ = np.array([flops_needed(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                              algo_doubling_rate_max_p[GRAPH_P],
                                                              initial_flops_p[GRAPH_P]),
                                possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                    max_reduction_p[GRAPH_P],
                                                                                    initial_flops_p[GRAPH_P]),
                                year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_))
plt.ylabel('log FLOPs needed to make TAI')
# Out:
# Text(0, 0.5, 'log FLOPs needed to make TAI')

# %%
for y in years:
    print('Year: {} - log FLOPs needed for TAI {} (~{})'.format(y,
                                                                np.round(np.log10(flops_[y - CURRENT_YEAR]), 1),
                                                                numerize(flops_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log FLOPs needed for TAI 32.5 (~292 nonillion)
# Year: 2024 - log FLOPs needed for TAI 32.3 (~186 nonillion)
# Year: 2025 - log FLOPs needed for TAI 32.1 (~118 nonillion)
# Year: 2026 - log FLOPs needed for TAI 31.9 (~75 nonillion)
# Year: 2027 - log FLOPs needed for TAI 31.7 (~48 nonillion)
# Year: 2028 - log FLOPs needed for TAI 31.5 (~31 nonillion)
# Year: 2029 - log FLOPs needed for TAI 31.3 (~21 nonillion)
# Year: 2030 - log FLOPs needed for TAI 31.1 (~14 nonillion)
# Year: 2031 - log FLOPs needed for TAI 31.0 (~10 nonillion)
# Year: 2032 - log FLOPs needed for TAI 30.9 (~7 nonillion)
# Year: 2033 - log FLOPs needed for TAI 30.8 (~6 nonillion)
# Year: 2034 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2035 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2036 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2037 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2038 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2039 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2040 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2041 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2042 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2043 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2044 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2045 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2046 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2047 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2048 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2049 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2050 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2051 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2052 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2053 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2054 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2055 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2056 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2057 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2058 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2059 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2060 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2061 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2062 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2063 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2064 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2065 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2066 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2067 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2068 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2069 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2070 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2071 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2072 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2073 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2074 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2075 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2076 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2077 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2078 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2079 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2080 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2081 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2082 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2083 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2084 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2085 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2086 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2087 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2088 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2089 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2090 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2091 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2092 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2093 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2094 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2095 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2096 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2097 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2098 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2099 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2100 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2101 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2102 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2103 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2104 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2105 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2106 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2107 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2108 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2109 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2110 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2111 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2112 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2113 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2114 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2115 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2116 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2117 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2118 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2119 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2120 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2121 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2122 - log FLOPs needed for TAI 30.5 (~3 nonillion)

# %% [markdown]
# ## FLOPs per Dollar (Given Declining Costs)

# %%
flops_per_dollar_ = np.array([flops_per_dollar(initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                               max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                               halving_rate=flops_halving_rate_p[GRAPH_P],
                                               year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(flops_per_dollar_))
plt.ylabel('log FLOPs per $1')
# Out:
# Text(0, 0.5, 'log FLOPs per $1')

# %%
for y in years:
    print('Year: {} - log {} FLOPs per $ (~{})'.format(y,
                                                       np.round(np.log10(flops_per_dollar_[y - CURRENT_YEAR]), 1),
                                                       numerize(flops_per_dollar_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log 18.0 FLOPs per $ (~1000 quadrillion)
# Year: 2024 - log 18.1 FLOPs per $ (~1 quintillion)
# Year: 2025 - log 18.2 FLOPs per $ (~2 quintillion)
# Year: 2026 - log 18.3 FLOPs per $ (~2 quintillion)
# Year: 2027 - log 18.4 FLOPs per $ (~2 quintillion)
# Year: 2028 - log 18.5 FLOPs per $ (~3 quintillion)
# Year: 2029 - log 18.6 FLOPs per $ (~4 quintillion)
# Year: 2030 - log 18.7 FLOPs per $ (~5 quintillion)
# Year: 2031 - log 18.8 FLOPs per $ (~6 quintillion)
# Year: 2032 - log 18.9 FLOPs per $ (~7 quintillion)
# Year: 2033 - log 19.0 FLOPs per $ (~9 quintillion)
# Year: 2034 - log 19.1 FLOPs per $ (~11 quintillion)
# Year: 2035 - log 19.1 FLOPs per $ (~14 quintillion)
# Year: 2036 - log 19.2 FLOPs per $ (~18 quintillion)
# Year: 2037 - log 19.3 FLOPs per $ (~22 quintillion)
# Year: 2038 - log 19.4 FLOPs per $ (~27 quintillion)
# Year: 2039 - log 19.5 FLOPs per $ (~34 quintillion)
# Year: 2040 - log 19.6 FLOPs per $ (~42 quintillion)
# Year: 2041 - log 19.7 FLOPs per $ (~53 quintillion)
# Year: 2042 - log 19.8 FLOPs per $ (~66 quintillion)
# Year: 2043 - log 19.9 FLOPs per $ (~82 quintillion)
# Year: 2044 - log 20.0 FLOPs per $ (~102 quintillion)
# Year: 2045 - log 20.1 FLOPs per $ (~127 quintillion)
# Year: 2046 - log 20.2 FLOPs per $ (~159 quintillion)
# Year: 2047 - log 20.3 FLOPs per $ (~198 quintillion)
# Year: 2048 - log 20.4 FLOPs per $ (~246 quintillion)
# Year: 2049 - log 20.5 FLOPs per $ (~307 quintillion)
# Year: 2050 - log 20.6 FLOPs per $ (~382 quintillion)
# Year: 2051 - log 20.7 FLOPs per $ (~477 quintillion)
# Year: 2052 - log 20.8 FLOPs per $ (~594 quintillion)
# Year: 2053 - log 20.9 FLOPs per $ (~740 quintillion)
# Year: 2054 - log 21.0 FLOPs per $ (~923 quintillion)
# Year: 2055 - log 21.1 FLOPs per $ (~1 sextillion)
# Year: 2056 - log 21.2 FLOPs per $ (~1 sextillion)
# Year: 2057 - log 21.3 FLOPs per $ (~2 sextillion)
# Year: 2058 - log 21.3 FLOPs per $ (~2 sextillion)
# Year: 2059 - log 21.4 FLOPs per $ (~3 sextillion)
# Year: 2060 - log 21.5 FLOPs per $ (~3 sextillion)
# Year: 2061 - log 21.6 FLOPs per $ (~4 sextillion)
# Year: 2062 - log 21.7 FLOPs per $ (~5 sextillion)
# Year: 2063 - log 21.8 FLOPs per $ (~7 sextillion)
# Year: 2064 - log 21.9 FLOPs per $ (~8 sextillion)
# Year: 2065 - log 22.0 FLOPs per $ (~10 sextillion)
# Year: 2066 - log 22.1 FLOPs per $ (~13 sextillion)
# Year: 2067 - log 22.2 FLOPs per $ (~16 sextillion)
# Year: 2068 - log 22.3 FLOPs per $ (~20 sextillion)
# Year: 2069 - log 22.4 FLOPs per $ (~25 sextillion)
# Year: 2070 - log 22.5 FLOPs per $ (~30 sextillion)
# Year: 2071 - log 22.6 FLOPs per $ (~38 sextillion)
# Year: 2072 - log 22.7 FLOPs per $ (~46 sextillion)
# Year: 2073 - log 22.8 FLOPs per $ (~57 sextillion)
# Year: 2074 - log 22.8 FLOPs per $ (~70 sextillion)
# Year: 2075 - log 22.9 FLOPs per $ (~86 sextillion)
# Year: 2076 - log 23.0 FLOPs per $ (~105 sextillion)
# Year: 2077 - log 23.1 FLOPs per $ (~128 sextillion)
# Year: 2078 - log 23.2 FLOPs per $ (~154 sextillion)
# Year: 2079 - log 23.3 FLOPs per $ (~185 sextillion)
# Year: 2080 - log 23.3 FLOPs per $ (~221 sextillion)
# Year: 2081 - log 23.4 FLOPs per $ (~261 sextillion)
# Year: 2082 - log 23.5 FLOPs per $ (~306 sextillion)
# Year: 2083 - log 23.5 FLOPs per $ (~354 sextillion)
# Year: 2084 - log 23.6 FLOPs per $ (~406 sextillion)
# Year: 2085 - log 23.7 FLOPs per $ (~460 sextillion)
# Year: 2086 - log 23.7 FLOPs per $ (~515 sextillion)
# Year: 2087 - log 23.8 FLOPs per $ (~570 sextillion)
# Year: 2088 - log 23.8 FLOPs per $ (~623 sextillion)
# Year: 2089 - log 23.8 FLOPs per $ (~673 sextillion)
# Year: 2090 - log 23.9 FLOPs per $ (~720 sextillion)
# Year: 2091 - log 23.9 FLOPs per $ (~762 sextillion)
# Year: 2092 - log 23.9 FLOPs per $ (~799 sextillion)
# Year: 2093 - log 23.9 FLOPs per $ (~832 sextillion)
# Year: 2094 - log 23.9 FLOPs per $ (~861 sextillion)
# Year: 2095 - log 23.9 FLOPs per $ (~885 sextillion)
# Year: 2096 - log 24.0 FLOPs per $ (~906 sextillion)
# Year: 2097 - log 24.0 FLOPs per $ (~923 sextillion)
# Year: 2098 - log 24.0 FLOPs per $ (~937 sextillion)
# Year: 2099 - log 24.0 FLOPs per $ (~949 sextillion)
# Year: 2100 - log 24.0 FLOPs per $ (~959 sextillion)
# Year: 2101 - log 24.0 FLOPs per $ (~967 sextillion)
# Year: 2102 - log 24.0 FLOPs per $ (~973 sextillion)
# Year: 2103 - log 24.0 FLOPs per $ (~978 sextillion)
# Year: 2104 - log 24.0 FLOPs per $ (~982 sextillion)
# Year: 2105 - log 24.0 FLOPs per $ (~986 sextillion)
# Year: 2106 - log 24.0 FLOPs per $ (~989 sextillion)
# Year: 2107 - log 24.0 FLOPs per $ (~991 sextillion)
# Year: 2108 - log 24.0 FLOPs per $ (~993 sextillion)
# Year: 2109 - log 24.0 FLOPs per $ (~994 sextillion)
# Year: 2110 - log 24.0 FLOPs per $ (~995 sextillion)
# Year: 2111 - log 24.0 FLOPs per $ (~996 sextillion)
# Year: 2112 - log 24.0 FLOPs per $ (~997 sextillion)
# Year: 2113 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2114 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2115 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2116 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2117 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2118 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2119 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2120 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2121 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2122 - log 24.0 FLOPs per $ (~1000 sextillion)

# %% [markdown]
# ## Max Possible OOM Reduction in TAI FLOP Size

# %%
# TODO: Update to include efficiency based
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                         max_reduction_p[GRAPH_P], t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('max OOM reduction')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> {} OOM reductions possible'.format(t,
                                                                 round(possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                                  max_reduction_p[GRAPH_P],
                                                                                                  t), 2)))
# Out:
# TAI log FLOP 24 -> 2.0 OOM reductions possible
# TAI log FLOP 25 -> 2.0 OOM reductions possible
# TAI log FLOP 26 -> 2.0 OOM reductions possible
# TAI log FLOP 27 -> 2.0 OOM reductions possible
# TAI log FLOP 28 -> 2.0 OOM reductions possible
# TAI log FLOP 29 -> 2.0 OOM reductions possible
# TAI log FLOP 30 -> 2.0 OOM reductions possible
# TAI log FLOP 31 -> 2.0 OOM reductions possible
# TAI log FLOP 32 -> 2.0 OOM reductions possible
# TAI log FLOP 33 -> 2.0 OOM reductions possible
# TAI log FLOP 34 -> 2.0 OOM reductions possible
# TAI log FLOP 35 -> 3.0 OOM reductions possible
# TAI log FLOP 36 -> 3.0 OOM reductions possible
# TAI log FLOP 37 -> 3.0 OOM reductions possible
# TAI log FLOP 38 -> 4.0 OOM reductions possible
# TAI log FLOP 39 -> 4.0 OOM reductions possible
# TAI log FLOP 40 -> 4.0 OOM reductions possible
# TAI log FLOP 41 -> 4.0 OOM reductions possible
# TAI log FLOP 42 -> 4.0 OOM reductions possible
# TAI log FLOP 43 -> 5.0 OOM reductions possible
# TAI log FLOP 44 -> 5.0 OOM reductions possible
# TAI log FLOP 45 -> 5.0 OOM reductions possible
# TAI log FLOP 46 -> 5.0 OOM reductions possible
# TAI log FLOP 47 -> 5.0 OOM reductions possible
# TAI log FLOP 48 -> 5.0 OOM reductions possible
# TAI log FLOP 49 -> 5.0 OOM reductions possible
# TAI log FLOP 50 -> 5.0 OOM reductions possible
# TAI log FLOP 51 -> 5.0 OOM reductions possible
# TAI log FLOP 52 -> 5.0 OOM reductions possible
# TAI log FLOP 53 -> 5.0 OOM reductions possible
# TAI log FLOP 54 -> 5.0 OOM reductions possible
# TAI log FLOP 55 -> 5.0 OOM reductions possible
# TAI log FLOP 56 -> 5.0 OOM reductions possible
# TAI log FLOP 57 -> 5.0 OOM reductions possible
# TAI log FLOP 58 -> 5.0 OOM reductions possible
# TAI log FLOP 59 -> 5.0 OOM reductions possible

# %% [markdown]
# ## Halving time (years) of compute requirements

# %%
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                              algo_doubling_rate_max_p[GRAPH_P],
                                              t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('number of years for compute requirements to halve')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> algo doubling rate {}yrs'.format(t,
                                                               round(algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                                     algo_doubling_rate_max_p[GRAPH_P],
                                                                                     t), 2)))
# Out:
# TAI log FLOP 24 -> algo doubling rate 2.03yrs
# TAI log FLOP 25 -> algo doubling rate 2.03yrs
# TAI log FLOP 26 -> algo doubling rate 2.03yrs
# TAI log FLOP 27 -> algo doubling rate 2.03yrs
# TAI log FLOP 28 -> algo doubling rate 2.03yrs
# TAI log FLOP 29 -> algo doubling rate 2.03yrs
# TAI log FLOP 30 -> algo doubling rate 2.03yrs
# TAI log FLOP 31 -> algo doubling rate 1.53yrs
# TAI log FLOP 32 -> algo doubling rate 1.49yrs
# TAI log FLOP 33 -> algo doubling rate 1.49yrs
# TAI log FLOP 34 -> algo doubling rate 1.49yrs
# TAI log FLOP 35 -> algo doubling rate 1.49yrs
# TAI log FLOP 36 -> algo doubling rate 1.49yrs
# TAI log FLOP 37 -> algo doubling rate 1.49yrs
# TAI log FLOP 38 -> algo doubling rate 1.49yrs
# TAI log FLOP 39 -> algo doubling rate 1.49yrs
# TAI log FLOP 40 -> algo doubling rate 1.49yrs
# TAI log FLOP 41 -> algo doubling rate 1.49yrs
# TAI log FLOP 42 -> algo doubling rate 1.49yrs
# TAI log FLOP 43 -> algo doubling rate 1.49yrs
# TAI log FLOP 44 -> algo doubling rate 1.49yrs
# TAI log FLOP 45 -> algo doubling rate 1.49yrs
# TAI log FLOP 46 -> algo doubling rate 1.49yrs
# TAI log FLOP 47 -> algo doubling rate 1.49yrs
# TAI log FLOP 48 -> algo doubling rate 1.49yrs
# TAI log FLOP 49 -> algo doubling rate 1.49yrs
# TAI log FLOP 50 -> algo doubling rate 1.49yrs
# TAI log FLOP 51 -> algo doubling rate 1.49yrs
# TAI log FLOP 52 -> algo doubling rate 1.49yrs
# TAI log FLOP 53 -> algo doubling rate 1.49yrs
# TAI log FLOP 54 -> algo doubling rate 1.49yrs
# TAI log FLOP 55 -> algo doubling rate 1.49yrs
# TAI log FLOP 56 -> algo doubling rate 1.49yrs
# TAI log FLOP 57 -> algo doubling rate 1.49yrs
# TAI log FLOP 58 -> algo doubling rate 1.49yrs
# TAI log FLOP 59 -> algo doubling rate 1.49yrs

# %% [markdown]
# ## Dollars Needed to Buy TAI (Given Algorithmic Progress and Decline in Cost per FLOP)

# %%
cost_of_tai_ = np.array([cost_of_tai(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                     possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P], max_reduction_p[GRAPH_P], initial_flops_p[GRAPH_P]),
                                     algo_doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                        algo_doubling_rate_max_p[GRAPH_P],
                                                                        initial_flops_p[GRAPH_P]),
                                     initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                     max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                     flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                     year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(cost_of_tai_))
plt.ylabel('log $ needed to buy TAI')
# Out:
# Text(0, 0.5, 'log $ needed to buy TAI')

# %%
for y in years:
    print('Year: {} - log $ {} to buy TAI (~{})'.format(y,
                                                        np.round(np.log10(cost_of_tai_[y - CURRENT_YEAR]), 1),
                                                        numerize(cost_of_tai_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log $ 14.5 to buy TAI (~292 trillion)
# Year: 2024 - log $ 14.2 to buy TAI (~149 trillion)
# Year: 2025 - log $ 13.9 to buy TAI (~76 trillion)
# Year: 2026 - log $ 13.6 to buy TAI (~39 trillion)
# Year: 2027 - log $ 13.3 to buy TAI (~20 trillion)
# Year: 2028 - log $ 13.0 to buy TAI (~10 trillion)
# Year: 2029 - log $ 12.7 to buy TAI (~6 trillion)
# Year: 2030 - log $ 12.5 to buy TAI (~3 trillion)
# Year: 2031 - log $ 12.2 to buy TAI (~2 trillion)
# Year: 2032 - log $ 12.0 to buy TAI (~1 trillion)
# Year: 2033 - log $ 11.8 to buy TAI (~627 billion)
# Year: 2034 - log $ 11.6 to buy TAI (~412 billion)
# Year: 2035 - log $ 11.5 to buy TAI (~285 billion)
# Year: 2036 - log $ 11.3 to buy TAI (~205 billion)
# Year: 2037 - log $ 11.2 to buy TAI (~153 billion)
# Year: 2038 - log $ 11.1 to buy TAI (~117 billion)
# Year: 2039 - log $ 11.0 to buy TAI (~91 billion)
# Year: 2040 - log $ 10.9 to buy TAI (~72 billion)
# Year: 2041 - log $ 10.8 to buy TAI (~57 billion)
# Year: 2042 - log $ 10.7 to buy TAI (~45 billion)
# Year: 2043 - log $ 10.6 to buy TAI (~36 billion)
# Year: 2044 - log $ 10.5 to buy TAI (~29 billion)
# Year: 2045 - log $ 10.4 to buy TAI (~23 billion)
# Year: 2046 - log $ 10.3 to buy TAI (~18 billion)
# Year: 2047 - log $ 10.2 to buy TAI (~15 billion)
# Year: 2048 - log $ 10.1 to buy TAI (~12 billion)
# Year: 2049 - log $ 10.0 to buy TAI (~10 billion)
# Year: 2050 - log $ 9.9 to buy TAI (~8 billion)
# Year: 2051 - log $ 9.8 to buy TAI (~6 billion)
# Year: 2052 - log $ 9.7 to buy TAI (~5 billion)
# Year: 2053 - log $ 9.6 to buy TAI (~4 billion)
# Year: 2054 - log $ 9.5 to buy TAI (~3 billion)
# Year: 2055 - log $ 9.4 to buy TAI (~3 billion)
# Year: 2056 - log $ 9.3 to buy TAI (~2 billion)
# Year: 2057 - log $ 9.2 to buy TAI (~2 billion)
# Year: 2058 - log $ 9.1 to buy TAI (~1 billion)
# Year: 2059 - log $ 9.0 to buy TAI (~1 billion)
# Year: 2060 - log $ 8.9 to buy TAI (~847 million)
# Year: 2061 - log $ 8.8 to buy TAI (~680 million)
# Year: 2062 - log $ 8.7 to buy TAI (~546 million)
# Year: 2063 - log $ 8.6 to buy TAI (~439 million)
# Year: 2064 - log $ 8.5 to buy TAI (~353 million)
# Year: 2065 - log $ 8.5 to buy TAI (~283 million)
# Year: 2066 - log $ 8.4 to buy TAI (~228 million)
# Year: 2067 - log $ 8.3 to buy TAI (~183 million)
# Year: 2068 - log $ 8.2 to buy TAI (~148 million)
# Year: 2069 - log $ 8.1 to buy TAI (~119 million)
# Year: 2070 - log $ 8.0 to buy TAI (~96 million)
# Year: 2071 - log $ 7.9 to buy TAI (~78 million)
# Year: 2072 - log $ 7.8 to buy TAI (~63 million)
# Year: 2073 - log $ 7.7 to buy TAI (~51 million)
# Year: 2074 - log $ 7.6 to buy TAI (~42 million)
# Year: 2075 - log $ 7.5 to buy TAI (~34 million)
# Year: 2076 - log $ 7.4 to buy TAI (~28 million)
# Year: 2077 - log $ 7.4 to buy TAI (~23 million)
# Year: 2078 - log $ 7.3 to buy TAI (~19 million)
# Year: 2079 - log $ 7.2 to buy TAI (~16 million)
# Year: 2080 - log $ 7.1 to buy TAI (~13 million)
# Year: 2081 - log $ 7.0 to buy TAI (~11 million)
# Year: 2082 - log $ 7.0 to buy TAI (~10 million)
# Year: 2083 - log $ 6.9 to buy TAI (~8 million)
# Year: 2084 - log $ 6.9 to buy TAI (~7 million)
# Year: 2085 - log $ 6.8 to buy TAI (~6 million)
# Year: 2086 - log $ 6.8 to buy TAI (~6 million)
# Year: 2087 - log $ 6.7 to buy TAI (~5 million)
# Year: 2088 - log $ 6.7 to buy TAI (~5 million)
# Year: 2089 - log $ 6.6 to buy TAI (~4 million)
# Year: 2090 - log $ 6.6 to buy TAI (~4 million)
# Year: 2091 - log $ 6.6 to buy TAI (~4 million)
# Year: 2092 - log $ 6.6 to buy TAI (~4 million)
# Year: 2093 - log $ 6.5 to buy TAI (~4 million)
# Year: 2094 - log $ 6.5 to buy TAI (~3 million)
# Year: 2095 - log $ 6.5 to buy TAI (~3 million)
# Year: 2096 - log $ 6.5 to buy TAI (~3 million)
# Year: 2097 - log $ 6.5 to buy TAI (~3 million)
# Year: 2098 - log $ 6.5 to buy TAI (~3 million)
# Year: 2099 - log $ 6.5 to buy TAI (~3 million)
# Year: 2100 - log $ 6.5 to buy TAI (~3 million)
# Year: 2101 - log $ 6.5 to buy TAI (~3 million)
# Year: 2102 - log $ 6.5 to buy TAI (~3 million)
# Year: 2103 - log $ 6.5 to buy TAI (~3 million)
# Year: 2104 - log $ 6.5 to buy TAI (~3 million)
# Year: 2105 - log $ 6.5 to buy TAI (~3 million)
# Year: 2106 - log $ 6.5 to buy TAI (~3 million)
# Year: 2107 - log $ 6.5 to buy TAI (~3 million)
# Year: 2108 - log $ 6.5 to buy TAI (~3 million)
# Year: 2109 - log $ 6.5 to buy TAI (~3 million)
# Year: 2110 - log $ 6.5 to buy TAI (~3 million)
# Year: 2111 - log $ 6.5 to buy TAI (~3 million)
# Year: 2112 - log $ 6.5 to buy TAI (~3 million)
# Year: 2113 - log $ 6.5 to buy TAI (~3 million)
# Year: 2114 - log $ 6.5 to buy TAI (~3 million)
# Year: 2115 - log $ 6.5 to buy TAI (~3 million)
# Year: 2116 - log $ 6.5 to buy TAI (~3 million)
# Year: 2117 - log $ 6.5 to buy TAI (~3 million)
# Year: 2118 - log $ 6.5 to buy TAI (~3 million)
# Year: 2119 - log $ 6.5 to buy TAI (~3 million)
# Year: 2120 - log $ 6.5 to buy TAI (~3 million)
# Year: 2121 - log $ 6.5 to buy TAI (~3 million)
# Year: 2122 - log $ 6.5 to buy TAI (~3 million)

# %% [markdown]
# ## FLOPs at Max Spend

# %%
flops_at_max_ = np.array([flops_at_max(initial_gdp=variables['initial_gdp'],
                                       gdp_growth=gdp_growth_p[GRAPH_P],
                                       initial_pay=10 ** initial_pay_p[GRAPH_P],
                                       spend_doubling_time=spend_doubling_time_p[GRAPH_P],
                                       max_gdp_frac=max_gdp_frac_p[GRAPH_P],
                                       initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                       max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                       flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                       year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_at_max_))
plt.ylabel('max log FLOPs bought given willingness to spend')
# Out:
# Text(0, 0.5, 'max log FLOPs bought given willingness to spend')

# %%
for y in years:
    print('Year: {} - max log FLOPs {} (~{} FLOP, ~{} petaFLOP/s-days)'.format(y,
                                                                               np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]), 1),
                                                                               numerize(flops_at_max_[y - CURRENT_YEAR]),
                                                                               log_flop_to_petaflop_sdays(np.log10(flops_at_max_[y - CURRENT_YEAR]))))
# Out:
# Year: 2023 - max log FLOPs 25.1 (~13 septillion FLOP, ~145601 petaFLOP/s-days)
# Year: 2024 - max log FLOPs 25.3 (~19 septillion FLOP, ~215418 petaFLOP/s-days)
# Year: 2025 - max log FLOPs 25.4 (~28 septillion FLOP, ~318707 petaFLOP/s-days)
# Year: 2026 - max log FLOPs 25.6 (~41 septillion FLOP, ~471512 petaFLOP/s-days)
# Year: 2027 - max log FLOPs 25.8 (~60 septillion FLOP, ~697562 petaFLOP/s-days)
# Year: 2028 - max log FLOPs 26.0 (~89 septillion FLOP, ~1031955 petaFLOP/s-days)
# Year: 2029 - max log FLOPs 26.1 (~132 septillion FLOP, ~1526594 petaFLOP/s-days)
# Year: 2030 - max log FLOPs 26.3 (~195 septillion FLOP, ~2258238 petaFLOP/s-days)
# Year: 2031 - max log FLOPs 26.5 (~289 septillion FLOP, ~3340384 petaFLOP/s-days)
# Year: 2032 - max log FLOPs 26.6 (~427 septillion FLOP, ~4940835 petaFLOP/s-days)
# Year: 2033 - max log FLOPs 26.8 (~631 septillion FLOP, ~7307656 petaFLOP/s-days)
# Year: 2034 - max log FLOPs 27.0 (~934 septillion FLOP, ~10807507 petaFLOP/s-days)
# Year: 2035 - max log FLOPs 27.1 (~1 octillion FLOP, ~15982247 petaFLOP/s-days)
# Year: 2036 - max log FLOPs 27.3 (~2 octillion FLOP, ~23632492 petaFLOP/s-days)
# Year: 2037 - max log FLOPs 27.5 (~3 octillion FLOP, ~34940907 petaFLOP/s-days)
# Year: 2038 - max log FLOPs 27.6 (~4 octillion FLOP, ~51654053 petaFLOP/s-days)
# Year: 2039 - max log FLOPs 27.8 (~7 octillion FLOP, ~76350463 petaFLOP/s-days)
# Year: 2040 - max log FLOPs 28.0 (~10 octillion FLOP, ~112835595 petaFLOP/s-days)
# Year: 2041 - max log FLOPs 28.2 (~14 octillion FLOP, ~166723331 petaFLOP/s-days)
# Year: 2042 - max log FLOPs 28.3 (~21 octillion FLOP, ~246291432 petaFLOP/s-days)
# Year: 2043 - max log FLOPs 28.5 (~31 octillion FLOP, ~363738919 petaFLOP/s-days)
# Year: 2044 - max log FLOPs 28.7 (~46 octillion FLOP, ~537032234 petaFLOP/s-days)
# Year: 2045 - max log FLOPs 28.8 (~68 octillion FLOP, ~792612642 petaFLOP/s-days)
# Year: 2046 - max log FLOPs 29.0 (~101 octillion FLOP, ~1169361116 petaFLOP/s-days)
# Year: 2047 - max log FLOPs 29.2 (~149 octillion FLOP, ~1724395412 petaFLOP/s-days)
# Year: 2048 - max log FLOPs 29.3 (~220 octillion FLOP, ~2541530390 petaFLOP/s-days)
# Year: 2049 - max log FLOPs 29.5 (~323 octillion FLOP, ~3743598850 petaFLOP/s-days)
# Year: 2050 - max log FLOPs 29.7 (~476 octillion FLOP, ~5510350781 petaFLOP/s-days)
# Year: 2051 - max log FLOPs 29.8 (~700 octillion FLOP, ~8104384042 petaFLOP/s-days)
# Year: 2052 - max log FLOPs 30.0 (~1 nonillion FLOP, ~11908590043 petaFLOP/s-days)
# Year: 2053 - max log FLOPs 30.2 (~2 nonillion FLOP, ~17480030348 petaFLOP/s-days)
# Year: 2054 - max log FLOPs 30.3 (~2 nonillion FLOP, ~25627131125 petaFLOP/s-days)
# Year: 2055 - max log FLOPs 30.5 (~3 nonillion FLOP, ~37519763661 petaFLOP/s-days)
# Year: 2056 - max log FLOPs 30.7 (~5 nonillion FLOP, ~54845377942 petaFLOP/s-days)
# Year: 2057 - max log FLOPs 30.8 (~7 nonillion FLOP, ~80029111555 petaFLOP/s-days)
# Year: 2058 - max log FLOPs 31.0 (~10 nonillion FLOP, ~116541965214 petaFLOP/s-days)
# Year: 2059 - max log FLOPs 31.2 (~15 nonillion FLOP, ~169328967954 petaFLOP/s-days)
# Year: 2060 - max log FLOPs 31.3 (~21 nonillion FLOP, ~245398943411 petaFLOP/s-days)
# Year: 2061 - max log FLOPs 31.5 (~31 nonillion FLOP, ~354629102507 petaFLOP/s-days)
# Year: 2062 - max log FLOPs 31.6 (~44 nonillion FLOP, ~510851070574 petaFLOP/s-days)
# Year: 2063 - max log FLOPs 31.8 (~63 nonillion FLOP, ~733299595869 petaFLOP/s-days)
# Year: 2064 - max log FLOPs 32.0 (~91 nonillion FLOP, ~1048520047645 petaFLOP/s-days)
# Year: 2065 - max log FLOPs 32.1 (~129 nonillion FLOP, ~1492844139580 petaFLOP/s-days)
# Year: 2066 - max log FLOPs 32.3 (~183 nonillion FLOP, ~2115552377421 petaFLOP/s-days)
# Year: 2067 - max log FLOPs 32.4 (~258 nonillion FLOP, ~2982842485345 petaFLOP/s-days)
# Year: 2068 - max log FLOPs 32.6 (~361 nonillion FLOP, ~4182709676684 petaFLOP/s-days)
# Year: 2069 - max log FLOPs 32.7 (~504 nonillion FLOP, ~5830808771579 petaFLOP/s-days)
# Year: 2070 - max log FLOPs 32.8 (~698 nonillion FLOP, ~8077298065856 petaFLOP/s-days)
# Year: 2071 - max log FLOPs 33.0 (~960 nonillion FLOP, ~11114544312053 petaFLOP/s-days)
# Year: 2072 - max log FLOPs 33.1 (~1 decillion FLOP, ~15185376007692 petaFLOP/s-days)
# Year: 2073 - max log FLOPs 33.3 (~2 decillion FLOP, ~20591283541613 petaFLOP/s-days)
# Year: 2074 - max log FLOPs 33.4 (~2 decillion FLOP, ~27699556514976 petaFLOP/s-days)
# Year: 2075 - max log FLOPs 33.5 (~3 decillion FLOP, ~36947812275076 petaFLOP/s-days)
# Year: 2076 - max log FLOPs 33.6 (~4 decillion FLOP, ~48843735532784 petaFLOP/s-days)
# Year: 2077 - max log FLOPs 33.7 (~6 decillion FLOP, ~63957221822473 petaFLOP/s-days)
# Year: 2078 - max log FLOPs 33.9 (~7 decillion FLOP, ~82901719130146 petaFLOP/s-days)
# Year: 2079 - max log FLOPs 34.0 (~9 decillion FLOP, ~106301755975181 petaFLOP/s-days)
# Year: 2080 - max log FLOPs 34.1 (~12 decillion FLOP, ~134744901027454 petaFLOP/s-days)
# Year: 2081 - max log FLOPs 34.2 (~15 decillion FLOP, ~168719140751423 petaFLOP/s-days)
# Year: 2082 - max log FLOPs 34.3 (~18 decillion FLOP, ~208540950326248 petaFLOP/s-days)
# Year: 2083 - max log FLOPs 34.3 (~22 decillion FLOP, ~254284475921495 petaFLOP/s-days)
# Year: 2084 - max log FLOPs 34.4 (~26 decillion FLOP, ~305726558233844 petaFLOP/s-days)
# Year: 2085 - max log FLOPs 34.5 (~31 decillion FLOP, ~362323437627024 petaFLOP/s-days)
# Year: 2086 - max log FLOPs 34.6 (~37 decillion FLOP, ~423230910473355 petaFLOP/s-days)
# Year: 2087 - max log FLOPs 34.6 (~42 decillion FLOP, ~487370356441696 petaFLOP/s-days)
# Year: 2088 - max log FLOPs 34.7 (~48 decillion FLOP, ~553531080117810 petaFLOP/s-days)
# Year: 2089 - max log FLOPs 34.7 (~54 decillion FLOP, ~620489415405134 petaFLOP/s-days)
# Year: 2090 - max log FLOPs 34.8 (~59 decillion FLOP, ~687121212402789 petaFLOP/s-days)
# Year: 2091 - max log FLOPs 34.8 (~65 decillion FLOP, ~752488005296296 petaFLOP/s-days)
# Year: 2092 - max log FLOPs 34.8 (~70 decillion FLOP, ~815886192840222 petaFLOP/s-days)
# Year: 2093 - max log FLOPs 34.9 (~76 decillion FLOP, ~876858828395800 petaFLOP/s-days)
# Year: 2094 - max log FLOPs 34.9 (~81 decillion FLOP, ~935177420087106 petaFLOP/s-days)
# Year: 2095 - max log FLOPs 34.9 (~86 decillion FLOP, ~990804785164422 petaFLOP/s-days)
# Year: 2096 - max log FLOPs 35.0 (~90 decillion FLOP, ~1043849846058589 petaFLOP/s-days)
# Year: 2097 - max log FLOPs 35.0 (~95 decillion FLOP, ~1094522784824242 petaFLOP/s-days)
# Year: 2098 - max log FLOPs 35.0 (~99 decillion FLOP, ~1143095766836686 petaFLOP/s-days)
# Year: 2099 - max log FLOPs 35.0 (~103 decillion FLOP, ~1189871584221703 petaFLOP/s-days)
# Year: 2100 - max log FLOPs 35.0 (~107 decillion FLOP, ~1235160529435076 petaFLOP/s-days)
# Year: 2101 - max log FLOPs 35.0 (~111 decillion FLOP, ~1279264624111670 petaFLOP/s-days)
# Year: 2102 - max log FLOPs 35.1 (~114 decillion FLOP, ~1322467814015448 petaFLOP/s-days)
# Year: 2103 - max log FLOPs 35.1 (~118 decillion FLOP, ~1365030661667033 petaFLOP/s-days)
# Year: 2104 - max log FLOPs 35.1 (~122 decillion FLOP, ~1407188222390355 petaFLOP/s-days)
# Year: 2105 - max log FLOPs 35.1 (~125 decillion FLOP, ~1449150037098447 petaFLOP/s-days)
# Year: 2106 - max log FLOPs 35.1 (~129 decillion FLOP, ~1491101433446849 petaFLOP/s-days)
# Year: 2107 - max log FLOPs 35.1 (~132 decillion FLOP, ~1533205555272013 petaFLOP/s-days)
# Year: 2108 - max log FLOPs 35.1 (~136 decillion FLOP, ~1575605723959448 petaFLOP/s-days)
# Year: 2109 - max log FLOPs 35.1 (~140 decillion FLOP, ~1618427874210088 petaFLOP/s-days)
# Year: 2110 - max log FLOPs 35.2 (~144 decillion FLOP, ~1661782906663048 petaFLOP/s-days)
# Year: 2111 - max log FLOPs 35.2 (~147 decillion FLOP, ~1705768868983956 petaFLOP/s-days)
# Year: 2112 - max log FLOPs 35.2 (~151 decillion FLOP, ~1750472923047902 petaFLOP/s-days)
# Year: 2113 - max log FLOPs 35.2 (~155 decillion FLOP, ~1795973085225766 petaFLOP/s-days)
# Year: 2114 - max log FLOPs 35.2 (~159 decillion FLOP, ~1842339744599834 petaFLOP/s-days)
# Year: 2115 - max log FLOPs 35.2 (~163 decillion FLOP, ~1889636973956607 petaFLOP/s-days)
# Year: 2116 - max log FLOPs 35.2 (~167 decillion FLOP, ~1937923653339776 petaFLOP/s-days)
# Year: 2117 - max log FLOPs 35.2 (~172 decillion FLOP, ~1987254427671480 petaFLOP/s-days)
# Year: 2118 - max log FLOPs 35.2 (~176 decillion FLOP, ~2037680519740866 petaFLOP/s-days)
# Year: 2119 - max log FLOPs 35.3 (~181 decillion FLOP, ~2089250418563181 petaFLOP/s-days)
# Year: 2120 - max log FLOPs 35.3 (~185 decillion FLOP, ~2142010461268918 petaFLOP/s-days)
# Year: 2121 - max log FLOPs 35.3 (~190 decillion FLOP, ~2196005324638036 petaFLOP/s-days)
# Year: 2122 - max log FLOPs 35.3 (~195 decillion FLOP, ~2251278440345482 petaFLOP/s-days)

# %% [markdown]
# ## Parameters at Max Spend

# %%
for y in years:
    print('Year: {} - max log parameters {} (~{} parameters)'.format(y,
                                                                     np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12, 1),
                                                                     numerize(10 ** (np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12))))
# Out:
# Year: 2023 - max log parameters 13.1 (~13 trillion parameters)
# Year: 2024 - max log parameters 13.3 (~19 trillion parameters)
# Year: 2025 - max log parameters 13.4 (~28 trillion parameters)
# Year: 2026 - max log parameters 13.6 (~41 trillion parameters)
# Year: 2027 - max log parameters 13.8 (~60 trillion parameters)
# Year: 2028 - max log parameters 14.0 (~89 trillion parameters)
# Year: 2029 - max log parameters 14.1 (~132 trillion parameters)
# Year: 2030 - max log parameters 14.3 (~195 trillion parameters)
# Year: 2031 - max log parameters 14.5 (~289 trillion parameters)
# Year: 2032 - max log parameters 14.6 (~427 trillion parameters)
# Year: 2033 - max log parameters 14.8 (~631 trillion parameters)
# Year: 2034 - max log parameters 15.0 (~934 trillion parameters)
# Year: 2035 - max log parameters 15.1 (~1 quadrillion parameters)
# Year: 2036 - max log parameters 15.3 (~2 quadrillion parameters)
# Year: 2037 - max log parameters 15.5 (~3 quadrillion parameters)
# Year: 2038 - max log parameters 15.6 (~4 quadrillion parameters)
# Year: 2039 - max log parameters 15.8 (~7 quadrillion parameters)
# Year: 2040 - max log parameters 16.0 (~10 quadrillion parameters)
# Year: 2041 - max log parameters 16.2 (~14 quadrillion parameters)
# Year: 2042 - max log parameters 16.3 (~21 quadrillion parameters)
# Year: 2043 - max log parameters 16.5 (~31 quadrillion parameters)
# Year: 2044 - max log parameters 16.7 (~46 quadrillion parameters)
# Year: 2045 - max log parameters 16.8 (~68 quadrillion parameters)
# Year: 2046 - max log parameters 17.0 (~101 quadrillion parameters)
# Year: 2047 - max log parameters 17.2 (~149 quadrillion parameters)
# Year: 2048 - max log parameters 17.3 (~220 quadrillion parameters)
# Year: 2049 - max log parameters 17.5 (~323 quadrillion parameters)
# Year: 2050 - max log parameters 17.7 (~476 quadrillion parameters)
# Year: 2051 - max log parameters 17.8 (~700 quadrillion parameters)
# Year: 2052 - max log parameters 18.0 (~1 quintillion parameters)
# Year: 2053 - max log parameters 18.2 (~2 quintillion parameters)
# Year: 2054 - max log parameters 18.3 (~2 quintillion parameters)
# Year: 2055 - max log parameters 18.5 (~3 quintillion parameters)
# Year: 2056 - max log parameters 18.7 (~5 quintillion parameters)
# Year: 2057 - max log parameters 18.8 (~7 quintillion parameters)
# Year: 2058 - max log parameters 19.0 (~10 quintillion parameters)
# Year: 2059 - max log parameters 19.2 (~15 quintillion parameters)
# Year: 2060 - max log parameters 19.3 (~21 quintillion parameters)
# Year: 2061 - max log parameters 19.5 (~31 quintillion parameters)
# Year: 2062 - max log parameters 19.6 (~44 quintillion parameters)
# Year: 2063 - max log parameters 19.8 (~63 quintillion parameters)
# Year: 2064 - max log parameters 20.0 (~91 quintillion parameters)
# Year: 2065 - max log parameters 20.1 (~129 quintillion parameters)
# Year: 2066 - max log parameters 20.3 (~183 quintillion parameters)
# Year: 2067 - max log parameters 20.4 (~258 quintillion parameters)
# Year: 2068 - max log parameters 20.6 (~361 quintillion parameters)
# Year: 2069 - max log parameters 20.7 (~504 quintillion parameters)
# Year: 2070 - max log parameters 20.8 (~698 quintillion parameters)
# Year: 2071 - max log parameters 21.0 (~960 quintillion parameters)
# Year: 2072 - max log parameters 21.1 (~1 sextillion parameters)
# Year: 2073 - max log parameters 21.3 (~2 sextillion parameters)
# Year: 2074 - max log parameters 21.4 (~2 sextillion parameters)
# Year: 2075 - max log parameters 21.5 (~3 sextillion parameters)
# Year: 2076 - max log parameters 21.6 (~4 sextillion parameters)
# Year: 2077 - max log parameters 21.7 (~6 sextillion parameters)
# Year: 2078 - max log parameters 21.9 (~7 sextillion parameters)
# Year: 2079 - max log parameters 22.0 (~9 sextillion parameters)
# Year: 2080 - max log parameters 22.1 (~12 sextillion parameters)
# Year: 2081 - max log parameters 22.2 (~15 sextillion parameters)
# Year: 2082 - max log parameters 22.3 (~18 sextillion parameters)
# Year: 2083 - max log parameters 22.3 (~22 sextillion parameters)
# Year: 2084 - max log parameters 22.4 (~26 sextillion parameters)
# Year: 2085 - max log parameters 22.5 (~31 sextillion parameters)
# Year: 2086 - max log parameters 22.6 (~37 sextillion parameters)
# Year: 2087 - max log parameters 22.6 (~42 sextillion parameters)
# Year: 2088 - max log parameters 22.7 (~48 sextillion parameters)
# Year: 2089 - max log parameters 22.7 (~54 sextillion parameters)
# Year: 2090 - max log parameters 22.8 (~59 sextillion parameters)
# Year: 2091 - max log parameters 22.8 (~65 sextillion parameters)
# Year: 2092 - max log parameters 22.8 (~70 sextillion parameters)
# Year: 2093 - max log parameters 22.9 (~76 sextillion parameters)
# Year: 2094 - max log parameters 22.9 (~81 sextillion parameters)
# Year: 2095 - max log parameters 22.9 (~86 sextillion parameters)
# Year: 2096 - max log parameters 23.0 (~90 sextillion parameters)
# Year: 2097 - max log parameters 23.0 (~95 sextillion parameters)
# Year: 2098 - max log parameters 23.0 (~99 sextillion parameters)
# Year: 2099 - max log parameters 23.0 (~103 sextillion parameters)
# Year: 2100 - max log parameters 23.0 (~107 sextillion parameters)
# Year: 2101 - max log parameters 23.0 (~111 sextillion parameters)
# Year: 2102 - max log parameters 23.1 (~114 sextillion parameters)
# Year: 2103 - max log parameters 23.1 (~118 sextillion parameters)
# Year: 2104 - max log parameters 23.1 (~122 sextillion parameters)
# Year: 2105 - max log parameters 23.1 (~125 sextillion parameters)
# Year: 2106 - max log parameters 23.1 (~129 sextillion parameters)
# Year: 2107 - max log parameters 23.1 (~132 sextillion parameters)
# Year: 2108 - max log parameters 23.1 (~136 sextillion parameters)
# Year: 2109 - max log parameters 23.1 (~140 sextillion parameters)
# Year: 2110 - max log parameters 23.2 (~144 sextillion parameters)
# Year: 2111 - max log parameters 23.2 (~147 sextillion parameters)
# Year: 2112 - max log parameters 23.2 (~151 sextillion parameters)
# Year: 2113 - max log parameters 23.2 (~155 sextillion parameters)
# Year: 2114 - max log parameters 23.2 (~159 sextillion parameters)
# Year: 2115 - max log parameters 23.2 (~163 sextillion parameters)
# Year: 2116 - max log parameters 23.2 (~167 sextillion parameters)
# Year: 2117 - max log parameters 23.2 (~172 sextillion parameters)
# Year: 2118 - max log parameters 23.2 (~176 sextillion parameters)
# Year: 2119 - max log parameters 23.3 (~181 sextillion parameters)
# Year: 2120 - max log parameters 23.3 (~185 sextillion parameters)
# Year: 2121 - max log parameters 23.3 (~190 sextillion parameters)
# Year: 2122 - max log parameters 23.3 (~195 sextillion parameters)

# %% [markdown]
# ## Chance of Non-scaling Delay

# %%
p_nonscaling_delay_ = np.array([p_nonscaling_delay(variables.get('initial_chance_of_nonscaling_issue', 0),
                                                   variables.get('final_chance_of_nonscaling_issue', 0),
                                                   year=y,
                                                   max_year=variables.get('nonscaling_issue_bottom_year', 0)) for y in years])

plt.plot(years[:60], p_nonscaling_delay_[:60])
plt.ylabel('chance of non-scaling delay by year')
# Out:
# Text(0, 0.5, 'chance of non-scaling delay by year')

# %%
for y in years:
    print('Year: {} - p(nonscaling delay) = {}%'.format(y,
                                                        np.round(p_nonscaling_delay_[y - CURRENT_YEAR] * 100, 1)))
# Out:
# Year: 2023 - p(nonscaling delay) = 94.2%
# Year: 2024 - p(nonscaling delay) = 93.9%
# Year: 2025 - p(nonscaling delay) = 93.6%
# Year: 2026 - p(nonscaling delay) = 93.1%
# Year: 2027 - p(nonscaling delay) = 92.4%
# Year: 2028 - p(nonscaling delay) = 91.6%
# Year: 2029 - p(nonscaling delay) = 90.5%
# Year: 2030 - p(nonscaling delay) = 89.0%
# Year: 2031 - p(nonscaling delay) = 87.2%
# Year: 2032 - p(nonscaling delay) = 84.9%
# Year: 2033 - p(nonscaling delay) = 82.1%
# Year: 2034 - p(nonscaling delay) = 78.7%
# Year: 2035 - p(nonscaling delay) = 74.8%
# Year: 2036 - p(nonscaling delay) = 70.4%
# Year: 2037 - p(nonscaling delay) = 65.6%
# Year: 2038 - p(nonscaling delay) = 60.8%
# Year: 2039 - p(nonscaling delay) = 56.0%
# Year: 2040 - p(nonscaling delay) = 51.5%
# Year: 2041 - p(nonscaling delay) = 47.4%
# Year: 2042 - p(nonscaling delay) = 43.9%
# Year: 2043 - p(nonscaling delay) = 40.9%
# Year: 2044 - p(nonscaling delay) = 38.4%
# Year: 2045 - p(nonscaling delay) = 36.5%
# Year: 2046 - p(nonscaling delay) = 34.9%
# Year: 2047 - p(nonscaling delay) = 33.7%
# Year: 2048 - p(nonscaling delay) = 32.8%
# Year: 2049 - p(nonscaling delay) = 32.1%
# Year: 2050 - p(nonscaling delay) = 31.6%
# Year: 2051 - p(nonscaling delay) = 31.2%
# Year: 2052 - p(nonscaling delay) = 30.9%
# Year: 2053 - p(nonscaling delay) = 30.6%
# Year: 2054 - p(nonscaling delay) = 30.5%
# Year: 2055 - p(nonscaling delay) = 30.4%
# Year: 2056 - p(nonscaling delay) = 30.3%
# Year: 2057 - p(nonscaling delay) = 30.2%
# Year: 2058 - p(nonscaling delay) = 30.1%
# Year: 2059 - p(nonscaling delay) = 30.1%
# Year: 2060 - p(nonscaling delay) = 30.1%
# Year: 2061 - p(nonscaling delay) = 30.1%
# Year: 2062 - p(nonscaling delay) = 30.0%
# Year: 2063 - p(nonscaling delay) = 30.0%
# Year: 2064 - p(nonscaling delay) = 30.0%
# Year: 2065 - p(nonscaling delay) = 30.0%
# Year: 2066 - p(nonscaling delay) = 30.0%
# Year: 2067 - p(nonscaling delay) = 30.0%
# Year: 2068 - p(nonscaling delay) = 30.0%
# Year: 2069 - p(nonscaling delay) = 30.0%
# Year: 2070 - p(nonscaling delay) = 30.0%
# Year: 2071 - p(nonscaling delay) = 30.0%
# Year: 2072 - p(nonscaling delay) = 30.0%
# Year: 2073 - p(nonscaling delay) = 30.0%
# Year: 2074 - p(nonscaling delay) = 30.0%
# Year: 2075 - p(nonscaling delay) = 30.0%
# Year: 2076 - p(nonscaling delay) = 30.0%
# Year: 2077 - p(nonscaling delay) = 30.0%
# Year: 2078 - p(nonscaling delay) = 30.0%
# Year: 2079 - p(nonscaling delay) = 30.0%
# Year: 2080 - p(nonscaling delay) = 30.0%
# Year: 2081 - p(nonscaling delay) = 30.0%
# Year: 2082 - p(nonscaling delay) = 30.0%
# Year: 2083 - p(nonscaling delay) = 30.0%
# Year: 2084 - p(nonscaling delay) = 30.0%
# Year: 2085 - p(nonscaling delay) = 30.0%
# Year: 2086 - p(nonscaling delay) = 30.0%
# Year: 2087 - p(nonscaling delay) = 30.0%
# Year: 2088 - p(nonscaling delay) = 30.0%
# Year: 2089 - p(nonscaling delay) = 30.0%
# Year: 2090 - p(nonscaling delay) = 30.0%
# Year: 2091 - p(nonscaling delay) = 30.0%
# Year: 2092 - p(nonscaling delay) = 30.0%
# Year: 2093 - p(nonscaling delay) = 30.0%
# Year: 2094 - p(nonscaling delay) = 30.0%
# Year: 2095 - p(nonscaling delay) = 30.0%
# Year: 2096 - p(nonscaling delay) = 30.0%
# Year: 2097 - p(nonscaling delay) = 30.0%
# Year: 2098 - p(nonscaling delay) = 30.0%
# Year: 2099 - p(nonscaling delay) = 30.0%
# Year: 2100 - p(nonscaling delay) = 30.0%
# Year: 2101 - p(nonscaling delay) = 30.0%
# Year: 2102 - p(nonscaling delay) = 30.0%
# Year: 2103 - p(nonscaling delay) = 30.0%
# Year: 2104 - p(nonscaling delay) = 30.0%
# Year: 2105 - p(nonscaling delay) = 30.0%
# Year: 2106 - p(nonscaling delay) = 30.0%
# Year: 2107 - p(nonscaling delay) = 30.0%
# Year: 2108 - p(nonscaling delay) = 30.0%
# Year: 2109 - p(nonscaling delay) = 30.0%
# Year: 2110 - p(nonscaling delay) = 30.0%
# Year: 2111 - p(nonscaling delay) = 30.0%
# Year: 2112 - p(nonscaling delay) = 30.0%
# Year: 2113 - p(nonscaling delay) = 30.0%
# Year: 2114 - p(nonscaling delay) = 30.0%
# Year: 2115 - p(nonscaling delay) = 30.0%
# Year: 2116 - p(nonscaling delay) = 30.0%
# Year: 2117 - p(nonscaling delay) = 30.0%
# Year: 2118 - p(nonscaling delay) = 30.0%
# Year: 2119 - p(nonscaling delay) = 30.0%
# Year: 2120 - p(nonscaling delay) = 30.0%
# Year: 2121 - p(nonscaling delay) = 30.0%
# Year: 2122 - p(nonscaling delay) = 30.0%

# %% [markdown]
# ## Run Model

# %%
def run_model(initial_gdp_, tai_flop_size_, nonscaling_delay_, algo_doubling_rate_,
              possible_algo_reduction_, initial_flops_per_dollar_, flops_halving_rate_,
              max_flops_per_dollar_, initial_pay_, gdp_growth_, max_gdp_frac_,
              willingness_ramp_, spend_doubling_time_, initial_chance_of_nonscaling_issue_,
              final_chance_of_nonscaling_issue_, nonscaling_issue_bottom_year_,
              willingness_spend_horizon_, print_diagnostic):
    queue_tai_year = 99999
    plt.ioff()
    if print_diagnostic:
        cost_of_tai_collector = []
        willingness_collector = []
    
    if print_diagnostic:
        print('It takes {} log FLOPs (~{}) for transformative capabilities.'.format(np.round(tai_flop_size_, 1),
                                                                                    numerize(10 ** tai_flop_size_)))
        print('Every {} years algorithms get 2x better, with {} log reductions possible.'.format(np.round(algo_doubling_rate_, 1),
                                                                                                 np.round(possible_algo_reduction_, 1)))
        print(('FLOPs start at a cost of {} log FLOPs (~{}) per 2022$USD. Every {} years they get ' +
               '2x cheaper, to a maximum of {} log FLOPs (~{}) per 2022$USD.').format(np.round(math.log10(initial_flops_per_dollar_), 1),
                                                                               numerize(initial_flops_per_dollar_),
                                                                               np.round(flops_halving_rate_, 1),
                                                                               np.round(math.log10(max_flops_per_dollar_), 1),
                                                                               numerize(max_flops_per_dollar_)))
        print(('We are willing to pay {} log 2022$USD (~{}) and this increases by {}x per year to a max of {}% of GDP. ' +
               'GDP grows at a rate of {}x per year.').format(np.round(math.log10(initial_pay_), 1),
                                                              numerize(initial_pay_),
                                                              np.round(spend_doubling_time_, 1),
                                                              np.round(max_gdp_frac_, 4),
                                                              np.round(gdp_growth_, 3)))
        if willingness_ramp_ < 1:
            print('In this simulation, if we are {}% of the way to paying for TAI, we will ramp to paying for TAI.'.format(np.round(willingness_ramp_ * 100)))

        if willingness_spend_horizon_ > 1:
            print('We are willing to spend over {} years to make TAI'.format(willingness_spend_horizon_))
            
        print(('If a non-scaling delay happens, it will take an additional {} years to produce TAI due' +
               ' to issues unrelated to scaling FLOP').format(np.round(nonscaling_delay_, 1)))
        print('---')
    
    tai_created = False
    is_nonscaling_issue = None
    for y in years:
        if not tai_created:
            flops_needed_ = flops_needed(initial_flops=10 ** tai_flop_size_,
                                         doubling_rate=algo_doubling_rate_,
                                         possible_reduction=10 ** possible_algo_reduction_,
                                         year=(y - CURRENT_YEAR))
            
            flops_per_dollar_ = flops_per_dollar(initial_flops_per_dollar=initial_flops_per_dollar_,
                                                 max_flops_per_dollar=max_flops_per_dollar_,
                                                 halving_rate=flops_halving_rate_,
                                                 year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200 or flops_needed_ > 10 ** 200:
                flops_needed_ = int(flops_needed_)
                flops_per_dollar_ = int(flops_per_dollar_)
                cost_of_tai_ = flops_needed_ // flops_per_dollar_
            else:
                cost_of_tai_ = flops_needed_ / flops_per_dollar_
            
            willingness_ = willingness_to_pay(initial_gdp=initial_gdp_,
                                              gdp_growth=gdp_growth_,
                                              initial_pay=initial_pay_,
                                              spend_doubling_time=spend_doubling_time_,
                                              max_gdp_frac=max_gdp_frac_,
                                              year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200:
                willingness_ = int(willingness_)
            if willingness_ > 10 ** 200:
                flops_per_dollar_ = int(flops_per_dollar_)
            
            if print_diagnostic:
                cost_of_tai_collector.append(cost_of_tai_)
                willingness_collector.append(willingness_)
            
            total_compute_ = willingness_ * flops_per_dollar_
            
            if print_diagnostic:
                out_str = ('Year: {} - {} max log FLOP ({}) available - TAI takes {} log FLOP ({}) - ' +
                           'log $ {} to buy TAI ({}) vs. willingness to pay log $ {} ({}) - {} log FLOPS per $ ({})')
                print(out_str.format(y,
                                     np.round(math.log10(total_compute_), 1),
                                     numerize(total_compute_),
                                     np.round(math.log10(flops_needed_), 1),
                                     numerize(flops_needed_),
                                     np.round(math.log10(cost_of_tai_), 1),
                                     numerize(cost_of_tai_),
                                     np.round(math.log10(willingness_), 1),
                                     numerize(willingness_),
                                     np.round(math.log10(flops_per_dollar_), 1),
                                     numerize(flops_per_dollar_)))
            
            if cost_of_tai_ > 10 ** 200:
                spend_tai_years = int(cost_of_tai_) // int(willingness_)
            else:
                spend_tai_years = cost_of_tai_ / willingness_
                
            if not is_nonscaling_issue and queue_tai_year < 99999 and print_diagnostic:
                print('-$- {}/{}'.format(y, queue_tai_year))
            if (cost_of_tai_ * willingness_ramp_) <= willingness_ or y >= queue_tai_year:
                if is_nonscaling_issue is None:
                    p_nonscaling_delay_ = p_nonscaling_delay(initial_chance_of_nonscaling_issue_,
                                                             final_chance_of_nonscaling_issue_,
                                                             year=y,
                                                             max_year=nonscaling_issue_bottom_year_)
                    is_nonscaling_issue = sq.event(p_nonscaling_delay_)
                    nonscaling_countdown = nonscaling_delay_
                    if print_diagnostic:
                        print('-- {} p_nonscaling_issue={}'.format('Nonscaling delay occured' if is_nonscaling_issue else 'Nonscaling issue did not occur',
                                                                   np.round(p_nonscaling_delay_, 4)))
                
                if not is_nonscaling_issue or nonscaling_countdown <= 0.1:
                    if print_diagnostic:
                        print('--- /!\ TAI CREATED in {}'.format(y))
                        plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
                    return y
                else:
                    if print_diagnostic:
                        print('/!\ FLOPs for TAI sufficient but needs {} more years to solve non-scaling issues'.format(np.round(nonscaling_countdown, 1)))
                    nonscaling_countdown -= 1
            elif (not is_nonscaling_issue and willingness_spend_horizon_ > 1 and
                  spend_tai_years <= willingness_spend_horizon_ and y + math.ceil(spend_tai_years) < queue_tai_year):
                queue_tai_year = y + math.ceil(spend_tai_years)
                if print_diagnostic:
                    print('-$- We have enough spend to make TAI in {} years (in {}) if sustained.'.format(math.ceil(spend_tai_years),
                                                                                                          queue_tai_year))
                
    if not tai_created:
        if print_diagnostic:
            print('--- :/ TAI NOT CREATED BEFORE {}'.format(MAX_YEAR + 1))
            plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
        return MAX_YEAR + 1
    
    
def define_event(verbose=False):
    tai_flop_size_ = sq.sample(sq.discrete(variables['tai_flop_size']))

    if tai_flop_size_ > 300:
        tai_flop_size_ = int(tai_flop_size_) # Handle overflow errors
    
    algo_doubling_rate_ = algo_halving_fn(sq.sample(variables['algo_doubling_rate_min']),
                                          sq.sample(variables['algo_doubling_rate_max']),
                                          tai_flop_size_)
    
    possible_algo_reduction_ = possible_algo_reduction_fn(sq.sample(variables['min_reduction']),
                                                          sq.sample(variables['max_reduction']),
                                                          tai_flop_size_)
    
    initial_flops_per_dollar_ = 10 ** sq.sample(variables['initial_flops_per_dollar'])
    flops_halving_rate_ = sq.sample(variables['flops_halving_rate'])
    max_flops_per_dollar_ = 10 ** sq.sample(variables['max_flops_per_dollar'])
    initial_pay_ = 10 ** sq.sample(variables['initial_pay'])
    gdp_growth_ = sq.sample(variables['gdp_growth'])
    max_gdp_frac_ = sq.sample(variables['max_gdp_frac'])
    
    willingness_ramp_happens = sq.event_occurs(variables.get('p_willingness_ramp', 0))
    if willingness_ramp_happens:
        willingness_ramp_ = sq.sample(variables.get('willingness_ramp', 1))
    else:
        willingness_ramp_ = 1
    
    initial_gdp_ = variables['initial_gdp']
    spend_doubling_time_ = sq.sample(variables['spend_doubling_time'])
    nonscaling_delay_ = sq.sample(variables.get('nonscaling_delay', sq.const(0)))
    initial_chance_of_nonscaling_issue_ = variables.get('initial_chance_of_nonscaling_issue', 0)
    final_chance_of_nonscaling_issue_ = variables.get('final_chance_of_nonscaling_issue', 0)
    nonscaling_issue_bottom_year_ = variables.get('nonscaling_issue_bottom_year', 0)
    willingness_spend_horizon_ = int(sq.sample(variables.get('willingness_spend_horizon', sq.const(1))))
    
    tai_year = run_model(initial_gdp_=initial_gdp_,
                         tai_flop_size_=tai_flop_size_,
                         nonscaling_delay_=nonscaling_delay_,
                         algo_doubling_rate_=algo_doubling_rate_,
                         possible_algo_reduction_=possible_algo_reduction_,
                         initial_flops_per_dollar_=initial_flops_per_dollar_,
                         flops_halving_rate_=flops_halving_rate_,
                         max_flops_per_dollar_=max_flops_per_dollar_,
                         initial_pay_=initial_pay_,
                         gdp_growth_=gdp_growth_,
                         max_gdp_frac_=max_gdp_frac_,
                         willingness_ramp_=willingness_ramp_,
                         spend_doubling_time_=spend_doubling_time_,
                         initial_chance_of_nonscaling_issue_=initial_chance_of_nonscaling_issue_,
                         final_chance_of_nonscaling_issue_=final_chance_of_nonscaling_issue_,
                         nonscaling_issue_bottom_year_=nonscaling_issue_bottom_year_,
                         willingness_spend_horizon_=willingness_spend_horizon_,
                         print_diagnostic=verbose)
    
    return {'tai_year': tai_year,
            'initial_gdp': initial_gdp_,
            'tai_flop_size': tai_flop_size_,
            'nonscaling_delay': nonscaling_delay_,
            'algo_doubling_rte': algo_doubling_rate_,
            'possible_algo_reduction': possible_algo_reduction_,
            'initial_flops_per_dollar': float(initial_flops_per_dollar_),
            'flops_halving_rate': flops_halving_rate_,
            'max_flops_per_dollar': float(max_flops_per_dollar_),
            'initial_pay': initial_pay_,
            'gdp_growth': gdp_growth_,
            'max_gdp_frac': max_gdp_frac_,
            'willingness_ramp_': willingness_ramp_,
            'spend_doubling_time_': spend_doubling_time_,
            'initial_chance_of_nonscaling_issue': initial_chance_of_nonscaling_issue_,
            'final_chance_of_nonscaling_issue': final_chance_of_nonscaling_issue_,
            'nonscaling_issue_bottom_year': nonscaling_issue_bottom_year_,
            'willingness_spend_horizon_': willingness_spend_horizon_}

print('Loaded')
# Out:
# Loaded

# %%
define_event(verbose=True)
# Out:
# It takes 24.2 log FLOPs (~2 septillion) for transformative capabilities.
# Every 2.0 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.4 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 3.2x per year to a max of 0.0005% of GDP. GDP grows at a rate of 1.026x per year.
# If a non-scaling delay happens, it will take an additional 7.7 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 25.1 max log FLOP (13 septillion) available - TAI takes 24.2 log FLOP (2 septillion) - log $ 6.2 to buy TAI (2 million) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.9421
# /!\ FLOPs for TAI sufficient but needs 7.7 more years to solve non-scaling issues
# Year: 2024 - 25.3 max log FLOP (21 septillion) available - TAI takes 24.1 log FLOP (1 septillion) - log $ 5.9 to buy TAI (844 thousand) vs. willingness to pay log $ 7.2 (16 million) - 18.1 log FLOPS per $ (1 quintillion)
# /!\ FLOPs for TAI sufficient but needs 6.7 more years to solve non-scaling issues
# Year: 2025 - 25.5 max log FLOP (35 septillion) available - TAI takes 23.9 log FLOP (806 sextillion) - log $ 5.7 to buy TAI (449 thousand) vs. willingness to pay log $ 7.3 (19 million) - 18.3 log FLOPS per $ (2 quintillion)
# /!\ FLOPs for TAI sufficient but needs 5.7 more years to solve non-scaling issues
# Year: 2026 - 25.8 max log FLOP (58 septillion) available - TAI takes 23.8 log FLOP (576 sextillion) - log $ 5.4 to buy TAI (239 thousand) vs. willingness to pay log $ 7.4 (24 million) - 18.4 log FLOPS per $ (2 quintillion)
# /!\ FLOPs for TAI sufficient but needs 4.7 more years to solve non-scaling issues
# Year: 2027 - 26.0 max log FLOP (97 septillion) available - TAI takes 23.6 log FLOP (413 sextillion) - log $ 5.1 to buy TAI (128 thousand) vs. willingness to pay log $ 7.5 (30 million) - 18.5 log FLOPS per $ (3 quintillion)
# /!\ FLOPs for TAI sufficient but needs 3.7 more years to solve non-scaling issues
# Year: 2028 - 26.2 max log FLOP (162 septillion) available - TAI takes 23.5 log FLOP (297 sextillion) - log $ 4.8 to buy TAI (69 thousand) vs. willingness to pay log $ 7.6 (38 million) - 18.6 log FLOPS per $ (4 quintillion)
# /!\ FLOPs for TAI sufficient but needs 2.7 more years to solve non-scaling issues
# Year: 2029 - 26.4 max log FLOP (271 septillion) available - TAI takes 23.3 log FLOP (215 sextillion) - log $ 4.6 to buy TAI (37 thousand) vs. willingness to pay log $ 7.7 (47 million) - 18.8 log FLOPS per $ (6 quintillion)
# /!\ FLOPs for TAI sufficient but needs 1.7 more years to solve non-scaling issues
# Year: 2030 - 26.7 max log FLOP (452 septillion) available - TAI takes 23.2 log FLOP (157 sextillion) - log $ 4.3 to buy TAI (20 thousand) vs. willingness to pay log $ 7.8 (58 million) - 18.9 log FLOPS per $ (8 quintillion)
# /!\ FLOPs for TAI sufficient but needs 0.7 more years to solve non-scaling issues
# Year: 2031 - 26.9 max log FLOP (753 septillion) available - TAI takes 23.1 log FLOP (116 sextillion) - log $ 4.0 to buy TAI (11 thousand) vs. willingness to pay log $ 7.9 (72 million) - 19.0 log FLOPS per $ (10 quintillion)
# --- /!\ TAI CREATED in 2031
# {'tai_year': 2031,
#  'initial_gdp': 23000000000000,
#  'tai_flop_size': 24.196910596290497,
#  'nonscaling_delay': 7.73184408317963,
#  'algo_doubling_rte': 2.0124520835553263,
#  'possible_algo_reduction': 2,
#  'initial_flops_per_dollar': 1e+18,
#  'flops_halving_rate': 2.3653637971627433,
#  'max_flops_per_dollar': 1e+24,
#  'initial_pay': 12589254.117941663,
#  'gdp_growth': 1.0261539591889095,
#  'max_gdp_frac': 0.0005181158479020301,
#  'willingness_ramp_': 1,
#  'spend_doubling_time_': 3.1641901747578776,
#  'initial_chance_of_nonscaling_issue': 0.95,
#  'final_chance_of_nonscaling_issue': 0.3,
#  'nonscaling_issue_bottom_year': 2050,
#  'willingness_spend_horizon_': 1}

# %%
for i in range(5):
    print('## RUN {} ##'.format(i + 1))
    define_event(verbose=True)
# Out:
# ## RUN 1 ##
# It takes 34.2 log FLOPs (~15 decillion) for transformative capabilities.
# Every 1.5 years algorithms get 2x better, with 3 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.8 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 1.2x per year to a max of 0.001% of GDP. GDP grows at a rate of 1.024x per year.
# If a non-scaling delay happens, it will take an additional 6.4 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 25.1 max log FLOP (13 septillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 16.2 to buy TAI (15 quadrillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 25.5 max log FLOP (29 septillion) available - TAI takes 34.0 log FLOP (10 decillion) - log $ 15.9 to buy TAI (8 quadrillion) vs. willingness to pay log $ 7.4 (22 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 25.8 max log FLOP (65 septillion) available - TAI takes 33.8 log FLOP (6 decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 7.6 (40 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 26.2 max log FLOP (149 septillion) available - TAI takes 33.6 log FLOP (4 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 7.9 (71 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2027 - 26.5 max log FLOP (340 septillion) available - TAI takes 33.4 log FLOP (2 decillion) - log $ 15.0 to buy TAI (912 trillion) vs. willingness to pay log $ 8.1 (126 million) - 18.4 log FLOPS per $ (3 quintillion)
# Year: 2028 - 26.9 max log FLOP (772 septillion) available - TAI takes 33.2 log FLOP (2 decillion) - log $ 14.7 to buy TAI (453 trillion) vs. willingness to pay log $ 8.4 (224 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2029 - 27.2 max log FLOP (2 octillion) available - TAI takes 33.0 log FLOP (995 nonillion) - log $ 14.4 to buy TAI (225 trillion) vs. willingness to pay log $ 8.6 (396 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2030 - 27.6 max log FLOP (4 octillion) available - TAI takes 32.8 log FLOP (636 nonillion) - log $ 14.1 to buy TAI (112 trillion) vs. willingness to pay log $ 8.8 (698 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2031 - 27.9 max log FLOP (9 octillion) available - TAI takes 32.6 log FLOP (408 nonillion) - log $ 13.8 to buy TAI (56 trillion) vs. willingness to pay log $ 9.1 (1 billion) - 18.9 log FLOPS per $ (7 quintillion)
# Year: 2032 - 28.3 max log FLOP (19 octillion) available - TAI takes 32.4 log FLOP (264 nonillion) - log $ 13.5 to buy TAI (28 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2033 - 28.6 max log FLOP (42 octillion) available - TAI takes 32.2 log FLOP (173 nonillion) - log $ 13.2 to buy TAI (15 trillion) vs. willingness to pay log $ 9.5 (4 billion) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2034 - 28.9 max log FLOP (88 octillion) available - TAI takes 32.1 log FLOP (115 nonillion) - log $ 12.9 to buy TAI (8 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2035 - 29.2 max log FLOP (174 octillion) available - TAI takes 31.9 log FLOP (78 nonillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 10.0 (9 billion) - 19.3 log FLOPS per $ (19 quintillion)
# Year: 2036 - 29.5 max log FLOP (323 octillion) available - TAI takes 31.7 log FLOP (55 nonillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 10.1 (13 billion) - 19.4 log FLOPS per $ (25 quintillion)
# Year: 2037 - 29.7 max log FLOP (558 octillion) available - TAI takes 31.6 log FLOP (41 nonillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 10.2 (17 billion) - 19.5 log FLOPS per $ (32 quintillion)
# Year: 2038 - 30.0 max log FLOP (894 octillion) available - TAI takes 31.5 log FLOP (31 nonillion) - log $ 11.9 to buy TAI (763 billion) vs. willingness to pay log $ 10.3 (22 billion) - 19.6 log FLOPS per $ (41 quintillion)
# Year: 2039 - 30.1 max log FLOP (1 nonillion) available - TAI takes 31.4 log FLOP (25 nonillion) - log $ 11.7 to buy TAI (483 billion) vs. willingness to pay log $ 10.4 (26 billion) - 19.7 log FLOPS per $ (52 quintillion)
# Year: 2040 - 30.3 max log FLOP (2 nonillion) available - TAI takes 31.3 log FLOP (22 nonillion) - log $ 11.5 to buy TAI (322 billion) vs. willingness to pay log $ 10.5 (29 billion) - 19.8 log FLOPS per $ (67 quintillion)
# Year: 2041 - 30.4 max log FLOP (3 nonillion) available - TAI takes 31.3 log FLOP (19 nonillion) - log $ 11.3 to buy TAI (224 billion) vs. willingness to pay log $ 10.5 (31 billion) - 19.9 log FLOPS per $ (86 quintillion)
# Year: 2042 - 30.6 max log FLOP (4 nonillion) available - TAI takes 31.2 log FLOP (18 nonillion) - log $ 11.2 to buy TAI (161 billion) vs. willingness to pay log $ 10.5 (33 billion) - 20.0 log FLOPS per $ (110 quintillion)
# Year: 2043 - 30.7 max log FLOP (5 nonillion) available - TAI takes 31.2 log FLOP (17 nonillion) - log $ 11.1 to buy TAI (119 billion) vs. willingness to pay log $ 10.5 (34 billion) - 20.1 log FLOPS per $ (141 quintillion)
# Year: 2044 - 30.8 max log FLOP (6 nonillion) available - TAI takes 31.2 log FLOP (16 nonillion) - log $ 11.0 to buy TAI (89 billion) vs. willingness to pay log $ 10.5 (35 billion) - 20.3 log FLOPS per $ (181 quintillion)
# Year: 2045 - 30.9 max log FLOP (8 nonillion) available - TAI takes 31.2 log FLOP (16 nonillion) - log $ 10.8 to buy TAI (68 billion) vs. willingness to pay log $ 10.6 (36 billion) - 20.4 log FLOPS per $ (232 quintillion)
# Year: 2046 - 31.0 max log FLOP (11 nonillion) available - TAI takes 31.2 log FLOP (16 nonillion) - log $ 10.7 to buy TAI (52 billion) vs. willingness to pay log $ 10.6 (37 billion) - 20.5 log FLOPS per $ (297 quintillion)
# Year: 2047 - 31.2 max log FLOP (15 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.6 to buy TAI (41 billion) vs. willingness to pay log $ 10.6 (38 billion) - 20.6 log FLOPS per $ (380 quintillion)
# Year: 2048 - 31.3 max log FLOP (19 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.5 to buy TAI (31 billion) vs. willingness to pay log $ 10.6 (39 billion) - 20.7 log FLOPS per $ (487 quintillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.3279
# /!\ FLOPs for TAI sufficient but needs 6.4 more years to solve non-scaling issues
# Year: 2049 - 31.4 max log FLOP (25 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.4 to buy TAI (24 billion) vs. willingness to pay log $ 10.6 (40 billion) - 20.8 log FLOPS per $ (623 quintillion)
# /!\ FLOPs for TAI sufficient but needs 5.4 more years to solve non-scaling issues
# Year: 2050 - 31.5 max log FLOP (33 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.3 to buy TAI (19 billion) vs. willingness to pay log $ 10.6 (41 billion) - 20.9 log FLOPS per $ (798 quintillion)
# /!\ FLOPs for TAI sufficient but needs 4.4 more years to solve non-scaling issues
# Year: 2051 - 31.6 max log FLOP (43 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.2 to buy TAI (15 billion) vs. willingness to pay log $ 10.6 (42 billion) - 21.0 log FLOPS per $ (1 sextillion)
# /!\ FLOPs for TAI sufficient but needs 3.4 more years to solve non-scaling issues
# Year: 2052 - 31.8 max log FLOP (56 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.1 to buy TAI (12 billion) vs. willingness to pay log $ 10.6 (43 billion) - 21.1 log FLOPS per $ (1 sextillion)
# /!\ FLOPs for TAI sufficient but needs 2.4 more years to solve non-scaling issues
# Year: 2053 - 31.9 max log FLOP (74 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 10.0 to buy TAI (9 billion) vs. willingness to pay log $ 10.6 (44 billion) - 21.2 log FLOPS per $ (2 sextillion)
# /!\ FLOPs for TAI sufficient but needs 1.4 more years to solve non-scaling issues
# Year: 2054 - 32.0 max log FLOP (97 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 9.8 to buy TAI (7 billion) vs. willingness to pay log $ 10.7 (45 billion) - 21.3 log FLOPS per $ (2 sextillion)
# /!\ FLOPs for TAI sufficient but needs 0.4 more years to solve non-scaling issues
# Year: 2055 - 32.1 max log FLOP (127 nonillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 9.7 to buy TAI (6 billion) vs. willingness to pay log $ 10.7 (46 billion) - 21.4 log FLOPS per $ (3 sextillion)
# --- /!\ TAI CREATED in 2055
# ## RUN 2 ##
# It takes 38.8 log FLOPs (~607 thousand decillion) for transformative capabilities.
# Every 1.9 years algorithms get 2x better, with 4 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 3.9 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.9 log 2022$USD (~89 million) and this increases by 4.5x per year to a max of 0.0006% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 2.6 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 25.9 max log FLOP (88 septillion) available - TAI takes 38.8 log FLOP (607 thousand decillion) - log $ 20.8 to buy TAI (607 quintillion) vs. willingness to pay log $ 7.9 (88 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.1 max log FLOP (122 septillion) available - TAI takes 38.6 log FLOP (420 thousand decillion) - log $ 20.5 to buy TAI (352 quintillion) vs. willingness to pay log $ 8.0 (102 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 26.2 max log FLOP (170 septillion) available - TAI takes 38.5 log FLOP (291 thousand decillion) - log $ 20.3 to buy TAI (204 quintillion) vs. willingness to pay log $ 8.1 (119 million) - 18.2 log FLOPS per $ (1 quintillion)
# Year: 2026 - 26.4 max log FLOP (237 septillion) available - TAI takes 38.3 log FLOP (201 thousand decillion) - log $ 20.1 to buy TAI (118 quintillion) vs. willingness to pay log $ 8.1 (139 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2027 - 26.5 max log FLOP (329 septillion) available - TAI takes 38.1 log FLOP (139 thousand decillion) - log $ 19.8 to buy TAI (68 quintillion) vs. willingness to pay log $ 8.2 (161 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2028 - 26.7 max log FLOP (458 septillion) available - TAI takes 38.0 log FLOP (96 thousand decillion) - log $ 19.6 to buy TAI (40 quintillion) vs. willingness to pay log $ 8.3 (188 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2029 - 26.8 max log FLOP (637 septillion) available - TAI takes 37.8 log FLOP (67 thousand decillion) - log $ 19.4 to buy TAI (23 quintillion) vs. willingness to pay log $ 8.3 (218 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2030 - 26.9 max log FLOP (885 septillion) available - TAI takes 37.7 log FLOP (46 thousand decillion) - log $ 19.1 to buy TAI (13 quintillion) vs. willingness to pay log $ 8.4 (254 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2031 - 27.1 max log FLOP (1 octillion) available - TAI takes 37.5 log FLOP (32 thousand decillion) - log $ 18.9 to buy TAI (8 quintillion) vs. willingness to pay log $ 8.5 (295 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2032 - 27.2 max log FLOP (2 octillion) available - TAI takes 37.3 log FLOP (22 thousand decillion) - log $ 18.6 to buy TAI (4 quintillion) vs. willingness to pay log $ 8.5 (343 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2033 - 27.4 max log FLOP (2 octillion) available - TAI takes 37.2 log FLOP (15 thousand decillion) - log $ 18.4 to buy TAI (3 quintillion) vs. willingness to pay log $ 8.6 (398 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2034 - 27.5 max log FLOP (3 octillion) available - TAI takes 37.0 log FLOP (11 thousand decillion) - log $ 18.2 to buy TAI (1 quintillion) vs. willingness to pay log $ 8.7 (463 million) - 18.9 log FLOPS per $ (7 quintillion)
# Year: 2035 - 27.7 max log FLOP (5 octillion) available - TAI takes 36.9 log FLOP (7 thousand decillion) - log $ 17.9 to buy TAI (867 quadrillion) vs. willingness to pay log $ 8.7 (537 million) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2036 - 27.8 max log FLOP (6 octillion) available - TAI takes 36.7 log FLOP (5 thousand decillion) - log $ 17.7 to buy TAI (504 quadrillion) vs. willingness to pay log $ 8.8 (623 million) - 19.0 log FLOPS per $ (10 quintillion)
# Year: 2037 - 27.9 max log FLOP (9 octillion) available - TAI takes 36.6 log FLOP (4 thousand decillion) - log $ 17.5 to buy TAI (293 quadrillion) vs. willingness to pay log $ 8.9 (723 million) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2038 - 28.1 max log FLOP (12 octillion) available - TAI takes 36.4 log FLOP (2 thousand decillion) - log $ 17.2 to buy TAI (171 quadrillion) vs. willingness to pay log $ 8.9 (838 million) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2039 - 28.2 max log FLOP (17 octillion) available - TAI takes 36.2 log FLOP (2 thousand decillion) - log $ 17.0 to buy TAI (100 quadrillion) vs. willingness to pay log $ 9.0 (971 million) - 19.2 log FLOPS per $ (17 quintillion)
# Year: 2040 - 28.4 max log FLOP (23 octillion) available - TAI takes 36.1 log FLOP (1 thousand decillion) - log $ 16.8 to buy TAI (59 quadrillion) vs. willingness to pay log $ 9.1 (1 billion) - 19.3 log FLOPS per $ (21 quintillion)
# Year: 2041 - 28.5 max log FLOP (32 octillion) available - TAI takes 35.9 log FLOP (863 decillion) - log $ 16.5 to buy TAI (35 quadrillion) vs. willingness to pay log $ 9.1 (1 billion) - 19.4 log FLOPS per $ (25 quintillion)
# Year: 2042 - 28.6 max log FLOP (44 octillion) available - TAI takes 35.8 log FLOP (616 decillion) - log $ 16.3 to buy TAI (21 quadrillion) vs. willingness to pay log $ 9.2 (2 billion) - 19.5 log FLOPS per $ (30 quintillion)
# Year: 2043 - 28.8 max log FLOP (61 octillion) available - TAI takes 35.6 log FLOP (445 decillion) - log $ 16.1 to buy TAI (13 quadrillion) vs. willingness to pay log $ 9.2 (2 billion) - 19.5 log FLOPS per $ (35 quintillion)
# Year: 2044 - 28.9 max log FLOP (85 octillion) available - TAI takes 35.5 log FLOP (326 decillion) - log $ 15.9 to buy TAI (8 quadrillion) vs. willingness to pay log $ 9.3 (2 billion) - 19.6 log FLOPS per $ (42 quintillion)
# Year: 2045 - 29.1 max log FLOP (117 octillion) available - TAI takes 35.4 log FLOP (245 decillion) - log $ 15.7 to buy TAI (5 quadrillion) vs. willingness to pay log $ 9.4 (2 billion) - 19.7 log FLOPS per $ (51 quintillion)
# Year: 2046 - 29.2 max log FLOP (160 octillion) available - TAI takes 35.3 log FLOP (188 decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 9.4 (3 billion) - 19.8 log FLOPS per $ (60 quintillion)
# Year: 2047 - 29.3 max log FLOP (220 octillion) available - TAI takes 35.2 log FLOP (149 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 9.5 (3 billion) - 19.9 log FLOPS per $ (72 quintillion)
# Year: 2048 - 29.5 max log FLOP (302 octillion) available - TAI takes 35.1 log FLOP (122 decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 9.5 (3 billion) - 19.9 log FLOPS per $ (86 quintillion)
# Year: 2049 - 29.6 max log FLOP (413 octillion) available - TAI takes 35.0 log FLOP (103 decillion) - log $ 15.0 to buy TAI (997 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 20.0 log FLOPS per $ (103 quintillion)
# Year: 2050 - 29.8 max log FLOP (564 octillion) available - TAI takes 35.0 log FLOP (90 decillion) - log $ 14.9 to buy TAI (729 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 20.1 log FLOPS per $ (123 quintillion)
# Year: 2051 - 29.9 max log FLOP (769 octillion) available - TAI takes 34.9 log FLOP (81 decillion) - log $ 14.7 to buy TAI (549 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 20.2 log FLOPS per $ (147 quintillion)
# Year: 2052 - 30.0 max log FLOP (1 nonillion) available - TAI takes 34.9 log FLOP (75 decillion) - log $ 14.6 to buy TAI (424 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 20.2 log FLOPS per $ (176 quintillion)
# Year: 2053 - 30.2 max log FLOP (1 nonillion) available - TAI takes 34.8 log FLOP (70 decillion) - log $ 14.5 to buy TAI (334 trillion) vs. willingness to pay log $ 9.8 (7 billion) - 20.3 log FLOPS per $ (210 quintillion)
# Year: 2054 - 30.3 max log FLOP (2 nonillion) available - TAI takes 34.8 log FLOP (67 decillion) - log $ 14.4 to buy TAI (268 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 20.4 log FLOPS per $ (252 quintillion)
# Year: 2055 - 30.4 max log FLOP (3 nonillion) available - TAI takes 34.8 log FLOP (65 decillion) - log $ 14.3 to buy TAI (217 trillion) vs. willingness to pay log $ 9.9 (9 billion) - 20.5 log FLOPS per $ (301 quintillion)
# Year: 2056 - 30.5 max log FLOP (3 nonillion) available - TAI takes 34.8 log FLOP (64 decillion) - log $ 14.3 to buy TAI (178 trillion) vs. willingness to pay log $ 10.0 (10 billion) - 20.6 log FLOPS per $ (359 quintillion)
# Year: 2057 - 30.7 max log FLOP (5 nonillion) available - TAI takes 34.8 log FLOP (63 decillion) - log $ 14.2 to buy TAI (147 trillion) vs. willingness to pay log $ 10.0 (11 billion) - 20.6 log FLOPS per $ (429 quintillion)
# Year: 2058 - 30.8 max log FLOP (6 nonillion) available - TAI takes 34.8 log FLOP (62 decillion) - log $ 14.1 to buy TAI (121 trillion) vs. willingness to pay log $ 10.1 (12 billion) - 20.7 log FLOPS per $ (513 quintillion)
# Year: 2059 - 30.9 max log FLOP (8 nonillion) available - TAI takes 34.8 log FLOP (62 decillion) - log $ 14.0 to buy TAI (101 trillion) vs. willingness to pay log $ 10.1 (14 billion) - 20.8 log FLOPS per $ (613 quintillion)
# Year: 2060 - 31.0 max log FLOP (11 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.9 to buy TAI (84 trillion) vs. willingness to pay log $ 10.2 (15 billion) - 20.9 log FLOPS per $ (733 quintillion)
# Year: 2061 - 31.2 max log FLOP (15 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 10.2 (17 billion) - 20.9 log FLOPS per $ (876 quintillion)
# Year: 2062 - 31.3 max log FLOP (19 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.8 to buy TAI (58 trillion) vs. willingness to pay log $ 10.3 (18 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2063 - 31.4 max log FLOP (25 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.7 to buy TAI (49 trillion) vs. willingness to pay log $ 10.3 (20 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2064 - 31.5 max log FLOP (33 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.6 to buy TAI (41 trillion) vs. willingness to pay log $ 10.3 (22 billion) - 21.2 log FLOPS per $ (1 sextillion)
# Year: 2065 - 31.6 max log FLOP (43 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.5 to buy TAI (34 trillion) vs. willingness to pay log $ 10.4 (24 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2066 - 31.7 max log FLOP (56 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.5 to buy TAI (28 trillion) vs. willingness to pay log $ 10.4 (26 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2067 - 31.9 max log FLOP (72 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.4 to buy TAI (24 trillion) vs. willingness to pay log $ 10.5 (28 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2068 - 32.0 max log FLOP (93 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.3 to buy TAI (20 trillion) vs. willingness to pay log $ 10.5 (30 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2069 - 32.1 max log FLOP (119 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.2 to buy TAI (17 trillion) vs. willingness to pay log $ 10.5 (33 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2070 - 32.2 max log FLOP (152 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.1 to buy TAI (14 trillion) vs. willingness to pay log $ 10.5 (35 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2071 - 32.3 max log FLOP (194 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 10.6 (37 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2072 - 32.4 max log FLOP (247 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 13.0 to buy TAI (10 trillion) vs. willingness to pay log $ 10.6 (40 billion) - 21.8 log FLOPS per $ (6 sextillion)
# Year: 2073 - 32.5 max log FLOP (312 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.9 to buy TAI (8 trillion) vs. willingness to pay log $ 10.6 (42 billion) - 21.9 log FLOPS per $ (7 sextillion)
# Year: 2074 - 32.6 max log FLOP (394 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.8 to buy TAI (7 trillion) vs. willingness to pay log $ 10.6 (45 billion) - 21.9 log FLOPS per $ (9 sextillion)
# Year: 2075 - 32.7 max log FLOP (496 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.8 to buy TAI (6 trillion) vs. willingness to pay log $ 10.7 (47 billion) - 22.0 log FLOPS per $ (11 sextillion)
# Year: 2076 - 32.8 max log FLOP (623 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.7 to buy TAI (5 trillion) vs. willingness to pay log $ 10.7 (50 billion) - 22.1 log FLOPS per $ (13 sextillion)
# Year: 2077 - 32.9 max log FLOP (781 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 10.7 (52 billion) - 22.2 log FLOPS per $ (15 sextillion)
# Year: 2078 - 33.0 max log FLOP (976 nonillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.5 to buy TAI (3 trillion) vs. willingness to pay log $ 10.7 (55 billion) - 22.3 log FLOPS per $ (18 sextillion)
# Year: 2079 - 33.1 max log FLOP (1 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.5 to buy TAI (3 trillion) vs. willingness to pay log $ 10.8 (57 billion) - 22.3 log FLOPS per $ (21 sextillion)
# Year: 2080 - 33.2 max log FLOP (2 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.4 to buy TAI (2 trillion) vs. willingness to pay log $ 10.8 (60 billion) - 22.4 log FLOPS per $ (25 sextillion)
# Year: 2081 - 33.3 max log FLOP (2 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 10.8 (62 billion) - 22.5 log FLOPS per $ (30 sextillion)
# Year: 2082 - 33.4 max log FLOP (2 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.2 to buy TAI (2 trillion) vs. willingness to pay log $ 10.8 (65 billion) - 22.6 log FLOPS per $ (36 sextillion)
# Year: 2083 - 33.5 max log FLOP (3 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.2 to buy TAI (1 trillion) vs. willingness to pay log $ 10.8 (68 billion) - 22.6 log FLOPS per $ (42 sextillion)
# Year: 2084 - 33.5 max log FLOP (4 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 10.8 (70 billion) - 22.7 log FLOPS per $ (50 sextillion)
# Year: 2085 - 33.6 max log FLOP (4 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 12.0 to buy TAI (1 trillion) vs. willingness to pay log $ 10.9 (73 billion) - 22.8 log FLOPS per $ (60 sextillion)
# Year: 2086 - 33.7 max log FLOP (5 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.9 to buy TAI (863 billion) vs. willingness to pay log $ 10.9 (76 billion) - 22.8 log FLOPS per $ (70 sextillion)
# Year: 2087 - 33.8 max log FLOP (7 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.9 to buy TAI (732 billion) vs. willingness to pay log $ 10.9 (78 billion) - 22.9 log FLOPS per $ (83 sextillion)
# Year: 2088 - 33.9 max log FLOP (8 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.8 to buy TAI (622 billion) vs. willingness to pay log $ 10.9 (81 billion) - 23.0 log FLOPS per $ (98 sextillion)
# Year: 2089 - 34.0 max log FLOP (10 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.7 to buy TAI (531 billion) vs. willingness to pay log $ 10.9 (84 billion) - 23.1 log FLOPS per $ (114 sextillion)
# Year: 2090 - 34.1 max log FLOP (12 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.7 to buy TAI (454 billion) vs. willingness to pay log $ 10.9 (87 billion) - 23.1 log FLOPS per $ (134 sextillion)
# Year: 2091 - 34.1 max log FLOP (14 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.6 to buy TAI (390 billion) vs. willingness to pay log $ 11.0 (90 billion) - 23.2 log FLOPS per $ (156 sextillion)
# Year: 2092 - 34.2 max log FLOP (17 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.5 to buy TAI (336 billion) vs. willingness to pay log $ 11.0 (93 billion) - 23.3 log FLOPS per $ (181 sextillion)
# Year: 2093 - 34.3 max log FLOP (20 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.5 to buy TAI (291 billion) vs. willingness to pay log $ 11.0 (96 billion) - 23.3 log FLOPS per $ (209 sextillion)
# Year: 2094 - 34.4 max log FLOP (24 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.4 to buy TAI (253 billion) vs. willingness to pay log $ 11.0 (99 billion) - 23.4 log FLOPS per $ (240 sextillion)
# Year: 2095 - 34.4 max log FLOP (28 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.3 to buy TAI (222 billion) vs. willingness to pay log $ 11.0 (102 billion) - 23.4 log FLOPS per $ (274 sextillion)
# Year: 2096 - 34.5 max log FLOP (33 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.3 to buy TAI (196 billion) vs. willingness to pay log $ 11.0 (106 billion) - 23.5 log FLOPS per $ (310 sextillion)
# Year: 2097 - 34.6 max log FLOP (38 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.2 to buy TAI (174 billion) vs. willingness to pay log $ 11.0 (109 billion) - 23.5 log FLOPS per $ (350 sextillion)
# Year: 2098 - 34.6 max log FLOP (44 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.2 to buy TAI (155 billion) vs. willingness to pay log $ 11.1 (112 billion) - 23.6 log FLOPS per $ (391 sextillion)
# Year: 2099 - 34.7 max log FLOP (50 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.1 to buy TAI (140 billion) vs. willingness to pay log $ 11.1 (116 billion) - 23.6 log FLOPS per $ (435 sextillion)
# Year: 2100 - 34.8 max log FLOP (57 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.1 to buy TAI (127 billion) vs. willingness to pay log $ 11.1 (120 billion) - 23.7 log FLOPS per $ (479 sextillion)
# Year: 2101 - 34.8 max log FLOP (65 decillion) available - TAI takes 34.8 log FLOP (61 decillion) - log $ 11.1 to buy TAI (116 billion) vs. willingness to pay log $ 11.1 (123 billion) - 23.7 log FLOPS per $ (523 sextillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.3
# --- /!\ TAI CREATED in 2101
# ## RUN 3 ##
# It takes 28.7 log FLOPs (~51 octillion) for transformative capabilities.
# Every 2.6 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 4.4 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 1.5x per year to a max of 0.0009% of GDP. GDP grows at a rate of 1.024x per year.
# If a non-scaling delay happens, it will take an additional 6.4 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 25.1 max log FLOP (13 septillion) available - TAI takes 28.7 log FLOP (51 octillion) - log $ 10.7 to buy TAI (51 billion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 25.4 max log FLOP (24 septillion) available - TAI takes 28.6 log FLOP (40 octillion) - log $ 10.5 to buy TAI (34 billion) vs. willingness to pay log $ 7.3 (20 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 25.6 max log FLOP (45 septillion) available - TAI takes 28.5 log FLOP (30 octillion) - log $ 10.3 to buy TAI (22 billion) vs. willingness to pay log $ 7.5 (33 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2026 - 25.9 max log FLOP (84 septillion) available - TAI takes 28.4 log FLOP (23 octillion) - log $ 10.2 to buy TAI (14 billion) vs. willingness to pay log $ 7.7 (52 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2027 - 26.2 max log FLOP (158 septillion) available - TAI takes 28.3 log FLOP (18 octillion) - log $ 10.0 to buy TAI (9 billion) vs. willingness to pay log $ 7.9 (84 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2028 - 26.5 max log FLOP (297 septillion) available - TAI takes 28.1 log FLOP (14 octillion) - log $ 9.8 to buy TAI (6 billion) vs. willingness to pay log $ 8.1 (135 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2029 - 26.7 max log FLOP (558 septillion) available - TAI takes 28.0 log FLOP (11 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 8.3 (216 million) - 18.4 log FLOPS per $ (3 quintillion)
# Year: 2030 - 27.0 max log FLOP (1 octillion) available - TAI takes 27.9 log FLOP (8 octillion) - log $ 9.4 to buy TAI (3 billion) vs. willingness to pay log $ 8.5 (345 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2031 - 27.3 max log FLOP (2 octillion) available - TAI takes 27.8 log FLOP (6 octillion) - log $ 9.3 to buy TAI (2 billion) vs. willingness to pay log $ 8.7 (551 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2032 - 27.6 max log FLOP (4 octillion) available - TAI takes 27.7 log FLOP (5 octillion) - log $ 9.1 to buy TAI (1 billion) vs. willingness to pay log $ 8.9 (876 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2033 - 27.8 max log FLOP (7 octillion) available - TAI takes 27.6 log FLOP (4 octillion) - log $ 8.9 to buy TAI (809 million) vs. willingness to pay log $ 9.1 (1 billion) - 18.7 log FLOPS per $ (5 quintillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.8208
# /!\ FLOPs for TAI sufficient but needs 6.4 more years to solve non-scaling issues
# Year: 2034 - 28.1 max log FLOP (12 octillion) available - TAI takes 27.5 log FLOP (3 octillion) - log $ 8.7 to buy TAI (548 million) vs. willingness to pay log $ 9.3 (2 billion) - 18.8 log FLOPS per $ (6 quintillion)
# /!\ FLOPs for TAI sufficient but needs 5.4 more years to solve non-scaling issues
# Year: 2035 - 28.3 max log FLOP (22 octillion) available - TAI takes 27.4 log FLOP (3 octillion) - log $ 8.6 to buy TAI (375 million) vs. willingness to pay log $ 9.5 (3 billion) - 18.8 log FLOPS per $ (7 quintillion)
# /!\ FLOPs for TAI sufficient but needs 4.4 more years to solve non-scaling issues
# Year: 2036 - 28.6 max log FLOP (39 octillion) available - TAI takes 27.3 log FLOP (2 octillion) - log $ 8.4 to buy TAI (260 million) vs. willingness to pay log $ 9.7 (5 billion) - 18.9 log FLOPS per $ (8 quintillion)
# /!\ FLOPs for TAI sufficient but needs 3.4 more years to solve non-scaling issues
# Year: 2037 - 28.8 max log FLOP (68 octillion) available - TAI takes 27.2 log FLOP (2 octillion) - log $ 8.3 to buy TAI (182 million) vs. willingness to pay log $ 9.9 (7 billion) - 19.0 log FLOPS per $ (9 quintillion)
# /!\ FLOPs for TAI sufficient but needs 2.4 more years to solve non-scaling issues
# Year: 2038 - 29.1 max log FLOP (112 octillion) available - TAI takes 27.1 log FLOP (1 octillion) - log $ 8.1 to buy TAI (130 million) vs. willingness to pay log $ 10.0 (10 billion) - 19.0 log FLOPS per $ (11 quintillion)
# /!\ FLOPs for TAI sufficient but needs 1.4 more years to solve non-scaling issues
# Year: 2039 - 29.3 max log FLOP (178 octillion) available - TAI takes 27.1 log FLOP (1 octillion) - log $ 8.0 to buy TAI (94 million) vs. willingness to pay log $ 10.1 (14 billion) - 19.1 log FLOPS per $ (13 quintillion)
# /!\ FLOPs for TAI sufficient but needs 0.4 more years to solve non-scaling issues
# Year: 2040 - 29.4 max log FLOP (268 octillion) available - TAI takes 27.0 log FLOP (1 octillion) - log $ 7.8 to buy TAI (70 million) vs. willingness to pay log $ 10.3 (18 billion) - 19.2 log FLOPS per $ (15 quintillion)
# --- /!\ TAI CREATED in 2040
# ## RUN 4 ##
# It takes 34.7 log FLOPs (~48 decillion) for transformative capabilities.
# Every 1.6 years algorithms get 2x better, with 3 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 3.7 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 3.2x per year to a max of 0.0006% of GDP. GDP grows at a rate of 1.021x per year.
# If a non-scaling delay happens, it will take an additional 4.4 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 25.1 max log FLOP (13 septillion) available - TAI takes 34.7 log FLOP (48 decillion) - log $ 16.7 to buy TAI (48 quadrillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 25.3 max log FLOP (19 septillion) available - TAI takes 34.5 log FLOP (31 decillion) - log $ 16.4 to buy TAI (26 quadrillion) vs. willingness to pay log $ 7.2 (16 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 25.5 max log FLOP (28 septillion) available - TAI takes 34.3 log FLOP (20 decillion) - log $ 16.1 to buy TAI (14 quadrillion) vs. willingness to pay log $ 7.3 (19 million) - 18.2 log FLOPS per $ (1 quintillion)
# Year: 2026 - 25.6 max log FLOP (43 septillion) available - TAI takes 34.1 log FLOP (13 decillion) - log $ 15.9 to buy TAI (7 quadrillion) vs. willingness to pay log $ 7.4 (24 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2027 - 25.8 max log FLOP (64 septillion) available - TAI takes 33.9 log FLOP (8 decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 7.5 (30 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2028 - 26.0 max log FLOP (97 septillion) available - TAI takes 33.7 log FLOP (5 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 7.6 (38 million) - 18.4 log FLOPS per $ (3 quintillion)
# Year: 2029 - 26.2 max log FLOP (146 septillion) available - TAI takes 33.5 log FLOP (3 decillion) - log $ 15.0 to buy TAI (1 quadrillion) vs. willingness to pay log $ 7.7 (47 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2030 - 26.3 max log FLOP (219 septillion) available - TAI takes 33.4 log FLOP (2 decillion) - log $ 14.8 to buy TAI (597 trillion) vs. willingness to pay log $ 7.8 (58 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2031 - 26.5 max log FLOP (329 septillion) available - TAI takes 33.2 log FLOP (1 decillion) - log $ 14.5 to buy TAI (322 trillion) vs. willingness to pay log $ 7.9 (72 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2032 - 26.7 max log FLOP (495 septillion) available - TAI takes 33.0 log FLOP (961 nonillion) - log $ 14.2 to buy TAI (175 trillion) vs. willingness to pay log $ 8.0 (90 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2033 - 26.9 max log FLOP (743 septillion) available - TAI takes 32.8 log FLOP (636 nonillion) - log $ 14.0 to buy TAI (96 trillion) vs. willingness to pay log $ 8.0 (112 million) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2034 - 27.0 max log FLOP (1 octillion) available - TAI takes 32.6 log FLOP (427 nonillion) - log $ 13.7 to buy TAI (53 trillion) vs. willingness to pay log $ 8.1 (139 million) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2035 - 27.2 max log FLOP (2 octillion) available - TAI takes 32.5 log FLOP (292 nonillion) - log $ 13.5 to buy TAI (30 trillion) vs. willingness to pay log $ 8.2 (173 million) - 19.0 log FLOPS per $ (10 quintillion)
# Year: 2036 - 27.4 max log FLOP (3 octillion) available - TAI takes 32.3 log FLOP (205 nonillion) - log $ 13.2 to buy TAI (17 trillion) vs. willingness to pay log $ 8.3 (215 million) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2037 - 27.6 max log FLOP (4 octillion) available - TAI takes 32.2 log FLOP (149 nonillion) - log $ 13.0 to buy TAI (11 trillion) vs. willingness to pay log $ 8.4 (266 million) - 19.2 log FLOPS per $ (14 quintillion)
# Year: 2038 - 27.8 max log FLOP (6 octillion) available - TAI takes 32.1 log FLOP (113 nonillion) - log $ 12.8 to buy TAI (7 trillion) vs. willingness to pay log $ 8.5 (331 million) - 19.2 log FLOPS per $ (17 quintillion)
# Year: 2039 - 27.9 max log FLOP (8 octillion) available - TAI takes 32.0 log FLOP (90 nonillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 8.6 (410 million) - 19.3 log FLOPS per $ (21 quintillion)
# Year: 2040 - 28.1 max log FLOP (13 octillion) available - TAI takes 31.9 log FLOP (75 nonillion) - log $ 12.5 to buy TAI (3 trillion) vs. willingness to pay log $ 8.7 (508 million) - 19.4 log FLOPS per $ (25 quintillion)
# Year: 2041 - 28.3 max log FLOP (19 octillion) available - TAI takes 31.8 log FLOP (65 nonillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 8.8 (629 million) - 19.5 log FLOPS per $ (30 quintillion)
# Year: 2042 - 28.5 max log FLOP (28 octillion) available - TAI takes 31.8 log FLOP (59 nonillion) - log $ 12.2 to buy TAI (2 trillion) vs. willingness to pay log $ 8.9 (777 million) - 19.6 log FLOPS per $ (37 quintillion)
# Year: 2043 - 28.6 max log FLOP (42 octillion) available - TAI takes 31.7 log FLOP (55 nonillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 9.0 (959 million) - 19.6 log FLOPS per $ (44 quintillion)
# Year: 2044 - 28.8 max log FLOP (63 octillion) available - TAI takes 31.7 log FLOP (52 nonillion) - log $ 12.0 to buy TAI (983 billion) vs. willingness to pay log $ 9.1 (1 billion) - 19.7 log FLOPS per $ (53 quintillion)
# Year: 2045 - 29.0 max log FLOP (94 octillion) available - TAI takes 31.7 log FLOP (51 nonillion) - log $ 11.9 to buy TAI (788 billion) vs. willingness to pay log $ 9.2 (1 billion) - 19.8 log FLOPS per $ (65 quintillion)
# Year: 2046 - 29.1 max log FLOP (139 octillion) available - TAI takes 31.7 log FLOP (50 nonillion) - log $ 11.8 to buy TAI (638 billion) vs. willingness to pay log $ 9.3 (2 billion) - 19.9 log FLOPS per $ (78 quintillion)
# Year: 2047 - 29.3 max log FLOP (205 octillion) available - TAI takes 31.7 log FLOP (49 nonillion) - log $ 11.7 to buy TAI (521 billion) vs. willingness to pay log $ 9.3 (2 billion) - 20.0 log FLOPS per $ (94 quintillion)
# Year: 2048 - 29.5 max log FLOP (302 octillion) available - TAI takes 31.7 log FLOP (49 nonillion) - log $ 11.6 to buy TAI (427 billion) vs. willingness to pay log $ 9.4 (3 billion) - 20.1 log FLOPS per $ (114 quintillion)
# Year: 2049 - 29.6 max log FLOP (443 octillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.5 to buy TAI (351 billion) vs. willingness to pay log $ 9.5 (3 billion) - 20.1 log FLOPS per $ (138 quintillion)
# Year: 2050 - 29.8 max log FLOP (646 octillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.5 to buy TAI (290 billion) vs. willingness to pay log $ 9.6 (4 billion) - 20.2 log FLOPS per $ (166 quintillion)
# Year: 2051 - 30.0 max log FLOP (937 octillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.4 to buy TAI (239 billion) vs. willingness to pay log $ 9.7 (5 billion) - 20.3 log FLOPS per $ (201 quintillion)
# Year: 2052 - 30.1 max log FLOP (1 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.3 to buy TAI (197 billion) vs. willingness to pay log $ 9.7 (6 billion) - 20.4 log FLOPS per $ (243 quintillion)
# Year: 2053 - 30.3 max log FLOP (2 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.2 to buy TAI (163 billion) vs. willingness to pay log $ 9.8 (7 billion) - 20.5 log FLOPS per $ (293 quintillion)
# Year: 2054 - 30.4 max log FLOP (3 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.1 to buy TAI (135 billion) vs. willingness to pay log $ 9.9 (8 billion) - 20.5 log FLOPS per $ (355 quintillion)
# Year: 2055 - 30.6 max log FLOP (4 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.0 to buy TAI (112 billion) vs. willingness to pay log $ 10.0 (9 billion) - 20.6 log FLOPS per $ (429 quintillion)
# Year: 2056 - 30.7 max log FLOP (5 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 11.0 to buy TAI (92 billion) vs. willingness to pay log $ 10.0 (10 billion) - 20.7 log FLOPS per $ (518 quintillion)
# Year: 2057 - 30.9 max log FLOP (7 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.9 to buy TAI (76 billion) vs. willingness to pay log $ 10.1 (12 billion) - 20.8 log FLOPS per $ (626 quintillion)
# Year: 2058 - 31.0 max log FLOP (10 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.8 to buy TAI (63 billion) vs. willingness to pay log $ 10.1 (14 billion) - 20.9 log FLOPS per $ (756 quintillion)
# Year: 2059 - 31.1 max log FLOP (14 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.7 to buy TAI (52 billion) vs. willingness to pay log $ 10.2 (15 billion) - 21.0 log FLOPS per $ (914 quintillion)
# Year: 2060 - 31.3 max log FLOP (19 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.6 to buy TAI (43 billion) vs. willingness to pay log $ 10.2 (17 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2061 - 31.4 max log FLOP (25 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.6 to buy TAI (36 billion) vs. willingness to pay log $ 10.3 (19 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2062 - 31.5 max log FLOP (33 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.5 to buy TAI (30 billion) vs. willingness to pay log $ 10.3 (20 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2063 - 31.6 max log FLOP (43 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.4 to buy TAI (25 billion) vs. willingness to pay log $ 10.3 (22 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2064 - 31.7 max log FLOP (55 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.3 to buy TAI (20 billion) vs. willingness to pay log $ 10.4 (24 billion) - 21.4 log FLOPS per $ (2 sextillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.3002
# /!\ FLOPs for TAI sufficient but needs 4.4 more years to solve non-scaling issues
# Year: 2065 - 31.9 max log FLOP (71 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.2 to buy TAI (17 billion) vs. willingness to pay log $ 10.4 (25 billion) - 21.5 log FLOPS per $ (3 sextillion)
# /!\ FLOPs for TAI sufficient but needs 3.4 more years to solve non-scaling issues
# Year: 2066 - 32.0 max log FLOP (91 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.1 to buy TAI (14 billion) vs. willingness to pay log $ 10.4 (27 billion) - 21.5 log FLOPS per $ (3 sextillion)
# /!\ FLOPs for TAI sufficient but needs 2.4 more years to solve non-scaling issues
# Year: 2067 - 32.1 max log FLOP (116 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.1 to buy TAI (12 billion) vs. willingness to pay log $ 10.4 (28 billion) - 21.6 log FLOPS per $ (4 sextillion)
# /!\ FLOPs for TAI sufficient but needs 1.4 more years to solve non-scaling issues
# Year: 2068 - 32.2 max log FLOP (147 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 10.0 to buy TAI (10 billion) vs. willingness to pay log $ 10.5 (29 billion) - 21.7 log FLOPS per $ (5 sextillion)
# /!\ FLOPs for TAI sufficient but needs 0.4 more years to solve non-scaling issues
# Year: 2069 - 32.3 max log FLOP (185 nonillion) available - TAI takes 31.7 log FLOP (48 nonillion) - log $ 9.9 to buy TAI (8 billion) vs. willingness to pay log $ 10.5 (31 billion) - 21.8 log FLOPS per $ (6 sextillion)
# --- /!\ TAI CREATED in 2069
# ## RUN 5 ##
# It takes 30.9 log FLOPs (~8 nonillion) for transformative capabilities.
# Every 1.6 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 3.3 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.6 log 2022$USD (~365 million) and this increases by 4.5x per year to a max of 0.0006% of GDP. GDP grows at a rate of 1.021x per year.
# If a non-scaling delay happens, it will take an additional 13.2 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.6 max log FLOP (356 septillion) available - TAI takes 30.9 log FLOP (8 nonillion) - log $ 12.9 to buy TAI (8 trillion) vs. willingness to pay log $ 8.6 (356 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.7 max log FLOP (511 septillion) available - TAI takes 30.7 log FLOP (5 nonillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 8.6 (414 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 26.9 max log FLOP (733 septillion) available - TAI takes 30.5 log FLOP (3 nonillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 8.7 (482 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 27.0 max log FLOP (1 octillion) available - TAI takes 30.3 log FLOP (2 nonillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 8.7 (560 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.2 max log FLOP (2 octillion) available - TAI takes 30.2 log FLOP (1 nonillion) - log $ 11.8 to buy TAI (638 billion) vs. willingness to pay log $ 8.8 (651 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2028 - 27.3 max log FLOP (2 octillion) available - TAI takes 30.0 log FLOP (985 octillion) - log $ 11.5 to buy TAI (346 billion) vs. willingness to pay log $ 8.9 (756 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2029 - 27.5 max log FLOP (3 octillion) available - TAI takes 29.8 log FLOP (667 octillion) - log $ 11.3 to buy TAI (190 billion) vs. willingness to pay log $ 8.9 (877 million) - 18.5 log FLOPS per $ (4 quintillion)
# Year: 2030 - 27.6 max log FLOP (4 octillion) available - TAI takes 29.7 log FLOP (461 octillion) - log $ 11.0 to buy TAI (106 billion) vs. willingness to pay log $ 9.0 (1 billion) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2031 - 27.8 max log FLOP (6 octillion) available - TAI takes 29.5 log FLOP (327 octillion) - log $ 10.8 to buy TAI (61 billion) vs. willingness to pay log $ 9.1 (1 billion) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2032 - 28.0 max log FLOP (9 octillion) available - TAI takes 29.4 log FLOP (240 octillion) - log $ 10.6 to buy TAI (36 billion) vs. willingness to pay log $ 9.1 (1 billion) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2033 - 28.1 max log FLOP (13 octillion) available - TAI takes 29.3 log FLOP (183 octillion) - log $ 10.4 to buy TAI (23 billion) vs. willingness to pay log $ 9.2 (2 billion) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2034 - 28.3 max log FLOP (18 octillion) available - TAI takes 29.2 log FLOP (146 octillion) - log $ 10.2 to buy TAI (15 billion) vs. willingness to pay log $ 9.3 (2 billion) - 19.0 log FLOPS per $ (10 quintillion)
# Year: 2035 - 28.4 max log FLOP (26 octillion) available - TAI takes 29.1 log FLOP (123 octillion) - log $ 10.0 to buy TAI (10 billion) vs. willingness to pay log $ 9.3 (2 billion) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2036 - 28.6 max log FLOP (37 octillion) available - TAI takes 29.0 log FLOP (107 octillion) - log $ 9.8 to buy TAI (7 billion) vs. willingness to pay log $ 9.4 (2 billion) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2037 - 28.7 max log FLOP (52 octillion) available - TAI takes 29.0 log FLOP (97 octillion) - log $ 9.7 to buy TAI (5 billion) vs. willingness to pay log $ 9.4 (3 billion) - 19.3 log FLOPS per $ (19 quintillion)
# Year: 2038 - 28.9 max log FLOP (73 octillion) available - TAI takes 29.0 log FLOP (91 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 9.5 (3 billion) - 19.4 log FLOPS per $ (23 quintillion)
# Year: 2039 - 29.0 max log FLOP (103 octillion) available - TAI takes 28.9 log FLOP (86 octillion) - log $ 9.5 to buy TAI (3 billion) vs. willingness to pay log $ 9.6 (4 billion) - 19.5 log FLOPS per $ (29 quintillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.56
# --- /!\ TAI CREATED in 2039

# %%
# %%time
tai_years = bayes.bayesnet(define_event,
                           find=lambda e: e['tai_year'],
                           verbose=True,
                           raw=True,
                           dump_cache_file='caches/tai_years',
                           reload_cache=True,
                           cores=7,
                           n=RUNS)
# Out:
# Reloading cache...
# Generating Bayes net with 7 cores...
# 10024it [02:58, 56.03it/s]
# Shuffling data...
# Waiting for other cores...
# Collecting data...
# 100%|██████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 195.61it/s]
# ...Collected!
# Caching in-memory...
# ...Cached!
# Writing cache to file `caches/tai_years.sqcache`...
# ...Cached!
# ...Finding
# ...Found!
# ...All done!
# CPU times: user 1min 55s, sys: 2.04 s, total: 1min 57s
# Wall time: 2min 59s

# %%
out = sq.get_percentiles(tai_years)
[str(o[0]) + '%: ' + (str(int(o[1])) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR)) for o in out.items()]

# NOTE: Ajeya's numbers should output something very close to:
# '5%': 2027,
# '10%: 2031',
# '20%: 2037',
# '30%: 2042',
# '40%: 2047',
# '50%: 2053',
# '60%: 2061',
# '70%: 2073',
# '80%: >2100',
# '90%: >2100',
# '95%: >2100'

# My latest numbers (2022 Aug 27 8:43PM CT):
# '1%: 2024',
# '5%: 2027',
# '10%: 2029',
# '20%: 2033',
# '30%: 2038',
# '40%: 2045',
# '50%: 2054',
# '60%: 2064',
# '70%: 2079',
# '80%: 2116',
# '90%: >2222',
# '95%: >2222',
# '99%: >2222']
# Out:
# ['1%: 2025',
#  '5%: 2028',
#  '10%: 2030',
#  '20%: 2036',
#  '30%: 2042',
#  '40%: 2048',
#  '50%: 2056',
#  '60%: 2066',
#  '70%: 2082',
#  '80%: >2123',
#  '90%: >2123',
#  '95%: >2123',
#  '99%: >2123']

# %%
[str(o[0]) + '%: ' + (str(int(o[1]) - CURRENT_YEAR) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR - CURRENT_YEAR)) + ' years from now' for o in out.items()]
# Out:
# ['1%: 2 years from now',
#  '5%: 5 years from now',
#  '10%: 7 years from now',
#  '20%: 13 years from now',
#  '30%: 19 years from now',
#  '40%: 25 years from now',
#  '50%: 33 years from now',
#  '60%: 43 years from now',
#  '70%: 59 years from now',
#  '80%: >100 years from now',
#  '90%: >100 years from now',
#  '95%: >100 years from now',
#  '99%: >100 years from now']

# %%
tai_years_ = np.array([MAX_YEAR + 1 if t > MAX_YEAR else t for t in tai_years])
count, bins_count = np.histogram(tai_years_, bins=(MAX_YEAR - CURRENT_YEAR))
bins = np.round(np.array([b for b in bins_count[1:] if b <= MAX_YEAR]))
pdf = count / sum(count)
cdf = np.cumsum(pdf)

plt.plot(bins, cdf[:len(bins)], label='CDF')
plt.legend()
plt.show()

# %%
d_ = dict(zip(years, cdf[:len(bins)]))

def bin_tai_yrs(low=None, hi=None):
    low = CURRENT_YEAR if low is None else low
    out = 1 - d_[low] if hi is None else d_[hi] - d_[low]
    return round(out * 100, 1)

print('<2024: {}%'.format(bin_tai_yrs(hi=2024)))
print('2025-2029: {}%'.format(bin_tai_yrs(2025, 2029)))
print('2030-2039: {}%'.format(bin_tai_yrs(2030, 2039)))
print('2040-2049: {}%'.format(bin_tai_yrs(2040, 2049)))
print('2050-2059: {}%'.format(bin_tai_yrs(2050, 2059)))
print('2060-2069: {}%'.format(bin_tai_yrs(2060, 2069)))
print('2070-2079: {}%'.format(bin_tai_yrs(2070, 2079)))
print('2080-2089: {}%'.format(bin_tai_yrs(2080, 2089)))
print('2090-2099: {}%'.format(bin_tai_yrs(2090, 2099)))
print('2100-2109: {}%'.format(bin_tai_yrs(2100, 2109)))
print('2110-2119: {}%'.format(bin_tai_yrs(2110, 2119)))
print('>2120: {}%'.format(bin_tai_yrs(low=2120)))
# Out:
# <2024: 0.7%
# 2025-2029: 7.9%
# 2030-2039: 16.1%
# 2040-2049: 12.8%
# 2050-2059: 11.0%
# 2060-2069: 7.5%
# 2070-2079: 5.2%
# 2080-2089: 3.5%
# 2090-2099: 2.0%
# 2100-2109: 1.7%
# 2110-2119: 1.1%
# >2120: 21.5%

# %%
pdf_smoothed = savitzky_golay(pdf[:len(bins)], 51, 3)
plt.plot(bins, pdf_smoothed, label='PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
cdf[:len(bins)]
# Out:
# array([0.0059, 0.0125, 0.0281, 0.0492, 0.0648, 0.0846, 0.1071, 0.1214,
#        0.1414, 0.1616, 0.1768, 0.1957, 0.2167, 0.2329, 0.2499, 0.2644,
#        0.2827, 0.2991, 0.3143, 0.3289, 0.3432, 0.3577, 0.3665, 0.3882,
#        0.4001, 0.415 , 0.4267, 0.4396, 0.4507, 0.4638, 0.4772, 0.4913,
#        0.5055, 0.5167, 0.5278, 0.5396, 0.5492, 0.5581, 0.5668, 0.5768,
#        0.5851, 0.5901, 0.6006, 0.6094, 0.6189, 0.6263, 0.633 , 0.6413,
#        0.6488, 0.6559, 0.661 , 0.6665, 0.6701, 0.6749, 0.682 , 0.6885,
#        0.6934, 0.698 , 0.7028, 0.7058, 0.7094, 0.7138, 0.7192, 0.7227,
#        0.7264, 0.7289, 0.7327, 0.7348, 0.7377, 0.7396, 0.7428, 0.7447,
#        0.7465, 0.7481, 0.7502, 0.752 , 0.7544, 0.757 , 0.759 , 0.7616,
#        0.7649, 0.7664, 0.7684, 0.7697, 0.7713, 0.7729, 0.7735, 0.7736,
#        0.7747, 0.7756, 0.7762, 0.7769, 0.7779, 0.7799, 0.7801, 0.7831,
#        0.7841, 0.7852, 0.7867])

# %%
pdf[:len(bins)]
# Out:
# array([0.0059, 0.0066, 0.0156, 0.0211, 0.0156, 0.0198, 0.0225, 0.0143,
#        0.02  , 0.0202, 0.0152, 0.0189, 0.021 , 0.0162, 0.017 , 0.0145,
#        0.0183, 0.0164, 0.0152, 0.0146, 0.0143, 0.0145, 0.0088, 0.0217,
#        0.0119, 0.0149, 0.0117, 0.0129, 0.0111, 0.0131, 0.0134, 0.0141,
#        0.0142, 0.0112, 0.0111, 0.0118, 0.0096, 0.0089, 0.0087, 0.01  ,
#        0.0083, 0.005 , 0.0105, 0.0088, 0.0095, 0.0074, 0.0067, 0.0083,
#        0.0075, 0.0071, 0.0051, 0.0055, 0.0036, 0.0048, 0.0071, 0.0065,
#        0.0049, 0.0046, 0.0048, 0.003 , 0.0036, 0.0044, 0.0054, 0.0035,
#        0.0037, 0.0025, 0.0038, 0.0021, 0.0029, 0.0019, 0.0032, 0.0019,
#        0.0018, 0.0016, 0.0021, 0.0018, 0.0024, 0.0026, 0.002 , 0.0026,
#        0.0033, 0.0015, 0.002 , 0.0013, 0.0016, 0.0016, 0.0006, 0.0001,
#        0.0011, 0.0009, 0.0006, 0.0007, 0.001 , 0.002 , 0.0002, 0.003 ,
#        0.001 , 0.0011, 0.0015])

# %%
## TODO: Update all

cotra_2020_cdf = [0.0214, 0.0272, 0.0328, 0.0385, 0.0458, 0.0551, 0.0641, 0.0721,
       0.0827, 0.0923, 0.1061, 0.1199, 0.1343, 0.1574, 0.175 , 0.1917,
       0.2108, 0.2321, 0.251 , 0.2825, 0.3001, 0.3177, 0.3317, 0.3531,
       0.3829, 0.4089, 0.4372, 0.4606, 0.4829, 0.4944, 0.504 , 0.5147,
       0.5243, 0.5335, 0.5423, 0.5521, 0.5608, 0.5719, 0.5826, 0.5922,
       0.6011, 0.6096, 0.6209, 0.6379, 0.6524, 0.6682, 0.682 , 0.6948,
       0.7084, 0.7207, 0.7314, 0.7362, 0.7407, 0.7456, 0.7506, 0.755 ,
       0.7594, 0.7626, 0.7668, 0.7698, 0.7725, 0.7745, 0.7765, 0.7775,
       0.7793, 0.7801, 0.781 , 0.7818, 0.7827, 0.7833, 0.7843, 0.7847,
       0.7852, 0.7858, 0.7861, 0.7868, 0.7874, 0.7882, 0.7887, 0.7891,
       0.7895, 0.7908, 0.7916, 0.7918, 0.7926, 0.7929, 0.7933, 0.7936,
       0.7941, 0.7949, 0.795 , 0.7954, 0.7957, 0.7962, 0.7969, 0.7976,
       0.7981, 0.7987, 0.7996, 0.8002, 0.8004, 0.801 , 0.8015, 0.8021,
       0.8025, 0.8029, 0.8034, 0.8041, 0.8045, 0.8052, 0.8059, 0.806 ,
       0.8066, 0.8071, 0.8079, 0.8087, 0.8089, 0.8093, 0.8093, 0.8095,
       0.8105, 0.8109, 0.8114, 0.8118, 0.8128, 0.8132, 0.8139, 0.8139,
       0.8144, 0.8149, 0.8154, 0.8162, 0.8167, 0.8173, 0.8177, 0.8185,
       0.8196, 0.82  , 0.821 , 0.8217, 0.8224, 0.8233, 0.8244, 0.8247,
       0.8254, 0.8262, 0.8267, 0.8274, 0.8277, 0.8288, 0.8294, 0.8298,
       0.8305, 0.8318, 0.8328, 0.8335, 0.8343, 0.8347, 0.8351, 0.8361,
       0.837 , 0.8376, 0.8385, 0.8398, 0.8404, 0.8413, 0.8419, 0.8427,
       0.8437, 0.8448, 0.8458, 0.8462, 0.8471, 0.8482, 0.8487, 0.8491,
       0.8498, 0.8505, 0.8507, 0.8511, 0.8519, 0.8526, 0.8534, 0.8542,
       0.855 , 0.8554, 0.8559, 0.8565, 0.857 , 0.8575, 0.8581, 0.8587,
       0.8592, 0.86  , 0.8605, 0.861 , 0.8615, 0.862 , 0.8629]
cotra_2020_pdf = np.append(np.array(cotra_2020_cdf[0]), np.diff(cotra_2020_cdf[:len(bins)]))
cotra_2020_pdf_smoothed = savitzky_golay(cotra_2020_pdf[:len(bins)], 51, 3)

cotra_2022_cdf = [0.0616, 0.0747, 0.0873, 0.1015, 0.118 , 0.1365, 0.1564, 0.1758,
       0.1981, 0.2188, 0.2531, 0.2768, 0.2975, 0.3193, 0.3481, 0.3728,
       0.4124, 0.433 , 0.4557, 0.4742, 0.4981, 0.5348, 0.569 , 0.6032,
       0.627 , 0.6404, 0.6507, 0.6611, 0.6701, 0.6801, 0.6893, 0.697 ,
       0.7051, 0.7115, 0.7186, 0.7252, 0.7331, 0.7411, 0.749 , 0.7577,
       0.7691, 0.7785, 0.7881, 0.799 , 0.807 , 0.8161, 0.8233, 0.8303,
       0.8348, 0.839 , 0.8429, 0.8462, 0.8494, 0.8517, 0.8532, 0.8553,
       0.8566, 0.8588, 0.8602, 0.862 , 0.8633, 0.864 , 0.8648, 0.8654,
       0.8662, 0.867 , 0.8672, 0.8677, 0.8683, 0.8686, 0.8689, 0.8689,
       0.8692, 0.8695, 0.8699, 0.8703, 0.8709, 0.8711, 0.8713, 0.8715,
       0.8719, 0.8721, 0.8727, 0.873 , 0.8736, 0.8739, 0.8742, 0.8746,
       0.875 , 0.8751, 0.8754, 0.8757, 0.8763, 0.8764, 0.8768, 0.8772,
       0.8775, 0.8775, 0.8776, 0.8779, 0.878 , 0.8781, 0.8783, 0.8789,
       0.8792, 0.8794, 0.8795, 0.8798, 0.8805, 0.8808, 0.8814, 0.8819,
       0.8822, 0.8826, 0.8827, 0.8828, 0.8832, 0.8834, 0.8837, 0.8839,
       0.8842, 0.8848, 0.8857, 0.8859, 0.8861, 0.8863, 0.8866, 0.8869,
       0.8869, 0.8873, 0.8878, 0.8889, 0.8896, 0.8904, 0.8906, 0.8911,
       0.8915, 0.892 , 0.8929, 0.8934, 0.8937, 0.8942, 0.8946, 0.8954,
       0.8959, 0.8963, 0.8969, 0.8972, 0.8975, 0.8984, 0.8988, 0.8993,
       0.8999, 0.9004, 0.9007, 0.9015, 0.9019, 0.9021, 0.9026, 0.9031,
       0.9037, 0.9041, 0.9048, 0.9054, 0.9057, 0.9062, 0.9067, 0.9075,
       0.9084, 0.9088, 0.909 , 0.9101, 0.9106, 0.9108, 0.9114, 0.9116,
       0.9121, 0.9127, 0.913 , 0.9137, 0.9144, 0.9147, 0.9154, 0.9159,
       0.9161, 0.9166, 0.9173, 0.9177, 0.9185, 0.9189, 0.9193, 0.9195,
       0.9195, 0.9198, 0.9204, 0.9205, 0.921 , 0.9216, 0.9221]
cotra_2022_pdf = np.append(np.array(cotra_2022_cdf[0]), np.diff(cotra_2022_cdf[:len(bins)]))
cotra_2022_pdf_smoothed = savitzky_golay(cotra_2022_pdf[:len(bins)], 51, 3)

peter_cdf = [0.0024, 0.0045, 0.0106, 0.0179, 0.0258, 0.0345, 0.0423, 0.0522,
       0.0638, 0.076 , 0.0885, 0.1028, 0.1165, 0.1332, 0.1498, 0.1669,
       0.1835, 0.2004, 0.2162, 0.2369, 0.2551, 0.2711, 0.2861, 0.3021,
       0.3184, 0.3314, 0.347 , 0.3589, 0.3729, 0.3882, 0.4022, 0.4142,
       0.4268, 0.4394, 0.4498, 0.4614, 0.471 , 0.4828, 0.4929, 0.5014,
       0.5097, 0.5179, 0.5275, 0.5359, 0.5456, 0.5545, 0.5634, 0.5711,
       0.5808, 0.5891, 0.5949, 0.6039, 0.6125, 0.6198, 0.6257, 0.6331,
       0.6392, 0.6453, 0.6503, 0.6571, 0.6629, 0.6684, 0.674 , 0.6803,
       0.6858, 0.6904, 0.6956, 0.7006, 0.7052, 0.7099, 0.7146, 0.7179,
       0.7209, 0.7253, 0.7293, 0.7325, 0.7352, 0.7388, 0.7421, 0.7448,
       0.7482, 0.7503, 0.7523, 0.7539, 0.7566, 0.7591, 0.7616, 0.7632,
       0.7667, 0.7685, 0.7699, 0.7714, 0.7729, 0.7749, 0.7769, 0.779 ,
       0.7808, 0.7829, 0.7849, 0.787 , 0.7878, 0.7895, 0.7902, 0.792 ,
       0.7931, 0.794 , 0.7952, 0.7967, 0.7981, 0.7993, 0.8003, 0.8021,
       0.8031, 0.8044, 0.8049, 0.8058, 0.8063, 0.8072, 0.8079, 0.8083,
       0.8091, 0.8096, 0.8101, 0.8111, 0.8116, 0.8126, 0.8131, 0.8142,
       0.815 , 0.8157, 0.8161, 0.817 , 0.8178, 0.8192, 0.8194, 0.8206,
       0.8209, 0.8211, 0.8217, 0.8221, 0.823 , 0.8234, 0.8237, 0.8245,
       0.825 , 0.8253, 0.8259, 0.8265, 0.8273, 0.8279, 0.8285, 0.8287,
       0.8294, 0.8297, 0.8302, 0.8302, 0.8311, 0.8315, 0.8316, 0.8318,
       0.832 , 0.8321, 0.8324, 0.8327, 0.8331, 0.8335, 0.8337, 0.8341,
       0.8342, 0.8344, 0.8347, 0.8349, 0.8353, 0.8359, 0.8365, 0.8371,
       0.8373, 0.8374, 0.8375, 0.8379, 0.8382, 0.8385, 0.8391, 0.8395,
       0.8398, 0.84  , 0.8406, 0.841 , 0.8413, 0.8417, 0.8419, 0.842 ,
       0.8426, 0.8427, 0.8432, 0.8434, 0.8439, 0.8444, 0.8448]
peter_pdf = np.append(np.array(peter_cdf[0]), np.diff(peter_cdf[:len(bins)]))
peter_pdf_smoothed = savitzky_golay(peter_pdf[:len(bins)], 51, 3)

plt.plot(bins[:99], cotra_2020_cdf[:99], label='Cotra 2020 CDF')
plt.plot(bins[:99], cotra_2022_cdf[:99], label='Cotra 2022 CDF (guess)')
plt.plot(bins[:99], peter_cdf[:99], label='Wildeford CDF')
plt.legend()
plt.show()

plt.plot(bins[:99], cotra_2020_pdf_smoothed[:99], label='Cotra 2020 PDF (smoothed)')
plt.plot(bins[:99], cotra_2022_pdf_smoothed[:99], label='Cotra 2022 PDF (guess, smoothed)')
plt.plot(bins[:99], peter_pdf_smoothed[:99], label='Wildeford PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## Sensitivity Analysis

# %%
print('## Default ##')
results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                      tai_flop_size_=36,
                                      nonscaling_delay_=0,
                                      algo_doubling_rate_=2,
                                      possible_algo_reduction_=2,
                                      initial_flops_per_dollar_=10 ** 18,
                                      flops_halving_rate_=2.5,
                                      max_flops_per_dollar_=10 ** 24,
                                      initial_pay_=10*M,
                                      gdp_growth_=1.03,
                                      max_gdp_frac_=1/1600,
                                      willingness_ramp_=1,
                                      spend_doubling_time_=2.5,
                                      initial_chance_of_nonscaling_issue_=0,
                                      final_chance_of_nonscaling_issue_=0,
                                      nonscaling_issue_bottom_year_=0,
                                      willingness_spend_horizon_=1,
                                      print_diagnostic=False), n=1000)
print('{}: {}'.format(t,
                      ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                       '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                       '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Default ##
# 59: [2068, 2068, 2068]

# %%
print('## TAI FLOP Size ##')
for t in range(20, 43):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=t,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(t,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## TAI FLOP Size ##
# 20: [2023, 2023, 2023]
# 21: [2023, 2023, 2023]
# 22: [2023, 2023, 2023]
# 23: [2023, 2023, 2023]
# 24: [2023, 2023, 2023]
# 25: [2024, 2024, 2024]
# 26: [2026, 2026, 2026]
# 27: [2029, 2029, 2029]
# 28: [2031, 2031, 2031]
# 29: [2034, 2034, 2034]
# 30: [2037, 2037, 2037]
# 31: [2041, 2041, 2041]
# 32: [2045, 2045, 2045]
# 33: [2049, 2049, 2049]
# 34: [2054, 2054, 2054]
# 35: [2061, 2061, 2061]
# 36: [2068, 2068, 2068]
# 37: [2092, 2092, 2092]
# 38: [2124, 2124, 2124]
# 39: [2124, 2124, 2124]
# 40: [2124, 2124, 2124]
# 41: [2124, 2124, 2124]
# 42: [2124, 2124, 2124]

# %%
print('## GDP Growth ##')
for g in range(0, 5):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1 + g/100,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + g / 100,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## GDP Growth ##
# 1.0: [2078, 2078, 2078]
# 1.01: [2073, 2073, 2073]
# 1.02: [2070, 2070, 2070]
# 1.03: [2068, 2068, 2068]
# 1.04: [2067, 2067, 2067]

# %%
print('## Max GDP Frac ##')
for g in [1/(500*K), 1/(250*K), 1/(100*K), 1/(50*K), 1/(10*K), 5/(10*K),
          1/2000, 1/1500, 1/1000, 2/1000, 3/1000, 4/1000, 5/1000, 1/100,
          2/100, 3/100, 4/100]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=g,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(g,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Max GDP Frac ##
# 2e-06: [2124, 2124, 2124]
# 4e-06: [2124, 2124, 2124]
# 1e-05: [2124, 2124, 2124]
# 2e-05: [2124, 2124, 2124]
# 0.0001: [2081, 2081, 2081]
# 0.0005: [2069, 2069, 2069]
# 0.0005: [2069, 2069, 2069]
# 0.0006666666666666666: [2068, 2068, 2068]
# 0.001: [2067, 2067, 2067]
# 0.002: [2065, 2065, 2065]
# 0.003: [2064, 2064, 2064]
# 0.004: [2063, 2063, 2063]
# 0.005: [2063, 2063, 2063]
# 0.01: [2062, 2062, 2062]
# 0.02: [2061, 2061, 2061]
# 0.03: [2061, 2061, 2061]
# 0.04: [2061, 2061, 2061]

# %%
print('## Spend Doubling Time ##')
for d in range(0, 50):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=1 + d / 10,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Spend Doubling Time ##
# 1.0: [2068, 2068, 2068]
# 1.1: [2068, 2068, 2068]
# 1.2: [2068, 2068, 2068]
# 1.3: [2068, 2068, 2068]
# 1.4: [2068, 2068, 2068]
# 1.5: [2068, 2068, 2068]
# 1.6: [2068, 2068, 2068]
# 1.7: [2068, 2068, 2068]
# 1.8: [2068, 2068, 2068]
# 1.9: [2068, 2068, 2068]
# 2.0: [2068, 2068, 2068]
# 2.1: [2068, 2068, 2068]
# 2.2: [2068, 2068, 2068]
# 2.3: [2068, 2068, 2068]
# 2.4: [2068, 2068, 2068]
# 2.5: [2068, 2068, 2068]
# 2.6: [2068, 2068, 2068]
# 2.7: [2069, 2069, 2069]
# 2.8: [2069, 2069, 2069]
# 2.9: [2069, 2069, 2069]
# 3.0: [2069, 2069, 2069]
# 3.1: [2069, 2069, 2069]
# 3.2: [2069, 2069, 2069]
# 3.3: [2070, 2070, 2070]
# 3.4: [2070, 2070, 2070]
# 3.5: [2070, 2070, 2070]
# 3.6: [2070, 2070, 2070]
# 3.7: [2071, 2071, 2071]
# 3.8: [2071, 2071, 2071]
# 3.9: [2072, 2072, 2072]
# 4.0: [2072, 2072, 2072]
# 4.1: [2072, 2072, 2072]
# 4.2: [2073, 2073, 2073]
# 4.3: [2073, 2073, 2073]
# 4.4: [2074, 2074, 2074]
# 4.5: [2074, 2074, 2074]
# 4.6: [2075, 2075, 2075]
# 4.7: [2075, 2075, 2075]
# 4.8: [2076, 2076, 2076]
# 4.9: [2077, 2077, 2077]
# 5.0: [2077, 2077, 2077]
# 5.1: [2078, 2078, 2078]
# 5.2: [2078, 2078, 2078]
# 5.3: [2079, 2079, 2079]
# 5.4: [2080, 2080, 2080]
# 5.5: [2081, 2081, 2081]
# 5.6: [2081, 2081, 2081]
# 5.7: [2082, 2082, 2082]
# 5.8: [2083, 2083, 2083]
# 5.9: [2084, 2084, 2084]

# %%
print('## Initial FLOPs per dollar ##')
for d in [17, 17.5, 18]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** d,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Initial FLOPs per dollar ##
# 17: [2076, 2076, 2076]
# 17.5: [2072, 2072, 2072]
# 18: [2068, 2068, 2068]

# %%
print('## Initial pay ##')
for p in range(70, 91):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10 ** (p / 10),
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('${}: {}'.format(numerize(10 ** (p / 10)),
                           ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                            '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                            '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Initial pay ##
# $10 million: [2068, 2068, 2068]
# $13 million: [2068, 2068, 2068]
# $16 million: [2068, 2068, 2068]
# $20 million: [2068, 2068, 2068]
# $25 million: [2068, 2068, 2068]
# $32 million: [2068, 2068, 2068]
# $40 million: [2068, 2068, 2068]
# $50 million: [2068, 2068, 2068]
# $63 million: [2068, 2068, 2068]
# $79 million: [2068, 2068, 2068]
# $100 million: [2068, 2068, 2068]
# $126 million: [2068, 2068, 2068]
# $158 million: [2068, 2068, 2068]
# $200 million: [2068, 2068, 2068]
# $251 million: [2068, 2068, 2068]
# $316 million: [2068, 2068, 2068]
# $398 million: [2068, 2068, 2068]
# $501 million: [2068, 2068, 2068]
# $631 million: [2068, 2068, 2068]
# $794 million: [2068, 2068, 2068]
# $1 billion: [2068, 2068, 2068]

# %%
print('## FLOPs halving rate ##')
for f in range(5, 41):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=f / 10,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## FLOPs halving rate ##
# 0.5: [2050, 2050, 2050]
# 0.6: [2050, 2050, 2050]
# 0.7: [2050, 2050, 2050]
# 0.8: [2050, 2050, 2050]
# 0.9: [2050, 2050, 2050]
# 1.0: [2050, 2050, 2050]
# 1.1: [2050, 2050, 2050]
# 1.2: [2051, 2051, 2051]
# 1.3: [2052, 2052, 2052]
# 1.4: [2053, 2053, 2053]
# 1.5: [2054, 2054, 2054]
# 1.6: [2055, 2055, 2055]
# 1.7: [2056, 2056, 2056]
# 1.8: [2058, 2058, 2058]
# 1.9: [2059, 2059, 2059]
# 2.0: [2061, 2061, 2061]
# 2.1: [2062, 2062, 2062]
# 2.2: [2064, 2064, 2064]
# 2.3: [2065, 2065, 2065]
# 2.4: [2067, 2067, 2067]
# 2.5: [2068, 2068, 2068]
# 2.6: [2070, 2070, 2070]
# 2.7: [2072, 2072, 2072]
# 2.8: [2073, 2073, 2073]
# 2.9: [2075, 2075, 2075]
# 3.0: [2076, 2076, 2076]
# 3.1: [2078, 2078, 2078]
# 3.2: [2079, 2079, 2079]
# 3.3: [2081, 2081, 2081]
# 3.4: [2082, 2082, 2082]
# 3.5: [2084, 2084, 2084]
# 3.6: [2085, 2085, 2085]
# 3.7: [2087, 2087, 2087]
# 3.8: [2088, 2088, 2088]
# 3.9: [2089, 2089, 2089]
# 4.0: [2091, 2091, 2091]

# %%
print('## Max FLOPs per dollar ##')
for f in range(20, 31):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** f,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Max FLOPs per dollar ##
# 20: [2124, 2124, 2124]
# 21: [2124, 2124, 2124]
# 22: [2124, 2124, 2124]
# 23: [2092, 2092, 2092]
# 24: [2068, 2068, 2068]
# 25: [2068, 2068, 2068]
# 26: [2068, 2068, 2068]
# 27: [2068, 2068, 2068]
# 28: [2068, 2068, 2068]
# 29: [2068, 2068, 2068]
# 30: [2068, 2068, 2068]

# %%
print('## Willingness ramp ##')
for r in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=r / 10,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Willingness ramp ##
# 0.1: [2061, 2061, 2061]
# 0.2: [2063, 2063, 2063]
# 0.3: [2064, 2064, 2064]
# 0.4: [2065, 2065, 2065]
# 0.5: [2066, 2066, 2066]
# 0.6: [2067, 2067, 2067]
# 0.7: [2067, 2067, 2067]
# 0.8: [2068, 2068, 2068]
# 0.9: [2068, 2068, 2068]
# 1.0: [2068, 2068, 2068]

# %%
print('## Willingness to spend horizon ##')
for y in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(y,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Willingness to spend horizon ##
# 1: [2068, 2068, 2068]
# 2: [2068, 2068, 2068]
# 3: [2067, 2067, 2067]
# 4: [2067, 2067, 2067]
# 5: [2067, 2067, 2067]
# 6: [2067, 2067, 2067]
# 7: [2067, 2067, 2067]
# 8: [2067, 2067, 2067]
# 9: [2067, 2067, 2067]
# 10: [2067, 2067, 2067]

# %%
print('## Algo doubling rate ##')
for d in range(10, 41, 2):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=d / 10,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Algo doubling rate ##
# 1.0: [2067, 2067, 2067]
# 1.2: [2067, 2067, 2067]
# 1.4: [2067, 2067, 2067]
# 1.6: [2067, 2067, 2067]
# 1.8: [2067, 2067, 2067]
# 2.0: [2067, 2067, 2067]
# 2.2: [2067, 2067, 2067]
# 2.4: [2067, 2067, 2067]
# 2.6: [2067, 2067, 2067]
# 2.8: [2068, 2068, 2068]
# 3.0: [2068, 2068, 2068]
# 3.2: [2068, 2068, 2068]
# 3.4: [2068, 2068, 2068]
# 3.6: [2068, 2068, 2068]
# 3.8: [2068, 2068, 2068]
# 4.0: [2068, 2068, 2068]

# %%
print('## Possible algo reduction ##')
for r in range(0, 13):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=r,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Possible algo reduction ##
# 0: [2102, 2102, 2102]
# 1: [2076, 2076, 2076]
# 2: [2067, 2067, 2067]
# 3: [2060, 2060, 2060]
# 4: [2055, 2055, 2055]
# 5: [2053, 2053, 2053]
# 6: [2052, 2052, 2052]
# 7: [2052, 2052, 2052]
# 8: [2052, 2052, 2052]
# 9: [2052, 2052, 2052]
# 10: [2052, 2052, 2052]
# 11: [2052, 2052, 2052]
# 12: [2052, 2052, 2052]

# %%
# TODO: Wildeford meta anchor horizon length
# TODO: Wildeford meta anchor efficiency w/ efficiency-based algorithmic reduction
# TODO: efficiency-based algorithmic reduction vs. regular algorithmic reduction

# %%
get_question(11558)
# Out:
# 11558 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates?
# 6192 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 1, 2031)
# Me -
# * Min: 1800
# * <Min: 0
# * Q1: 482363.462
# * Mid: 4955454.895
# * Q3: 14696518.042
# * >Max: 0.02200000000000002
# * Max: 10000000000
# Metaculus -
# * Min: 1800
# * <Min: 0.0
# * Q1: 3109866.189
# * Mid: 31948526.063
# * Q3: 281004112.704
# * >Max: 0.07401999999999997
# * Max: 10000000000
# -
# 6559 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 1, 2026)
# Me -
# * Min: 3640
# * <Min: 0
# * Q1: 330449.338
# * Mid: 899946.671
# * Q3: 1310339.199
# * >Max: 0.010000000000000009
# * Max: 1000000000
# Metaculus -
# * Min: 3640
# * <Min: 0.0
# * Q1: 618087.295
# * Mid: 5195921.5
# * Q3: 49506740.334
# * >Max: 0.12192999999999998
# * Max: 1000000000
# -
# 6517 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (February 14, 2023)
# Metaculus -
# * Min: 3640
# * <Min: 0.0
# * Q1: 17623.15
# * Mid: 51507.61
# * Q3: 150542.549
# * >Max: 0.029410000000000047
# * Max: 2000000
# -
# 6148 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 14, 2022)
# Resolved as 320532.1027084993
# -

# %%
# https://www.metaculus.com/questions/11558/maximum-compute-used-in-ai-training/
# TODO: Fetch from Metaculus, look side by side
# TODO: Be able to predict back
for y in [2022, 2025, 2030]:
    print('-')
    print('## {} ##'.format(y))
    for i in range(3):
        flops_at_max_ = flops_at_max(initial_gdp=variables['initial_gdp'],
                                     gdp_growth=[1.02, 1.025, 1.03][i],
                                     initial_pay=[10*M, 100*M, 1*B][i],
                                     spend_doubling_time=[1, 2, 3][i],
                                     max_gdp_frac=[1/1000, 4/1000, 1/100][i],
                                     initial_flops_per_dollar=10 ** 18,
                                     max_flops_per_dollar=10 ** 24,
                                     flops_halving_rate=[2, 2.5, 3][i],
                                     year=(y - CURRENT_YEAR))

        print('{}: {} max log FLOPs / ~{} petaFLOP/s-days)'.format(['25th', 'mean', '75th'][i],
                                                                   np.round(np.log10(flops_at_max_), 1),
                                                                   log_flop_to_petaflop_sdays(np.log10(flops_at_max_))))
# Out:
# -
# ## 2022 ##
# 25th: 24.5 max log FLOPs / ~40911 petaFLOP/s-days)
# mean: 25.7 max log FLOPs / ~619751 petaFLOP/s-days)
# 75th: 26.8 max log FLOPs / ~7265380 petaFLOP/s-days)
# -
# ## 2025 ##
# 25th: 25.9 max log FLOPs / ~924379 petaFLOP/s-days)
# mean: 26.5 max log FLOPs / ~4021998 petaFLOP/s-days)
# 75th: 27.4 max log FLOPs / ~28976286 petaFLOP/s-days)
# -
# ## 2030 ##
# 25th: 28.1 max log FLOPs / ~159863445 petaFLOP/s-days)
# mean: 27.9 max log FLOPs / ~90261450 petaFLOP/s-days)
# 75th: 28.4 max log FLOPs / ~288816073 petaFLOP/s-days)
