# %% [markdown]
# ## Library

# %%
import math
import random

import numpy as np
import matplotlib.pyplot as plt

import squigglepy as sq
from squigglepy import bayes
from squigglepy.numbers import K, M, B, T

from copy import copy, deepcopy
from scipy import stats
from pprint import pprint
print('Loaded 1')

exec(open('utils.py').read())
print('Loaded 2')

exec(open('/Users/peterhurford/dev/forecastflow/library.py').read()) # TODO: Package?
print('Loaded 3')
# Out:
# Loaded 1
# Loaded 2
# Loaded 3

# %% [markdown]
# ## Variables (customize these)

# %%
# Customize these!!!

# Global variables - probably don't want to change these but you could.
RUNS = 10000                                      # Number of runs to do (default 1000)
CURRENT_YEAR = 2023                               # What year to start the run on? (default: 2023)
MAX_YEAR = 2123                                   # What year to end the run on? (default: 2123)
USE_NUMBERS = 'Wildeford'                         # Which variable set (see below) to use?
GRAPH_P = 50                                      # What percentile to graph on the graphs below? (default: 50)
VARIABLE_SETS = {}


VARIABLE_SETS['Cotra2020'] = {
    'initial_gdp': 23*T,                  # GDP in `CURRENT_YEAR` of country that will develop TAI (default: 23 trillion)
    'tai_flop_size': sq.sample(load_cache_file='caches/cotra_2020'),  # Cache generated in "Anchors" notebook
    # 90% CI, it takes 10^X FLOPs to run a transformative AI at inference.
    # Note: A petaflop/s-day (pfs-day) consists of performing 10^15 neural net operations per second for one day,
    # or a total of about 10^20 operations
    'algo_doubling_rate_max': 3.5,        # 90% CI, algorithms get twice as efficient every X years (maximum)
    'algo_doubling_rate_min': 2,          # 90% CI, algorithms get twice as efficient every X years (minimum)
    'min_reduction': 2,                   # 90% CI, the minimum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'max_reduction': 5,                   # 90% CI, the maximum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'initial_flops_per_dollar': 17,       # 90% CI, as of today, we can buy 10^X FLOPs per $
    'flops_halving_rate': 2.5,            # 90% CI, the cost of FLOPs per $ halves every X years
    'max_flops_per_dollar': 24,           # 90% CI, the cheapest FLOPs will get is 10^X FLOPs per $
    'initial_pay': 8.7,                   # 90% CI, as of today the maximum we would pay for TAI is $10^X
    'gdp_growth': 1.03,                   # 90% CI, GDP will increase by a factor of X each year
    'max_gdp_frac': 0.01,                 # 90% CI, the maximum % of GDP that would be spent on TAI is $10^X
    'spend_doubling_time': 2.5            # 90% CI, our willingness to spend on TAI doubles every X years
}


VARIABLE_SETS['Cotra2022'] = deepcopy(VARIABLE_SETS['Cotra2020'])
VARIABLE_SETS['Cotra2022']['tai_flop_size'] = sq.sample(load_cache_file='caches/cotra_2022')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Cotra2022']['initial_flops_per_dollar'] = 18


def wildeford_max_gdp_frac():
    small_project = sq.lognorm(1 / (250*K), 1 / (3*K))
    modern_megaproject = sq.lognorm(1/K, 1/600)
    old_form_megaproject = sq.lognorm(1/500, 1/150)
    gigaproject = sq.lognorm(1/150, 1/50)
    
    r_ = random.random()
    if r_ < 0.1:
        gdp_frac = small_project
        percent_spent_on_compute = sq.lognorm(0.2,0.6, lclip=0.1, rclip=0.9)
    elif r_ < 0.8:
        gdp_frac = modern_megaproject
        percent_spent_on_compute = sq.lognorm(0.4,0.7, lclip=0.1, rclip=0.9)
    elif r_ < 0.95:
        gdp_frac = old_form_megaproject
        percent_spent_on_compute = sq.lognorm(0.5,0.9, lclip=0.1, rclip=0.9)
    else:
        gdp_frac = gigaproject
        percent_spent_on_compute = sq.lognorm(0.6,0.9, lclip=0.1, rclip=0.9)

    return ~gdp_frac * ~percent_spent_on_compute

VARIABLE_SETS['Wildeford'] = deepcopy(VARIABLE_SETS['Cotra2022'])
VARIABLE_SETS['Wildeford']['tai_flop_size'] = sq.sample(load_cache_file='caches/meta_anchor')  # Cache generated in "Anchors" notebook

"""
VARIABLE_SETS['Wildeford']['flops_halving_rate'] = sq.lognorm(2, 5)
VARIABLE_SETS['Wildeford']['initial_pay'] = sq.mixture([[0.8, sq.const(7.1)],
                                                        [0.2, sq.lognorm(7.1,9, lclip=7.1)]]) #NEW
VARIABLE_SETS['Wildeford']['gdp_growth'] = sq.lognorm(1.015, 1.035) #NEW
VARIABLE_SETS['Wildeford']['max_gdp_frac'] = wildeford_max_gdp_frac #NEW
VARIABLE_SETS['Wildeford']['spend_doubling_time'] = sq.mixture([[0.8, sq.lognorm(3,6)],
                                                                [0.2, sq.lognorm(1,2, lclip=1)]]) #NEW
# TODO: Willingness to spend connected to commercialization
VARIABLE_SETS['Wildeford']['initial_chance_of_nonscaling_issue'] = 0.95 #NEW
VARIABLE_SETS['Wildeford']['final_chance_of_nonscaling_issue'] = 0.3 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_issue_bottom_year'] = 2050 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_delay'] = sq.mixture([[0.7, sq.lognorm(2,10)],
                                                             [0.3, sq.lognorm(5,40)]]) #NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_max'] = sq.norm(1,3) # NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_min'] = sq.norm(1,2) # NEW
VARIABLE_SETS['Wildeford']['min_reduction'] = 2 # TODO: Connect to efficiency within tai_flop_size / should correlate with tai_flop_size
VARIABLE_SETS['Wildeford']['max_reduction'] = 5
"""

# These equations define how variables change over time or in relationship to other variables.
def gdp(initial_gdp, gdp_growth, year):
    return initial_gdp * (gdp_growth ** year)


def willingness_to_pay(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac, year):
    gdp_ = gdp(initial_gdp=initial_gdp, gdp_growth=gdp_growth, year=year)
    x = (np.log(2) / spend_doubling_time) * year
    if x < 650:
        y = math.log10(initial_pay) + math.log10(math.exp(x)) - math.log10(1 + initial_pay / (gdp_ * max_gdp_frac) * math.exp(x))
        if y > 300:
            y = int(y) # Handle overflow errors
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_pay) + (year/spend_doubling_time)/3.3)
    

def algo_halving_fn(min_speed, max_speed, tai_flop_size):
    if max_speed < min_speed:
        max_speed = min_speed
    if min_speed > max_speed:
        min_speed = max_speed
    return min(max(max_speed - (round((tai_flop_size - 29) / 2) / 2), min_speed), max_speed)


def flops_needed(initial_flops, possible_reduction, doubling_rate, year):
    x = (np.log(2) / doubling_rate) * year
    if x < 650:
        y = (math.log10(initial_flops) - max(math.log10(math.exp(x)) - math.log10(1 + (1/possible_reduction) * math.exp(x)), 0))
        if y > 300:
            y = int(y) # Handle overflow errors        
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops) - (1/possible_reduction))

    
def flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, halving_rate, year):
    x = (np.log(2) / halving_rate) * year
    if x < 650:
        y = (math.log10(initial_flops_per_dollar) + math.log10(math.exp(x)) - math.log10(1 + initial_flops_per_dollar / max_flops_per_dollar * math.exp(x)))
        if y > 300:
            y = int(y) # Handle overflow errors                
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops_per_dollar) + (year/halving_rate)/3.3)

    
def cost_of_tai(initial_flops, possible_reduction, algo_doubling_rate, initial_flops_per_dollar, max_flops_per_dollar,
                flops_halving_rate, year):
    return (flops_needed(initial_flops, possible_reduction, algo_doubling_rate, year) /
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def flops_at_max(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac,
                 initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year):
    return (willingness_to_pay(initial_gdp=initial_gdp,
                               gdp_growth=gdp_growth,
                               initial_pay=initial_pay,
                               spend_doubling_time=spend_doubling_time,
                               max_gdp_frac=max_gdp_frac,
                               year=year) *
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def possible_algo_reduction_fn(min_reduction, max_reduction, tai_flop_size):
    if max_reduction < min_reduction:
        max_reduction = min_reduction
    if min_reduction > max_reduction:
        min_reduction = max_reduction
    return min(max(min_reduction + round((tai_flop_size - 32) / 4), min_reduction), max_reduction)


# NEW
def p_nonscaling_delay(initial_p, final_p, year, max_year):
    return generalized_logistic_curve(x=year - CURRENT_YEAR,
                                      slope=0.3,
                                      shift=3 * (max_year - CURRENT_YEAR),
                                      push=1,
                                      maximum=final_p,
                                      minimum=initial_p)
    

# ------------- Ignore below here ------------
years = list(range(CURRENT_YEAR, MAX_YEAR))
variables = VARIABLE_SETS[USE_NUMBERS]
print('Loaded')
# Out:
# Loaded

# %%
initial_flop_size_s = variables['tai_flop_size']
initial_flops_p = sq.get_percentiles(initial_flop_size_s)
plt.hist(initial_flop_size_s, bins = 200)
pprint(initial_flops_p)
# Out:
# {1: 19.11630707758291,
#  5: 23.941307377818696,
#  10: 25.219871192867576,
#  20: 26.791699170660326,
#  30: 28.66329561390483,
#  40: 30.533261889816366,
#  50: 32.428925602346915,
#  60: 34.426576264600236,
#  70: 36.519627346776915,
#  80: 39.07879986968247,
#  90: 42.63365086609802,
#  95: 45.815569551366316,
#  99: 52.38077728364052}

# %%
min_reduction_p = sq.get_percentiles(sq.sample(variables['min_reduction'], n=1000))
min_reduction_p
# Out:
# {1: 2.0,
#  5: 2.0,
#  10: 2.0,
#  20: 2.0,
#  30: 2.0,
#  40: 2.0,
#  50: 2.0,
#  60: 2.0,
#  70: 2.0,
#  80: 2.0,
#  90: 2.0,
#  95: 2.0,
#  99: 2.0}

# %%
max_reduction_p = sq.get_percentiles(sq.sample(variables['max_reduction'], n=1000), reverse=True)
max_reduction_p
# Out:
# {99: 5.0,
#  95: 5.0,
#  90: 5.0,
#  80: 5.0,
#  70: 5.0,
#  60: 5.0,
#  50: 5.0,
#  40: 5.0,
#  30: 5.0,
#  20: 5.0,
#  10: 5.0,
#  5: 5.0,
#  1: 5.0}

# %%
algo_doubling_rate_min_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_min'], n=1000), reverse=True)
algo_doubling_rate_min_p
# Out:
# {99: 2.0,
#  95: 2.0,
#  90: 2.0,
#  80: 2.0,
#  70: 2.0,
#  60: 2.0,
#  50: 2.0,
#  40: 2.0,
#  30: 2.0,
#  20: 2.0,
#  10: 2.0,
#  5: 2.0,
#  1: 2.0}

# %%
algo_doubling_rate_max_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_max'], n=1000), reverse=True)
algo_doubling_rate_max_p
# Out:
# {99: 3.5,
#  95: 3.5,
#  90: 3.5,
#  80: 3.5,
#  70: 3.5,
#  60: 3.5,
#  50: 3.5,
#  40: 3.5,
#  30: 3.5,
#  20: 3.5,
#  10: 3.5,
#  5: 3.5,
#  1: 3.5}

# %%
initial_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['initial_flops_per_dollar'], n=1000))
initial_flops_per_dollar_p
# Out:
# {1: 18.0,
#  5: 18.0,
#  10: 18.0,
#  20: 18.0,
#  30: 18.0,
#  40: 18.0,
#  50: 18.0,
#  60: 18.0,
#  70: 18.0,
#  80: 18.0,
#  90: 18.0,
#  95: 18.0,
#  99: 18.0}

# %%
flops_halving_rate_p = sq.get_percentiles(sq.sample(variables['flops_halving_rate'], n=1000), reverse=True)
flops_halving_rate_p
# Out:
# {99: 2.5,
#  95: 2.5,
#  90: 2.5,
#  80: 2.5,
#  70: 2.5,
#  60: 2.5,
#  50: 2.5,
#  40: 2.5,
#  30: 2.5,
#  20: 2.5,
#  10: 2.5,
#  5: 2.5,
#  1: 2.5}

# %%
max_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['max_flops_per_dollar'], n=1000))
max_flops_per_dollar_p
# Out:
# {1: 24.0,
#  5: 24.0,
#  10: 24.0,
#  20: 24.0,
#  30: 24.0,
#  40: 24.0,
#  50: 24.0,
#  60: 24.0,
#  70: 24.0,
#  80: 24.0,
#  90: 24.0,
#  95: 24.0,
#  99: 24.0}

# %%
initial_pay_p = sq.get_percentiles(sq.sample(variables['initial_pay'], n=1000))
initial_pay_p
# Out:
# {1: 8.7,
#  5: 8.7,
#  10: 8.7,
#  20: 8.7,
#  30: 8.7,
#  40: 8.7,
#  50: 8.7,
#  60: 8.7,
#  70: 8.7,
#  80: 8.7,
#  90: 8.7,
#  95: 8.7,
#  99: 8.7}

# %%
gdp_growth_p = sq.get_percentiles(sq.sample(variables['gdp_growth'], n=1000))
gdp_growth_p
# Out:
# {1: 1.03,
#  5: 1.03,
#  10: 1.03,
#  20: 1.03,
#  30: 1.03,
#  40: 1.03,
#  50: 1.03,
#  60: 1.03,
#  70: 1.03,
#  80: 1.03,
#  90: 1.03,
#  95: 1.03,
#  99: 1.03}

# %%
max_gdp_frac_p = sq.get_percentiles(sq.sample(variables['max_gdp_frac'], n=1000))
max_gdp_frac_p
# Out:
# {1: 0.01,
#  5: 0.01,
#  10: 0.01,
#  20: 0.01,
#  30: 0.01,
#  40: 0.01,
#  50: 0.01,
#  60: 0.01,
#  70: 0.01,
#  80: 0.01,
#  90: 0.01,
#  95: 0.01,
#  99: 0.01}

# %%
willingness_ramp = variables.get('willingness_ramp', 0)
if willingness_ramp != 0:
    willingness_ramp_p = sq.get_percentiles(sq.sample(willingness_ramp), n=1000)
    pprint(willingness_ramp_p)
else:
    print(0)
# Out:
# 0

# %%
spend_doubling_time_p = sq.get_percentiles(sq.sample(variables['spend_doubling_time'], n=1000), reverse=True)
spend_doubling_time_p
# Out:
# {99: 2.5,
#  95: 2.5,
#  90: 2.5,
#  80: 2.5,
#  70: 2.5,
#  60: 2.5,
#  50: 2.5,
#  40: 2.5,
#  30: 2.5,
#  20: 2.5,
#  10: 2.5,
#  5: 2.5,
#  1: 2.5}

# %%
nonscaling_delay = variables.get('nonscaling_delay', 0)
if nonscaling_delay != 0:
    nonscaling_delay_p = sq.get_percentiles(np.ceil(sq.sample(nonscaling_delay, n=1000)), reverse=True)
    pprint(nonscaling_delay_p)
else:
    print(0)
# Out:
# 0

# %%
willingness_spend_horizon = variables.get('willingness_spend_horizon', 1)
if willingness_spend_horizon != 1:
    willingness_spend_horizon_p = sq.get_percentiles(sq.sample(willingness_spend_horizon, n=1000))
    pprint(willingness_spend_horizon_p)
else:
    print(1)
# Out:
# 1

# %% [markdown]
# ## GDP Over Time

# %%
gdp_ = np.array([gdp(initial_gdp=variables['initial_gdp'],
                     gdp_growth=gdp_growth_p[GRAPH_P],
                     year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(gdp_))
plt.ylabel('log GDP')
# Out:
# Text(0, 0.5, 'log GDP')

# %%
for y in years:
    print('Year: {} - GDP log 2022$USD {} (~{})'.format(y,
                                                        np.round(np.log10(gdp_[y - CURRENT_YEAR]), 1),
                                                        numerize(gdp_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - GDP log 2022$USD 13.4 (~23 trillion)
# Year: 2024 - GDP log 2022$USD 13.4 (~24 trillion)
# Year: 2025 - GDP log 2022$USD 13.4 (~24 trillion)
# Year: 2026 - GDP log 2022$USD 13.4 (~25 trillion)
# Year: 2027 - GDP log 2022$USD 13.4 (~26 trillion)
# Year: 2028 - GDP log 2022$USD 13.4 (~27 trillion)
# Year: 2029 - GDP log 2022$USD 13.4 (~27 trillion)
# Year: 2030 - GDP log 2022$USD 13.5 (~28 trillion)
# Year: 2031 - GDP log 2022$USD 13.5 (~29 trillion)
# Year: 2032 - GDP log 2022$USD 13.5 (~30 trillion)
# Year: 2033 - GDP log 2022$USD 13.5 (~31 trillion)
# Year: 2034 - GDP log 2022$USD 13.5 (~32 trillion)
# Year: 2035 - GDP log 2022$USD 13.5 (~33 trillion)
# Year: 2036 - GDP log 2022$USD 13.5 (~34 trillion)
# Year: 2037 - GDP log 2022$USD 13.5 (~35 trillion)
# Year: 2038 - GDP log 2022$USD 13.6 (~36 trillion)
# Year: 2039 - GDP log 2022$USD 13.6 (~37 trillion)
# Year: 2040 - GDP log 2022$USD 13.6 (~38 trillion)
# Year: 2041 - GDP log 2022$USD 13.6 (~39 trillion)
# Year: 2042 - GDP log 2022$USD 13.6 (~40 trillion)
# Year: 2043 - GDP log 2022$USD 13.6 (~42 trillion)
# Year: 2044 - GDP log 2022$USD 13.6 (~43 trillion)
# Year: 2045 - GDP log 2022$USD 13.6 (~44 trillion)
# Year: 2046 - GDP log 2022$USD 13.7 (~45 trillion)
# Year: 2047 - GDP log 2022$USD 13.7 (~47 trillion)
# Year: 2048 - GDP log 2022$USD 13.7 (~48 trillion)
# Year: 2049 - GDP log 2022$USD 13.7 (~50 trillion)
# Year: 2050 - GDP log 2022$USD 13.7 (~51 trillion)
# Year: 2051 - GDP log 2022$USD 13.7 (~53 trillion)
# Year: 2052 - GDP log 2022$USD 13.7 (~54 trillion)
# Year: 2053 - GDP log 2022$USD 13.7 (~56 trillion)
# Year: 2054 - GDP log 2022$USD 13.8 (~58 trillion)
# Year: 2055 - GDP log 2022$USD 13.8 (~59 trillion)
# Year: 2056 - GDP log 2022$USD 13.8 (~61 trillion)
# Year: 2057 - GDP log 2022$USD 13.8 (~63 trillion)
# Year: 2058 - GDP log 2022$USD 13.8 (~65 trillion)
# Year: 2059 - GDP log 2022$USD 13.8 (~67 trillion)
# Year: 2060 - GDP log 2022$USD 13.8 (~69 trillion)
# Year: 2061 - GDP log 2022$USD 13.8 (~71 trillion)
# Year: 2062 - GDP log 2022$USD 13.9 (~73 trillion)
# Year: 2063 - GDP log 2022$USD 13.9 (~75 trillion)
# Year: 2064 - GDP log 2022$USD 13.9 (~77 trillion)
# Year: 2065 - GDP log 2022$USD 13.9 (~80 trillion)
# Year: 2066 - GDP log 2022$USD 13.9 (~82 trillion)
# Year: 2067 - GDP log 2022$USD 13.9 (~84 trillion)
# Year: 2068 - GDP log 2022$USD 13.9 (~87 trillion)
# Year: 2069 - GDP log 2022$USD 14.0 (~90 trillion)
# Year: 2070 - GDP log 2022$USD 14.0 (~92 trillion)
# Year: 2071 - GDP log 2022$USD 14.0 (~95 trillion)
# Year: 2072 - GDP log 2022$USD 14.0 (~98 trillion)
# Year: 2073 - GDP log 2022$USD 14.0 (~101 trillion)
# Year: 2074 - GDP log 2022$USD 14.0 (~104 trillion)
# Year: 2075 - GDP log 2022$USD 14.0 (~107 trillion)
# Year: 2076 - GDP log 2022$USD 14.0 (~110 trillion)
# Year: 2077 - GDP log 2022$USD 14.1 (~113 trillion)
# Year: 2078 - GDP log 2022$USD 14.1 (~117 trillion)
# Year: 2079 - GDP log 2022$USD 14.1 (~120 trillion)
# Year: 2080 - GDP log 2022$USD 14.1 (~124 trillion)
# Year: 2081 - GDP log 2022$USD 14.1 (~128 trillion)
# Year: 2082 - GDP log 2022$USD 14.1 (~132 trillion)
# Year: 2083 - GDP log 2022$USD 14.1 (~136 trillion)
# Year: 2084 - GDP log 2022$USD 14.1 (~140 trillion)
# Year: 2085 - GDP log 2022$USD 14.2 (~144 trillion)
# Year: 2086 - GDP log 2022$USD 14.2 (~148 trillion)
# Year: 2087 - GDP log 2022$USD 14.2 (~153 trillion)
# Year: 2088 - GDP log 2022$USD 14.2 (~157 trillion)
# Year: 2089 - GDP log 2022$USD 14.2 (~162 trillion)
# Year: 2090 - GDP log 2022$USD 14.2 (~167 trillion)
# Year: 2091 - GDP log 2022$USD 14.2 (~172 trillion)
# Year: 2092 - GDP log 2022$USD 14.2 (~177 trillion)
# Year: 2093 - GDP log 2022$USD 14.3 (~182 trillion)
# Year: 2094 - GDP log 2022$USD 14.3 (~188 trillion)
# Year: 2095 - GDP log 2022$USD 14.3 (~193 trillion)
# Year: 2096 - GDP log 2022$USD 14.3 (~199 trillion)
# Year: 2097 - GDP log 2022$USD 14.3 (~205 trillion)
# Year: 2098 - GDP log 2022$USD 14.3 (~211 trillion)
# Year: 2099 - GDP log 2022$USD 14.3 (~217 trillion)
# Year: 2100 - GDP log 2022$USD 14.4 (~224 trillion)
# Year: 2101 - GDP log 2022$USD 14.4 (~231 trillion)
# Year: 2102 - GDP log 2022$USD 14.4 (~238 trillion)
# Year: 2103 - GDP log 2022$USD 14.4 (~245 trillion)
# Year: 2104 - GDP log 2022$USD 14.4 (~252 trillion)
# Year: 2105 - GDP log 2022$USD 14.4 (~260 trillion)
# Year: 2106 - GDP log 2022$USD 14.4 (~267 trillion)
# Year: 2107 - GDP log 2022$USD 14.4 (~275 trillion)
# Year: 2108 - GDP log 2022$USD 14.5 (~284 trillion)
# Year: 2109 - GDP log 2022$USD 14.5 (~292 trillion)
# Year: 2110 - GDP log 2022$USD 14.5 (~301 trillion)
# Year: 2111 - GDP log 2022$USD 14.5 (~310 trillion)
# Year: 2112 - GDP log 2022$USD 14.5 (~319 trillion)
# Year: 2113 - GDP log 2022$USD 14.5 (~329 trillion)
# Year: 2114 - GDP log 2022$USD 14.5 (~339 trillion)
# Year: 2115 - GDP log 2022$USD 14.5 (~349 trillion)
# Year: 2116 - GDP log 2022$USD 14.6 (~359 trillion)
# Year: 2117 - GDP log 2022$USD 14.6 (~370 trillion)
# Year: 2118 - GDP log 2022$USD 14.6 (~381 trillion)
# Year: 2119 - GDP log 2022$USD 14.6 (~393 trillion)
# Year: 2120 - GDP log 2022$USD 14.6 (~405 trillion)
# Year: 2121 - GDP log 2022$USD 14.6 (~417 trillion)
# Year: 2122 - GDP log 2022$USD 14.6 (~429 trillion)

# %% [markdown]
# ## Willingness to Pay Over Time

# %%
for p in [20, 50, 80]:
    print('-')
    print('-')
    print('## {} ##'.format(p))
    willingness = np.array([willingness_to_pay(initial_gdp=variables['initial_gdp'],
                                               gdp_growth=gdp_growth_p[p],
                                               initial_pay=10 ** initial_pay_p[p],
                                               spend_doubling_time=spend_doubling_time_p[p],
                                               max_gdp_frac=max_gdp_frac_p[p],
                                               year=(y - CURRENT_YEAR)) for y in years])
    for y in years:
        print('Year: {} - willingness log 2022$USD per year {} (~{})'.format(y,
                                                                             np.round(np.log10(willingness[y - CURRENT_YEAR]), 1),
                                                                             numerize(willingness[y - CURRENT_YEAR])))


    plt.plot(years, np.log10(willingness))
plt.ylabel('log 2022$USD/yr willing to spend on TAI')
plt.show()
# Out:
# -
# -
# ## 20 ##
# Year: 2023 - willingness log 2022$USD per year 8.7 (~500 million)
# Year: 2024 - willingness log 2022$USD per year 8.8 (~659 million)
# Year: 2025 - willingness log 2022$USD per year 8.9 (~870 million)
# Year: 2026 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2027 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2028 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2029 - willingness log 2022$USD per year 9.4 (~3 billion)
# Year: 2030 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2031 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2032 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2033 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2034 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2035 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2036 - willingness log 2022$USD per year 10.2 (~17 billion)
# Year: 2037 - willingness log 2022$USD per year 10.4 (~23 billion)
# Year: 2038 - willingness log 2022$USD per year 10.5 (~29 billion)
# Year: 2039 - willingness log 2022$USD per year 10.6 (~38 billion)
# Year: 2040 - willingness log 2022$USD per year 10.7 (~49 billion)
# Year: 2041 - willingness log 2022$USD per year 10.8 (~62 billion)
# Year: 2042 - willingness log 2022$USD per year 10.9 (~78 billion)
# Year: 2043 - willingness log 2022$USD per year 11.0 (~98 billion)
# Year: 2044 - willingness log 2022$USD per year 11.1 (~121 billion)
# Year: 2045 - willingness log 2022$USD per year 11.2 (~148 billion)
# Year: 2046 - willingness log 2022$USD per year 11.3 (~179 billion)
# Year: 2047 - willingness log 2022$USD per year 11.3 (~212 billion)
# Year: 2048 - willingness log 2022$USD per year 11.4 (~248 billion)
# Year: 2049 - willingness log 2022$USD per year 11.5 (~286 billion)
# Year: 2050 - willingness log 2022$USD per year 11.5 (~325 billion)
# Year: 2051 - willingness log 2022$USD per year 11.6 (~364 billion)
# Year: 2052 - willingness log 2022$USD per year 11.6 (~402 billion)
# Year: 2053 - willingness log 2022$USD per year 11.6 (~439 billion)
# Year: 2054 - willingness log 2022$USD per year 11.7 (~474 billion)
# Year: 2055 - willingness log 2022$USD per year 11.7 (~508 billion)
# Year: 2056 - willingness log 2022$USD per year 11.7 (~540 billion)
# Year: 2057 - willingness log 2022$USD per year 11.8 (~571 billion)
# Year: 2058 - willingness log 2022$USD per year 11.8 (~600 billion)
# Year: 2059 - willingness log 2022$USD per year 11.8 (~628 billion)
# Year: 2060 - willingness log 2022$USD per year 11.8 (~655 billion)
# Year: 2061 - willingness log 2022$USD per year 11.8 (~682 billion)
# Year: 2062 - willingness log 2022$USD per year 11.8 (~708 billion)
# Year: 2063 - willingness log 2022$USD per year 11.9 (~734 billion)
# Year: 2064 - willingness log 2022$USD per year 11.9 (~759 billion)
# Year: 2065 - willingness log 2022$USD per year 11.9 (~785 billion)
# Year: 2066 - willingness log 2022$USD per year 11.9 (~811 billion)
# Year: 2067 - willingness log 2022$USD per year 11.9 (~837 billion)
# Year: 2068 - willingness log 2022$USD per year 11.9 (~864 billion)
# Year: 2069 - willingness log 2022$USD per year 12.0 (~891 billion)
# Year: 2070 - willingness log 2022$USD per year 12.0 (~919 billion)
# Year: 2071 - willingness log 2022$USD per year 12.0 (~947 billion)
# Year: 2072 - willingness log 2022$USD per year 12.0 (~977 billion)
# Year: 2073 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2074 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2075 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2076 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2077 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2078 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2079 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2080 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2081 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2082 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2083 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2084 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2085 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2086 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2087 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2088 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2089 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2090 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2091 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2092 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2093 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2094 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2095 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2096 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2097 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2098 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2099 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2100 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2101 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2102 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2103 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2104 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2105 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2106 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2107 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2108 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2109 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2110 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2111 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2112 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2113 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2114 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2115 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2116 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2117 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2118 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2119 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2120 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2121 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2122 - willingness log 2022$USD per year 12.6 (~4 trillion)
# -
# -
# ## 50 ##
# Year: 2023 - willingness log 2022$USD per year 8.7 (~500 million)
# Year: 2024 - willingness log 2022$USD per year 8.8 (~659 million)
# Year: 2025 - willingness log 2022$USD per year 8.9 (~870 million)
# Year: 2026 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2027 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2028 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2029 - willingness log 2022$USD per year 9.4 (~3 billion)
# Year: 2030 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2031 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2032 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2033 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2034 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2035 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2036 - willingness log 2022$USD per year 10.2 (~17 billion)
# Year: 2037 - willingness log 2022$USD per year 10.4 (~23 billion)
# Year: 2038 - willingness log 2022$USD per year 10.5 (~29 billion)
# Year: 2039 - willingness log 2022$USD per year 10.6 (~38 billion)
# Year: 2040 - willingness log 2022$USD per year 10.7 (~49 billion)
# Year: 2041 - willingness log 2022$USD per year 10.8 (~62 billion)
# Year: 2042 - willingness log 2022$USD per year 10.9 (~78 billion)
# Year: 2043 - willingness log 2022$USD per year 11.0 (~98 billion)
# Year: 2044 - willingness log 2022$USD per year 11.1 (~121 billion)
# Year: 2045 - willingness log 2022$USD per year 11.2 (~148 billion)
# Year: 2046 - willingness log 2022$USD per year 11.3 (~179 billion)
# Year: 2047 - willingness log 2022$USD per year 11.3 (~212 billion)
# Year: 2048 - willingness log 2022$USD per year 11.4 (~248 billion)
# Year: 2049 - willingness log 2022$USD per year 11.5 (~286 billion)
# Year: 2050 - willingness log 2022$USD per year 11.5 (~325 billion)
# Year: 2051 - willingness log 2022$USD per year 11.6 (~364 billion)
# Year: 2052 - willingness log 2022$USD per year 11.6 (~402 billion)
# Year: 2053 - willingness log 2022$USD per year 11.6 (~439 billion)
# Year: 2054 - willingness log 2022$USD per year 11.7 (~474 billion)
# Year: 2055 - willingness log 2022$USD per year 11.7 (~508 billion)
# Year: 2056 - willingness log 2022$USD per year 11.7 (~540 billion)
# Year: 2057 - willingness log 2022$USD per year 11.8 (~571 billion)
# Year: 2058 - willingness log 2022$USD per year 11.8 (~600 billion)
# Year: 2059 - willingness log 2022$USD per year 11.8 (~628 billion)
# Year: 2060 - willingness log 2022$USD per year 11.8 (~655 billion)
# Year: 2061 - willingness log 2022$USD per year 11.8 (~682 billion)
# Year: 2062 - willingness log 2022$USD per year 11.8 (~708 billion)
# Year: 2063 - willingness log 2022$USD per year 11.9 (~734 billion)
# Year: 2064 - willingness log 2022$USD per year 11.9 (~759 billion)
# Year: 2065 - willingness log 2022$USD per year 11.9 (~785 billion)
# Year: 2066 - willingness log 2022$USD per year 11.9 (~811 billion)
# Year: 2067 - willingness log 2022$USD per year 11.9 (~837 billion)
# Year: 2068 - willingness log 2022$USD per year 11.9 (~864 billion)
# Year: 2069 - willingness log 2022$USD per year 12.0 (~891 billion)
# Year: 2070 - willingness log 2022$USD per year 12.0 (~919 billion)
# Year: 2071 - willingness log 2022$USD per year 12.0 (~947 billion)
# Year: 2072 - willingness log 2022$USD per year 12.0 (~977 billion)
# Year: 2073 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2074 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2075 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2076 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2077 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2078 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2079 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2080 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2081 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2082 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2083 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2084 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2085 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2086 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2087 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2088 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2089 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2090 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2091 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2092 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2093 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2094 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2095 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2096 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2097 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2098 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2099 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2100 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2101 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2102 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2103 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2104 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2105 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2106 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2107 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2108 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2109 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2110 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2111 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2112 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2113 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2114 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2115 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2116 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2117 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2118 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2119 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2120 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2121 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2122 - willingness log 2022$USD per year 12.6 (~4 trillion)
# -
# -
# ## 80 ##
# Year: 2023 - willingness log 2022$USD per year 8.7 (~500 million)
# Year: 2024 - willingness log 2022$USD per year 8.8 (~659 million)
# Year: 2025 - willingness log 2022$USD per year 8.9 (~870 million)
# Year: 2026 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2027 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2028 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2029 - willingness log 2022$USD per year 9.4 (~3 billion)
# Year: 2030 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2031 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2032 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2033 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2034 - willingness log 2022$USD per year 10.0 (~10 billion)
# Year: 2035 - willingness log 2022$USD per year 10.1 (~13 billion)
# Year: 2036 - willingness log 2022$USD per year 10.2 (~17 billion)
# Year: 2037 - willingness log 2022$USD per year 10.4 (~23 billion)
# Year: 2038 - willingness log 2022$USD per year 10.5 (~29 billion)
# Year: 2039 - willingness log 2022$USD per year 10.6 (~38 billion)
# Year: 2040 - willingness log 2022$USD per year 10.7 (~49 billion)
# Year: 2041 - willingness log 2022$USD per year 10.8 (~62 billion)
# Year: 2042 - willingness log 2022$USD per year 10.9 (~78 billion)
# Year: 2043 - willingness log 2022$USD per year 11.0 (~98 billion)
# Year: 2044 - willingness log 2022$USD per year 11.1 (~121 billion)
# Year: 2045 - willingness log 2022$USD per year 11.2 (~148 billion)
# Year: 2046 - willingness log 2022$USD per year 11.3 (~179 billion)
# Year: 2047 - willingness log 2022$USD per year 11.3 (~212 billion)
# Year: 2048 - willingness log 2022$USD per year 11.4 (~248 billion)
# Year: 2049 - willingness log 2022$USD per year 11.5 (~286 billion)
# Year: 2050 - willingness log 2022$USD per year 11.5 (~325 billion)
# Year: 2051 - willingness log 2022$USD per year 11.6 (~364 billion)
# Year: 2052 - willingness log 2022$USD per year 11.6 (~402 billion)
# Year: 2053 - willingness log 2022$USD per year 11.6 (~439 billion)
# Year: 2054 - willingness log 2022$USD per year 11.7 (~474 billion)
# Year: 2055 - willingness log 2022$USD per year 11.7 (~508 billion)
# Year: 2056 - willingness log 2022$USD per year 11.7 (~540 billion)
# Year: 2057 - willingness log 2022$USD per year 11.8 (~571 billion)
# Year: 2058 - willingness log 2022$USD per year 11.8 (~600 billion)
# Year: 2059 - willingness log 2022$USD per year 11.8 (~628 billion)
# Year: 2060 - willingness log 2022$USD per year 11.8 (~655 billion)
# Year: 2061 - willingness log 2022$USD per year 11.8 (~682 billion)
# Year: 2062 - willingness log 2022$USD per year 11.8 (~708 billion)
# Year: 2063 - willingness log 2022$USD per year 11.9 (~734 billion)
# Year: 2064 - willingness log 2022$USD per year 11.9 (~759 billion)
# Year: 2065 - willingness log 2022$USD per year 11.9 (~785 billion)
# Year: 2066 - willingness log 2022$USD per year 11.9 (~811 billion)
# Year: 2067 - willingness log 2022$USD per year 11.9 (~837 billion)
# Year: 2068 - willingness log 2022$USD per year 11.9 (~864 billion)
# Year: 2069 - willingness log 2022$USD per year 12.0 (~891 billion)
# Year: 2070 - willingness log 2022$USD per year 12.0 (~919 billion)
# Year: 2071 - willingness log 2022$USD per year 12.0 (~947 billion)
# Year: 2072 - willingness log 2022$USD per year 12.0 (~977 billion)
# Year: 2073 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2074 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2075 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2076 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2077 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2078 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2079 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2080 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2081 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2082 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2083 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2084 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2085 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2086 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2087 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2088 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2089 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2090 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2091 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2092 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2093 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2094 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2095 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2096 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2097 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2098 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2099 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2100 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2101 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2102 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2103 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2104 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2105 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2106 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2107 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2108 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2109 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2110 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2111 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2112 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2113 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2114 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2115 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2116 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2117 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2118 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2119 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2120 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2121 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2122 - willingness log 2022$USD per year 12.6 (~4 trillion)

# %% [markdown]
# ## FLOPs Needed to Make TAI (Given Algorithmic Progress)

# %%
flops_ = np.array([flops_needed(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                              algo_doubling_rate_max_p[GRAPH_P],
                                                              initial_flops_p[GRAPH_P]),
                                possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                    max_reduction_p[GRAPH_P],
                                                                                    initial_flops_p[GRAPH_P]),
                                year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_))
plt.ylabel('log FLOPs needed to make TAI')
# Out:
# Text(0, 0.5, 'log FLOPs needed to make TAI')

# %%
for y in years:
    print('Year: {} - log FLOPs needed for TAI {} (~{})'.format(y,
                                                                np.round(np.log10(flops_[y - CURRENT_YEAR]), 1),
                                                                numerize(flops_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log FLOPs needed for TAI 32.4 (~268 nonillion)
# Year: 2024 - log FLOPs needed for TAI 32.3 (~206 nonillion)
# Year: 2025 - log FLOPs needed for TAI 32.2 (~157 nonillion)
# Year: 2026 - log FLOPs needed for TAI 32.1 (~120 nonillion)
# Year: 2027 - log FLOPs needed for TAI 32.0 (~91 nonillion)
# Year: 2028 - log FLOPs needed for TAI 31.8 (~70 nonillion)
# Year: 2029 - log FLOPs needed for TAI 31.7 (~54 nonillion)
# Year: 2030 - log FLOPs needed for TAI 31.6 (~41 nonillion)
# Year: 2031 - log FLOPs needed for TAI 31.5 (~32 nonillion)
# Year: 2032 - log FLOPs needed for TAI 31.4 (~25 nonillion)
# Year: 2033 - log FLOPs needed for TAI 31.3 (~19 nonillion)
# Year: 2034 - log FLOPs needed for TAI 31.2 (~15 nonillion)
# Year: 2035 - log FLOPs needed for TAI 31.1 (~12 nonillion)
# Year: 2036 - log FLOPs needed for TAI 31.0 (~10 nonillion)
# Year: 2037 - log FLOPs needed for TAI 30.9 (~8 nonillion)
# Year: 2038 - log FLOPs needed for TAI 30.8 (~7 nonillion)
# Year: 2039 - log FLOPs needed for TAI 30.8 (~6 nonillion)
# Year: 2040 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2041 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2042 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2043 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2044 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2045 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2046 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2047 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2048 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2049 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2050 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2051 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2052 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2053 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2054 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2055 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2056 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2057 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2058 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2059 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2060 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2061 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2062 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2063 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2064 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2065 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2066 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2067 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2068 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2069 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2070 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2071 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2072 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2073 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2074 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2075 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2076 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2077 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2078 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2079 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2080 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2081 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2082 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2083 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2084 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2085 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2086 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2087 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2088 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2089 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2090 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2091 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2092 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2093 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2094 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2095 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2096 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2097 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2098 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2099 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2100 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2101 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2102 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2103 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2104 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2105 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2106 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2107 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2108 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2109 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2110 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2111 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2112 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2113 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2114 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2115 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2116 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2117 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2118 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2119 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2120 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2121 - log FLOPs needed for TAI 30.4 (~3 nonillion)
# Year: 2122 - log FLOPs needed for TAI 30.4 (~3 nonillion)

# %% [markdown]
# ## FLOPs per Dollar (Given Declining Costs)

# %%
flops_per_dollar_ = np.array([flops_per_dollar(initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                               max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                               halving_rate=flops_halving_rate_p[GRAPH_P],
                                               year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(flops_per_dollar_))
plt.ylabel('log FLOPs per $1')
# Out:
# Text(0, 0.5, 'log FLOPs per $1')

# %%
for y in years:
    print('Year: {} - log {} FLOPs per $ (~{})'.format(y,
                                                       np.round(np.log10(flops_per_dollar_[y - CURRENT_YEAR]), 1),
                                                       numerize(flops_per_dollar_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log 18.0 FLOPs per $ (~1000 quadrillion)
# Year: 2024 - log 18.1 FLOPs per $ (~1 quintillion)
# Year: 2025 - log 18.2 FLOPs per $ (~2 quintillion)
# Year: 2026 - log 18.4 FLOPs per $ (~2 quintillion)
# Year: 2027 - log 18.5 FLOPs per $ (~3 quintillion)
# Year: 2028 - log 18.6 FLOPs per $ (~4 quintillion)
# Year: 2029 - log 18.7 FLOPs per $ (~5 quintillion)
# Year: 2030 - log 18.8 FLOPs per $ (~7 quintillion)
# Year: 2031 - log 19.0 FLOPs per $ (~9 quintillion)
# Year: 2032 - log 19.1 FLOPs per $ (~12 quintillion)
# Year: 2033 - log 19.2 FLOPs per $ (~16 quintillion)
# Year: 2034 - log 19.3 FLOPs per $ (~21 quintillion)
# Year: 2035 - log 19.4 FLOPs per $ (~28 quintillion)
# Year: 2036 - log 19.6 FLOPs per $ (~37 quintillion)
# Year: 2037 - log 19.7 FLOPs per $ (~49 quintillion)
# Year: 2038 - log 19.8 FLOPs per $ (~64 quintillion)
# Year: 2039 - log 19.9 FLOPs per $ (~84 quintillion)
# Year: 2040 - log 20.0 FLOPs per $ (~111 quintillion)
# Year: 2041 - log 20.2 FLOPs per $ (~147 quintillion)
# Year: 2042 - log 20.3 FLOPs per $ (~194 quintillion)
# Year: 2043 - log 20.4 FLOPs per $ (~256 quintillion)
# Year: 2044 - log 20.5 FLOPs per $ (~338 quintillion)
# Year: 2045 - log 20.6 FLOPs per $ (~446 quintillion)
# Year: 2046 - log 20.8 FLOPs per $ (~588 quintillion)
# Year: 2047 - log 20.9 FLOPs per $ (~775 quintillion)
# Year: 2048 - log 21.0 FLOPs per $ (~1 sextillion)
# Year: 2049 - log 21.1 FLOPs per $ (~1 sextillion)
# Year: 2050 - log 21.3 FLOPs per $ (~2 sextillion)
# Year: 2051 - log 21.4 FLOPs per $ (~2 sextillion)
# Year: 2052 - log 21.5 FLOPs per $ (~3 sextillion)
# Year: 2053 - log 21.6 FLOPs per $ (~4 sextillion)
# Year: 2054 - log 21.7 FLOPs per $ (~5 sextillion)
# Year: 2055 - log 21.9 FLOPs per $ (~7 sextillion)
# Year: 2056 - log 22.0 FLOPs per $ (~9 sextillion)
# Year: 2057 - log 22.1 FLOPs per $ (~12 sextillion)
# Year: 2058 - log 22.2 FLOPs per $ (~16 sextillion)
# Year: 2059 - log 22.3 FLOPs per $ (~21 sextillion)
# Year: 2060 - log 22.4 FLOPs per $ (~28 sextillion)
# Year: 2061 - log 22.6 FLOPs per $ (~36 sextillion)
# Year: 2062 - log 22.7 FLOPs per $ (~47 sextillion)
# Year: 2063 - log 22.8 FLOPs per $ (~62 sextillion)
# Year: 2064 - log 22.9 FLOPs per $ (~80 sextillion)
# Year: 2065 - log 23.0 FLOPs per $ (~102 sextillion)
# Year: 2066 - log 23.1 FLOPs per $ (~131 sextillion)
# Year: 2067 - log 23.2 FLOPs per $ (~166 sextillion)
# Year: 2068 - log 23.3 FLOPs per $ (~208 sextillion)
# Year: 2069 - log 23.4 FLOPs per $ (~257 sextillion)
# Year: 2070 - log 23.5 FLOPs per $ (~313 sextillion)
# Year: 2071 - log 23.6 FLOPs per $ (~376 sextillion)
# Year: 2072 - log 23.6 FLOPs per $ (~443 sextillion)
# Year: 2073 - log 23.7 FLOPs per $ (~512 sextillion)
# Year: 2074 - log 23.8 FLOPs per $ (~580 sextillion)
# Year: 2075 - log 23.8 FLOPs per $ (~646 sextillion)
# Year: 2076 - log 23.8 FLOPs per $ (~707 sextillion)
# Year: 2077 - log 23.9 FLOPs per $ (~761 sextillion)
# Year: 2078 - log 23.9 FLOPs per $ (~807 sextillion)
# Year: 2079 - log 23.9 FLOPs per $ (~847 sextillion)
# Year: 2080 - log 23.9 FLOPs per $ (~880 sextillion)
# Year: 2081 - log 24.0 FLOPs per $ (~906 sextillion)
# Year: 2082 - log 24.0 FLOPs per $ (~927 sextillion)
# Year: 2083 - log 24.0 FLOPs per $ (~944 sextillion)
# Year: 2084 - log 24.0 FLOPs per $ (~957 sextillion)
# Year: 2085 - log 24.0 FLOPs per $ (~967 sextillion)
# Year: 2086 - log 24.0 FLOPs per $ (~975 sextillion)
# Year: 2087 - log 24.0 FLOPs per $ (~981 sextillion)
# Year: 2088 - log 24.0 FLOPs per $ (~985 sextillion)
# Year: 2089 - log 24.0 FLOPs per $ (~989 sextillion)
# Year: 2090 - log 24.0 FLOPs per $ (~992 sextillion)
# Year: 2091 - log 24.0 FLOPs per $ (~994 sextillion)
# Year: 2092 - log 24.0 FLOPs per $ (~995 sextillion)
# Year: 2093 - log 24.0 FLOPs per $ (~996 sextillion)
# Year: 2094 - log 24.0 FLOPs per $ (~997 sextillion)
# Year: 2095 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2096 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2097 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2098 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2099 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2100 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2101 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2102 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2103 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2104 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2105 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2106 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2107 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2108 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2109 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2110 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2111 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2112 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2113 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2114 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2115 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2116 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2117 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2118 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2119 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2120 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2121 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2122 - log 24.0 FLOPs per $ (~1000 sextillion)

# %% [markdown]
# ## Max Possible OOM Reduction in TAI FLOP Size

# %%
# TODO: Update to include efficiency based
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                         max_reduction_p[GRAPH_P], t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('max OOM reduction')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> {} OOM reductions possible'.format(t,
                                                                 round(possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                                  max_reduction_p[GRAPH_P],
                                                                                                  t), 2)))
# Out:
# TAI log FLOP 24 -> 2.0 OOM reductions possible
# TAI log FLOP 25 -> 2.0 OOM reductions possible
# TAI log FLOP 26 -> 2.0 OOM reductions possible
# TAI log FLOP 27 -> 2.0 OOM reductions possible
# TAI log FLOP 28 -> 2.0 OOM reductions possible
# TAI log FLOP 29 -> 2.0 OOM reductions possible
# TAI log FLOP 30 -> 2.0 OOM reductions possible
# TAI log FLOP 31 -> 2.0 OOM reductions possible
# TAI log FLOP 32 -> 2.0 OOM reductions possible
# TAI log FLOP 33 -> 2.0 OOM reductions possible
# TAI log FLOP 34 -> 2.0 OOM reductions possible
# TAI log FLOP 35 -> 3.0 OOM reductions possible
# TAI log FLOP 36 -> 3.0 OOM reductions possible
# TAI log FLOP 37 -> 3.0 OOM reductions possible
# TAI log FLOP 38 -> 4.0 OOM reductions possible
# TAI log FLOP 39 -> 4.0 OOM reductions possible
# TAI log FLOP 40 -> 4.0 OOM reductions possible
# TAI log FLOP 41 -> 4.0 OOM reductions possible
# TAI log FLOP 42 -> 4.0 OOM reductions possible
# TAI log FLOP 43 -> 5.0 OOM reductions possible
# TAI log FLOP 44 -> 5.0 OOM reductions possible
# TAI log FLOP 45 -> 5.0 OOM reductions possible
# TAI log FLOP 46 -> 5.0 OOM reductions possible
# TAI log FLOP 47 -> 5.0 OOM reductions possible
# TAI log FLOP 48 -> 5.0 OOM reductions possible
# TAI log FLOP 49 -> 5.0 OOM reductions possible
# TAI log FLOP 50 -> 5.0 OOM reductions possible
# TAI log FLOP 51 -> 5.0 OOM reductions possible
# TAI log FLOP 52 -> 5.0 OOM reductions possible
# TAI log FLOP 53 -> 5.0 OOM reductions possible
# TAI log FLOP 54 -> 5.0 OOM reductions possible
# TAI log FLOP 55 -> 5.0 OOM reductions possible
# TAI log FLOP 56 -> 5.0 OOM reductions possible
# TAI log FLOP 57 -> 5.0 OOM reductions possible
# TAI log FLOP 58 -> 5.0 OOM reductions possible
# TAI log FLOP 59 -> 5.0 OOM reductions possible

# %% [markdown]
# ## Halving time (years) of compute requirements

# %%
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                              algo_doubling_rate_max_p[GRAPH_P],
                                              t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('number of years for compute requirements to halve')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> algo doubling rate {}yrs'.format(t,
                                                               round(algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                                     algo_doubling_rate_max_p[GRAPH_P],
                                                                                     t), 2)))
# Out:
# TAI log FLOP 24 -> algo doubling rate 3.5yrs
# TAI log FLOP 25 -> algo doubling rate 3.5yrs
# TAI log FLOP 26 -> algo doubling rate 3.5yrs
# TAI log FLOP 27 -> algo doubling rate 3.5yrs
# TAI log FLOP 28 -> algo doubling rate 3.5yrs
# TAI log FLOP 29 -> algo doubling rate 3.5yrs
# TAI log FLOP 30 -> algo doubling rate 3.5yrs
# TAI log FLOP 31 -> algo doubling rate 3.0yrs
# TAI log FLOP 32 -> algo doubling rate 2.5yrs
# TAI log FLOP 33 -> algo doubling rate 2.5yrs
# TAI log FLOP 34 -> algo doubling rate 2.5yrs
# TAI log FLOP 35 -> algo doubling rate 2.0yrs
# TAI log FLOP 36 -> algo doubling rate 2.0yrs
# TAI log FLOP 37 -> algo doubling rate 2.0yrs
# TAI log FLOP 38 -> algo doubling rate 2.0yrs
# TAI log FLOP 39 -> algo doubling rate 2.0yrs
# TAI log FLOP 40 -> algo doubling rate 2.0yrs
# TAI log FLOP 41 -> algo doubling rate 2.0yrs
# TAI log FLOP 42 -> algo doubling rate 2.0yrs
# TAI log FLOP 43 -> algo doubling rate 2.0yrs
# TAI log FLOP 44 -> algo doubling rate 2.0yrs
# TAI log FLOP 45 -> algo doubling rate 2.0yrs
# TAI log FLOP 46 -> algo doubling rate 2.0yrs
# TAI log FLOP 47 -> algo doubling rate 2.0yrs
# TAI log FLOP 48 -> algo doubling rate 2.0yrs
# TAI log FLOP 49 -> algo doubling rate 2.0yrs
# TAI log FLOP 50 -> algo doubling rate 2.0yrs
# TAI log FLOP 51 -> algo doubling rate 2.0yrs
# TAI log FLOP 52 -> algo doubling rate 2.0yrs
# TAI log FLOP 53 -> algo doubling rate 2.0yrs
# TAI log FLOP 54 -> algo doubling rate 2.0yrs
# TAI log FLOP 55 -> algo doubling rate 2.0yrs
# TAI log FLOP 56 -> algo doubling rate 2.0yrs
# TAI log FLOP 57 -> algo doubling rate 2.0yrs
# TAI log FLOP 58 -> algo doubling rate 2.0yrs
# TAI log FLOP 59 -> algo doubling rate 2.0yrs

# %% [markdown]
# ## Dollars Needed to Buy TAI (Given Algorithmic Progress and Decline in Cost per FLOP)

# %%
cost_of_tai_ = np.array([cost_of_tai(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                     possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P], max_reduction_p[GRAPH_P], initial_flops_p[GRAPH_P]),
                                     algo_doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                        algo_doubling_rate_max_p[GRAPH_P],
                                                                        initial_flops_p[GRAPH_P]),
                                     initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                     max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                     flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                     year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(cost_of_tai_))
plt.ylabel('log $ needed to buy TAI')
# Out:
# Text(0, 0.5, 'log $ needed to buy TAI')

# %%
for y in years:
    print('Year: {} - log $ {} to buy TAI (~{})'.format(y,
                                                        np.round(np.log10(cost_of_tai_[y - CURRENT_YEAR]), 1),
                                                        numerize(cost_of_tai_[y - CURRENT_YEAR])))
# Out:
# Year: 2023 - log $ 14.4 to buy TAI (~268 trillion)
# Year: 2024 - log $ 14.2 to buy TAI (~156 trillion)
# Year: 2025 - log $ 14.0 to buy TAI (~90 trillion)
# Year: 2026 - log $ 13.7 to buy TAI (~52 trillion)
# Year: 2027 - log $ 13.5 to buy TAI (~30 trillion)
# Year: 2028 - log $ 13.2 to buy TAI (~17 trillion)
# Year: 2029 - log $ 13.0 to buy TAI (~10 trillion)
# Year: 2030 - log $ 12.8 to buy TAI (~6 trillion)
# Year: 2031 - log $ 12.5 to buy TAI (~3 trillion)
# Year: 2032 - log $ 12.3 to buy TAI (~2 trillion)
# Year: 2033 - log $ 12.1 to buy TAI (~1 trillion)
# Year: 2034 - log $ 11.9 to buy TAI (~730 billion)
# Year: 2035 - log $ 11.6 to buy TAI (~442 billion)
# Year: 2036 - log $ 11.4 to buy TAI (~272 billion)
# Year: 2037 - log $ 11.2 to buy TAI (~169 billion)
# Year: 2038 - log $ 11.0 to buy TAI (~108 billion)
# Year: 2039 - log $ 10.8 to buy TAI (~69 billion)
# Year: 2040 - log $ 10.7 to buy TAI (~46 billion)
# Year: 2041 - log $ 10.5 to buy TAI (~31 billion)
# Year: 2042 - log $ 10.3 to buy TAI (~21 billion)
# Year: 2043 - log $ 10.2 to buy TAI (~15 billion)
# Year: 2044 - log $ 10.0 to buy TAI (~10 billion)
# Year: 2045 - log $ 9.9 to buy TAI (~7 billion)
# Year: 2046 - log $ 9.7 to buy TAI (~5 billion)
# Year: 2047 - log $ 9.6 to buy TAI (~4 billion)
# Year: 2048 - log $ 9.5 to buy TAI (~3 billion)
# Year: 2049 - log $ 9.3 to buy TAI (~2 billion)
# Year: 2050 - log $ 9.2 to buy TAI (~2 billion)
# Year: 2051 - log $ 9.1 to buy TAI (~1 billion)
# Year: 2052 - log $ 9.0 to buy TAI (~896 million)
# Year: 2053 - log $ 8.8 to buy TAI (~674 million)
# Year: 2054 - log $ 8.7 to buy TAI (~509 million)
# Year: 2055 - log $ 8.6 to buy TAI (~384 million)
# Year: 2056 - log $ 8.5 to buy TAI (~291 million)
# Year: 2057 - log $ 8.3 to buy TAI (~221 million)
# Year: 2058 - log $ 8.2 to buy TAI (~168 million)
# Year: 2059 - log $ 8.1 to buy TAI (~127 million)
# Year: 2060 - log $ 8.0 to buy TAI (~97 million)
# Year: 2061 - log $ 7.9 to buy TAI (~74 million)
# Year: 2062 - log $ 7.8 to buy TAI (~57 million)
# Year: 2063 - log $ 7.6 to buy TAI (~44 million)
# Year: 2064 - log $ 7.5 to buy TAI (~34 million)
# Year: 2065 - log $ 7.4 to buy TAI (~26 million)
# Year: 2066 - log $ 7.3 to buy TAI (~21 million)
# Year: 2067 - log $ 7.2 to buy TAI (~16 million)
# Year: 2068 - log $ 7.1 to buy TAI (~13 million)
# Year: 2069 - log $ 7.0 to buy TAI (~10 million)
# Year: 2070 - log $ 6.9 to buy TAI (~9 million)
# Year: 2071 - log $ 6.9 to buy TAI (~7 million)
# Year: 2072 - log $ 6.8 to buy TAI (~6 million)
# Year: 2073 - log $ 6.7 to buy TAI (~5 million)
# Year: 2074 - log $ 6.7 to buy TAI (~5 million)
# Year: 2075 - log $ 6.6 to buy TAI (~4 million)
# Year: 2076 - log $ 6.6 to buy TAI (~4 million)
# Year: 2077 - log $ 6.5 to buy TAI (~4 million)
# Year: 2078 - log $ 6.5 to buy TAI (~3 million)
# Year: 2079 - log $ 6.5 to buy TAI (~3 million)
# Year: 2080 - log $ 6.5 to buy TAI (~3 million)
# Year: 2081 - log $ 6.5 to buy TAI (~3 million)
# Year: 2082 - log $ 6.5 to buy TAI (~3 million)
# Year: 2083 - log $ 6.5 to buy TAI (~3 million)
# Year: 2084 - log $ 6.4 to buy TAI (~3 million)
# Year: 2085 - log $ 6.4 to buy TAI (~3 million)
# Year: 2086 - log $ 6.4 to buy TAI (~3 million)
# Year: 2087 - log $ 6.4 to buy TAI (~3 million)
# Year: 2088 - log $ 6.4 to buy TAI (~3 million)
# Year: 2089 - log $ 6.4 to buy TAI (~3 million)
# Year: 2090 - log $ 6.4 to buy TAI (~3 million)
# Year: 2091 - log $ 6.4 to buy TAI (~3 million)
# Year: 2092 - log $ 6.4 to buy TAI (~3 million)
# Year: 2093 - log $ 6.4 to buy TAI (~3 million)
# Year: 2094 - log $ 6.4 to buy TAI (~3 million)
# Year: 2095 - log $ 6.4 to buy TAI (~3 million)
# Year: 2096 - log $ 6.4 to buy TAI (~3 million)
# Year: 2097 - log $ 6.4 to buy TAI (~3 million)
# Year: 2098 - log $ 6.4 to buy TAI (~3 million)
# Year: 2099 - log $ 6.4 to buy TAI (~3 million)
# Year: 2100 - log $ 6.4 to buy TAI (~3 million)
# Year: 2101 - log $ 6.4 to buy TAI (~3 million)
# Year: 2102 - log $ 6.4 to buy TAI (~3 million)
# Year: 2103 - log $ 6.4 to buy TAI (~3 million)
# Year: 2104 - log $ 6.4 to buy TAI (~3 million)
# Year: 2105 - log $ 6.4 to buy TAI (~3 million)
# Year: 2106 - log $ 6.4 to buy TAI (~3 million)
# Year: 2107 - log $ 6.4 to buy TAI (~3 million)
# Year: 2108 - log $ 6.4 to buy TAI (~3 million)
# Year: 2109 - log $ 6.4 to buy TAI (~3 million)
# Year: 2110 - log $ 6.4 to buy TAI (~3 million)
# Year: 2111 - log $ 6.4 to buy TAI (~3 million)
# Year: 2112 - log $ 6.4 to buy TAI (~3 million)
# Year: 2113 - log $ 6.4 to buy TAI (~3 million)
# Year: 2114 - log $ 6.4 to buy TAI (~3 million)
# Year: 2115 - log $ 6.4 to buy TAI (~3 million)
# Year: 2116 - log $ 6.4 to buy TAI (~3 million)
# Year: 2117 - log $ 6.4 to buy TAI (~3 million)
# Year: 2118 - log $ 6.4 to buy TAI (~3 million)
# Year: 2119 - log $ 6.4 to buy TAI (~3 million)
# Year: 2120 - log $ 6.4 to buy TAI (~3 million)
# Year: 2121 - log $ 6.4 to buy TAI (~3 million)
# Year: 2122 - log $ 6.4 to buy TAI (~3 million)

# %% [markdown]
# ## FLOPs at Max Spend

# %%
flops_at_max_ = np.array([flops_at_max(initial_gdp=variables['initial_gdp'],
                                       gdp_growth=gdp_growth_p[GRAPH_P],
                                       initial_pay=10 ** initial_pay_p[GRAPH_P],
                                       spend_doubling_time=spend_doubling_time_p[GRAPH_P],
                                       max_gdp_frac=max_gdp_frac_p[GRAPH_P],
                                       initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                       max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                       flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                       year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_at_max_))
plt.ylabel('max log FLOPs bought given willingness to spend')
# Out:
# Text(0, 0.5, 'max log FLOPs bought given willingness to spend')

# %%
for y in years:
    print('Year: {} - max log FLOPs {} (~{} FLOP, ~{} petaFLOP/s-days)'.format(y,
                                                                               np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]), 1),
                                                                               numerize(flops_at_max_[y - CURRENT_YEAR]),
                                                                               log_flop_to_petaflop_sdays(np.log10(flops_at_max_[y - CURRENT_YEAR]))))
# Out:
# Year: 2023 - max log FLOPs 26.7 (~500 septillion FLOP, ~5788160 petaFLOP/s-days)
# Year: 2024 - max log FLOPs 26.9 (~870 septillion FLOP, ~10071613 petaFLOP/s-days)
# Year: 2025 - max log FLOPs 27.2 (~2 octillion FLOP, ~17521978 petaFLOP/s-days)
# Year: 2026 - max log FLOPs 27.4 (~3 octillion FLOP, ~30476994 petaFLOP/s-days)
# Year: 2027 - max log FLOPs 27.7 (~5 octillion FLOP, ~52995557 petaFLOP/s-days)
# Year: 2028 - max log FLOPs 27.9 (~8 octillion FLOP, ~92119456 petaFLOP/s-days)
# Year: 2029 - max log FLOPs 28.1 (~14 octillion FLOP, ~160053360 petaFLOP/s-days)
# Year: 2030 - max log FLOPs 28.4 (~24 octillion FLOP, ~277923359 petaFLOP/s-days)
# Year: 2031 - max log FLOPs 28.6 (~42 octillion FLOP, ~482239424 petaFLOP/s-days)
# Year: 2032 - max log FLOPs 28.9 (~72 octillion FLOP, ~835968586 petaFLOP/s-days)
# Year: 2033 - max log FLOPs 29.1 (~125 octillion FLOP, ~1447424932 petaFLOP/s-days)
# Year: 2034 - max log FLOPs 29.3 (~216 octillion FLOP, ~2502314969 petaFLOP/s-days)
# Year: 2035 - max log FLOPs 29.6 (~373 octillion FLOP, ~4317717332 petaFLOP/s-days)
# Year: 2036 - max log FLOPs 29.8 (~642 octillion FLOP, ~7432205112 petaFLOP/s-days)
# Year: 2037 - max log FLOPs 30.0 (~1 nonillion FLOP, ~12754642497 petaFLOP/s-days)
# Year: 2038 - max log FLOPs 30.3 (~2 nonillion FLOP, ~21806469886 petaFLOP/s-days)
# Year: 2039 - max log FLOPs 30.5 (~3 nonillion FLOP, ~37109515869 petaFLOP/s-days)
# Year: 2040 - max log FLOPs 30.7 (~5 nonillion FLOP, ~62793906010 petaFLOP/s-days)
# Year: 2041 - max log FLOPs 31.0 (~9 nonillion FLOP, ~105527351497 petaFLOP/s-days)
# Year: 2042 - max log FLOPs 31.2 (~15 nonillion FLOP, ~175894399121 petaFLOP/s-days)
# Year: 2043 - max log FLOPs 31.4 (~25 nonillion FLOP, ~290375799920 petaFLOP/s-days)
# Year: 2044 - max log FLOPs 31.6 (~41 nonillion FLOP, ~474087092562 petaFLOP/s-days)
# Year: 2045 - max log FLOPs 31.8 (~66 nonillion FLOP, ~764430374713 petaFLOP/s-days)
# Year: 2046 - max log FLOPs 32.0 (~105 nonillion FLOP, ~1215807569701 petaFLOP/s-days)
# Year: 2047 - max log FLOPs 32.2 (~165 nonillion FLOP, ~1905572625077 petaFLOP/s-days)
# Year: 2048 - max log FLOPs 32.4 (~254 nonillion FLOP, ~2941514941226 petaFLOP/s-days)
# Year: 2049 - max log FLOPs 32.6 (~386 nonillion FLOP, ~4471408441312 petaFLOP/s-days)
# Year: 2050 - max log FLOPs 32.8 (~578 nonillion FLOP, ~6695531011412 petaFLOP/s-days)
# Year: 2051 - max log FLOPs 32.9 (~854 nonillion FLOP, ~9883510053743 petaFLOP/s-days)
# Year: 2052 - max log FLOPs 33.1 (~1 decillion FLOP, ~14397318600413 petaFLOP/s-days)
# Year: 2053 - max log FLOPs 33.3 (~2 decillion FLOP, ~20722705449335 petaFLOP/s-days)
# Year: 2054 - max log FLOPs 33.4 (~3 decillion FLOP, ~29511821560308 petaFLOP/s-days)
# Year: 2055 - max log FLOPs 33.6 (~4 decillion FLOP, ~41640356935701 petaFLOP/s-days)
# Year: 2056 - max log FLOPs 33.7 (~5 decillion FLOP, ~58283139160494 petaFLOP/s-days)
# Year: 2057 - max log FLOPs 33.8 (~7 decillion FLOP, ~81012772099467 petaFLOP/s-days)
# Year: 2058 - max log FLOPs 34.0 (~10 decillion FLOP, ~111926252756439 petaFLOP/s-days)
# Year: 2059 - max log FLOPs 34.1 (~13 decillion FLOP, ~153804101212917 petaFLOP/s-days)
# Year: 2060 - max log FLOPs 34.3 (~18 decillion FLOP, ~210304528090284 petaFLOP/s-days)
# Year: 2061 - max log FLOPs 34.4 (~25 decillion FLOP, ~286190201652660 petaFLOP/s-days)
# Year: 2062 - max log FLOPs 34.5 (~33 decillion FLOP, ~387575296995410 petaFLOP/s-days)
# Year: 2063 - max log FLOPs 34.7 (~45 decillion FLOP, ~522163211238782 petaFLOP/s-days)
# Year: 2064 - max log FLOPs 34.8 (~60 decillion FLOP, ~699418239268062 petaFLOP/s-days)
# Year: 2065 - max log FLOPs 34.9 (~80 decillion FLOP, ~930577256714947 petaFLOP/s-days)
# Year: 2066 - max log FLOPs 35.0 (~106 decillion FLOP, ~1228365491984031 petaFLOP/s-days)
# Year: 2067 - max log FLOPs 35.1 (~139 decillion FLOP, ~1606250772905584 petaFLOP/s-days)
# Year: 2068 - max log FLOPs 35.3 (~179 decillion FLOP, ~2077086734639998 petaFLOP/s-days)
# Year: 2069 - max log FLOPs 35.4 (~229 decillion FLOP, ~2651103786086439 petaFLOP/s-days)
# Year: 2070 - max log FLOPs 35.5 (~288 decillion FLOP, ~3333441545018589 petaFLOP/s-days)
# Year: 2071 - max log FLOPs 35.6 (~356 decillion FLOP, ~4121748733476640 petaFLOP/s-days)
# Year: 2072 - max log FLOPs 35.6 (~432 decillion FLOP, ~5004662419105546 petaFLOP/s-days)
# Year: 2073 - max log FLOPs 35.7 (~515 decillion FLOP, ~5961982727485097 petaFLOP/s-days)
# Year: 2074 - max log FLOPs 35.8 (~602 decillion FLOP, ~6966912550862773 petaFLOP/s-days)
# Year: 2075 - max log FLOPs 35.8 (~690 decillion FLOP, ~7989944647713444 petaFLOP/s-days)
# Year: 2076 - max log FLOPs 35.9 (~778 decillion FLOP, ~9003272559114456 petaFLOP/s-days)
# Year: 2077 - max log FLOPs 35.9 (~863 decillion FLOP, ~9984421984605482 petaFLOP/s-days)
# Year: 2078 - max log FLOPs 36.0 (~943 decillion FLOP, ~10918238336892204 petaFLOP/s-days)
# Year: 2079 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~11797099666799954 petaFLOP/s-days)
# Year: 2080 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~12619813803034658 petaFLOP/s-days)
# Year: 2081 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~13389879193348020 petaFLOP/s-days)
# Year: 2082 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~14113691985936394 petaFLOP/s-days)
# Year: 2083 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~14799046670535628 petaFLOP/s-days)
# Year: 2084 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~15454055138533758 petaFLOP/s-days)
# Year: 2085 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~16086465118186086 petaFLOP/s-days)
# Year: 2086 - max log FLOPs 36.2 (~1 thousand decillion FLOP, ~16703293980739896 petaFLOP/s-days)
# Year: 2087 - max log FLOPs 36.2 (~1 thousand decillion FLOP, ~17310681679703750 petaFLOP/s-days)
# Year: 2088 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~17913880241438342 petaFLOP/s-days)
# Year: 2089 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~18517318786926288 petaFLOP/s-days)
# Year: 2090 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19124703402086716 petaFLOP/s-days)
# Year: 2091 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19739126999622892 petaFLOP/s-days)
# Year: 2092 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~20363175335148432 petaFLOP/s-days)
# Year: 2093 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~20999022424367372 petaFLOP/s-days)
# Year: 2094 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~21648512856734824 petaFLOP/s-days)
# Year: 2095 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~22313230866540812 petaFLOP/s-days)
# Year: 2096 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~22994557211929564 petaFLOP/s-days)
# Year: 2097 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~23693715407147548 petaFLOP/s-days)
# Year: 2098 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~24411808961663332 petaFLOP/s-days)
# Year: 2099 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~25149851190103744 petaFLOP/s-days)
# Year: 2100 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~25908788979311132 petaFLOP/s-days)
# Year: 2101 - max log FLOPs 36.4 (~2 thousand decillion FLOP, ~26689521694325084 petaFLOP/s-days)
# Year: 2102 - max log FLOPs 36.4 (~2 thousand decillion FLOP, ~27492916205668484 petaFLOP/s-days)
# Year: 2103 - max log FLOPs 36.4 (~2 thousand decillion FLOP, ~28319818840571320 petaFLOP/s-days)
# Year: 2104 - max log FLOPs 36.4 (~3 thousand decillion FLOP, ~29171064906089484 petaFLOP/s-days)
# Year: 2105 - max log FLOPs 36.4 (~3 thousand decillion FLOP, ~30047486302713152 petaFLOP/s-days)
# Year: 2106 - max log FLOPs 36.4 (~3 thousand decillion FLOP, ~30949917640945568 petaFLOP/s-days)
# Year: 2107 - max log FLOPs 36.4 (~3 thousand decillion FLOP, ~31879201187451368 petaFLOP/s-days)
# Year: 2108 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~32836190898516912 petaFLOP/s-days)
# Year: 2109 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~33821755743739716 petaFLOP/s-days)
# Year: 2110 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~34836782479439860 petaFLOP/s-days)
# Year: 2111 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~35882177996994352 petaFLOP/s-days)
# Year: 2112 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~36958871344320768 petaFLOP/s-days)
# Year: 2113 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~38067815497561232 petaFLOP/s-days)
# Year: 2114 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~39209988943368200 petaFLOP/s-days)
# Year: 2115 - max log FLOPs 36.5 (~3 thousand decillion FLOP, ~40386397119226480 petaFLOP/s-days)
# Year: 2116 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~41598073749021304 petaFLOP/s-days)
# Year: 2117 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~42846082103137640 petaFLOP/s-days)
# Year: 2118 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~44131516206145640 petaFLOP/s-days)
# Year: 2119 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~45455502010259344 petaFLOP/s-days)
# Year: 2120 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~46819198549016312 petaFLOP/s-days)
# Year: 2121 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~48223799082601816 petaFLOP/s-days)
# Year: 2122 - max log FLOPs 36.6 (~4 thousand decillion FLOP, ~49670532244024192 petaFLOP/s-days)

# %% [markdown]
# ## Parameters at Max Spend

# %%
for y in years:
    print('Year: {} - max log parameters {} (~{} parameters)'.format(y,
                                                                     np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12, 1),
                                                                     numerize(10 ** (np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12))))
# Out:
# Year: 2023 - max log parameters 14.7 (~500 trillion parameters)
# Year: 2024 - max log parameters 14.9 (~870 trillion parameters)
# Year: 2025 - max log parameters 15.2 (~2 quadrillion parameters)
# Year: 2026 - max log parameters 15.4 (~3 quadrillion parameters)
# Year: 2027 - max log parameters 15.7 (~5 quadrillion parameters)
# Year: 2028 - max log parameters 15.9 (~8 quadrillion parameters)
# Year: 2029 - max log parameters 16.1 (~14 quadrillion parameters)
# Year: 2030 - max log parameters 16.4 (~24 quadrillion parameters)
# Year: 2031 - max log parameters 16.6 (~42 quadrillion parameters)
# Year: 2032 - max log parameters 16.9 (~72 quadrillion parameters)
# Year: 2033 - max log parameters 17.1 (~125 quadrillion parameters)
# Year: 2034 - max log parameters 17.3 (~216 quadrillion parameters)
# Year: 2035 - max log parameters 17.6 (~373 quadrillion parameters)
# Year: 2036 - max log parameters 17.8 (~642 quadrillion parameters)
# Year: 2037 - max log parameters 18.0 (~1 quintillion parameters)
# Year: 2038 - max log parameters 18.3 (~2 quintillion parameters)
# Year: 2039 - max log parameters 18.5 (~3 quintillion parameters)
# Year: 2040 - max log parameters 18.7 (~5 quintillion parameters)
# Year: 2041 - max log parameters 19.0 (~9 quintillion parameters)
# Year: 2042 - max log parameters 19.2 (~15 quintillion parameters)
# Year: 2043 - max log parameters 19.4 (~25 quintillion parameters)
# Year: 2044 - max log parameters 19.6 (~41 quintillion parameters)
# Year: 2045 - max log parameters 19.8 (~66 quintillion parameters)
# Year: 2046 - max log parameters 20.0 (~105 quintillion parameters)
# Year: 2047 - max log parameters 20.2 (~165 quintillion parameters)
# Year: 2048 - max log parameters 20.4 (~254 quintillion parameters)
# Year: 2049 - max log parameters 20.6 (~386 quintillion parameters)
# Year: 2050 - max log parameters 20.8 (~578 quintillion parameters)
# Year: 2051 - max log parameters 20.9 (~854 quintillion parameters)
# Year: 2052 - max log parameters 21.1 (~1 sextillion parameters)
# Year: 2053 - max log parameters 21.3 (~2 sextillion parameters)
# Year: 2054 - max log parameters 21.4 (~3 sextillion parameters)
# Year: 2055 - max log parameters 21.6 (~4 sextillion parameters)
# Year: 2056 - max log parameters 21.7 (~5 sextillion parameters)
# Year: 2057 - max log parameters 21.8 (~7 sextillion parameters)
# Year: 2058 - max log parameters 22.0 (~10 sextillion parameters)
# Year: 2059 - max log parameters 22.1 (~13 sextillion parameters)
# Year: 2060 - max log parameters 22.3 (~18 sextillion parameters)
# Year: 2061 - max log parameters 22.4 (~25 sextillion parameters)
# Year: 2062 - max log parameters 22.5 (~33 sextillion parameters)
# Year: 2063 - max log parameters 22.7 (~45 sextillion parameters)
# Year: 2064 - max log parameters 22.8 (~60 sextillion parameters)
# Year: 2065 - max log parameters 22.9 (~80 sextillion parameters)
# Year: 2066 - max log parameters 23.0 (~106 sextillion parameters)
# Year: 2067 - max log parameters 23.1 (~139 sextillion parameters)
# Year: 2068 - max log parameters 23.3 (~179 sextillion parameters)
# Year: 2069 - max log parameters 23.4 (~229 sextillion parameters)
# Year: 2070 - max log parameters 23.5 (~288 sextillion parameters)
# Year: 2071 - max log parameters 23.6 (~356 sextillion parameters)
# Year: 2072 - max log parameters 23.6 (~432 sextillion parameters)
# Year: 2073 - max log parameters 23.7 (~515 sextillion parameters)
# Year: 2074 - max log parameters 23.8 (~602 sextillion parameters)
# Year: 2075 - max log parameters 23.8 (~690 sextillion parameters)
# Year: 2076 - max log parameters 23.9 (~778 sextillion parameters)
# Year: 2077 - max log parameters 23.9 (~863 sextillion parameters)
# Year: 2078 - max log parameters 24.0 (~943 sextillion parameters)
# Year: 2079 - max log parameters 24.0 (~1 septillion parameters)
# Year: 2080 - max log parameters 24.0 (~1 septillion parameters)
# Year: 2081 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2082 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2083 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2084 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2085 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2086 - max log parameters 24.2 (~1 septillion parameters)
# Year: 2087 - max log parameters 24.2 (~1 septillion parameters)
# Year: 2088 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2089 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2090 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2091 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2092 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2093 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2094 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2095 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2096 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2097 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2098 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2099 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2100 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2101 - max log parameters 24.4 (~2 septillion parameters)
# Year: 2102 - max log parameters 24.4 (~2 septillion parameters)
# Year: 2103 - max log parameters 24.4 (~2 septillion parameters)
# Year: 2104 - max log parameters 24.4 (~3 septillion parameters)
# Year: 2105 - max log parameters 24.4 (~3 septillion parameters)
# Year: 2106 - max log parameters 24.4 (~3 septillion parameters)
# Year: 2107 - max log parameters 24.4 (~3 septillion parameters)
# Year: 2108 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2109 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2110 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2111 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2112 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2113 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2114 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2115 - max log parameters 24.5 (~3 septillion parameters)
# Year: 2116 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2117 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2118 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2119 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2120 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2121 - max log parameters 24.6 (~4 septillion parameters)
# Year: 2122 - max log parameters 24.6 (~4 septillion parameters)

# %% [markdown]
# ## Chance of Non-scaling Delay

# %%
p_nonscaling_delay_ = np.array([p_nonscaling_delay(variables.get('initial_chance_of_nonscaling_issue', 0),
                                                   variables.get('final_chance_of_nonscaling_issue', 0),
                                                   year=y,
                                                   max_year=variables.get('nonscaling_issue_bottom_year', 0)) for y in years])

plt.plot(years[:60], p_nonscaling_delay_[:60])
plt.ylabel('chance of non-scaling delay by year')
# Out:
# Text(0, 0.5, 'chance of non-scaling delay by year')

# %%
for y in years:
    print('Year: {} - p(nonscaling delay) = {}%'.format(y,
                                                        np.round(p_nonscaling_delay_[y - CURRENT_YEAR] * 100, 1)))
# Out:
# Year: 2023 - p(nonscaling delay) = 0.0%
# Year: 2024 - p(nonscaling delay) = 0.0%
# Year: 2025 - p(nonscaling delay) = 0.0%
# Year: 2026 - p(nonscaling delay) = 0.0%
# Year: 2027 - p(nonscaling delay) = 0.0%
# Year: 2028 - p(nonscaling delay) = 0.0%
# Year: 2029 - p(nonscaling delay) = 0.0%
# Year: 2030 - p(nonscaling delay) = 0.0%
# Year: 2031 - p(nonscaling delay) = 0.0%
# Year: 2032 - p(nonscaling delay) = 0.0%
# Year: 2033 - p(nonscaling delay) = 0.0%
# Year: 2034 - p(nonscaling delay) = 0.0%
# Year: 2035 - p(nonscaling delay) = 0.0%
# Year: 2036 - p(nonscaling delay) = 0.0%
# Year: 2037 - p(nonscaling delay) = 0.0%
# Year: 2038 - p(nonscaling delay) = 0.0%
# Year: 2039 - p(nonscaling delay) = 0.0%
# Year: 2040 - p(nonscaling delay) = 0.0%
# Year: 2041 - p(nonscaling delay) = 0.0%
# Year: 2042 - p(nonscaling delay) = 0.0%
# Year: 2043 - p(nonscaling delay) = 0.0%
# Year: 2044 - p(nonscaling delay) = 0.0%
# Year: 2045 - p(nonscaling delay) = 0.0%
# Year: 2046 - p(nonscaling delay) = 0.0%
# Year: 2047 - p(nonscaling delay) = 0.0%
# Year: 2048 - p(nonscaling delay) = 0.0%
# Year: 2049 - p(nonscaling delay) = 0.0%
# Year: 2050 - p(nonscaling delay) = 0.0%
# Year: 2051 - p(nonscaling delay) = 0.0%
# Year: 2052 - p(nonscaling delay) = 0.0%
# Year: 2053 - p(nonscaling delay) = 0.0%
# Year: 2054 - p(nonscaling delay) = 0.0%
# Year: 2055 - p(nonscaling delay) = 0.0%
# Year: 2056 - p(nonscaling delay) = 0.0%
# Year: 2057 - p(nonscaling delay) = 0.0%
# Year: 2058 - p(nonscaling delay) = 0.0%
# Year: 2059 - p(nonscaling delay) = 0.0%
# Year: 2060 - p(nonscaling delay) = 0.0%
# Year: 2061 - p(nonscaling delay) = 0.0%
# Year: 2062 - p(nonscaling delay) = 0.0%
# Year: 2063 - p(nonscaling delay) = 0.0%
# Year: 2064 - p(nonscaling delay) = 0.0%
# Year: 2065 - p(nonscaling delay) = 0.0%
# Year: 2066 - p(nonscaling delay) = 0.0%
# Year: 2067 - p(nonscaling delay) = 0.0%
# Year: 2068 - p(nonscaling delay) = 0.0%
# Year: 2069 - p(nonscaling delay) = 0.0%
# Year: 2070 - p(nonscaling delay) = 0.0%
# Year: 2071 - p(nonscaling delay) = 0.0%
# Year: 2072 - p(nonscaling delay) = 0.0%
# Year: 2073 - p(nonscaling delay) = 0.0%
# Year: 2074 - p(nonscaling delay) = 0.0%
# Year: 2075 - p(nonscaling delay) = 0.0%
# Year: 2076 - p(nonscaling delay) = 0.0%
# Year: 2077 - p(nonscaling delay) = 0.0%
# Year: 2078 - p(nonscaling delay) = 0.0%
# Year: 2079 - p(nonscaling delay) = 0.0%
# Year: 2080 - p(nonscaling delay) = 0.0%
# Year: 2081 - p(nonscaling delay) = 0.0%
# Year: 2082 - p(nonscaling delay) = 0.0%
# Year: 2083 - p(nonscaling delay) = 0.0%
# Year: 2084 - p(nonscaling delay) = 0.0%
# Year: 2085 - p(nonscaling delay) = 0.0%
# Year: 2086 - p(nonscaling delay) = 0.0%
# Year: 2087 - p(nonscaling delay) = 0.0%
# Year: 2088 - p(nonscaling delay) = 0.0%
# Year: 2089 - p(nonscaling delay) = 0.0%
# Year: 2090 - p(nonscaling delay) = 0.0%
# Year: 2091 - p(nonscaling delay) = 0.0%
# Year: 2092 - p(nonscaling delay) = 0.0%
# Year: 2093 - p(nonscaling delay) = 0.0%
# Year: 2094 - p(nonscaling delay) = 0.0%
# Year: 2095 - p(nonscaling delay) = 0.0%
# Year: 2096 - p(nonscaling delay) = 0.0%
# Year: 2097 - p(nonscaling delay) = 0.0%
# Year: 2098 - p(nonscaling delay) = 0.0%
# Year: 2099 - p(nonscaling delay) = 0.0%
# Year: 2100 - p(nonscaling delay) = 0.0%
# Year: 2101 - p(nonscaling delay) = 0.0%
# Year: 2102 - p(nonscaling delay) = 0.0%
# Year: 2103 - p(nonscaling delay) = 0.0%
# Year: 2104 - p(nonscaling delay) = 0.0%
# Year: 2105 - p(nonscaling delay) = 0.0%
# Year: 2106 - p(nonscaling delay) = 0.0%
# Year: 2107 - p(nonscaling delay) = 0.0%
# Year: 2108 - p(nonscaling delay) = 0.0%
# Year: 2109 - p(nonscaling delay) = 0.0%
# Year: 2110 - p(nonscaling delay) = 0.0%
# Year: 2111 - p(nonscaling delay) = 0.0%
# Year: 2112 - p(nonscaling delay) = 0.0%
# Year: 2113 - p(nonscaling delay) = 0.0%
# Year: 2114 - p(nonscaling delay) = 0.0%
# Year: 2115 - p(nonscaling delay) = 0.0%
# Year: 2116 - p(nonscaling delay) = 0.0%
# Year: 2117 - p(nonscaling delay) = 0.0%
# Year: 2118 - p(nonscaling delay) = 0.0%
# Year: 2119 - p(nonscaling delay) = 0.0%
# Year: 2120 - p(nonscaling delay) = 0.0%
# Year: 2121 - p(nonscaling delay) = 0.0%
# Year: 2122 - p(nonscaling delay) = 0.0%

# %% [markdown]
# ## Run Model

# %%
def run_model(initial_gdp_, tai_flop_size_, nonscaling_delay_, algo_doubling_rate_,
              possible_algo_reduction_, initial_flops_per_dollar_, flops_halving_rate_,
              max_flops_per_dollar_, initial_pay_, gdp_growth_, max_gdp_frac_,
              willingness_ramp_, spend_doubling_time_, initial_chance_of_nonscaling_issue_,
              final_chance_of_nonscaling_issue_, nonscaling_issue_bottom_year_,
              willingness_spend_horizon_, print_diagnostic):
    queue_tai_year = 99999
    plt.ioff()
    if print_diagnostic:
        cost_of_tai_collector = []
        willingness_collector = []
    
    if print_diagnostic:
        print('It takes {} log FLOPs (~{}) for transformative capabilities.'.format(np.round(tai_flop_size_, 1),
                                                                                    numerize(10 ** tai_flop_size_)))
        print('Every {} years algorithms get 2x better, with {} log reductions possible.'.format(np.round(algo_doubling_rate_, 1),
                                                                                                 np.round(possible_algo_reduction_, 1)))
        print(('FLOPs start at a cost of {} log FLOPs (~{}) per 2022$USD. Every {} years they get ' +
               '2x cheaper, to a maximum of {} log FLOPs (~{}) per 2022$USD.').format(np.round(math.log10(initial_flops_per_dollar_), 1),
                                                                               numerize(initial_flops_per_dollar_),
                                                                               np.round(flops_halving_rate_, 1),
                                                                               np.round(math.log10(max_flops_per_dollar_), 1),
                                                                               numerize(max_flops_per_dollar_)))
        print(('We are willing to pay {} log 2022$USD (~{}) and this increases by {}x per year to a max of {}% of GDP. ' +
               'GDP grows at a rate of {}x per year.').format(np.round(math.log10(initial_pay_), 1),
                                                              numerize(initial_pay_),
                                                              np.round(spend_doubling_time_, 1),
                                                              np.round(max_gdp_frac_, 4),
                                                              np.round(gdp_growth_, 3)))
        if willingness_ramp_ < 1:
            print('In this simulation, if we are {}% of the way to paying for TAI, we will ramp to paying for TAI.'.format(np.round(willingness_ramp_ * 100)))

        if willingness_spend_horizon_ > 1:
            print('We are willing to spend over {} years to make TAI'.format(willingness_spend_horizon_))
            
        print(('If a non-scaling delay happens, it will take an additional {} years to produce TAI due' +
               ' to issues unrelated to scaling FLOP').format(np.round(nonscaling_delay_, 1)))
        print('---')
    
    tai_created = False
    is_nonscaling_issue = None
    for y in years:
        if not tai_created:
            flops_needed_ = flops_needed(initial_flops=10 ** tai_flop_size_,
                                         doubling_rate=algo_doubling_rate_,
                                         possible_reduction=10 ** possible_algo_reduction_,
                                         year=(y - CURRENT_YEAR))
            
            flops_per_dollar_ = flops_per_dollar(initial_flops_per_dollar=initial_flops_per_dollar_,
                                                 max_flops_per_dollar=max_flops_per_dollar_,
                                                 halving_rate=flops_halving_rate_,
                                                 year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200 or flops_needed_ > 10 ** 200:
                flops_needed_ = int(flops_needed_)
                flops_per_dollar_ = int(flops_per_dollar_)
                cost_of_tai_ = flops_needed_ // flops_per_dollar_
            else:
                cost_of_tai_ = flops_needed_ / flops_per_dollar_
            
            willingness_ = willingness_to_pay(initial_gdp=initial_gdp_,
                                              gdp_growth=gdp_growth_,
                                              initial_pay=initial_pay_,
                                              spend_doubling_time=spend_doubling_time_,
                                              max_gdp_frac=max_gdp_frac_,
                                              year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200:
                willingness_ = int(willingness_)
            if willingness_ > 10 ** 200:
                flops_per_dollar_ = int(flops_per_dollar_)
            
            if print_diagnostic:
                cost_of_tai_collector.append(cost_of_tai_)
                willingness_collector.append(willingness_)
            
            total_compute_ = willingness_ * flops_per_dollar_
            
            if print_diagnostic:
                out_str = ('Year: {} - {} max log FLOP ({}) available - TAI takes {} log FLOP ({}) - ' +
                           'log $ {} to buy TAI ({}) vs. willingness to pay log $ {} ({}) - {} log FLOPS per $ ({})')
                print(out_str.format(y,
                                     np.round(math.log10(total_compute_), 1),
                                     numerize(total_compute_),
                                     np.round(math.log10(flops_needed_), 1),
                                     numerize(flops_needed_),
                                     np.round(math.log10(cost_of_tai_), 1),
                                     numerize(cost_of_tai_),
                                     np.round(math.log10(willingness_), 1),
                                     numerize(willingness_),
                                     np.round(math.log10(flops_per_dollar_), 1),
                                     numerize(flops_per_dollar_)))
            
            if cost_of_tai_ > 10 ** 200:
                spend_tai_years = int(cost_of_tai_) // int(willingness_)
            else:
                spend_tai_years = cost_of_tai_ / willingness_
                
            if not is_nonscaling_issue and queue_tai_year < 99999 and print_diagnostic:
                print('-$- {}/{}'.format(y, queue_tai_year))
            if (cost_of_tai_ * willingness_ramp_) <= willingness_ or y >= queue_tai_year:
                if is_nonscaling_issue is None:
                    p_nonscaling_delay_ = p_nonscaling_delay(initial_chance_of_nonscaling_issue_,
                                                             final_chance_of_nonscaling_issue_,
                                                             year=y,
                                                             max_year=nonscaling_issue_bottom_year_)
                    is_nonscaling_issue = sq.event(p_nonscaling_delay_)
                    nonscaling_countdown = nonscaling_delay_
                    if print_diagnostic:
                        print('-- {} p_nonscaling_issue={}'.format('Nonscaling delay occured' if is_nonscaling_issue else 'Nonscaling issue did not occur',
                                                                   np.round(p_nonscaling_delay_, 4)))
                
                if not is_nonscaling_issue or nonscaling_countdown <= 0.1:
                    if print_diagnostic:
                        print('--- /!\ TAI CREATED in {}'.format(y))
                        plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
                    return y
                else:
                    if print_diagnostic:
                        print('/!\ FLOPs for TAI sufficient but needs {} more years to solve non-scaling issues'.format(np.round(nonscaling_countdown, 1)))
                    nonscaling_countdown -= 1
            elif (not is_nonscaling_issue and willingness_spend_horizon_ > 1 and
                  spend_tai_years <= willingness_spend_horizon_ and y + math.ceil(spend_tai_years) < queue_tai_year):
                queue_tai_year = y + math.ceil(spend_tai_years)
                if print_diagnostic:
                    print('-$- We have enough spend to make TAI in {} years (in {}) if sustained.'.format(math.ceil(spend_tai_years),
                                                                                                          queue_tai_year))
                
    if not tai_created:
        if print_diagnostic:
            print('--- :/ TAI NOT CREATED BEFORE {}'.format(MAX_YEAR + 1))
            plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
        return MAX_YEAR + 1
    
    
def define_event(verbose=False):
    tai_flop_size_ = sq.sample(sq.discrete(variables['tai_flop_size']))

    if tai_flop_size_ > 300:
        tai_flop_size_ = int(tai_flop_size_) # Handle overflow errors
    
    algo_doubling_rate_ = algo_halving_fn(sq.sample(variables['algo_doubling_rate_min']),
                                          sq.sample(variables['algo_doubling_rate_max']),
                                          tai_flop_size_)
    
    possible_algo_reduction_ = possible_algo_reduction_fn(sq.sample(variables['min_reduction']),
                                                          sq.sample(variables['max_reduction']),
                                                          tai_flop_size_)
    
    initial_flops_per_dollar_ = 10 ** sq.sample(variables['initial_flops_per_dollar'])
    flops_halving_rate_ = sq.sample(variables['flops_halving_rate'])
    max_flops_per_dollar_ = 10 ** sq.sample(variables['max_flops_per_dollar'])
    initial_pay_ = 10 ** sq.sample(variables['initial_pay'])
    gdp_growth_ = sq.sample(variables['gdp_growth'])
    max_gdp_frac_ = sq.sample(variables['max_gdp_frac'])
    
    willingness_ramp_happens = sq.event_occurs(variables.get('p_willingness_ramp', 0))
    if willingness_ramp_happens:
        willingness_ramp_ = sq.sample(variables.get('willingness_ramp', 1))
    else:
        willingness_ramp_ = 1
    
    initial_gdp_ = variables['initial_gdp']
    spend_doubling_time_ = sq.sample(variables['spend_doubling_time'])
    nonscaling_delay_ = sq.sample(variables.get('nonscaling_delay', sq.const(0)))
    initial_chance_of_nonscaling_issue_ = variables.get('initial_chance_of_nonscaling_issue', 0)
    final_chance_of_nonscaling_issue_ = variables.get('final_chance_of_nonscaling_issue', 0)
    nonscaling_issue_bottom_year_ = variables.get('nonscaling_issue_bottom_year', 0)
    willingness_spend_horizon_ = int(sq.sample(variables.get('willingness_spend_horizon', sq.const(1))))
    
    tai_year = run_model(initial_gdp_=initial_gdp_,
                         tai_flop_size_=tai_flop_size_,
                         nonscaling_delay_=nonscaling_delay_,
                         algo_doubling_rate_=algo_doubling_rate_,
                         possible_algo_reduction_=possible_algo_reduction_,
                         initial_flops_per_dollar_=initial_flops_per_dollar_,
                         flops_halving_rate_=flops_halving_rate_,
                         max_flops_per_dollar_=max_flops_per_dollar_,
                         initial_pay_=initial_pay_,
                         gdp_growth_=gdp_growth_,
                         max_gdp_frac_=max_gdp_frac_,
                         willingness_ramp_=willingness_ramp_,
                         spend_doubling_time_=spend_doubling_time_,
                         initial_chance_of_nonscaling_issue_=initial_chance_of_nonscaling_issue_,
                         final_chance_of_nonscaling_issue_=final_chance_of_nonscaling_issue_,
                         nonscaling_issue_bottom_year_=nonscaling_issue_bottom_year_,
                         willingness_spend_horizon_=willingness_spend_horizon_,
                         print_diagnostic=verbose)
    
    return {'tai_year': tai_year,
            'initial_gdp': initial_gdp_,
            'tai_flop_size': tai_flop_size_,
            'nonscaling_delay': nonscaling_delay_,
            'algo_doubling_rte': algo_doubling_rate_,
            'possible_algo_reduction': possible_algo_reduction_,
            'initial_flops_per_dollar': float(initial_flops_per_dollar_),
            'flops_halving_rate': flops_halving_rate_,
            'max_flops_per_dollar': float(max_flops_per_dollar_),
            'initial_pay': initial_pay_,
            'gdp_growth': gdp_growth_,
            'max_gdp_frac': max_gdp_frac_,
            'willingness_ramp_': willingness_ramp_,
            'spend_doubling_time_': spend_doubling_time_,
            'initial_chance_of_nonscaling_issue': initial_chance_of_nonscaling_issue_,
            'final_chance_of_nonscaling_issue': final_chance_of_nonscaling_issue_,
            'nonscaling_issue_bottom_year': nonscaling_issue_bottom_year_,
            'willingness_spend_horizon_': willingness_spend_horizon_}

print('Loaded')
# Out:
# Loaded

# %%
define_event(verbose=True)
# Out:
# It takes 42.1 log FLOPs (~1 billion decillion) for transformative capabilities.
# Every 2 years algorithms get 2x better, with 5 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 42.1 log FLOP (1 billion decillion) - log $ 24.1 to buy TAI (1 septillion) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.9 max log FLOP (870 septillion) available - TAI takes 42.0 log FLOP (896 million decillion) - log $ 23.8 to buy TAI (679 sextillion) vs. willingness to pay log $ 8.8 (659 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 27.2 max log FLOP (2 octillion) available - TAI takes 41.8 log FLOP (634 million decillion) - log $ 23.6 to buy TAI (364 sextillion) vs. willingness to pay log $ 8.9 (870 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 27.4 max log FLOP (3 octillion) available - TAI takes 41.7 log FLOP (448 million decillion) - log $ 23.3 to buy TAI (195 sextillion) vs. willingness to pay log $ 9.1 (1 billion) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.7 max log FLOP (5 octillion) available - TAI takes 41.5 log FLOP (317 million decillion) - log $ 23.0 to buy TAI (104 sextillion) vs. willingness to pay log $ 9.2 (2 billion) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2028 - 27.9 max log FLOP (8 octillion) available - TAI takes 41.4 log FLOP (224 million decillion) - log $ 22.7 to buy TAI (56 sextillion) vs. willingness to pay log $ 9.3 (2 billion) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2029 - 28.1 max log FLOP (14 octillion) available - TAI takes 41.2 log FLOP (158 million decillion) - log $ 22.5 to buy TAI (30 sextillion) vs. willingness to pay log $ 9.4 (3 billion) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2030 - 28.4 max log FLOP (24 octillion) available - TAI takes 41.0 log FLOP (112 million decillion) - log $ 22.2 to buy TAI (16 sextillion) vs. willingness to pay log $ 9.5 (3 billion) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2031 - 28.6 max log FLOP (42 octillion) available - TAI takes 40.9 log FLOP (79 million decillion) - log $ 21.9 to buy TAI (9 sextillion) vs. willingness to pay log $ 9.7 (5 billion) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2032 - 28.9 max log FLOP (72 octillion) available - TAI takes 40.7 log FLOP (56 million decillion) - log $ 21.7 to buy TAI (5 sextillion) vs. willingness to pay log $ 9.8 (6 billion) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2033 - 29.1 max log FLOP (125 octillion) available - TAI takes 40.6 log FLOP (40 million decillion) - log $ 21.4 to buy TAI (2 sextillion) vs. willingness to pay log $ 9.9 (8 billion) - 19.2 log FLOPS per $ (16 quintillion)
# Year: 2034 - 29.3 max log FLOP (216 octillion) available - TAI takes 40.4 log FLOP (28 million decillion) - log $ 21.1 to buy TAI (1 sextillion) vs. willingness to pay log $ 10.0 (10 billion) - 19.3 log FLOPS per $ (21 quintillion)
# Year: 2035 - 29.6 max log FLOP (373 octillion) available - TAI takes 40.3 log FLOP (20 million decillion) - log $ 20.9 to buy TAI (711 quintillion) vs. willingness to pay log $ 10.1 (13 billion) - 19.4 log FLOPS per $ (28 quintillion)
# Year: 2036 - 29.8 max log FLOP (642 octillion) available - TAI takes 40.1 log FLOP (14 million decillion) - log $ 20.6 to buy TAI (381 quintillion) vs. willingness to pay log $ 10.2 (17 billion) - 19.6 log FLOPS per $ (37 quintillion)
# Year: 2037 - 30.0 max log FLOP (1 nonillion) available - TAI takes 40.0 log FLOP (10 million decillion) - log $ 20.3 to buy TAI (204 quintillion) vs. willingness to pay log $ 10.4 (23 billion) - 19.7 log FLOPS per $ (49 quintillion)
# Year: 2038 - 30.3 max log FLOP (2 nonillion) available - TAI takes 39.8 log FLOP (7 million decillion) - log $ 20.0 to buy TAI (110 quintillion) vs. willingness to pay log $ 10.5 (29 billion) - 19.8 log FLOPS per $ (64 quintillion)
# Year: 2039 - 30.5 max log FLOP (3 nonillion) available - TAI takes 39.7 log FLOP (5 million decillion) - log $ 19.8 to buy TAI (59 quintillion) vs. willingness to pay log $ 10.6 (38 billion) - 19.9 log FLOPS per $ (84 quintillion)
# Year: 2040 - 30.7 max log FLOP (5 nonillion) available - TAI takes 39.5 log FLOP (4 million decillion) - log $ 19.5 to buy TAI (32 quintillion) vs. willingness to pay log $ 10.7 (49 billion) - 20.0 log FLOPS per $ (111 quintillion)
# Year: 2041 - 31.0 max log FLOP (9 nonillion) available - TAI takes 39.4 log FLOP (2 million decillion) - log $ 19.2 to buy TAI (17 quintillion) vs. willingness to pay log $ 10.8 (62 billion) - 20.2 log FLOPS per $ (147 quintillion)
# Year: 2042 - 31.2 max log FLOP (15 nonillion) available - TAI takes 39.2 log FLOP (2 million decillion) - log $ 19.0 to buy TAI (9 quintillion) vs. willingness to pay log $ 10.9 (78 billion) - 20.3 log FLOPS per $ (194 quintillion)
# Year: 2043 - 31.4 max log FLOP (25 nonillion) available - TAI takes 39.1 log FLOP (1 million decillion) - log $ 18.7 to buy TAI (5 quintillion) vs. willingness to pay log $ 11.0 (98 billion) - 20.4 log FLOPS per $ (256 quintillion)
# Year: 2044 - 31.6 max log FLOP (41 nonillion) available - TAI takes 38.9 log FLOP (888 thousand decillion) - log $ 18.4 to buy TAI (3 quintillion) vs. willingness to pay log $ 11.1 (121 billion) - 20.5 log FLOPS per $ (338 quintillion)
# Year: 2045 - 31.8 max log FLOP (66 nonillion) available - TAI takes 38.8 log FLOP (631 thousand decillion) - log $ 18.2 to buy TAI (1 quintillion) vs. willingness to pay log $ 11.2 (148 billion) - 20.6 log FLOPS per $ (446 quintillion)
# Year: 2046 - 32.0 max log FLOP (105 nonillion) available - TAI takes 38.7 log FLOP (450 thousand decillion) - log $ 17.9 to buy TAI (766 quadrillion) vs. willingness to pay log $ 11.3 (179 billion) - 20.8 log FLOPS per $ (588 quintillion)
# Year: 2047 - 32.2 max log FLOP (165 nonillion) available - TAI takes 38.5 log FLOP (322 thousand decillion) - log $ 17.6 to buy TAI (415 quadrillion) vs. willingness to pay log $ 11.3 (212 billion) - 20.9 log FLOPS per $ (775 quintillion)
# Year: 2048 - 32.4 max log FLOP (254 nonillion) available - TAI takes 38.4 log FLOP (231 thousand decillion) - log $ 17.4 to buy TAI (226 quadrillion) vs. willingness to pay log $ 11.4 (248 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2049 - 32.6 max log FLOP (386 nonillion) available - TAI takes 38.2 log FLOP (167 thousand decillion) - log $ 17.1 to buy TAI (124 quadrillion) vs. willingness to pay log $ 11.5 (286 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2050 - 32.8 max log FLOP (578 nonillion) available - TAI takes 38.1 log FLOP (122 thousand decillion) - log $ 16.8 to buy TAI (69 quadrillion) vs. willingness to pay log $ 11.5 (325 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2051 - 32.9 max log FLOP (854 nonillion) available - TAI takes 38.0 log FLOP (90 thousand decillion) - log $ 16.6 to buy TAI (38 quadrillion) vs. willingness to pay log $ 11.6 (364 billion) - 21.4 log FLOPS per $ (2 sextillion)
# Year: 2052 - 33.1 max log FLOP (1 decillion) available - TAI takes 37.8 log FLOP (67 thousand decillion) - log $ 16.3 to buy TAI (22 quadrillion) vs. willingness to pay log $ 11.6 (402 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2053 - 33.3 max log FLOP (2 decillion) available - TAI takes 37.7 log FLOP (51 thousand decillion) - log $ 16.1 to buy TAI (13 quadrillion) vs. willingness to pay log $ 11.6 (439 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2054 - 33.4 max log FLOP (3 decillion) available - TAI takes 37.6 log FLOP (40 thousand decillion) - log $ 15.9 to buy TAI (7 quadrillion) vs. willingness to pay log $ 11.7 (474 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2055 - 33.6 max log FLOP (4 decillion) available - TAI takes 37.5 log FLOP (32 thousand decillion) - log $ 15.7 to buy TAI (5 quadrillion) vs. willingness to pay log $ 11.7 (508 billion) - 21.9 log FLOPS per $ (7 sextillion)
# Year: 2056 - 33.7 max log FLOP (5 decillion) available - TAI takes 37.4 log FLOP (26 thousand decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 11.7 (540 billion) - 22.0 log FLOPS per $ (9 sextillion)
# Year: 2057 - 33.8 max log FLOP (7 decillion) available - TAI takes 37.3 log FLOP (22 thousand decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 11.8 (571 billion) - 22.1 log FLOPS per $ (12 sextillion)
# Year: 2058 - 34.0 max log FLOP (10 decillion) available - TAI takes 37.3 log FLOP (20 thousand decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 11.8 (600 billion) - 22.2 log FLOPS per $ (16 sextillion)
# Year: 2059 - 34.1 max log FLOP (13 decillion) available - TAI takes 37.2 log FLOP (18 thousand decillion) - log $ 14.9 to buy TAI (827 trillion) vs. willingness to pay log $ 11.8 (628 billion) - 22.3 log FLOPS per $ (21 sextillion)
# Year: 2060 - 34.3 max log FLOP (18 decillion) available - TAI takes 37.2 log FLOP (16 thousand decillion) - log $ 14.8 to buy TAI (580 trillion) vs. willingness to pay log $ 11.8 (655 billion) - 22.4 log FLOPS per $ (28 sextillion)
# Year: 2061 - 34.4 max log FLOP (25 decillion) available - TAI takes 37.2 log FLOP (15 thousand decillion) - log $ 14.6 to buy TAI (416 trillion) vs. willingness to pay log $ 11.8 (682 billion) - 22.6 log FLOPS per $ (36 sextillion)
# Year: 2062 - 34.5 max log FLOP (33 decillion) available - TAI takes 37.2 log FLOP (14 thousand decillion) - log $ 14.5 to buy TAI (304 trillion) vs. willingness to pay log $ 11.8 (708 billion) - 22.7 log FLOPS per $ (47 sextillion)
# Year: 2063 - 34.7 max log FLOP (45 decillion) available - TAI takes 37.1 log FLOP (14 thousand decillion) - log $ 14.4 to buy TAI (226 trillion) vs. willingness to pay log $ 11.9 (734 billion) - 22.8 log FLOPS per $ (62 sextillion)
# Year: 2064 - 34.8 max log FLOP (60 decillion) available - TAI takes 37.1 log FLOP (14 thousand decillion) - log $ 14.2 to buy TAI (170 trillion) vs. willingness to pay log $ 11.9 (759 billion) - 22.9 log FLOPS per $ (80 sextillion)
# Year: 2065 - 34.9 max log FLOP (80 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 14.1 to buy TAI (130 trillion) vs. willingness to pay log $ 11.9 (785 billion) - 23.0 log FLOPS per $ (102 sextillion)
# Year: 2066 - 35.0 max log FLOP (106 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 14.0 to buy TAI (100 trillion) vs. willingness to pay log $ 11.9 (811 billion) - 23.1 log FLOPS per $ (131 sextillion)
# Year: 2067 - 35.1 max log FLOP (139 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.9 to buy TAI (78 trillion) vs. willingness to pay log $ 11.9 (837 billion) - 23.2 log FLOPS per $ (166 sextillion)
# Year: 2068 - 35.3 max log FLOP (179 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.8 to buy TAI (62 trillion) vs. willingness to pay log $ 11.9 (864 billion) - 23.3 log FLOPS per $ (208 sextillion)
# Year: 2069 - 35.4 max log FLOP (229 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.7 to buy TAI (50 trillion) vs. willingness to pay log $ 12.0 (891 billion) - 23.4 log FLOPS per $ (257 sextillion)
# Year: 2070 - 35.5 max log FLOP (288 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.6 to buy TAI (41 trillion) vs. willingness to pay log $ 12.0 (919 billion) - 23.5 log FLOPS per $ (313 sextillion)
# Year: 2071 - 35.6 max log FLOP (356 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.5 to buy TAI (34 trillion) vs. willingness to pay log $ 12.0 (947 billion) - 23.6 log FLOPS per $ (376 sextillion)
# Year: 2072 - 35.6 max log FLOP (432 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.5 to buy TAI (29 trillion) vs. willingness to pay log $ 12.0 (977 billion) - 23.6 log FLOPS per $ (443 sextillion)
# Year: 2073 - 35.7 max log FLOP (515 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.4 to buy TAI (25 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.7 log FLOPS per $ (512 sextillion)
# Year: 2074 - 35.8 max log FLOP (602 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.3 to buy TAI (22 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (580 sextillion)
# Year: 2075 - 35.8 max log FLOP (690 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.3 to buy TAI (20 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (646 sextillion)
# Year: 2076 - 35.9 max log FLOP (778 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.3 to buy TAI (18 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (707 sextillion)
# Year: 2077 - 35.9 max log FLOP (863 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.2 to buy TAI (17 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (761 sextillion)
# Year: 2078 - 36.0 max log FLOP (943 decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.2 to buy TAI (16 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (807 sextillion)
# Year: 2079 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.2 to buy TAI (15 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (847 sextillion)
# Year: 2080 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.2 to buy TAI (14 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (880 sextillion)
# Year: 2081 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (14 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (906 sextillion)
# Year: 2082 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (14 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (927 sextillion)
# Year: 2083 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (944 sextillion)
# Year: 2084 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (957 sextillion)
# Year: 2085 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (967 sextillion)
# Year: 2086 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (975 sextillion)
# Year: 2087 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (981 sextillion)
# Year: 2088 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (985 sextillion)
# Year: 2089 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (989 sextillion)
# Year: 2090 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (992 sextillion)
# Year: 2091 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (994 sextillion)
# Year: 2092 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (995 sextillion)
# Year: 2093 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2094 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2095 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2096 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2097 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2098 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2099 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2100 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2101 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2102 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2103 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2104 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2105 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2106 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2107 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2108 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2109 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2110 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2111 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2112 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2113 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2114 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2115 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2116 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2117 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2118 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2119 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2120 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2121 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2122 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# --- :/ TAI NOT CREATED BEFORE 2124
# {'tai_year': 2124,
#  'initial_gdp': 23000000000000,
#  'tai_flop_size': 42.10276936636302,
#  'nonscaling_delay': 0,
#  'algo_doubling_rte': 2,
#  'possible_algo_reduction': 5,
#  'initial_flops_per_dollar': 1e+18,
#  'flops_halving_rate': 2.5,
#  'max_flops_per_dollar': 1e+24,
#  'initial_pay': 501187233.6272715,
#  'gdp_growth': 1.03,
#  'max_gdp_frac': 0.01,
#  'willingness_ramp_': 1,
#  'spend_doubling_time_': 2.5,
#  'initial_chance_of_nonscaling_issue': 0,
#  'final_chance_of_nonscaling_issue': 0,
#  'nonscaling_issue_bottom_year': 0,
#  'willingness_spend_horizon_': 1}

# %%
for i in range(5):
    print('## RUN {} ##'.format(i + 1))
    define_event(verbose=True)
# Out:
# ## RUN 1 ##
# It takes 26.4 log FLOPs (~258 septillion) for transformative capabilities.
# Every 3.5 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 26.4 log FLOP (258 septillion) - log $ 8.4 to buy TAI (258 million) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.0
# --- /!\ TAI CREATED in 2023
# ## RUN 2 ##
# It takes 28.0 log FLOPs (~9 octillion) for transformative capabilities.
# Every 3.5 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 28.0 log FLOP (9 octillion) - log $ 10.0 to buy TAI (9 billion) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.9 max log FLOP (870 septillion) available - TAI takes 27.9 log FLOP (8 octillion) - log $ 9.8 to buy TAI (6 billion) vs. willingness to pay log $ 8.8 (659 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 27.2 max log FLOP (2 octillion) available - TAI takes 27.8 log FLOP (6 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 8.9 (870 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 27.4 max log FLOP (3 octillion) available - TAI takes 27.7 log FLOP (5 octillion) - log $ 9.4 to buy TAI (2 billion) vs. willingness to pay log $ 9.1 (1 billion) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.7 max log FLOP (5 octillion) available - TAI takes 27.6 log FLOP (4 octillion) - log $ 9.2 to buy TAI (1 billion) vs. willingness to pay log $ 9.2 (2 billion) - 18.5 log FLOPS per $ (3 quintillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.0
# --- /!\ TAI CREATED in 2027
# ## RUN 3 ##
# It takes 26.7 log FLOPs (~527 septillion) for transformative capabilities.
# Every 3.5 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 26.7 log FLOP (527 septillion) - log $ 8.7 to buy TAI (527 million) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.9 max log FLOP (870 septillion) available - TAI takes 26.6 log FLOP (438 septillion) - log $ 8.5 to buy TAI (332 million) vs. willingness to pay log $ 8.8 (659 million) - 18.1 log FLOPS per $ (1 quintillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.0
# --- /!\ TAI CREATED in 2024
# ## RUN 4 ##
# It takes 27.8 log FLOPs (~7 octillion) for transformative capabilities.
# Every 3.5 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 27.8 log FLOP (7 octillion) - log $ 9.8 to buy TAI (7 billion) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.9 max log FLOP (870 septillion) available - TAI takes 27.8 log FLOP (6 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 8.8 (659 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 27.2 max log FLOP (2 octillion) available - TAI takes 27.7 log FLOP (5 octillion) - log $ 9.4 to buy TAI (3 billion) vs. willingness to pay log $ 8.9 (870 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 27.4 max log FLOP (3 octillion) available - TAI takes 27.6 log FLOP (4 octillion) - log $ 9.2 to buy TAI (2 billion) vs. willingness to pay log $ 9.1 (1 billion) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.7 max log FLOP (5 octillion) available - TAI takes 27.5 log FLOP (3 octillion) - log $ 9.0 to buy TAI (1 billion) vs. willingness to pay log $ 9.2 (2 billion) - 18.5 log FLOPS per $ (3 quintillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.0
# --- /!\ TAI CREATED in 2027
# ## RUN 5 ##
# It takes 50.5 log FLOPs (~340 quadrillion decillion) for transformative capabilities.
# Every 2 years algorithms get 2x better, with 5 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.7 log 2022$USD (~501 million) and this increases by 2.5x per year to a max of 0.01% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2023 - 26.7 max log FLOP (500 septillion) available - TAI takes 50.5 log FLOP (340 quadrillion decillion) - log $ 32.5 to buy TAI (340 nonillion) vs. willingness to pay log $ 8.7 (500 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2024 - 26.9 max log FLOP (870 septillion) available - TAI takes 50.4 log FLOP (240 quadrillion decillion) - log $ 32.3 to buy TAI (182 nonillion) vs. willingness to pay log $ 8.8 (659 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 27.2 max log FLOP (2 octillion) available - TAI takes 50.2 log FLOP (170 quadrillion decillion) - log $ 32.0 to buy TAI (98 nonillion) vs. willingness to pay log $ 8.9 (870 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 27.4 max log FLOP (3 octillion) available - TAI takes 50.1 log FLOP (120 quadrillion decillion) - log $ 31.7 to buy TAI (52 nonillion) vs. willingness to pay log $ 9.1 (1 billion) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.7 max log FLOP (5 octillion) available - TAI takes 49.9 log FLOP (85 quadrillion decillion) - log $ 31.4 to buy TAI (28 nonillion) vs. willingness to pay log $ 9.2 (2 billion) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2028 - 27.9 max log FLOP (8 octillion) available - TAI takes 49.8 log FLOP (60 quadrillion decillion) - log $ 31.2 to buy TAI (15 nonillion) vs. willingness to pay log $ 9.3 (2 billion) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2029 - 28.1 max log FLOP (14 octillion) available - TAI takes 49.6 log FLOP (42 quadrillion decillion) - log $ 30.9 to buy TAI (8 nonillion) vs. willingness to pay log $ 9.4 (3 billion) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2030 - 28.4 max log FLOP (24 octillion) available - TAI takes 49.5 log FLOP (30 quadrillion decillion) - log $ 30.6 to buy TAI (4 nonillion) vs. willingness to pay log $ 9.5 (3 billion) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2031 - 28.6 max log FLOP (42 octillion) available - TAI takes 49.3 log FLOP (21 quadrillion decillion) - log $ 30.4 to buy TAI (2 nonillion) vs. willingness to pay log $ 9.7 (5 billion) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2032 - 28.9 max log FLOP (72 octillion) available - TAI takes 49.2 log FLOP (15 quadrillion decillion) - log $ 30.1 to buy TAI (1 nonillion) vs. willingness to pay log $ 9.8 (6 billion) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2033 - 29.1 max log FLOP (125 octillion) available - TAI takes 49.0 log FLOP (11 quadrillion decillion) - log $ 29.8 to buy TAI (664 octillion) vs. willingness to pay log $ 9.9 (8 billion) - 19.2 log FLOPS per $ (16 quintillion)
# Year: 2034 - 29.3 max log FLOP (216 octillion) available - TAI takes 48.9 log FLOP (8 quadrillion decillion) - log $ 29.6 to buy TAI (356 octillion) vs. willingness to pay log $ 10.0 (10 billion) - 19.3 log FLOPS per $ (21 quintillion)
# Year: 2035 - 29.6 max log FLOP (373 octillion) available - TAI takes 48.7 log FLOP (5 quadrillion decillion) - log $ 29.3 to buy TAI (191 octillion) vs. willingness to pay log $ 10.1 (13 billion) - 19.4 log FLOPS per $ (28 quintillion)
# Year: 2036 - 29.8 max log FLOP (642 octillion) available - TAI takes 48.6 log FLOP (4 quadrillion decillion) - log $ 29.0 to buy TAI (102 octillion) vs. willingness to pay log $ 10.2 (17 billion) - 19.6 log FLOPS per $ (37 quintillion)
# Year: 2037 - 30.0 max log FLOP (1 nonillion) available - TAI takes 48.4 log FLOP (3 quadrillion decillion) - log $ 28.7 to buy TAI (55 octillion) vs. willingness to pay log $ 10.4 (23 billion) - 19.7 log FLOPS per $ (49 quintillion)
# Year: 2038 - 30.3 max log FLOP (2 nonillion) available - TAI takes 48.3 log FLOP (2 quadrillion decillion) - log $ 28.5 to buy TAI (29 octillion) vs. willingness to pay log $ 10.5 (29 billion) - 19.8 log FLOPS per $ (64 quintillion)
# Year: 2039 - 30.5 max log FLOP (3 nonillion) available - TAI takes 48.1 log FLOP (1 quadrillion decillion) - log $ 28.2 to buy TAI (16 octillion) vs. willingness to pay log $ 10.6 (38 billion) - 19.9 log FLOPS per $ (84 quintillion)
# Year: 2040 - 30.7 max log FLOP (5 nonillion) available - TAI takes 48.0 log FLOP (942 trillion decillion) - log $ 27.9 to buy TAI (8 octillion) vs. willingness to pay log $ 10.7 (49 billion) - 20.0 log FLOPS per $ (111 quintillion)
# Year: 2041 - 31.0 max log FLOP (9 nonillion) available - TAI takes 47.8 log FLOP (667 trillion decillion) - log $ 27.7 to buy TAI (5 octillion) vs. willingness to pay log $ 10.8 (62 billion) - 20.2 log FLOPS per $ (147 quintillion)
# Year: 2042 - 31.2 max log FLOP (15 nonillion) available - TAI takes 47.7 log FLOP (473 trillion decillion) - log $ 27.4 to buy TAI (2 octillion) vs. willingness to pay log $ 10.9 (78 billion) - 20.3 log FLOPS per $ (194 quintillion)
# Year: 2043 - 31.4 max log FLOP (25 nonillion) available - TAI takes 47.5 log FLOP (335 trillion decillion) - log $ 27.1 to buy TAI (1 octillion) vs. willingness to pay log $ 11.0 (98 billion) - 20.4 log FLOPS per $ (256 quintillion)
# Year: 2044 - 31.6 max log FLOP (41 nonillion) available - TAI takes 47.4 log FLOP (238 trillion decillion) - log $ 26.8 to buy TAI (705 septillion) vs. willingness to pay log $ 11.1 (121 billion) - 20.5 log FLOPS per $ (338 quintillion)
# Year: 2045 - 31.8 max log FLOP (66 nonillion) available - TAI takes 47.2 log FLOP (169 trillion decillion) - log $ 26.6 to buy TAI (380 septillion) vs. willingness to pay log $ 11.2 (148 billion) - 20.6 log FLOPS per $ (446 quintillion)
# Year: 2046 - 32.0 max log FLOP (105 nonillion) available - TAI takes 47.1 log FLOP (121 trillion decillion) - log $ 26.3 to buy TAI (205 septillion) vs. willingness to pay log $ 11.3 (179 billion) - 20.8 log FLOPS per $ (588 quintillion)
# Year: 2047 - 32.2 max log FLOP (165 nonillion) available - TAI takes 46.9 log FLOP (86 trillion decillion) - log $ 26.0 to buy TAI (111 septillion) vs. willingness to pay log $ 11.3 (212 billion) - 20.9 log FLOPS per $ (775 quintillion)
# Year: 2048 - 32.4 max log FLOP (254 nonillion) available - TAI takes 46.8 log FLOP (62 trillion decillion) - log $ 25.8 to buy TAI (61 septillion) vs. willingness to pay log $ 11.4 (248 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2049 - 32.6 max log FLOP (386 nonillion) available - TAI takes 46.7 log FLOP (45 trillion decillion) - log $ 25.5 to buy TAI (33 septillion) vs. willingness to pay log $ 11.5 (286 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2050 - 32.8 max log FLOP (578 nonillion) available - TAI takes 46.5 log FLOP (33 trillion decillion) - log $ 25.3 to buy TAI (18 septillion) vs. willingness to pay log $ 11.5 (325 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2051 - 32.9 max log FLOP (854 nonillion) available - TAI takes 46.4 log FLOP (24 trillion decillion) - log $ 25.0 to buy TAI (10 septillion) vs. willingness to pay log $ 11.6 (364 billion) - 21.4 log FLOPS per $ (2 sextillion)
# Year: 2052 - 33.1 max log FLOP (1 decillion) available - TAI takes 46.3 log FLOP (18 trillion decillion) - log $ 24.8 to buy TAI (6 septillion) vs. willingness to pay log $ 11.6 (402 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2053 - 33.3 max log FLOP (2 decillion) available - TAI takes 46.1 log FLOP (14 trillion decillion) - log $ 24.5 to buy TAI (3 septillion) vs. willingness to pay log $ 11.6 (439 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2054 - 33.4 max log FLOP (3 decillion) available - TAI takes 46.0 log FLOP (11 trillion decillion) - log $ 24.3 to buy TAI (2 septillion) vs. willingness to pay log $ 11.7 (474 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2055 - 33.6 max log FLOP (4 decillion) available - TAI takes 45.9 log FLOP (9 trillion decillion) - log $ 24.1 to buy TAI (1 septillion) vs. willingness to pay log $ 11.7 (508 billion) - 21.9 log FLOPS per $ (7 sextillion)
# Year: 2056 - 33.7 max log FLOP (5 decillion) available - TAI takes 45.8 log FLOP (7 trillion decillion) - log $ 23.9 to buy TAI (758 sextillion) vs. willingness to pay log $ 11.7 (540 billion) - 22.0 log FLOPS per $ (9 sextillion)
# Year: 2057 - 33.8 max log FLOP (7 decillion) available - TAI takes 45.8 log FLOP (6 trillion decillion) - log $ 23.7 to buy TAI (488 sextillion) vs. willingness to pay log $ 11.8 (571 billion) - 22.1 log FLOPS per $ (12 sextillion)
# Year: 2058 - 34.0 max log FLOP (10 decillion) available - TAI takes 45.7 log FLOP (5 trillion decillion) - log $ 23.5 to buy TAI (324 sextillion) vs. willingness to pay log $ 11.8 (600 billion) - 22.2 log FLOPS per $ (16 sextillion)
# Year: 2059 - 34.1 max log FLOP (13 decillion) available - TAI takes 45.7 log FLOP (5 trillion decillion) - log $ 23.3 to buy TAI (222 sextillion) vs. willingness to pay log $ 11.8 (628 billion) - 22.3 log FLOPS per $ (21 sextillion)
# Year: 2060 - 34.3 max log FLOP (18 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 23.2 to buy TAI (156 sextillion) vs. willingness to pay log $ 11.8 (655 billion) - 22.4 log FLOPS per $ (28 sextillion)
# Year: 2061 - 34.4 max log FLOP (25 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 23.0 to buy TAI (112 sextillion) vs. willingness to pay log $ 11.8 (682 billion) - 22.6 log FLOPS per $ (36 sextillion)
# Year: 2062 - 34.5 max log FLOP (33 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 22.9 to buy TAI (81 sextillion) vs. willingness to pay log $ 11.8 (708 billion) - 22.7 log FLOPS per $ (47 sextillion)
# Year: 2063 - 34.7 max log FLOP (45 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 22.8 to buy TAI (61 sextillion) vs. willingness to pay log $ 11.9 (734 billion) - 22.8 log FLOPS per $ (62 sextillion)
# Year: 2064 - 34.8 max log FLOP (60 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 22.7 to buy TAI (46 sextillion) vs. willingness to pay log $ 11.9 (759 billion) - 22.9 log FLOPS per $ (80 sextillion)
# Year: 2065 - 34.9 max log FLOP (80 decillion) available - TAI takes 45.6 log FLOP (4 trillion decillion) - log $ 22.5 to buy TAI (35 sextillion) vs. willingness to pay log $ 11.9 (785 billion) - 23.0 log FLOPS per $ (102 sextillion)
# Year: 2066 - 35.0 max log FLOP (106 decillion) available - TAI takes 45.5 log FLOP (4 trillion decillion) - log $ 22.4 to buy TAI (27 sextillion) vs. willingness to pay log $ 11.9 (811 billion) - 23.1 log FLOPS per $ (131 sextillion)
# Year: 2067 - 35.1 max log FLOP (139 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 22.3 to buy TAI (21 sextillion) vs. willingness to pay log $ 11.9 (837 billion) - 23.2 log FLOPS per $ (166 sextillion)
# Year: 2068 - 35.3 max log FLOP (179 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 22.2 to buy TAI (17 sextillion) vs. willingness to pay log $ 11.9 (864 billion) - 23.3 log FLOPS per $ (208 sextillion)
# Year: 2069 - 35.4 max log FLOP (229 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 22.1 to buy TAI (13 sextillion) vs. willingness to pay log $ 12.0 (891 billion) - 23.4 log FLOPS per $ (257 sextillion)
# Year: 2070 - 35.5 max log FLOP (288 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 22.0 to buy TAI (11 sextillion) vs. willingness to pay log $ 12.0 (919 billion) - 23.5 log FLOPS per $ (313 sextillion)
# Year: 2071 - 35.6 max log FLOP (356 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 22.0 to buy TAI (9 sextillion) vs. willingness to pay log $ 12.0 (947 billion) - 23.6 log FLOPS per $ (376 sextillion)
# Year: 2072 - 35.6 max log FLOP (432 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.9 to buy TAI (8 sextillion) vs. willingness to pay log $ 12.0 (977 billion) - 23.6 log FLOPS per $ (443 sextillion)
# Year: 2073 - 35.7 max log FLOP (515 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.8 to buy TAI (7 sextillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.7 log FLOPS per $ (512 sextillion)
# Year: 2074 - 35.8 max log FLOP (602 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.8 to buy TAI (6 sextillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (580 sextillion)
# Year: 2075 - 35.8 max log FLOP (690 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.7 to buy TAI (5 sextillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (646 sextillion)
# Year: 2076 - 35.9 max log FLOP (778 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.7 to buy TAI (5 sextillion) vs. willingness to pay log $ 12.0 (1 trillion) - 23.8 log FLOPS per $ (707 sextillion)
# Year: 2077 - 35.9 max log FLOP (863 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.7 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (761 sextillion)
# Year: 2078 - 36.0 max log FLOP (943 decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (807 sextillion)
# Year: 2079 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (847 sextillion)
# Year: 2080 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 23.9 log FLOPS per $ (880 sextillion)
# Year: 2081 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (906 sextillion)
# Year: 2082 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (927 sextillion)
# Year: 2083 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (944 sextillion)
# Year: 2084 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (957 sextillion)
# Year: 2085 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (4 sextillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (967 sextillion)
# Year: 2086 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (975 sextillion)
# Year: 2087 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (981 sextillion)
# Year: 2088 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (985 sextillion)
# Year: 2089 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (989 sextillion)
# Year: 2090 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (992 sextillion)
# Year: 2091 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (994 sextillion)
# Year: 2092 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (995 sextillion)
# Year: 2093 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2094 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2095 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2096 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2097 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2098 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2099 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2100 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2101 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2102 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2103 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2104 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2105 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2106 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2107 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2108 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2109 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2110 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2111 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2112 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2113 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2114 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2115 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2116 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2117 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2118 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2119 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2120 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2121 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2122 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 45.5 log FLOP (3 trillion decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# --- :/ TAI NOT CREATED BEFORE 2124

# %%
# %%time
tai_years = bayes.bayesnet(define_event,
                           find=lambda e: e['tai_year'],
                           verbose=True,
                           raw=True,
                           dump_cache_file='caches/tai_years',
                           reload_cache=True,
                           cores=7,
                           n=RUNS)
# Out:
# Reloading cache...
# Generating Bayes net with 7 cores...
# 10024it [02:52, 58.24it/s]
# Shuffling data...
# Waiting for other cores...
# Collecting data...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 217.95it/s]
# ...Collected!
# Caching in-memory...
# ...Cached!
# Writing cache to file `caches/tai_years.sqcache`...
# ...Cached!
# ...Finding
# ...Found!
# ...All done!
# CPU times: user 1min 52s, sys: 1.98 s, total: 1min 54s
# Wall time: 2min 52s
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/peterhurford/.virtualenvs/dev/lib/python3.9/site-packages/multiprocess/connection.py", line 224, in recv_bytes
#     buf = self._recv_bytes(maxlength)

# %%
out = sq.get_percentiles(tai_years)
[str(o[0]) + '%: ' + (str(int(o[1])) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR)) for o in out.items()]

# NOTE: Ajeya's numbers should output something very close to:
# '5%': 2027,
# '10%: 2031',
# '20%: 2037',
# '30%: 2042',
# '40%: 2047',
# '50%: 2053',
# '60%: 2061',
# '70%: 2073',
# '80%: >2100',
# '90%: >2100',
# '95%: >2100'

# My latest numbers (2022 Aug 27 8:43PM CT):
# '1%: 2024',
# '5%: 2027',
# '10%: 2029',
# '20%: 2033',
# '30%: 2038',
# '40%: 2045',
# '50%: 2054',
# '60%: 2064',
# '70%: 2079',
# '80%: 2116',
# '90%: >2222',
# '95%: >2222',
# '99%: >2222']
# Out:
# ['1%: 2023',
#  '5%: 2023',
#  '10%: 2023',
#  '20%: 2024',
#  '30%: 2030',
#  '40%: 2035',
#  '50%: 2040',
#  '60%: 2045',
#  '70%: 2056',
#  '80%: 2068',
#  '90%: >2123',
#  '95%: >2123',
#  '99%: >2123']

# %%
[str(o[0]) + '%: ' + (str(int(o[1]) - CURRENT_YEAR) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR - CURRENT_YEAR)) + ' years from now' for o in out.items()]
# Out:
# ['1%: 0 years from now',
#  '5%: 0 years from now',
#  '10%: 0 years from now',
#  '20%: 1 years from now',
#  '30%: 7 years from now',
#  '40%: 12 years from now',
#  '50%: 17 years from now',
#  '60%: 22 years from now',
#  '70%: 33 years from now',
#  '80%: 45 years from now',
#  '90%: >100 years from now',
#  '95%: >100 years from now',
#  '99%: >100 years from now']

# %%
tai_years_ = np.array([MAX_YEAR + 1 if t > MAX_YEAR else t for t in tai_years])
count, bins_count = np.histogram(tai_years_, bins=(MAX_YEAR - CURRENT_YEAR))
bins = np.round(np.array([b for b in bins_count[1:] if b <= MAX_YEAR]))
pdf = count / sum(count)
cdf = np.cumsum(pdf)

plt.plot(bins, cdf[:len(bins)], label='CDF')
plt.legend()
plt.show()

# %%
d_ = dict(zip(years, cdf[:len(bins)]))

def bin_tai_yrs(low=None, hi=None):
    low = CURRENT_YEAR if low is None else low
    out = 1 - d_[low] if hi is None else d_[hi] - d_[low]
    return round(out * 100, 1)

print('<2024: {}%'.format(bin_tai_yrs(hi=2024)))
print('2025-2029: {}%'.format(bin_tai_yrs(2025, 2029)))
print('2030-2039: {}%'.format(bin_tai_yrs(2030, 2039)))
print('2040-2049: {}%'.format(bin_tai_yrs(2040, 2049)))
print('2050-2059: {}%'.format(bin_tai_yrs(2050, 2059)))
print('2060-2069: {}%'.format(bin_tai_yrs(2060, 2069)))
print('2070-2079: {}%'.format(bin_tai_yrs(2070, 2079)))
print('2080-2089: {}%'.format(bin_tai_yrs(2080, 2089)))
print('2090-2099: {}%'.format(bin_tai_yrs(2090, 2099)))
print('2100-2109: {}%'.format(bin_tai_yrs(2100, 2109)))
print('2110-2119: {}%'.format(bin_tai_yrs(2110, 2119)))
print('>2120: {}%'.format(bin_tai_yrs(low=2120)))
# Out:
# <2024: 2.4%
# 2025-2029: 5.6%
# 2030-2039: 17.9%
# 2040-2049: 14.0%
# 2050-2059: 7.2%
# 2060-2069: 6.4%
# 2070-2079: 1.5%
# 2080-2089: 1.0%
# 2090-2099: 0.4%
# 2100-2109: 0.2%
# 2110-2119: 0.4%
# >2120: 14.6%

# %%
pdf_smoothed = savitzky_golay(pdf[:len(bins)], 51, 3)
plt.plot(bins, pdf_smoothed, label='PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
cdf[:len(bins)]
# Out:
# array([0.2079, 0.2317, 0.2457, 0.259 , 0.273 , 0.2884, 0.3017, 0.3248,
#        0.3438, 0.3592, 0.3816, 0.4019, 0.4194, 0.4383, 0.4572, 0.4831,
#        0.5034, 0.5167, 0.5328, 0.5538, 0.5776, 0.6028, 0.6231, 0.635 ,
#        0.6455, 0.6532, 0.6567, 0.6644, 0.6721, 0.6784, 0.6854, 0.6952,
#        0.7015, 0.7085, 0.7134, 0.7225, 0.7365, 0.7491, 0.7596, 0.7687,
#        0.7778, 0.7842, 0.7898, 0.7961, 0.8003, 0.808 , 0.8129, 0.8185,
#        0.822 , 0.8241, 0.8269, 0.8276, 0.829 , 0.8311, 0.8318, 0.8332,
#        0.8332, 0.8332, 0.8346, 0.8353, 0.8374, 0.8374, 0.8374, 0.8388,
#        0.8395, 0.8409, 0.843 , 0.8437, 0.8444, 0.8444, 0.8444, 0.8444,
#        0.8458, 0.8465, 0.8465, 0.8472, 0.8472, 0.8479, 0.8479, 0.8479,
#        0.8486, 0.8486, 0.8493, 0.8493, 0.85  , 0.85  , 0.85  , 0.8507,
#        0.8507, 0.8514, 0.8514, 0.8521, 0.8521, 0.8535, 0.8542, 0.8542,
#        0.8542, 0.8542, 0.8542])

# %%
pdf[:len(bins)]
# Out:
# array([0.2079, 0.0238, 0.014 , 0.0133, 0.014 , 0.0154, 0.0133, 0.0231,
#        0.019 , 0.0154, 0.0224, 0.0203, 0.0175, 0.0189, 0.0189, 0.0259,
#        0.0203, 0.0133, 0.0161, 0.021 , 0.0238, 0.0252, 0.0203, 0.0119,
#        0.0105, 0.0077, 0.0035, 0.0077, 0.0077, 0.0063, 0.007 , 0.0098,
#        0.0063, 0.007 , 0.0049, 0.0091, 0.014 , 0.0126, 0.0105, 0.0091,
#        0.0091, 0.0064, 0.0056, 0.0063, 0.0042, 0.0077, 0.0049, 0.0056,
#        0.0035, 0.0021, 0.0028, 0.0007, 0.0014, 0.0021, 0.0007, 0.0014,
#        0.    , 0.    , 0.0014, 0.0007, 0.0021, 0.    , 0.    , 0.0014,
#        0.0007, 0.0014, 0.0021, 0.0007, 0.0007, 0.    , 0.    , 0.    ,
#        0.0014, 0.0007, 0.    , 0.0007, 0.    , 0.0007, 0.    , 0.    ,
#        0.0007, 0.    , 0.0007, 0.    , 0.0007, 0.    , 0.    , 0.0007,
#        0.    , 0.0007, 0.    , 0.0007, 0.    , 0.0014, 0.0007, 0.    ,
#        0.    , 0.    , 0.    ])

# %%
## TODO: Update all

cotra_2020_cdf = [0.0214, 0.0272, 0.0328, 0.0385, 0.0458, 0.0551, 0.0641, 0.0721,
       0.0827, 0.0923, 0.1061, 0.1199, 0.1343, 0.1574, 0.175 , 0.1917,
       0.2108, 0.2321, 0.251 , 0.2825, 0.3001, 0.3177, 0.3317, 0.3531,
       0.3829, 0.4089, 0.4372, 0.4606, 0.4829, 0.4944, 0.504 , 0.5147,
       0.5243, 0.5335, 0.5423, 0.5521, 0.5608, 0.5719, 0.5826, 0.5922,
       0.6011, 0.6096, 0.6209, 0.6379, 0.6524, 0.6682, 0.682 , 0.6948,
       0.7084, 0.7207, 0.7314, 0.7362, 0.7407, 0.7456, 0.7506, 0.755 ,
       0.7594, 0.7626, 0.7668, 0.7698, 0.7725, 0.7745, 0.7765, 0.7775,
       0.7793, 0.7801, 0.781 , 0.7818, 0.7827, 0.7833, 0.7843, 0.7847,
       0.7852, 0.7858, 0.7861, 0.7868, 0.7874, 0.7882, 0.7887, 0.7891,
       0.7895, 0.7908, 0.7916, 0.7918, 0.7926, 0.7929, 0.7933, 0.7936,
       0.7941, 0.7949, 0.795 , 0.7954, 0.7957, 0.7962, 0.7969, 0.7976,
       0.7981, 0.7987, 0.7996, 0.8002, 0.8004, 0.801 , 0.8015, 0.8021,
       0.8025, 0.8029, 0.8034, 0.8041, 0.8045, 0.8052, 0.8059, 0.806 ,
       0.8066, 0.8071, 0.8079, 0.8087, 0.8089, 0.8093, 0.8093, 0.8095,
       0.8105, 0.8109, 0.8114, 0.8118, 0.8128, 0.8132, 0.8139, 0.8139,
       0.8144, 0.8149, 0.8154, 0.8162, 0.8167, 0.8173, 0.8177, 0.8185,
       0.8196, 0.82  , 0.821 , 0.8217, 0.8224, 0.8233, 0.8244, 0.8247,
       0.8254, 0.8262, 0.8267, 0.8274, 0.8277, 0.8288, 0.8294, 0.8298,
       0.8305, 0.8318, 0.8328, 0.8335, 0.8343, 0.8347, 0.8351, 0.8361,
       0.837 , 0.8376, 0.8385, 0.8398, 0.8404, 0.8413, 0.8419, 0.8427,
       0.8437, 0.8448, 0.8458, 0.8462, 0.8471, 0.8482, 0.8487, 0.8491,
       0.8498, 0.8505, 0.8507, 0.8511, 0.8519, 0.8526, 0.8534, 0.8542,
       0.855 , 0.8554, 0.8559, 0.8565, 0.857 , 0.8575, 0.8581, 0.8587,
       0.8592, 0.86  , 0.8605, 0.861 , 0.8615, 0.862 , 0.8629]
cotra_2020_pdf = np.append(np.array(cotra_2020_cdf[0]), np.diff(cotra_2020_cdf[:len(bins)]))
cotra_2020_pdf_smoothed = savitzky_golay(cotra_2020_pdf[:len(bins)], 51, 3)

cotra_2022_cdf = [0.0616, 0.0747, 0.0873, 0.1015, 0.118 , 0.1365, 0.1564, 0.1758,
       0.1981, 0.2188, 0.2531, 0.2768, 0.2975, 0.3193, 0.3481, 0.3728,
       0.4124, 0.433 , 0.4557, 0.4742, 0.4981, 0.5348, 0.569 , 0.6032,
       0.627 , 0.6404, 0.6507, 0.6611, 0.6701, 0.6801, 0.6893, 0.697 ,
       0.7051, 0.7115, 0.7186, 0.7252, 0.7331, 0.7411, 0.749 , 0.7577,
       0.7691, 0.7785, 0.7881, 0.799 , 0.807 , 0.8161, 0.8233, 0.8303,
       0.8348, 0.839 , 0.8429, 0.8462, 0.8494, 0.8517, 0.8532, 0.8553,
       0.8566, 0.8588, 0.8602, 0.862 , 0.8633, 0.864 , 0.8648, 0.8654,
       0.8662, 0.867 , 0.8672, 0.8677, 0.8683, 0.8686, 0.8689, 0.8689,
       0.8692, 0.8695, 0.8699, 0.8703, 0.8709, 0.8711, 0.8713, 0.8715,
       0.8719, 0.8721, 0.8727, 0.873 , 0.8736, 0.8739, 0.8742, 0.8746,
       0.875 , 0.8751, 0.8754, 0.8757, 0.8763, 0.8764, 0.8768, 0.8772,
       0.8775, 0.8775, 0.8776, 0.8779, 0.878 , 0.8781, 0.8783, 0.8789,
       0.8792, 0.8794, 0.8795, 0.8798, 0.8805, 0.8808, 0.8814, 0.8819,
       0.8822, 0.8826, 0.8827, 0.8828, 0.8832, 0.8834, 0.8837, 0.8839,
       0.8842, 0.8848, 0.8857, 0.8859, 0.8861, 0.8863, 0.8866, 0.8869,
       0.8869, 0.8873, 0.8878, 0.8889, 0.8896, 0.8904, 0.8906, 0.8911,
       0.8915, 0.892 , 0.8929, 0.8934, 0.8937, 0.8942, 0.8946, 0.8954,
       0.8959, 0.8963, 0.8969, 0.8972, 0.8975, 0.8984, 0.8988, 0.8993,
       0.8999, 0.9004, 0.9007, 0.9015, 0.9019, 0.9021, 0.9026, 0.9031,
       0.9037, 0.9041, 0.9048, 0.9054, 0.9057, 0.9062, 0.9067, 0.9075,
       0.9084, 0.9088, 0.909 , 0.9101, 0.9106, 0.9108, 0.9114, 0.9116,
       0.9121, 0.9127, 0.913 , 0.9137, 0.9144, 0.9147, 0.9154, 0.9159,
       0.9161, 0.9166, 0.9173, 0.9177, 0.9185, 0.9189, 0.9193, 0.9195,
       0.9195, 0.9198, 0.9204, 0.9205, 0.921 , 0.9216, 0.9221]
cotra_2022_pdf = np.append(np.array(cotra_2022_cdf[0]), np.diff(cotra_2022_cdf[:len(bins)]))
cotra_2022_pdf_smoothed = savitzky_golay(cotra_2022_pdf[:len(bins)], 51, 3)

peter_cdf = [0.0024, 0.0045, 0.0106, 0.0179, 0.0258, 0.0345, 0.0423, 0.0522,
       0.0638, 0.076 , 0.0885, 0.1028, 0.1165, 0.1332, 0.1498, 0.1669,
       0.1835, 0.2004, 0.2162, 0.2369, 0.2551, 0.2711, 0.2861, 0.3021,
       0.3184, 0.3314, 0.347 , 0.3589, 0.3729, 0.3882, 0.4022, 0.4142,
       0.4268, 0.4394, 0.4498, 0.4614, 0.471 , 0.4828, 0.4929, 0.5014,
       0.5097, 0.5179, 0.5275, 0.5359, 0.5456, 0.5545, 0.5634, 0.5711,
       0.5808, 0.5891, 0.5949, 0.6039, 0.6125, 0.6198, 0.6257, 0.6331,
       0.6392, 0.6453, 0.6503, 0.6571, 0.6629, 0.6684, 0.674 , 0.6803,
       0.6858, 0.6904, 0.6956, 0.7006, 0.7052, 0.7099, 0.7146, 0.7179,
       0.7209, 0.7253, 0.7293, 0.7325, 0.7352, 0.7388, 0.7421, 0.7448,
       0.7482, 0.7503, 0.7523, 0.7539, 0.7566, 0.7591, 0.7616, 0.7632,
       0.7667, 0.7685, 0.7699, 0.7714, 0.7729, 0.7749, 0.7769, 0.779 ,
       0.7808, 0.7829, 0.7849, 0.787 , 0.7878, 0.7895, 0.7902, 0.792 ,
       0.7931, 0.794 , 0.7952, 0.7967, 0.7981, 0.7993, 0.8003, 0.8021,
       0.8031, 0.8044, 0.8049, 0.8058, 0.8063, 0.8072, 0.8079, 0.8083,
       0.8091, 0.8096, 0.8101, 0.8111, 0.8116, 0.8126, 0.8131, 0.8142,
       0.815 , 0.8157, 0.8161, 0.817 , 0.8178, 0.8192, 0.8194, 0.8206,
       0.8209, 0.8211, 0.8217, 0.8221, 0.823 , 0.8234, 0.8237, 0.8245,
       0.825 , 0.8253, 0.8259, 0.8265, 0.8273, 0.8279, 0.8285, 0.8287,
       0.8294, 0.8297, 0.8302, 0.8302, 0.8311, 0.8315, 0.8316, 0.8318,
       0.832 , 0.8321, 0.8324, 0.8327, 0.8331, 0.8335, 0.8337, 0.8341,
       0.8342, 0.8344, 0.8347, 0.8349, 0.8353, 0.8359, 0.8365, 0.8371,
       0.8373, 0.8374, 0.8375, 0.8379, 0.8382, 0.8385, 0.8391, 0.8395,
       0.8398, 0.84  , 0.8406, 0.841 , 0.8413, 0.8417, 0.8419, 0.842 ,
       0.8426, 0.8427, 0.8432, 0.8434, 0.8439, 0.8444, 0.8448]
peter_pdf = np.append(np.array(peter_cdf[0]), np.diff(peter_cdf[:len(bins)]))
peter_pdf_smoothed = savitzky_golay(peter_pdf[:len(bins)], 51, 3)

plt.plot(bins[:99], cotra_2020_cdf[:99], label='Cotra 2020 CDF')
plt.plot(bins[:99], cotra_2022_cdf[:99], label='Cotra 2022 CDF (guess)')
plt.plot(bins[:99], peter_cdf[:99], label='Wildeford CDF')
plt.legend()
plt.show()

plt.plot(bins[:99], cotra_2020_pdf_smoothed[:99], label='Cotra 2020 PDF (smoothed)')
plt.plot(bins[:99], cotra_2022_pdf_smoothed[:99], label='Cotra 2022 PDF (guess, smoothed)')
plt.plot(bins[:99], peter_pdf_smoothed[:99], label='Wildeford PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## Sensitivity Analysis

# %%
print('## Default ##')
results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                      tai_flop_size_=36,
                                      nonscaling_delay_=0,
                                      algo_doubling_rate_=2,
                                      possible_algo_reduction_=2,
                                      initial_flops_per_dollar_=10 ** 18,
                                      flops_halving_rate_=2.5,
                                      max_flops_per_dollar_=10 ** 24,
                                      initial_pay_=10*M,
                                      gdp_growth_=1.03,
                                      max_gdp_frac_=1/1600,
                                      willingness_ramp_=1,
                                      spend_doubling_time_=2.5,
                                      initial_chance_of_nonscaling_issue_=0,
                                      final_chance_of_nonscaling_issue_=0,
                                      nonscaling_issue_bottom_year_=0,
                                      willingness_spend_horizon_=1,
                                      print_diagnostic=False), n=1000)
print('{}: {}'.format(t,
                      ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                       '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                       '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Default ##
# 59: [2068, 2068, 2068]

# %%
print('## TAI FLOP Size ##')
for t in range(20, 43):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=t,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(t,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## TAI FLOP Size ##
# 20: [2023, 2023, 2023]
# 21: [2023, 2023, 2023]
# 22: [2023, 2023, 2023]
# 23: [2023, 2023, 2023]
# 24: [2023, 2023, 2023]
# 25: [2024, 2024, 2024]
# 26: [2026, 2026, 2026]
# 27: [2029, 2029, 2029]
# 28: [2031, 2031, 2031]
# 29: [2034, 2034, 2034]
# 30: [2037, 2037, 2037]
# 31: [2041, 2041, 2041]
# 32: [2045, 2045, 2045]
# 33: [2049, 2049, 2049]
# 34: [2054, 2054, 2054]
# 35: [2061, 2061, 2061]
# 36: [2068, 2068, 2068]
# 37: [2092, 2092, 2092]
# 38: [2124, 2124, 2124]
# 39: [2124, 2124, 2124]
# 40: [2124, 2124, 2124]
# 41: [2124, 2124, 2124]
# 42: [2124, 2124, 2124]

# %%
print('## GDP Growth ##')
for g in range(0, 5):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1 + g/100,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + g / 100,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## GDP Growth ##
# 1.0: [2078, 2078, 2078]
# 1.01: [2073, 2073, 2073]
# 1.02: [2070, 2070, 2070]
# 1.03: [2068, 2068, 2068]
# 1.04: [2067, 2067, 2067]

# %%
print('## Max GDP Frac ##')
for g in [1/(500*K), 1/(250*K), 1/(100*K), 1/(50*K), 1/(10*K), 5/(10*K),
          1/2000, 1/1500, 1/1000, 2/1000, 3/1000, 4/1000, 5/1000, 1/100,
          2/100, 3/100, 4/100]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=g,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(g,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Max GDP Frac ##
# 2e-06: [2124, 2124, 2124]
# 4e-06: [2124, 2124, 2124]
# 1e-05: [2124, 2124, 2124]

# %%
print('## Spend Doubling Time ##')
for d in range(0, 50):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=1 + d / 10,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Initial FLOPs per dollar ##')
for d in [17, 17.5, 18]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** d,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Initial pay ##')
for p in range(70, 91):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10 ** (p / 10),
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('${}: {}'.format(numerize(10 ** (p / 10)),
                           ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                            '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                            '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## FLOPs halving rate ##')
for f in range(5, 41):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=f / 10,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Max FLOPs per dollar ##')
for f in range(20, 31):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** f,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Willingness ramp ##')
for r in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=r / 10,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Willingness to spend horizon ##')
for y in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(y,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Algo doubling rate ##')
for d in range(10, 41, 2):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=d / 10,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Possible algo reduction ##')
for r in range(0, 13):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=r,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
# TODO: Wildeford meta anchor horizon length
# TODO: Wildeford meta anchor efficiency w/ efficiency-based algorithmic reduction
# TODO: efficiency-based algorithmic reduction vs. regular algorithmic reduction

# %%
get_question(11558)

# %%
# https://www.metaculus.com/questions/11558/maximum-compute-used-in-ai-training/
# TODO: Fetch from Metaculus, look side by side
# TODO: Be able to predict back
for y in [2022, 2025, 2030]:
    print('-')
    print('## {} ##'.format(y))
    for i in range(3):
        flops_at_max_ = flops_at_max(initial_gdp=variables['initial_gdp'],
                                     gdp_growth=[1.02, 1.025, 1.03][i],
                                     initial_pay=[10*M, 100*M, 1*B][i],
                                     spend_doubling_time=[1, 2, 3][i],
                                     max_gdp_frac=[1/1000, 4/1000, 1/100][i],
                                     initial_flops_per_dollar=10 ** 18,
                                     max_flops_per_dollar=10 ** 24,
                                     flops_halving_rate=[2, 2.5, 3][i],
                                     year=(y - CURRENT_YEAR))

        print('{}: {} max log FLOPs / ~{} petaFLOP/s-days)'.format(['25th', 'mean', '75th'][i],
                                                                   np.round(np.log10(flops_at_max_), 1),
                                                                   log_flop_to_petaflop_sdays(np.log10(flops_at_max_))))
