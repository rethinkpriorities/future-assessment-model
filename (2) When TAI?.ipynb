# %% [markdown]
# ## Library

# %%
import math
import random

import numpy as np
import matplotlib.pyplot as plt

import squigglepy as sq
from squigglepy import bayes
from squigglepy.numbers import K, M, B, T

from copy import copy, deepcopy
from scipy import stats
from pprint import pprint
print('Loaded 1')

exec(open('utils.py').read())
print('Loaded 2')

exec(open('/Users/peterhurford/dev/forecastflow/library.py').read()) # TODO: Package?
print('Loaded 3')
# Out:
# Loaded 1
# Loaded 2
# Loaded 3

# %% [markdown]
# ## Variables (customize these)

# %%
# Customize these!!!

# Global variables - probably don't want to change these but you could.
RUNS = 10000                                      # Number of runs to do (default 1000)
CURRENT_YEAR = 2022                               # What year to start the run on? (default: 2022)
MAX_YEAR = 2222                                   # What year to end the run on? (default: 2100)
USE_NUMBERS = 'Wildeford'                         # Which variable set (see below) to use?
GRAPH_P = 50                                      # What percentile to graph on the graphs below? (default: 50)
VARIABLE_SETS = {}


VARIABLE_SETS['Cotra2020'] = {
    'initial_gdp': 21.3*T, # GDP in `CURRENT_YEAR` of country that will develop TAI (default: 21.3 trillion)
    'tai_flop_size': sq.sample(load_cache_file='caches/cotra_2020'),  # Cache generated in "Anchors" notebook
    # 90% CI, it takes 10^X FLOPs to run a transformative AI at inference.
    # Note: A petaflop/s-day (pfs-day) consists of performing 10^15 neural net operations per second for one day,
    # or a total of about 10^20 operations
    'algo_doubling_rate_max': 3.5,        # 90% CI, algorithms get twice as efficient every X years (maximum)
    'algo_doubling_rate_min': 2,          # 90% CI, algorithms get twice as efficient every X years (minimum)
    'min_reduction': 2,                   # 90% CI, the minimum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'max_reduction': 5,                   # 90% CI, the maximum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'initial_flops_per_dollar': 17,       # 90% CI, as of today, we can buy 10^X FLOPs per $
    'flops_halving_rate': 2.5,            # 90% CI, the cost of FLOPs per $ halves every X years
    'max_flops_per_dollar': 24,           # 90% CI, the cheapest FLOPs will get is 10^X FLOPs per $
    'initial_pay': 8.7,                   # 90% CI, as of today the maximum we would pay for TAI is $10^X
    'gdp_growth': 1.03,                   # 90% CI, GDP will increase by a factor of X each year
    'max_gdp_frac': 0.01,                 # 90% CI, the maximum % of GDP that would be spent on TAI is $10^X
    'spend_doubling_time': 2.5            # 90% CI, our willingness to spend on TAI doubles every X years
}


VARIABLE_SETS['Cotra2022'] = deepcopy(VARIABLE_SETS['Cotra2020'])
VARIABLE_SETS['Cotra2022']['tai_flop_size'] = sq.sample(load_cache_file='caches/cotra_2022')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Cotra2022']['initial_flops_per_dollar'] = sq.const(18)


def wildeford_max_gdp_frac():
    small_project = sq.lognorm(1 / (250*K), 1 / (3*K))
    modern_megaproject = sq.lognorm(1/K, 1/600)
    old_form_megaproject = sq.lognorm(1/500, 1/150)
    gigaproject = sq.lognorm(1/150, 1/50)
    
    r_ = random.random()
    if r_ < 0.1:
        gdp_frac = small_project
        percent_spent_on_compute = sq.lognorm(0.2,0.6, lclip=0.1, rclip=0.9)
    elif r_ < 0.8:
        gdp_frac = modern_megaproject
        percent_spent_on_compute = sq.lognorm(0.4,0.7, lclip=0.1, rclip=0.9)
    elif r_ < 0.95:
        gdp_frac = old_form_megaproject
        percent_spent_on_compute = sq.lognorm(0.5,0.9, lclip=0.1, rclip=0.9)
    else:
        gdp_frac = gigaproject
        percent_spent_on_compute = sq.lognorm(0.6,0.9, lclip=0.1, rclip=0.9)

    return ~gdp_frac * ~percent_spent_on_compute

VARIABLE_SETS['Wildeford'] = deepcopy(VARIABLE_SETS['Cotra2022'])
VARIABLE_SETS['Wildeford']['tai_flop_size'] = sq.sample(load_cache_file='caches/meta_anchor')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Wildeford']['flops_halving_rate'] = sq.lognorm(2, 5)
VARIABLE_SETS['Wildeford']['initial_pay'] = sq.mixture([[0.8, sq.const(7.1)],
                                                        [0.2, sq.lognorm(7.1,9, lclip=7.1)]]) #NEW
VARIABLE_SETS['Wildeford']['gdp_growth'] = sq.lognorm(1.015, 1.035) #NEW
VARIABLE_SETS['Wildeford']['max_gdp_frac'] = wildeford_max_gdp_frac #NEW
VARIABLE_SETS['Wildeford']['spend_doubling_time'] = sq.mixture([[0.8, sq.lognorm(3,6)],
                                                                [0.2, sq.lognorm(1,2, lclip=1)]]) #NEW
# TODO: Willingness to spend connected to commercialization
VARIABLE_SETS['Wildeford']['initial_chance_of_nonscaling_issue'] = 0.95 #NEW
VARIABLE_SETS['Wildeford']['final_chance_of_nonscaling_issue'] = 0.3 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_issue_bottom_year'] = 2050 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_delay'] = sq.mixture([[0.7, sq.lognorm(2,10)],
                                                             [0.3, sq.lognorm(5,40)]]) #NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_max'] = sq.norm(1,3) # NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_min'] = sq.norm(1,2) # NEW
VARIABLE_SETS['Wildeford']['min_reduction'] = 2 # TODO: Connect to efficiency within tai_flop_size / should correlate with tai_flop_size
VARIABLE_SETS['Wildeford']['max_reduction'] = 5


# These equations define how variables change over time or in relationship to other variables.
def gdp(initial_gdp, gdp_growth, year):
    return initial_gdp * (gdp_growth ** year)


def willingness_to_pay(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac, year):
    gdp_ = gdp(initial_gdp=initial_gdp, gdp_growth=gdp_growth, year=year)
    x = (np.log(2) / spend_doubling_time) * year
    if x < 650:
        y = math.log10(initial_pay) + math.log10(math.exp(x)) - math.log10(1 + initial_pay / (gdp_ * max_gdp_frac) * math.exp(x))
        if y > 300:
            y = int(y) # Handle overflow errors
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_pay) + (year/spend_doubling_time)/3.3)
    

def algo_halving_fn(min_speed, max_speed, tai_flop_size):
    if max_speed < min_speed:
        max_speed = min_speed
    if min_speed > max_speed:
        min_speed = max_speed
    return min(max(max_speed - (round((tai_flop_size - 29) / 2) / 2), min_speed), max_speed)


def flops_needed(initial_flops, possible_reduction, doubling_rate, year):
    x = (np.log(2) / doubling_rate) * year
    if x < 650:
        y = (math.log10(initial_flops) - max(math.log10(math.exp(x)) - math.log10(1 + (1/possible_reduction) * math.exp(x)), 0))
        if y > 300:
            y = int(y) # Handle overflow errors        
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops) - (1/possible_reduction))

    
def flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, halving_rate, year):
    x = (np.log(2) / halving_rate) * year
    if x < 650:
        y = (math.log10(initial_flops_per_dollar) + math.log10(math.exp(x)) - math.log10(1 + initial_flops_per_dollar / max_flops_per_dollar * math.exp(x)))
        if y > 300:
            y = int(y) # Handle overflow errors                
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops_per_dollar) + (year/halving_rate)/3.3)

    
def cost_of_tai(initial_flops, possible_reduction, algo_doubling_rate, initial_flops_per_dollar, max_flops_per_dollar,
                flops_halving_rate, year):
    return (flops_needed(initial_flops, possible_reduction, algo_doubling_rate, year) /
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def flops_at_max(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac,
                 initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year):
    return (willingness_to_pay(initial_gdp=initial_gdp,
                               gdp_growth=gdp_growth,
                               initial_pay=initial_pay,
                               spend_doubling_time=spend_doubling_time,
                               max_gdp_frac=max_gdp_frac,
                               year=year) *
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def possible_algo_reduction_fn(min_reduction, max_reduction, tai_flop_size):
    if max_reduction < min_reduction:
        max_reduction = min_reduction
    if min_reduction > max_reduction:
        min_reduction = max_reduction
    return min(max(min_reduction + round((tai_flop_size - 32) / 4), min_reduction), max_reduction)


# NEW
def p_nonscaling_delay(initial_p, final_p, year, max_year):
    return generalized_logistic_curve(x=year - CURRENT_YEAR,
                                      slope=0.3,
                                      shift=3 * (max_year - CURRENT_YEAR),
                                      push=1,
                                      maximum=final_p,
                                      minimum=initial_p)
    

# ------------- Ignore below here ------------
years = list(range(CURRENT_YEAR, MAX_YEAR))
variables = VARIABLE_SETS[USE_NUMBERS]
print('Loaded')
# Out:
# Loaded

# %%
initial_flop_size_s = variables['tai_flop_size']
initial_flops_p = sq.get_percentiles(initial_flop_size_s)
plt.hist(initial_flop_size_s, bins = 200)
pprint(initial_flops_p)
# Out:
# {1: 19.51442579759248,
#  5: 24.09681815678129,
#  10: 25.298177862352397,
#  20: 26.921552923486843,
#  30: 28.704086115867877,
#  40: 30.676466923755562,
#  50: 32.52715347903024,
#  60: 34.45454242769943,
#  70: 36.528940762792566,
#  80: 39.08555989442817,
#  90: 42.87866559508511,
#  95: 45.85686277860358,
#  99: 51.52593269057209}

# %%
min_reduction_p = sq.get_percentiles(sq.sample(variables['min_reduction'], n=1000))
min_reduction_p
# Out:
# {1: 2.0,
#  5: 2.0,
#  10: 2.0,
#  20: 2.0,
#  30: 2.0,
#  40: 2.0,
#  50: 2.0,
#  60: 2.0,
#  70: 2.0,
#  80: 2.0,
#  90: 2.0,
#  95: 2.0,
#  99: 2.0}

# %%
max_reduction_p = sq.get_percentiles(sq.sample(variables['max_reduction'], n=1000), reverse=True)
max_reduction_p
# Out:
# {99: 5.0,
#  95: 5.0,
#  90: 5.0,
#  80: 5.0,
#  70: 5.0,
#  60: 5.0,
#  50: 5.0,
#  40: 5.0,
#  30: 5.0,
#  20: 5.0,
#  10: 5.0,
#  5: 5.0,
#  1: 5.0}

# %%
algo_doubling_rate_min_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_min'], n=1000), reverse=True)
algo_doubling_rate_min_p
# Out:
# {99: 0.7584400732446873,
#  95: 0.9767744259241169,
#  90: 1.0856012892522653,
#  80: 1.2407445638673296,
#  70: 1.3210113100268568,
#  60: 1.4102234758243115,
#  50: 1.4863531883119272,
#  40: 1.5724094857851016,
#  30: 1.648363941513076,
#  20: 1.7479670503834526,
#  10: 1.8805245478257828,
#  5: 1.993601066387724,
#  1: 2.1592632671646257}

# %%
algo_doubling_rate_max_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_max'], n=1000), reverse=True)
algo_doubling_rate_max_p
# Out:
# {99: 0.56919573528412,
#  95: 1.0532740417785549,
#  90: 1.2539880643967358,
#  80: 1.4879260530550038,
#  70: 1.6878129890679994,
#  60: 1.8607473007759547,
#  50: 2.0116167842142536,
#  40: 2.1750103321001886,
#  30: 2.3383929985331386,
#  20: 2.525656381410696,
#  10: 2.7799110885374465,
#  5: 2.9945333098726445,
#  1: 3.3694411222802554}

# %%
initial_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['initial_flops_per_dollar'], n=1000))
initial_flops_per_dollar_p
# Out:
# {1: 18.0,
#  5: 18.0,
#  10: 18.0,
#  20: 18.0,
#  30: 18.0,
#  40: 18.0,
#  50: 18.0,
#  60: 18.0,
#  70: 18.0,
#  80: 18.0,
#  90: 18.0,
#  95: 18.0,
#  99: 18.0}

# %%
flops_halving_rate_p = sq.get_percentiles(sq.sample(variables['flops_halving_rate'], n=1000), reverse=True)
flops_halving_rate_p
# Out:
# {99: 1.6702788565877507,
#  95: 2.0531912681310267,
#  90: 2.237698170193191,
#  80: 2.5514032865915586,
#  70: 2.73813089468898,
#  60: 2.9483556781138125,
#  50: 3.140438507133732,
#  40: 3.3497773831442577,
#  30: 3.6442694360021877,
#  20: 3.9963326659003684,
#  10: 4.471864891087493,
#  5: 4.855594088720706,
#  1: 5.928039882254584}

# %%
max_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['max_flops_per_dollar'], n=1000))
max_flops_per_dollar_p
# Out:
# {1: 24.0,
#  5: 24.0,
#  10: 24.0,
#  20: 24.0,
#  30: 24.0,
#  40: 24.0,
#  50: 24.0,
#  60: 24.0,
#  70: 24.0,
#  80: 24.0,
#  90: 24.0,
#  95: 24.0,
#  99: 24.0}

# %%
initial_pay_p = sq.get_percentiles(sq.sample(variables['initial_pay'], n=1000))
initial_pay_p
# Out:
# {1: 7.1,
#  5: 7.1,
#  10: 7.1,
#  20: 7.1,
#  30: 7.1,
#  40: 7.1,
#  50: 7.1,
#  60: 7.1,
#  70: 7.1,
#  80: 7.210467860613481,
#  90: 8.054897861378247,
#  95: 8.466885487352231,
#  99: 9.041893973890765}

# %%
gdp_growth_p = sq.get_percentiles(sq.sample(variables['gdp_growth'], n=1000))
gdp_growth_p
# Out:
# {1: 1.0114792518250206,
#  5: 1.0148167902426684,
#  10: 1.0171193094689484,
#  20: 1.0196113636427249,
#  30: 1.0217109559902546,
#  40: 1.0231265787762684,
#  50: 1.0245897971510314,
#  60: 1.0260825892630647,
#  70: 1.0276893685858701,
#  80: 1.0298550366779455,
#  90: 1.0327798116895508,
#  95: 1.0347459904645804,
#  99: 1.0392540457291117}

# %%
max_gdp_frac_p = sq.get_percentiles(sq.sample(variables['max_gdp_frac'], n=1000))
max_gdp_frac_p
# Out:
# {1: 3.0153677613184473e-06,
#  5: 1.6978336123013204e-05,
#  10: 0.00038838259725008505,
#  20: 0.0005382523278743072,
#  30: 0.0006095699965687506,
#  40: 0.0006594007231881976,
#  50: 0.0007235748789114148,
#  60: 0.00078071583060471,
#  70: 0.0008616243854270918,
#  80: 0.0010938294189253828,
#  90: 0.002772562644674295,
#  95: 0.004404457550274898,
#  99: 0.01140681053948841}

# %%
willingness_ramp = variables.get('willingness_ramp', 0)
if willingness_ramp != 0:
    willingness_ramp_p = sq.get_percentiles(sq.sample(willingness_ramp), n=1000)
    pprint(willingness_ramp_p)
else:
    print(0)
# Out:
# 0

# %%
spend_doubling_time_p = sq.get_percentiles(sq.sample(variables['spend_doubling_time'], n=1000), reverse=True)
spend_doubling_time_p
# Out:
# {99: 1.0,
#  95: 1.2187412865960425,
#  90: 1.4155747107572787,
#  80: 2.476184130523622,
#  70: 3.313544349110374,
#  60: 3.675789254250966,
#  50: 3.992340474345312,
#  40: 4.257652720561143,
#  30: 4.534656282756133,
#  20: 4.8679518393808525,
#  10: 5.321718168609152,
#  5: 5.7979160617575065,
#  1: 6.738778836667169}

# %%
nonscaling_delay = variables.get('nonscaling_delay', 0)
if nonscaling_delay != 0:
    nonscaling_delay_p = sq.get_percentiles(np.ceil(sq.sample(nonscaling_delay, n=1000)), reverse=True)
    pprint(nonscaling_delay_p)
else:
    print(0)
# Out:
# {1: 41.0,
#  5: 25.0,
#  10: 19.0,
#  20: 12.0,
#  30: 9.0,
#  40: 7.0,
#  50: 6.0,
#  60: 5.0,
#  70: 4.0,
#  80: 4.0,
#  90: 3.0,
#  95: 3.0,
#  99: 2.0}

# %%
willingness_spend_horizon = variables.get('willingness_spend_horizon', 1)
if willingness_spend_horizon != 1:
    willingness_spend_horizon_p = sq.get_percentiles(sq.sample(willingness_spend_horizon, n=1000))
    pprint(willingness_spend_horizon_p)
else:
    print(1)
# Out:
# 1

# %% [markdown]
# ## GDP Over Time

# %%
gdp_ = np.array([gdp(initial_gdp=variables['initial_gdp'],
                     gdp_growth=gdp_growth_p[GRAPH_P],
                     year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(gdp_))
plt.ylabel('log GDP')
# Out:
# Text(0, 0.5, 'log GDP')

# %%
for y in years:
    print('Year: {} - GDP log 2022$USD {} (~{})'.format(y,
                                                        np.round(np.log10(gdp_[y - CURRENT_YEAR]), 1),
                                                        numerize(gdp_[y - CURRENT_YEAR])))
# Out:
# Year: 2161 - GDP log 2022$USD 14.8 (~623 trillion)
# Year: 2162 - GDP log 2022$USD 14.8 (~639 trillion)
# Year: 2163 - GDP log 2022$USD 14.8 (~655 trillion)
# Year: 2164 - GDP log 2022$USD 14.8 (~671 trillion)
# Year: 2165 - GDP log 2022$USD 14.8 (~687 trillion)
# Year: 2166 - GDP log 2022$USD 14.8 (~704 trillion)
# Year: 2167 - GDP log 2022$USD 14.9 (~721 trillion)
# Year: 2168 - GDP log 2022$USD 14.9 (~739 trillion)
# Year: 2169 - GDP log 2022$USD 14.9 (~757 trillion)
# Year: 2170 - GDP log 2022$USD 14.9 (~776 trillion)
# Year: 2171 - GDP log 2022$USD 14.9 (~795 trillion)
# Year: 2172 - GDP log 2022$USD 14.9 (~814 trillion)
# Year: 2173 - GDP log 2022$USD 14.9 (~835 trillion)
# Year: 2174 - GDP log 2022$USD 14.9 (~855 trillion)
# Year: 2175 - GDP log 2022$USD 14.9 (~876 trillion)
# Year: 2176 - GDP log 2022$USD 15.0 (~898 trillion)
# Year: 2177 - GDP log 2022$USD 15.0 (~920 trillion)
# Year: 2178 - GDP log 2022$USD 15.0 (~942 trillion)
# Year: 2179 - GDP log 2022$USD 15.0 (~965 trillion)
# Year: 2180 - GDP log 2022$USD 15.0 (~989 trillion)
# Year: 2181 - GDP log 2022$USD 15.0 (~1 quadrillion)
# Year: 2182 - GDP log 2022$USD 15.0 (~1 quadrillion)
# Year: 2183 - GDP log 2022$USD 15.0 (~1 quadrillion)
# Year: 2184 - GDP log 2022$USD 15.0 (~1 quadrillion)
# Year: 2185 - GDP log 2022$USD 15.0 (~1 quadrillion)
# Year: 2186 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2187 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2188 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2189 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2190 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2191 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2192 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2193 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2194 - GDP log 2022$USD 15.1 (~1 quadrillion)
# Year: 2195 - GDP log 2022$USD 15.2 (~1 quadrillion)
# Year: 2196 - GDP log 2022$USD 15.2 (~1 quadrillion)
# Year: 2197 - GDP log 2022$USD 15.2 (~1 quadrillion)
# Year: 2198 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2199 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2200 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2201 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2202 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2203 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2204 - GDP log 2022$USD 15.2 (~2 quadrillion)
# Year: 2205 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2206 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2207 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2208 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2209 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2210 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2211 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2212 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2213 - GDP log 2022$USD 15.3 (~2 quadrillion)
# Year: 2214 - GDP log 2022$USD 15.4 (~2 quadrillion)
# Year: 2215 - GDP log 2022$USD 15.4 (~2 quadrillion)
# Year: 2216 - GDP log 2022$USD 15.4 (~2 quadrillion)
# Year: 2217 - GDP log 2022$USD 15.4 (~2 quadrillion)
# Year: 2218 - GDP log 2022$USD 15.4 (~2 quadrillion)
# Year: 2219 - GDP log 2022$USD 15.4 (~3 quadrillion)
# Year: 2220 - GDP log 2022$USD 15.4 (~3 quadrillion)
# Year: 2221 - GDP log 2022$USD 15.4 (~3 quadrillion)

# %% [markdown]
# ## Willingness to Pay Over Time

# %%
for p in [20, 50, 80]:
    print('-')
    print('-')
    print('## {} ##'.format(p))
    willingness = np.array([willingness_to_pay(initial_gdp=variables['initial_gdp'],
                                               gdp_growth=gdp_growth_p[p],
                                               initial_pay=10 ** initial_pay_p[p],
                                               spend_doubling_time=spend_doubling_time_p[p],
                                               max_gdp_frac=max_gdp_frac_p[p],
                                               year=(y - CURRENT_YEAR)) for y in years])
    for y in years:
        print('Year: {} - willingness log 2022$USD per year {} (~{})'.format(y,
                                                                             np.round(np.log10(willingness[y - CURRENT_YEAR]), 1),
                                                                             numerize(willingness[y - CURRENT_YEAR])))


    plt.plot(years, np.log10(willingness))
plt.ylabel('log 2022$USD/yr willing to spend on TAI')
plt.show()
# Out:
# -
# -
# ## 20 ##
# Year: 2022 - willingness log 2022$USD per year 7.1 (~13 million)
# Year: 2023 - willingness log 2022$USD per year 7.2 (~14 million)
# Year: 2024 - willingness log 2022$USD per year 7.2 (~17 million)
# Year: 2025 - willingness log 2022$USD per year 7.3 (~19 million)
# Year: 2134 - willingness log 2022$USD per year 11.8 (~628 billion)
# Year: 2135 - willingness log 2022$USD per year 11.8 (~647 billion)
# Year: 2136 - willingness log 2022$USD per year 11.8 (~667 billion)
# Year: 2137 - willingness log 2022$USD per year 11.8 (~686 billion)
# Year: 2138 - willingness log 2022$USD per year 11.8 (~707 billion)
# Year: 2139 - willingness log 2022$USD per year 11.9 (~728 billion)
# Year: 2140 - willingness log 2022$USD per year 11.9 (~750 billion)
# Year: 2141 - willingness log 2022$USD per year 11.9 (~772 billion)
# Year: 2142 - willingness log 2022$USD per year 11.9 (~795 billion)
# Year: 2143 - willingness log 2022$USD per year 11.9 (~819 billion)
# Year: 2144 - willingness log 2022$USD per year 11.9 (~843 billion)
# Year: 2145 - willingness log 2022$USD per year 11.9 (~869 billion)
# Year: 2146 - willingness log 2022$USD per year 12.0 (~894 billion)
# Year: 2147 - willingness log 2022$USD per year 12.0 (~921 billion)
# Year: 2148 - willingness log 2022$USD per year 12.0 (~949 billion)
# Year: 2149 - willingness log 2022$USD per year 12.0 (~977 billion)
# Year: 2150 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2151 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2152 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2153 - willingness log 2022$USD per year 12.0 (~1 trillion)
# Year: 2154 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2155 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2156 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2157 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2158 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2159 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2160 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2161 - willingness log 2022$USD per year 12.1 (~1 trillion)
# Year: 2162 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2163 - willingness log 2022$USD per year 12.2 (~1 trillion)
# Year: 2164 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2165 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2166 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2167 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2168 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2169 - willingness log 2022$USD per year 12.2 (~2 trillion)
# Year: 2170 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2171 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2172 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2173 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2174 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2175 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2176 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2177 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2178 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2179 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2180 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2181 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2182 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2183 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2184 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2185 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2186 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2187 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2188 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2189 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2190 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2191 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2192 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2193 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2194 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2195 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2196 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2197 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2198 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2199 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2200 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2201 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2202 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2203 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2204 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2205 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2206 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2207 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2208 - willingness log 2022$USD per year 12.7 (~6 trillion)
# Year: 2209 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2210 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2211 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2212 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2213 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2214 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2215 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2216 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2217 - willingness log 2022$USD per year 12.9 (~7 trillion)
# Year: 2218 - willingness log 2022$USD per year 12.9 (~7 trillion)
# Year: 2219 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2220 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2221 - willingness log 2022$USD per year 12.9 (~8 trillion)

# %% [markdown]
# ## FLOPs Needed to Make TAI (Given Algorithmic Progress)

# %%
flops_ = np.array([flops_needed(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                              algo_doubling_rate_max_p[GRAPH_P],
                                                              initial_flops_p[GRAPH_P]),
                                possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                    max_reduction_p[GRAPH_P],
                                                                                    initial_flops_p[GRAPH_P]),
                                year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_))
plt.ylabel('log FLOPs needed to make TAI')
# Out:
# Text(0, 0.5, 'log FLOPs needed to make TAI')

# %%
for y in years:
    print('Year: {} - log FLOPs needed for TAI {} (~{})'.format(y,
                                                                np.round(np.log10(flops_[y - CURRENT_YEAR]), 1),
                                                                numerize(flops_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log FLOPs needed for TAI 32.5 (~337 nonillion)
# Year: 2023 - log FLOPs needed for TAI 32.3 (~215 nonillion)
# Year: 2024 - log FLOPs needed for TAI 32.1 (~136 nonillion)
# Year: 2025 - log FLOPs needed for TAI 31.9 (~86 nonillion)
# Year: 2026 - log FLOPs needed for TAI 31.7 (~55 nonillion)
# Year: 2027 - log FLOPs needed for TAI 31.6 (~36 nonillion)
# Year: 2028 - log FLOPs needed for TAI 31.4 (~24 nonillion)
# Year: 2029 - log FLOPs needed for TAI 31.2 (~16 nonillion)
# Year: 2030 - log FLOPs needed for TAI 31.1 (~11 nonillion)
# Year: 2031 - log FLOPs needed for TAI 30.9 (~8 nonillion)
# Year: 2032 - log FLOPs needed for TAI 30.8 (~7 nonillion)
# Year: 2033 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2034 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2035 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2036 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2037 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2038 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2039 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2040 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2041 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2042 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2043 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2044 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2045 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2046 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2047 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2048 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2049 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2050 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2051 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2052 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2053 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2054 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2055 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2056 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2057 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2058 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2059 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2060 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2061 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2062 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2063 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2064 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2065 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2066 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2067 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2068 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2069 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2070 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2071 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2072 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2073 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2074 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2075 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2076 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2077 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2078 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2079 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2080 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2081 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2082 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2083 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2084 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2085 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2086 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2087 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2088 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2089 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2090 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2091 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2092 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2093 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2094 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2095 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2096 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2097 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2098 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2099 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2100 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2101 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2102 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2103 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2104 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2105 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2106 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2107 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2108 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2109 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2110 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2111 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2112 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2113 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2114 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2115 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2116 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2117 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2118 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2119 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2120 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2121 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2122 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2123 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2124 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2125 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2126 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2127 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2128 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2129 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2130 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2131 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2132 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2133 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2134 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2135 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2136 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2137 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2138 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2139 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2140 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2141 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2142 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2143 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2144 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2145 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2146 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2147 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2148 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2149 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2150 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2151 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2152 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2153 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2154 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2155 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2156 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2157 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2158 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2159 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2160 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2161 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2162 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2163 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2164 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2165 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2166 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2167 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2168 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2169 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2170 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2171 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2172 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2173 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2174 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2175 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2176 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2177 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2178 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2179 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2180 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2181 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2182 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2183 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2184 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2185 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2186 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2187 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2188 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2189 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2190 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2191 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2192 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2193 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2194 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2195 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2196 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2197 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2198 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2199 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2200 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2201 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2202 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2203 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2204 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2205 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2206 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2207 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2208 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2209 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2210 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2211 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2212 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2213 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2214 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2215 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2216 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2217 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2218 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2219 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2220 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2221 - log FLOPs needed for TAI 30.5 (~3 nonillion)

# %% [markdown]
# ## FLOPs per Dollar (Given Declining Costs)

# %%
flops_per_dollar_ = np.array([flops_per_dollar(initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                               max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                               halving_rate=flops_halving_rate_p[GRAPH_P],
                                               year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(flops_per_dollar_))
plt.ylabel('log FLOPs per $1')
# Out:
# Text(0, 0.5, 'log FLOPs per $1')

# %%
for y in years:
    print('Year: {} - log {} FLOPs per $ (~{})'.format(y,
                                                       np.round(np.log10(flops_per_dollar_[y - CURRENT_YEAR]), 1),
                                                       numerize(flops_per_dollar_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log 18.0 FLOPs per $ (~1000 quadrillion)
# Year: 2023 - log 18.1 FLOPs per $ (~1 quintillion)
# Year: 2024 - log 18.2 FLOPs per $ (~2 quintillion)
# Year: 2025 - log 18.3 FLOPs per $ (~2 quintillion)
# Year: 2026 - log 18.4 FLOPs per $ (~2 quintillion)
# Year: 2027 - log 18.5 FLOPs per $ (~3 quintillion)
# Year: 2028 - log 18.6 FLOPs per $ (~4 quintillion)
# Year: 2029 - log 18.7 FLOPs per $ (~5 quintillion)
# Year: 2030 - log 18.8 FLOPs per $ (~6 quintillion)
# Year: 2031 - log 18.9 FLOPs per $ (~7 quintillion)
# Year: 2032 - log 19.0 FLOPs per $ (~9 quintillion)
# Year: 2033 - log 19.1 FLOPs per $ (~11 quintillion)
# Year: 2034 - log 19.2 FLOPs per $ (~14 quintillion)
# Year: 2035 - log 19.2 FLOPs per $ (~18 quintillion)
# Year: 2036 - log 19.3 FLOPs per $ (~22 quintillion)
# Year: 2037 - log 19.4 FLOPs per $ (~27 quintillion)
# Year: 2038 - log 19.5 FLOPs per $ (~34 quintillion)
# Year: 2039 - log 19.6 FLOPs per $ (~43 quintillion)
# Year: 2040 - log 19.7 FLOPs per $ (~53 quintillion)
# Year: 2041 - log 19.8 FLOPs per $ (~66 quintillion)
# Year: 2042 - log 19.9 FLOPs per $ (~83 quintillion)
# Year: 2043 - log 20.0 FLOPs per $ (~103 quintillion)
# Year: 2044 - log 20.1 FLOPs per $ (~128 quintillion)
# Year: 2045 - log 20.2 FLOPs per $ (~160 quintillion)
# Year: 2046 - log 20.3 FLOPs per $ (~200 quintillion)
# Year: 2047 - log 20.4 FLOPs per $ (~249 quintillion)
# Year: 2048 - log 20.5 FLOPs per $ (~311 quintillion)
# Year: 2049 - log 20.6 FLOPs per $ (~387 quintillion)
# Year: 2050 - log 20.7 FLOPs per $ (~483 quintillion)
# Year: 2051 - log 20.8 FLOPs per $ (~602 quintillion)
# Year: 2052 - log 20.9 FLOPs per $ (~751 quintillion)
# Year: 2053 - log 21.0 FLOPs per $ (~936 quintillion)
# Year: 2054 - log 21.1 FLOPs per $ (~1 sextillion)
# Year: 2055 - log 21.2 FLOPs per $ (~1 sextillion)
# Year: 2056 - log 21.3 FLOPs per $ (~2 sextillion)
# Year: 2057 - log 21.4 FLOPs per $ (~2 sextillion)
# Year: 2058 - log 21.4 FLOPs per $ (~3 sextillion)
# Year: 2059 - log 21.5 FLOPs per $ (~4 sextillion)
# Year: 2060 - log 21.6 FLOPs per $ (~4 sextillion)
# Year: 2061 - log 21.7 FLOPs per $ (~5 sextillion)
# Year: 2062 - log 21.8 FLOPs per $ (~7 sextillion)
# Year: 2063 - log 21.9 FLOPs per $ (~8 sextillion)
# Year: 2064 - log 22.0 FLOPs per $ (~11 sextillion)
# Year: 2065 - log 22.1 FLOPs per $ (~13 sextillion)
# Year: 2066 - log 22.2 FLOPs per $ (~16 sextillion)
# Year: 2067 - log 22.3 FLOPs per $ (~20 sextillion)
# Year: 2068 - log 22.4 FLOPs per $ (~25 sextillion)
# Year: 2069 - log 22.5 FLOPs per $ (~31 sextillion)
# Year: 2070 - log 22.6 FLOPs per $ (~38 sextillion)
# Year: 2071 - log 22.7 FLOPs per $ (~47 sextillion)
# Year: 2072 - log 22.8 FLOPs per $ (~58 sextillion)
# Year: 2073 - log 22.9 FLOPs per $ (~72 sextillion)
# Year: 2074 - log 22.9 FLOPs per $ (~88 sextillion)
# Year: 2075 - log 23.0 FLOPs per $ (~107 sextillion)
# Year: 2076 - log 23.1 FLOPs per $ (~130 sextillion)
# Year: 2077 - log 23.2 FLOPs per $ (~158 sextillion)
# Year: 2078 - log 23.3 FLOPs per $ (~189 sextillion)
# Year: 2079 - log 23.4 FLOPs per $ (~225 sextillion)
# Year: 2080 - log 23.4 FLOPs per $ (~266 sextillion)
# Year: 2081 - log 23.5 FLOPs per $ (~311 sextillion)
# Year: 2082 - log 23.6 FLOPs per $ (~361 sextillion)
# Year: 2083 - log 23.6 FLOPs per $ (~413 sextillion)
# Year: 2084 - log 23.7 FLOPs per $ (~467 sextillion)
# Year: 2085 - log 23.7 FLOPs per $ (~522 sextillion)
# Year: 2086 - log 23.8 FLOPs per $ (~577 sextillion)
# Year: 2087 - log 23.8 FLOPs per $ (~630 sextillion)
# Year: 2088 - log 23.8 FLOPs per $ (~680 sextillion)
# Year: 2089 - log 23.9 FLOPs per $ (~726 sextillion)
# Year: 2090 - log 23.9 FLOPs per $ (~767 sextillion)
# Year: 2091 - log 23.9 FLOPs per $ (~804 sextillion)
# Year: 2092 - log 23.9 FLOPs per $ (~837 sextillion)
# Year: 2093 - log 23.9 FLOPs per $ (~865 sextillion)
# Year: 2094 - log 23.9 FLOPs per $ (~889 sextillion)
# Year: 2095 - log 24.0 FLOPs per $ (~909 sextillion)
# Year: 2096 - log 24.0 FLOPs per $ (~925 sextillion)
# Year: 2097 - log 24.0 FLOPs per $ (~939 sextillion)
# Year: 2098 - log 24.0 FLOPs per $ (~951 sextillion)
# Year: 2099 - log 24.0 FLOPs per $ (~960 sextillion)
# Year: 2100 - log 24.0 FLOPs per $ (~968 sextillion)
# Year: 2101 - log 24.0 FLOPs per $ (~974 sextillion)
# Year: 2102 - log 24.0 FLOPs per $ (~979 sextillion)
# Year: 2103 - log 24.0 FLOPs per $ (~983 sextillion)
# Year: 2104 - log 24.0 FLOPs per $ (~986 sextillion)
# Year: 2105 - log 24.0 FLOPs per $ (~989 sextillion)
# Year: 2106 - log 24.0 FLOPs per $ (~991 sextillion)
# Year: 2107 - log 24.0 FLOPs per $ (~993 sextillion)
# Year: 2108 - log 24.0 FLOPs per $ (~994 sextillion)
# Year: 2109 - log 24.0 FLOPs per $ (~995 sextillion)
# Year: 2110 - log 24.0 FLOPs per $ (~996 sextillion)
# Year: 2111 - log 24.0 FLOPs per $ (~997 sextillion)
# Year: 2112 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2113 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2114 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2115 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2116 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2117 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2118 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2119 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2120 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2121 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2122 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2123 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2124 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2125 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2126 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2127 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2128 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2129 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2130 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2131 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2132 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2133 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2134 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2135 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2136 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2137 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2138 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2139 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2140 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2141 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2142 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2143 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2144 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2145 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2146 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2147 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2148 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2149 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2150 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2151 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2152 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2153 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2154 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2155 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2156 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2157 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2158 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2159 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2160 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2161 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2162 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2163 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2164 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2165 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2166 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2167 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2168 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2169 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2170 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2171 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2172 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2173 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2174 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2175 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2176 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2177 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2178 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2179 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2180 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2181 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2182 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2183 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2184 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2185 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2186 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2187 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2188 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2189 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2190 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2191 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2192 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2193 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2194 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2195 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2196 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2197 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2198 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2199 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2200 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2201 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2202 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2203 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2204 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2205 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2206 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2207 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2208 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2209 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2210 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2211 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2212 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2213 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2214 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2215 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2216 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2217 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2218 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2219 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2220 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2221 - log 24.0 FLOPs per $ (~1000 sextillion)

# %% [markdown]
# ## Max Possible OOM Reduction in TAI FLOP Size

# %%
# TODO: Update to include efficiency based
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                         max_reduction_p[GRAPH_P], t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('max OOM reduction')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> {} OOM reductions possible'.format(t,
                                                                 round(possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                                  max_reduction_p[GRAPH_P],
                                                                                                  t), 2)))
# Out:
# TAI log FLOP 24 -> 2.0 OOM reductions possible
# TAI log FLOP 25 -> 2.0 OOM reductions possible
# TAI log FLOP 26 -> 2.0 OOM reductions possible
# TAI log FLOP 27 -> 2.0 OOM reductions possible
# TAI log FLOP 28 -> 2.0 OOM reductions possible
# TAI log FLOP 29 -> 2.0 OOM reductions possible
# TAI log FLOP 30 -> 2.0 OOM reductions possible
# TAI log FLOP 31 -> 2.0 OOM reductions possible
# TAI log FLOP 32 -> 2.0 OOM reductions possible
# TAI log FLOP 33 -> 2.0 OOM reductions possible
# TAI log FLOP 34 -> 2.0 OOM reductions possible
# TAI log FLOP 35 -> 3.0 OOM reductions possible
# TAI log FLOP 36 -> 3.0 OOM reductions possible
# TAI log FLOP 37 -> 3.0 OOM reductions possible
# TAI log FLOP 38 -> 4.0 OOM reductions possible
# TAI log FLOP 39 -> 4.0 OOM reductions possible
# TAI log FLOP 40 -> 4.0 OOM reductions possible
# TAI log FLOP 41 -> 4.0 OOM reductions possible
# TAI log FLOP 42 -> 4.0 OOM reductions possible
# TAI log FLOP 43 -> 5.0 OOM reductions possible
# TAI log FLOP 44 -> 5.0 OOM reductions possible
# TAI log FLOP 45 -> 5.0 OOM reductions possible
# TAI log FLOP 46 -> 5.0 OOM reductions possible
# TAI log FLOP 47 -> 5.0 OOM reductions possible
# TAI log FLOP 48 -> 5.0 OOM reductions possible
# TAI log FLOP 49 -> 5.0 OOM reductions possible
# TAI log FLOP 50 -> 5.0 OOM reductions possible
# TAI log FLOP 51 -> 5.0 OOM reductions possible
# TAI log FLOP 52 -> 5.0 OOM reductions possible
# TAI log FLOP 53 -> 5.0 OOM reductions possible
# TAI log FLOP 54 -> 5.0 OOM reductions possible
# TAI log FLOP 55 -> 5.0 OOM reductions possible
# TAI log FLOP 56 -> 5.0 OOM reductions possible
# TAI log FLOP 57 -> 5.0 OOM reductions possible
# TAI log FLOP 58 -> 5.0 OOM reductions possible
# TAI log FLOP 59 -> 5.0 OOM reductions possible

# %% [markdown]
# ## Halving time (years) of compute requirements

# %%
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                              algo_doubling_rate_max_p[GRAPH_P],
                                              t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('number of years for compute requirements to halve')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> algo doubling rate {}yrs'.format(t,
                                                               round(algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                                     algo_doubling_rate_max_p[GRAPH_P],
                                                                                     t), 2)))
# Out:
# TAI log FLOP 24 -> algo doubling rate 2.01yrs
# TAI log FLOP 25 -> algo doubling rate 2.01yrs
# TAI log FLOP 26 -> algo doubling rate 2.01yrs
# TAI log FLOP 27 -> algo doubling rate 2.01yrs
# TAI log FLOP 28 -> algo doubling rate 2.01yrs
# TAI log FLOP 29 -> algo doubling rate 2.01yrs
# TAI log FLOP 30 -> algo doubling rate 2.01yrs
# TAI log FLOP 31 -> algo doubling rate 1.51yrs
# TAI log FLOP 32 -> algo doubling rate 1.49yrs
# TAI log FLOP 33 -> algo doubling rate 1.49yrs
# TAI log FLOP 34 -> algo doubling rate 1.49yrs
# TAI log FLOP 35 -> algo doubling rate 1.49yrs
# TAI log FLOP 36 -> algo doubling rate 1.49yrs
# TAI log FLOP 37 -> algo doubling rate 1.49yrs
# TAI log FLOP 38 -> algo doubling rate 1.49yrs
# TAI log FLOP 39 -> algo doubling rate 1.49yrs
# TAI log FLOP 40 -> algo doubling rate 1.49yrs
# TAI log FLOP 41 -> algo doubling rate 1.49yrs
# TAI log FLOP 42 -> algo doubling rate 1.49yrs
# TAI log FLOP 43 -> algo doubling rate 1.49yrs
# TAI log FLOP 44 -> algo doubling rate 1.49yrs
# TAI log FLOP 45 -> algo doubling rate 1.49yrs
# TAI log FLOP 46 -> algo doubling rate 1.49yrs
# TAI log FLOP 47 -> algo doubling rate 1.49yrs
# TAI log FLOP 48 -> algo doubling rate 1.49yrs
# TAI log FLOP 49 -> algo doubling rate 1.49yrs
# TAI log FLOP 50 -> algo doubling rate 1.49yrs
# TAI log FLOP 51 -> algo doubling rate 1.49yrs
# TAI log FLOP 52 -> algo doubling rate 1.49yrs
# TAI log FLOP 53 -> algo doubling rate 1.49yrs
# TAI log FLOP 54 -> algo doubling rate 1.49yrs
# TAI log FLOP 55 -> algo doubling rate 1.49yrs
# TAI log FLOP 56 -> algo doubling rate 1.49yrs
# TAI log FLOP 57 -> algo doubling rate 1.49yrs
# TAI log FLOP 58 -> algo doubling rate 1.49yrs
# TAI log FLOP 59 -> algo doubling rate 1.49yrs

# %% [markdown]
# ## Dollars Needed to Buy TAI (Given Algorithmic Progress and Decline in Cost per FLOP)

# %%
cost_of_tai_ = np.array([cost_of_tai(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                     possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P], max_reduction_p[GRAPH_P], initial_flops_p[GRAPH_P]),
                                     algo_doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                        algo_doubling_rate_max_p[GRAPH_P],
                                                                        initial_flops_p[GRAPH_P]),
                                     initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                     max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                     flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                     year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(cost_of_tai_))
plt.ylabel('log $ needed to buy TAI')
# Out:
# Text(0, 0.5, 'log $ needed to buy TAI')

# %%
for y in years:
    print('Year: {} - log $ {} to buy TAI (~{})'.format(y,
                                                        np.round(np.log10(cost_of_tai_[y - CURRENT_YEAR]), 1),
                                                        numerize(cost_of_tai_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log $ 14.5 to buy TAI (~337 trillion)
# Year: 2023 - log $ 14.2 to buy TAI (~172 trillion)
# Year: 2024 - log $ 13.9 to buy TAI (~87 trillion)
# Year: 2025 - log $ 13.6 to buy TAI (~45 trillion)
# Year: 2026 - log $ 13.4 to buy TAI (~23 trillion)
# Year: 2027 - log $ 13.1 to buy TAI (~12 trillion)
# Year: 2028 - log $ 12.8 to buy TAI (~6 trillion)
# Year: 2029 - log $ 12.5 to buy TAI (~3 trillion)
# Year: 2030 - log $ 12.3 to buy TAI (~2 trillion)
# Year: 2031 - log $ 12.1 to buy TAI (~1 trillion)
# Year: 2032 - log $ 11.9 to buy TAI (~720 billion)
# Year: 2033 - log $ 11.7 to buy TAI (~473 billion)
# Year: 2034 - log $ 11.5 to buy TAI (~327 billion)
# Year: 2035 - log $ 11.4 to buy TAI (~235 billion)
# Year: 2036 - log $ 11.2 to buy TAI (~176 billion)
# Year: 2037 - log $ 11.1 to buy TAI (~134 billion)
# Year: 2038 - log $ 11.0 to buy TAI (~104 billion)
# Year: 2039 - log $ 10.9 to buy TAI (~82 billion)
# Year: 2040 - log $ 10.8 to buy TAI (~65 billion)
# Year: 2041 - log $ 10.7 to buy TAI (~52 billion)
# Year: 2042 - log $ 10.6 to buy TAI (~41 billion)
# Year: 2043 - log $ 10.5 to buy TAI (~33 billion)
# Year: 2044 - log $ 10.4 to buy TAI (~26 billion)
# Year: 2045 - log $ 10.3 to buy TAI (~21 billion)
# Year: 2046 - log $ 10.2 to buy TAI (~17 billion)
# Year: 2047 - log $ 10.1 to buy TAI (~14 billion)
# Year: 2048 - log $ 10.0 to buy TAI (~11 billion)
# Year: 2049 - log $ 9.9 to buy TAI (~9 billion)
# Year: 2050 - log $ 9.8 to buy TAI (~7 billion)
# Year: 2051 - log $ 9.7 to buy TAI (~6 billion)
# Year: 2052 - log $ 9.7 to buy TAI (~4 billion)
# Year: 2053 - log $ 9.6 to buy TAI (~4 billion)
# Year: 2054 - log $ 9.5 to buy TAI (~3 billion)
# Year: 2055 - log $ 9.4 to buy TAI (~2 billion)
# Year: 2209 - log $ 6.5 to buy TAI (~3 million)
# Year: 2210 - log $ 6.5 to buy TAI (~3 million)
# Year: 2211 - log $ 6.5 to buy TAI (~3 million)
# Year: 2212 - log $ 6.5 to buy TAI (~3 million)
# Year: 2213 - log $ 6.5 to buy TAI (~3 million)
# Year: 2214 - log $ 6.5 to buy TAI (~3 million)
# Year: 2215 - log $ 6.5 to buy TAI (~3 million)
# Year: 2216 - log $ 6.5 to buy TAI (~3 million)
# Year: 2217 - log $ 6.5 to buy TAI (~3 million)
# Year: 2218 - log $ 6.5 to buy TAI (~3 million)
# Year: 2219 - log $ 6.5 to buy TAI (~3 million)
# Year: 2220 - log $ 6.5 to buy TAI (~3 million)
# Year: 2221 - log $ 6.5 to buy TAI (~3 million)

# %% [markdown]
# ## FLOPs at Max Spend

# %%
flops_at_max_ = np.array([flops_at_max(initial_gdp=variables['initial_gdp'],
                                       gdp_growth=gdp_growth_p[GRAPH_P],
                                       initial_pay=10 ** initial_pay_p[GRAPH_P],
                                       spend_doubling_time=spend_doubling_time_p[GRAPH_P],
                                       max_gdp_frac=max_gdp_frac_p[GRAPH_P],
                                       initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                       max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                       flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                       year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_at_max_))
plt.ylabel('max log FLOPs bought given willingness to spend')
# Out:
# Text(0, 0.5, 'max log FLOPs bought given willingness to spend')

# %%
for y in years:
    print('Year: {} - max log FLOPs {} (~{} FLOP, ~{} petaFLOP/s-days)'.format(y,
                                                                               np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]), 1),
                                                                               numerize(flops_at_max_[y - CURRENT_YEAR]),
                                                                               log_flop_to_petaflop_sdays(np.log10(flops_at_max_[y - CURRENT_YEAR]))))
# Out:
# Year: 2022 - max log FLOPs 25.1 (~13 septillion FLOP, ~145590 petaFLOP/s-days)
# Year: 2023 - max log FLOPs 25.3 (~19 septillion FLOP, ~215939 petaFLOP/s-days)
# Year: 2024 - max log FLOPs 25.4 (~28 septillion FLOP, ~320275 petaFLOP/s-days)
# Year: 2025 - max log FLOPs 25.6 (~41 septillion FLOP, ~475012 petaFLOP/s-days)
# Year: 2026 - max log FLOPs 25.8 (~61 septillion FLOP, ~704487 petaFLOP/s-days)
# Year: 2027 - max log FLOPs 26.0 (~90 septillion FLOP, ~1044785 petaFLOP/s-days)
# Year: 2028 - max log FLOPs 26.1 (~134 septillion FLOP, ~1549402 petaFLOP/s-days)
# Year: 2029 - max log FLOPs 26.3 (~199 septillion FLOP, ~2297639 petaFLOP/s-days)
# Year: 2030 - max log FLOPs 26.5 (~294 septillion FLOP, ~3407040 petaFLOP/s-days)
# Year: 2031 - max log FLOPs 26.6 (~436 septillion FLOP, ~5051803 petaFLOP/s-days)
# Year: 2032 - max log FLOPs 26.8 (~647 septillion FLOP, ~7490058 petaFLOP/s-days)
# Year: 2033 - max log FLOPs 27.0 (~959 septillion FLOP, ~11104239 petaFLOP/s-days)
# Year: 2034 - max log FLOPs 27.2 (~1 octillion FLOP, ~16460824 petaFLOP/s-days)
# Year: 2035 - max log FLOPs 27.3 (~2 octillion FLOP, ~24398713 petaFLOP/s-days)
# Year: 2036 - max log FLOPs 27.5 (~3 octillion FLOP, ~36159907 petaFLOP/s-days)
# Year: 2037 - max log FLOPs 27.7 (~5 octillion FLOP, ~53582623 petaFLOP/s-days)
# Year: 2038 - max log FLOPs 27.8 (~7 octillion FLOP, ~79386517 petaFLOP/s-days)
# Year: 2039 - max log FLOPs 28.0 (~10 octillion FLOP, ~117593658 petaFLOP/s-days)
# Year: 2040 - max log FLOPs 28.2 (~15 octillion FLOP, ~174149351 petaFLOP/s-days)
# Year: 2041 - max log FLOPs 28.3 (~22 octillion FLOP, ~257836830 petaFLOP/s-days)
# Year: 2042 - max log FLOPs 28.5 (~33 octillion FLOP, ~381623479 petaFLOP/s-days)
# Year: 2043 - max log FLOPs 28.7 (~49 octillion FLOP, ~564639691 petaFLOP/s-days)
# Year: 2044 - max log FLOPs 28.9 (~72 octillion FLOP, ~835083473 petaFLOP/s-days)
# Year: 2045 - max log FLOPs 29.0 (~107 octillion FLOP, ~1234476783 petaFLOP/s-days)
# Year: 2046 - max log FLOPs 29.2 (~158 octillion FLOP, ~1823890721 petaFLOP/s-days)
# Year: 2047 - max log FLOPs 29.4 (~233 octillion FLOP, ~2693030199 petaFLOP/s-days)
# Year: 2048 - max log FLOPs 29.5 (~343 octillion FLOP, ~3973457927 petaFLOP/s-days)
# Year: 2049 - max log FLOPs 29.7 (~506 octillion FLOP, ~5857787685 petaFLOP/s-days)
# Year: 2050 - max log FLOPs 29.9 (~745 octillion FLOP, ~8627448418 petaFLOP/s-days)
# Year: 2051 - max log FLOPs 30.0 (~1 nonillion FLOP, ~12692693291 petaFLOP/s-days)
# Year: 2052 - max log FLOPs 30.2 (~2 nonillion FLOP, ~18650003343 petaFLOP/s-days)
# Year: 2053 - max log FLOPs 30.4 (~2 nonillion FLOP, ~27364040910 petaFLOP/s-days)
# Year: 2054 - max log FLOPs 30.5 (~3 nonillion FLOP, ~40083996098 petaFLOP/s-days)
# Year: 2055 - max log FLOPs 30.7 (~5 nonillion FLOP, ~58607714410 petaFLOP/s-days)
# Year: 2056 - max log FLOPs 30.9 (~7 nonillion FLOP, ~85511580640 petaFLOP/s-days)
# Year: 2057 - max log FLOPs 31.0 (~11 nonillion FLOP, ~124469939711 petaFLOP/s-days)
# Year: 2058 - max log FLOPs 31.2 (~16 nonillion FLOP, ~180694993855 petaFLOP/s-days)
# Year: 2059 - max log FLOPs 31.4 (~23 nonillion FLOP, ~261536672640 petaFLOP/s-days)
# Year: 2060 - max log FLOPs 31.5 (~33 nonillion FLOP, ~377291821235 petaFLOP/s-days)
# Year: 2061 - max log FLOPs 31.7 (~47 nonillion FLOP, ~542282859507 petaFLOP/s-days)
# Year: 2062 - max log FLOPs 31.8 (~67 nonillion FLOP, ~776277185468 petaFLOP/s-days)
# Year: 2063 - max log FLOPs 32.0 (~96 nonillion FLOP, ~1106328982980 petaFLOP/s-days)
# Year: 2064 - max log FLOPs 32.1 (~136 nonillion FLOP, ~1569133181697 petaFLOP/s-days)
# Year: 2065 - max log FLOPs 32.3 (~191 nonillion FLOP, ~2213984862373 petaFLOP/s-days)
# Year: 2066 - max log FLOPs 32.4 (~268 nonillion FLOP, ~3106433191731 petaFLOP/s-days)
# Year: 2067 - max log FLOPs 32.6 (~374 nonillion FLOP, ~4332702328600 petaFLOP/s-days)
# Year: 2068 - max log FLOPs 32.7 (~519 nonillion FLOP, ~6004915715642 petaFLOP/s-days)
# Year: 2069 - max log FLOPs 32.9 (~714 nonillion FLOP, ~8267094442154 petaFLOP/s-days)
# Year: 2070 - max log FLOPs 33.0 (~976 nonillion FLOP, ~11301790127073 petaFLOP/s-days)
# Year: 2071 - max log FLOPs 33.1 (~1 decillion FLOP, ~15337038294144 petaFLOP/s-days)
# Year: 2072 - max log FLOPs 33.3 (~2 decillion FLOP, ~20653056477047 petaFLOP/s-days)
# Year: 2073 - max log FLOPs 33.4 (~2 decillion FLOP, ~27587741971154 petaFLOP/s-days)
# Year: 2074 - max log FLOPs 33.5 (~3 decillion FLOP, ~36539542837933 petaFLOP/s-days)
# Year: 2075 - max log FLOPs 33.6 (~4 decillion FLOP, ~47965717272694 petaFLOP/s-days)
# Year: 2076 - max log FLOPs 33.7 (~5 decillion FLOP, ~62373468176553 petaFLOP/s-days)
# Year: 2077 - max log FLOPs 33.8 (~7 decillion FLOP, ~80301157678307 petaFLOP/s-days)
# Year: 2078 - max log FLOPs 33.9 (~9 decillion FLOP, ~102287111034744 petaFLOP/s-days)
# Year: 2079 - max log FLOPs 34.0 (~11 decillion FLOP, ~128824830518089 petaFLOP/s-days)
# Year: 2080 - max log FLOPs 34.1 (~14 decillion FLOP, ~160306097387739 petaFLOP/s-days)
# Year: 2081 - max log FLOPs 34.2 (~17 decillion FLOP, ~196957409654102 petaFLOP/s-days)
# Year: 2082 - max log FLOPs 34.3 (~21 decillion FLOP, ~238779730100286 petaFLOP/s-days)
# Year: 2083 - max log FLOPs 34.4 (~25 decillion FLOP, ~285504973259016 petaFLOP/s-days)
# Year: 2084 - max log FLOPs 34.5 (~29 decillion FLOP, ~336582916103122 petaFLOP/s-days)
# Year: 2085 - max log FLOPs 34.5 (~34 decillion FLOP, ~391207709631436 petaFLOP/s-days)
# Year: 2086 - max log FLOPs 34.6 (~39 decillion FLOP, ~448384204501992 petaFLOP/s-days)
# Year: 2087 - max log FLOPs 34.6 (~44 decillion FLOP, ~507023643935821 petaFLOP/s-days)
# Year: 2088 - max log FLOPs 34.7 (~49 decillion FLOP, ~566050147033992 petaFLOP/s-days)
# Year: 2089 - max log FLOPs 34.7 (~54 decillion FLOP, ~624497236210099 petaFLOP/s-days)
# Year: 2090 - max log FLOPs 34.8 (~59 decillion FLOP, ~681578086965241 petaFLOP/s-days)
# Year: 2091 - max log FLOPs 34.8 (~64 decillion FLOP, ~736721801252939 petaFLOP/s-days)
# Year: 2092 - max log FLOPs 34.8 (~68 decillion FLOP, ~789577028101749 petaFLOP/s-days)
# Year: 2093 - max log FLOPs 34.9 (~73 decillion FLOP, ~839990606028184 petaFLOP/s-days)
# Year: 2094 - max log FLOPs 34.9 (~77 decillion FLOP, ~887971426409839 petaFLOP/s-days)
# Year: 2095 - max log FLOPs 34.9 (~81 decillion FLOP, ~933649015443456 petaFLOP/s-days)
# Year: 2096 - max log FLOPs 34.9 (~84 decillion FLOP, ~977233836952726 petaFLOP/s-days)
# Year: 2097 - max log FLOPs 34.9 (~88 decillion FLOP, ~1018983404524685 petaFLOP/s-days)
# Year: 2098 - max log FLOPs 35.0 (~92 decillion FLOP, ~1059175829285440 petaFLOP/s-days)
# Year: 2099 - max log FLOPs 35.0 (~95 decillion FLOP, ~1098090752321206 petaFLOP/s-days)
# Year: 2100 - max log FLOPs 35.0 (~98 decillion FLOP, ~1135996690230373 petaFLOP/s-days)
# Year: 2101 - max log FLOPs 35.0 (~101 decillion FLOP, ~1173143468281083 petaFLOP/s-days)
# Year: 2102 - max log FLOPs 35.0 (~105 decillion FLOP, ~1209758413185456 petaFLOP/s-days)
# Year: 2103 - max log FLOPs 35.0 (~108 decillion FLOP, ~1246045152921528 petaFLOP/s-days)
# Year: 2104 - max log FLOPs 35.0 (~111 decillion FLOP, ~1282184108612451 petaFLOP/s-days)
# Year: 2105 - max log FLOPs 35.1 (~114 decillion FLOP, ~1318333997737352 petaFLOP/s-days)
# Year: 2106 - max log FLOPs 35.1 (~117 decillion FLOP, ~1354633868639788 petaFLOP/s-days)
# Year: 2107 - max log FLOPs 35.1 (~120 decillion FLOP, ~1391205344370228 petaFLOP/s-days)
# Year: 2108 - max log FLOPs 35.1 (~123 decillion FLOP, ~1428154871288460 petaFLOP/s-days)
# Year: 2109 - max log FLOPs 35.1 (~127 decillion FLOP, ~1465575851095139 petaFLOP/s-days)
# Year: 2110 - max log FLOPs 35.1 (~130 decillion FLOP, ~1503550591645210 petaFLOP/s-days)
# Year: 2111 - max log FLOPs 35.1 (~133 decillion FLOP, ~1542152048974308 petaFLOP/s-days)
# Year: 2112 - max log FLOPs 35.1 (~137 decillion FLOP, ~1581445356144260 petaFLOP/s-days)
# Year: 2113 - max log FLOPs 35.1 (~140 decillion FLOP, ~1621489148155856 petaFLOP/s-days)
# Year: 2114 - max log FLOPs 35.2 (~144 decillion FLOP, ~1662336699486860 petaFLOP/s-days)
# Year: 2115 - max log FLOPs 35.2 (~147 decillion FLOP, ~1704036894054176 petaFLOP/s-days)
# Year: 2116 - max log FLOPs 35.2 (~151 decillion FLOP, ~1746635048126634 petaFLOP/s-days)
# Year: 2117 - max log FLOPs 35.2 (~155 decillion FLOP, ~1790173605972036 petaFLOP/s-days)
# Year: 2118 - max log FLOPs 35.2 (~159 decillion FLOP, ~1834692726490552 petaFLOP/s-days)
# Year: 2119 - max log FLOPs 35.2 (~162 decillion FLOP, ~1880230777195327 petaFLOP/s-days)
# Year: 2120 - max log FLOPs 35.2 (~166 decillion FLOP, ~1926824749918595 petaFLOP/s-days)
# Year: 2121 - max log FLOPs 35.2 (~171 decillion FLOP, ~1974510610698858 petaFLOP/s-days)
# Year: 2122 - max log FLOPs 35.2 (~175 decillion FLOP, ~2023323594526172 petaFLOP/s-days)
# Year: 2123 - max log FLOPs 35.3 (~179 decillion FLOP, ~2073298454026100 petaFLOP/s-days)
# Year: 2124 - max log FLOPs 35.3 (~184 decillion FLOP, ~2124469669758523 petaFLOP/s-days)
# Year: 2125 - max log FLOPs 35.3 (~188 decillion FLOP, ~2176871628591610 petaFLOP/s-days)
# Year: 2126 - max log FLOPs 35.3 (~193 decillion FLOP, ~2230538775567327 petaFLOP/s-days)
# Year: 2127 - max log FLOPs 35.3 (~197 decillion FLOP, ~2285505743790218 petaFLOP/s-days)
# Year: 2128 - max log FLOPs 35.3 (~202 decillion FLOP, ~2341807466120874 petaFLOP/s-days)
# Year: 2129 - max log FLOPs 35.3 (~207 decillion FLOP, ~2399479271826420 petaFLOP/s-days)
# Year: 2130 - max log FLOPs 35.3 (~212 decillion FLOP, ~2458556970812796 petaFLOP/s-days)
# Year: 2131 - max log FLOPs 35.3 (~218 decillion FLOP, ~2519076927622760 petaFLOP/s-days)
# Year: 2132 - max log FLOPs 35.3 (~223 decillion FLOP, ~2581076127016051 petaFLOP/s-days)
# Year: 2133 - max log FLOPs 35.4 (~228 decillion FLOP, ~2644592232642682 petaFLOP/s-days)
# Year: 2134 - max log FLOPs 35.4 (~234 decillion FLOP, ~2709663640066502 petaFLOP/s-days)
# Year: 2135 - max log FLOPs 35.4 (~240 decillion FLOP, ~2776329525183996 petaFLOP/s-days)
# Year: 2136 - max log FLOPs 35.4 (~246 decillion FLOP, ~2844629888909956 petaFLOP/s-days)
# Year: 2137 - max log FLOPs 35.4 (~252 decillion FLOP, ~2914605598855518 petaFLOP/s-days)
# Year: 2138 - max log FLOPs 35.4 (~258 decillion FLOP, ~2986298428603561 petaFLOP/s-days)
# Year: 2139 - max log FLOPs 35.4 (~264 decillion FLOP, ~3059751095087834 petaFLOP/s-days)
# Year: 2140 - max log FLOPs 35.4 (~271 decillion FLOP, ~3135007294498687 petaFLOP/s-days)
# Year: 2141 - max log FLOPs 35.4 (~278 decillion FLOP, ~3212111737069654 petaFLOP/s-days)
# Year: 2142 - max log FLOPs 35.5 (~284 decillion FLOP, ~3291110181044116 petaFLOP/s-days)
# Year: 2143 - max log FLOPs 35.5 (~291 decillion FLOP, ~3372049466071548 petaFLOP/s-days)
# Year: 2144 - max log FLOPs 35.5 (~299 decillion FLOP, ~3454977546247438 petaFLOP/s-days)
# Year: 2145 - max log FLOPs 35.5 (~306 decillion FLOP, ~3539943522974493 petaFLOP/s-days)
# Year: 2146 - max log FLOPs 35.5 (~313 decillion FLOP, ~3626997677801188 petaFLOP/s-days)
# Year: 2147 - max log FLOPs 35.5 (~321 decillion FLOP, ~3716191505366366 petaFLOP/s-days)
# Year: 2148 - max log FLOPs 35.5 (~329 decillion FLOP, ~3807577746563644 petaFLOP/s-days)
# Year: 2149 - max log FLOPs 35.5 (~337 decillion FLOP, ~3901210422024753 petaFLOP/s-days)
# Year: 2150 - max log FLOPs 35.5 (~345 decillion FLOP, ~3997144866004280 petaFLOP/s-days)
# Year: 2151 - max log FLOPs 35.5 (~354 decillion FLOP, ~4095437760742632 petaFLOP/s-days)
# Year: 2152 - max log FLOPs 35.6 (~363 decillion FLOP, ~4196147171373335 petaFLOP/s-days)
# Year: 2153 - max log FLOPs 35.6 (~371 decillion FLOP, ~4299332581433041 petaFLOP/s-days)
# Year: 2154 - max log FLOPs 35.6 (~381 decillion FLOP, ~4405054929028030 petaFLOP/s-days)
# Year: 2155 - max log FLOPs 35.6 (~390 decillion FLOP, ~4513376643706465 petaFLOP/s-days)
# Year: 2156 - max log FLOPs 35.6 (~400 decillion FLOP, ~4624361684080651 petaFLOP/s-days)
# Year: 2157 - max log FLOPs 35.6 (~409 decillion FLOP, ~4738075576240606 petaFLOP/s-days)
# Year: 2158 - max log FLOPs 35.6 (~419 decillion FLOP, ~4854585452998300 petaFLOP/s-days)
# Year: 2159 - max log FLOPs 35.6 (~430 decillion FLOP, ~4973960094000819 petaFLOP/s-days)
# Year: 2160 - max log FLOPs 35.6 (~440 decillion FLOP, ~5096269966745511 petaFLOP/s-days)
# Year: 2161 - max log FLOPs 35.7 (~451 decillion FLOP, ~5221587268532860 petaFLOP/s-days)
# Year: 2162 - max log FLOPs 35.7 (~462 decillion FLOP, ~5349985969390205 petaFLOP/s-days)
# Year: 2163 - max log FLOPs 35.7 (~474 decillion FLOP, ~5481541855998337 petaFLOP/s-days)
# Year: 2164 - max log FLOPs 35.7 (~485 decillion FLOP, ~5616332576653218 petaFLOP/s-days)
# Year: 2165 - max log FLOPs 35.7 (~497 decillion FLOP, ~5754437687295042 petaFLOP/s-days)
# Year: 2166 - max log FLOPs 35.7 (~509 decillion FLOP, ~5895938698634563 petaFLOP/s-days)
# Year: 2167 - max log FLOPs 35.7 (~522 decillion FLOP, ~6040919124411200 petaFLOP/s-days)
# Year: 2168 - max log FLOPs 35.7 (~535 decillion FLOP, ~6189464530811307 petaFLOP/s-days)
# Year: 2169 - max log FLOPs 35.7 (~548 decillion FLOP, ~6341662587081091 petaFLOP/s-days)
# Year: 2170 - max log FLOPs 35.7 (~561 decillion FLOP, ~6497603117365520 petaFLOP/s-days)
# Year: 2171 - max log FLOPs 35.8 (~575 decillion FLOP, ~6657378153805461 petaFLOP/s-days)
# Year: 2172 - max log FLOPs 35.8 (~589 decillion FLOP, ~6821081990926308 petaFLOP/s-days)
# Year: 2173 - max log FLOPs 35.8 (~604 decillion FLOP, ~6988811241353145 petaFLOP/s-days)
# Year: 2174 - max log FLOPs 35.8 (~619 decillion FLOP, ~7160664892883834 petaFLOP/s-days)
# Year: 2175 - max log FLOPs 35.8 (~634 decillion FLOP, ~7336744366957870 petaFLOP/s-days)
# Year: 2176 - max log FLOPs 35.8 (~649 decillion FLOP, ~7517153578553203 petaFLOP/s-days)
# Year: 2177 - max log FLOPs 35.8 (~665 decillion FLOP, ~7701998997551646 petaFLOP/s-days)
- max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19386728406580052 petaFLOP/s-days)
# Year: 2216 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19863444126548380 petaFLOP/s-days)
# Year: 2217 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~20351882189248212 petaFLOP/s-days)
# Year: 2218 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~20852330844724368 petaFLOP/s-days)
# Year: 2219 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~21365085431028928 petaFLOP/s-days)
# Year: 2220 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~21890448548515712 petaFLOP/s-days)
# Year: 2221 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~22428730238419392 petaFLOP/s-days)

# %% [markdown]
# ## Parameters at Max Spend

# %%
for y in years:
    print('Year: {} - max log parameters {} (~{} parameters)'.format(y,
                                                                     np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12, 1),
                                                                     numerize(10 ** (np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12))))
# Out:
# Year: 2022 - max log parameters 13.1 (~13 trillion parameters)
# Year: 2023 - max log parameters 13.3 (~19 trillion parameters)
# Year: 2024 - max log parameters 13.4 (~28 trillion parameters)
# Year: 2025 - max log parameters 13.6 (~41 trillion parameters)
# Year: 2026 - max log parameters 13.8 (~61 trillion parameters)
# Year: 2027 - max log parameters 14.0 (~90 trillion parameters)
# Year: 2028 - max log parameters 14.1 (~134 trillion parameters)
# Year: 2029 - max log parameters 14.3 (~199 trillion parameters)
# Year: 2030 - max log parameters 14.5 (~294 trillion parameters)
# Year: 2031 - max log parameters 14.6 (~436 trillion parameters)
# Year: 2032 - max log parameters 14.8 (~647 trillion parameters)
# Year: 2033 - max log parameters 15.0 (~959 trillion parameters)
# Year: 2034 - max log parameters 15.2 (~1 quadrillion parameters)
# Year: 2035 - max log parameters 15.3 (~2 quadrillion parameters)
# Year: 2036 - max log parameters 15.5 (~3 quadrillion parameters)
# Year: 2037 - max log parameters 15.7 (~5 quadrillion parameters)
# Year: 2038 - max log parameters 15.8 (~7 quadrillion parameters)
# Year: 2039 - max log parameters 16.0 (~10 quadrillion parameters)
# Year: 2040 - max log parameters 16.2 (~15 quadrillion parameters)
# Year: 2041 - max log parameters 16.3 (~22 quadrillion parameters)
# Year: 2042 - max log parameters 16.5 (~33 quadrillion parameters)
# Year: 2043 - max log parameters 16.7 (~49 quadrillion parameters)
# Year: 2044 - max log parameters 16.9 (~72 quadrillion parameters)
# Year: 2045 - max log parameters 17.0 (~107 quadrillion parameters)
# Year: 2046 - max log parameters 17.2 (~158 quadrillion parameters)
# Year: 2047 - max log parameters 17.4 (~233 quadrillion parameters)
# Year: 2048 - max log parameters 17.5 (~343 quadrillion parameters)
# Year: 2049 - max log parameters 17.7 (~506 quadrillion parameters)
# Year: 2050 - max log parameters 17.9 (~745 quadrillion parameters)
# Year: 2051 - max log parameters 18.0 (~1 quintillion parameters)
# Year: 2052 - max log parameters 18.2 (~2 quintillion parameters)
# Year: 2053 - max log parameters 18.4 (~2 quintillion parameters)
# Year: 2054 - max log parameters 18.5 (~3 quintillion parameters)
# Year: 2055 - max log parameters 18.7 (~5 quintillion parameters)
# Year: 2056 - max log parameters 18.9 (~7 quintillion parameters)
# Year: 2057 - max log parameters 19.0 (~11 quintillion parameters)
# Year: 2058 - max log parameters 19.2 (~16 quintillion parameters)
- max log parameters 24.3 (~2 septillion parameters)
# Year: 2221 - max log parameters 24.3 (~2 septillion parameters)

# %% [markdown]
# ## Chance of Non-scaling Delay

# %%
p_nonscaling_delay_ = np.array([p_nonscaling_delay(variables.get('initial_chance_of_nonscaling_issue', 0),
                                                   variables.get('final_chance_of_nonscaling_issue', 0),
                                                   year=y,
                                                   max_year=variables.get('nonscaling_issue_bottom_year', 0)) for y in years])

plt.plot(years[:60], p_nonscaling_delay_[:60])
plt.ylabel('chance of non-scaling delay by year')
# Out:
# Text(0, 0.5, 'chance of non-scaling delay by year')

# %%
for y in years:
    print('Year: {} - p(nonscaling delay) = {}%'.format(y,
                                                        np.round(p_nonscaling_delay_[y - CURRENT_YEAR] * 100, 1)))
# Out:
# Year: 2022 - p(nonscaling delay) = 94.2%
# Year: 2023 - p(nonscaling delay) = 94.0%
# Year: 2024 - p(nonscaling delay) = 93.6%
# Year: 2025 - p(nonscaling delay) = 93.2%
# Year: 2026 - p(nonscaling delay) = 92.5%
# Year: 2027 - p(nonscaling delay) = 91.7%
# Year: 2028 - p(nonscaling delay) = 90.6%
# Year: 2029 - p(nonscaling delay) = 89.2%
# Year: 2030 - p(nonscaling delay) = 87.5%
# Year: 2031 - p(nonscaling delay) = 85.2%
# Year: 2032 - p(nonscaling delay) = 82.5%
# Year: 2033 - p(nonscaling delay) = 79.1%
# Year: 2034 - p(nonscaling delay) = 75.3%
# Year: 2035 - p(nonscaling delay) = 70.9%
# Year: 2036 - p(nonscaling delay) = 66.2%
# Year: 2037 - p(nonscaling delay) = 61.4%
# Year: 2038 - p(nonscaling delay) = 56.6%
# Year: 2039 - p(nonscaling delay) = 52.0%
# Year: 2040 - p(nonscaling delay) = 47.9%
# Year: 2041 - p(nonscaling delay) = 44.3%
# Year: 2042 - p(nonscaling delay) = 41.2%
# Year: 2043 - p(nonscaling delay) = 38.7%
# Year: 2044 - p(nonscaling delay) = 36.7%
# Year: 2045 - p(nonscaling delay) = 35.1%
# Year: 2046 - p(nonscaling delay) = 33.8%
# Year: 2047 - p(nonscaling delay) = 32.9%
# Year: 2048 - p(nonscaling delay) = 32.2%
# Year: 2049 - p(nonscaling delay) = 31.6%
# Year: 2050 - p(nonscaling delay) = 31.2%
# Year: 2051 - p(nonscaling delay) = 30.9%
# Year: 2052 - p(nonscaling delay) = 30.7%
# Year: 2053 - p(nonscaling delay) = 30.5%
# Year: 2054 - p(nonscaling delay) = 30.4%
# Year: 2055 - p(nonscaling delay) = 30.3%
# Year: 2056 - p(nonscaling delay) = 30.2%
# Year: 2057 - p(nonscaling delay) = 30.2%
# Year: 2058 - p(nonscaling delay) = 30.1%
# Year: 2059 - p(nonscaling delay) = 30.1%
# Year: 2060 - p(nonscaling delay) = 30.1%
# Year: 2061 - p(nonscaling delay) = 30.0%
# Year: 2062 - p(nonscaling delay) = 30.0%
# Year: 2063 - p(nonscaling delay) = 30.0%
# Year: 2064 - p(nonscaling delay) = 30.0%
# Year: 2065 - p(nonscaling delay) = 30.0%
# Year: 2066 - p(nonscaling delay) = 30.0%
# Year: 2067 - p(nonscaling delay) = 30.0%
# Year: 2068 - p(nonscaling delay) = 30.0%
# Year: 2069 - p(nonscaling delay) = 30.0%
# Year: 2070 - p(nonscaling delay) = 30.0%
# Year: 2071 - p(nonscaling delay) = 30.0%
# Year: 2072 - p(nonscaling delay) = 30.0%
# Year: 2073 - p(nonscaling delay) = 30.0%
# Year: 2074 - p(nonscaling delay) = 30.0%
# Year: 2075 - p(nonscaling delay) = 30.0%
# Year: 2076 - p(nonscaling delay) = 30.0%
# Year: 2077 - p(nonscaling delay) = 30.0%
# Year: 2078 - p(nonscaling delay) = 30.0%
# Year: 2079 - p(nonscaling delay) = 30.0%
# Year: 2080 - p(nonscaling delay) = 30.0%
# Year: 2081 - p(nonscaling delay) = 30.0%
# Year: 2082 - p(nonscaling delay) = 30.0%
# Year: 2083 - p(nonscaling delay) = 30.0%
# Year: 2084 - p(nonscaling delay) = 30.0%
# Year: 2085 - p(nonscaling delay) = 30.0%
# Year: 2086 - p(nonscaling delay) = 30.0%
# Year: 2087 - p(nonscaling delay) = 30.0%
# Year: 2088 - p(nonscaling delay) = 30.0%
# Year: 2089 - p(nonscaling delay) = 30.0%
# Year: 2090 - p(nonscaling delay) = 30.0%
# Year: 2091 - p(nonscaling delay) = 30.0%
# Year: 2092 - p(nonscaling delay) = 30.0%
# Year: 2093 - p(nonscaling delay) = 30.0%
# Year: 2094 - p(nonscaling delay) = 30.0%
# Year: 2095 - p(nonscaling delay) = 30.0%
# Year: 2096 - p(nonscaling delay) = 30.0%
# Year: 2097 - p(nonscaling delay) = 30.0%
# Year: 2098 - p(nonscaling delay) = 30.0%
# Year: 2099 - p(nonscaling delay) = 30.0%
# Year: 2100 - p(nonscaling delay) = 30.0%
# Year: 2101 - p(nonscaling delay) = 30.0%
# Year: 2102 - p(nonscaling delay) = 30.0%
# Year: 2103 - p(nonscaling delay) = 30.0%
# Year: 2104 - p(nonscaling delay) = 30.0%
# Year: 2105 - p(nonscaling delay) = 30.0%
# Year: 2106 - p(nonscaling delay) = 30.0%
# Year: 2107 - p(nonscaling delay) = 30.0%
# Year: 2108 - p(nonscaling delay) = 30.0%
# Year: 2109 - p(nonscaling delay) = 30.0%
# Year: 2110 - p(nonscaling delay) = 30.0%
# Year: 2111 - p(nonscaling delay) = 30.0%
# Year: 2112 - p(nonscaling delay) = 30.0%
# Year: 2113 - p(nonscaling delay) = 30.0%
# Year: 2114 - p(nonscaling delay) = 30.0%
# Year: 2115 - p(nonscaling delay) = 30.0%
# Year: 2116 - p(nonscaling delay) = 30.0%
# Year: 2117 - p(nonscaling delay) = 30.0%
# Year: 2118 - p(nonscaling delay) = 30.0%
# Year: 2119 - p(nonscaling delay) = 30.0%
# Year: 2120 - p(nonscaling delay) = 30.0%
# Year: 2121 - p(nonscaling delay) = 30.0%
# Year: 2122 - p(nonscaling delay) = 30.0%
# Year: 2123 - p(nonscaling delay) = 30.0%
# Year: 2124 - p(nonscaling delay) = 30.0%
# Year: 2125 - p(nonscaling delay) = 30.0%
# Year: 2126 - p(nonscaling delay) = 30.0%
# Year: 2127 - p(nonscaling delay) = 30.0%
# Year: 2128 - p(nonscaling delay) = 30.0%
# Year: 2129 - p(nonscaling delay) = 30.0%
# Year: 2130 - p(nonscaling delay) = 30.0%
# Year: 2131 - p(nonscaling delay) = 30.0%
# Year: 2132 - p(nonscaling delay) = 30.0%
# Year: 2133 - p(nonscaling delay) = 30.0%
# Year: 2134 - p(nonscaling delay) = 30.0%
# Year: 2135 - p(nonscaling delay) = 30.0%
# Year: 2136 - p(nonscaling delay) = 30.0%
# Year: 2137 - p(nonscaling delay) = 30.0%
# Year: 2138 - p(nonscaling delay) = 30.0%
# Year: 2139 - p(nonscaling delay) = 30.0%
# Year: 2140 - p(nonscaling delay) = 30.0%
# Year: 2141 - p(nonscaling delay) = 30.0%
# Year: 2142 - p(nonscaling delay) = 30.0%
# Year: 2143 - p(nonscaling delay) = 30.0%
# Year: 2144 - p(nonscaling delay) = 30.0%
# Year: 2145 - p(nonscaling delay) = 30.0%
# Year: 2146 - p(nonscaling delay) = 30.0%
# Year: 2147 - p(nonscaling delay) = 30.0%
# Year: 2148 - p(nonscaling delay) = 30.0%
# Year: 2149 - p(nonscaling delay) = 30.0%
# Year: 2150 - p(nonscaling delay) = 30.0%
# Year: 2151 - p(nonscaling delay) = 30.0%
# Year: 2152 - p(nonscaling delay) = 30.0%
# Year: 2153 - p(nonscaling delay) = 30.0%
# Year: 2154 - p(nonscaling delay) = 30.0%
# Year: 2155 - p(nonscaling delay) = 30.0%
# Year: 2156 - p(nonscaling delay) = 30.0%
# Year: 2157 - p(nonscaling delay) = 30.0%
# Year: 2158 - p(nonscaling delay) = 30.0%
# Year: 2159 - p(nonscaling delay) = 30.0%
# Year: 2160 - p(nonscaling delay) = 30.0%
# Year: 2161 - p(nonscaling delay) = 30.0%
# Year: 2162 - p(nonscaling delay) = 30.0%
# Year: 2163 - p(nonscaling delay) = 30.0%
# Year: 2164 - p(nonscaling delay) = 30.0%
# Year: 2165 - p(nonscaling delay) = 30.0%
# Year: 2166 - p(nonscaling delay) = 30.0%
# Year: 2167 - p(nonscaling delay) = 30.0%
# Year: 2168 - p(nonscaling delay) = 30.0%
# Year: 2169 - p(nonscaling delay) = 30.0%
# Year: 2170 - p(nonscaling delay) = 30.0%
# Year: 2171 - p(nonscaling delay) = 30.0%
# Year: 2172 - p(nonscaling delay) = 30.0%
# Year: 2173 - p(nonscaling delay) = 30.0%
# Year: 2174 - p(nonscaling delay) = 30.0%
# Year: 2175 - p(nonscaling delay) = 30.0%
# Year: 2176 - p(nonscaling delay) = 30.0%
# Year: 2177 - p(nonscaling delay) = 30.0%
# Year: 2178 - p(nonscaling delay) = 30.0%
# Year: 2179 - p(nonscaling delay) = 30.0%
# Year: 2180 - p(nonscaling delay) = 30.0%
# Year: 2181 - p(nonscaling delay) = 30.0%
# Year: 2182 - p(nonscaling delay) = 30.0%
# Year: 2183 - p(nonscaling delay) = 30.0%
# Year: 2184 - p(nonscaling delay) = 30.0%
# Year: 2185 - p(nonscaling delay) = 30.0%
# Year: 2186 - p(nonscaling delay) = 30.0%
# Year: 2187 - p(nonscaling delay) = 30.0%
# Year: 2188 - p(nonscaling delay) = 30.0%
# Year: 2189 - p(nonscaling delay) = 30.0%
# Year: 2190 - p(nonscaling delay) = 30.0%
# Year: 2191 - p(nonscaling delay) = 30.0%
# Year: 2192 - p(nonscaling delay) = 30.0%
# Year: 2193 - p(nonscaling delay) = 30.0%
# Year: 2194 - p(nonscaling delay) = 30.0%
# Year: 2195 - p(nonscaling delay) = 30.0%
# Year: 2196 - p(nonscaling delay) = 30.0%
# Year: 2197 - p(nonscaling delay) = 30.0%
# Year: 2198 - p(nonscaling delay) = 30.0%
# Year: 2199 - p(nonscaling delay) = 30.0%
# Year: 2200 - p(nonscaling delay) = 30.0%
# Year: 2201 - p(nonscaling delay) = 30.0%
# Year: 2202 - p(nonscaling delay) = 30.0%
# Year: 2203 - p(nonscaling delay) = 30.0%
# Year: 2204 - p(nonscaling delay) = 30.0%
# Year: 2205 - p(nonscaling delay) = 30.0%
# Year: 2206 - p(nonscaling delay) = 30.0%
# Year: 2207 - p(nonscaling delay) = 30.0%
# Year: 2208 - p(nonscaling delay) = 30.0%
# Year: 2209 - p(nonscaling delay) = 30.0%
# Year: 2210 - p(nonscaling delay) = 30.0%
# Year: 2211 - p(nonscaling delay) = 30.0%
# Year: 2212 - p(nonscaling delay) = 30.0%
# Year: 2213 - p(nonscaling delay) = 30.0%
# Year: 2214 - p(nonscaling delay) = 30.0%
# Year: 2215 - p(nonscaling delay) = 30.0%
# Year: 2216 - p(nonscaling delay) = 30.0%
# Year: 2217 - p(nonscaling delay) = 30.0%
# Year: 2218 - p(nonscaling delay) = 30.0%
# Year: 2219 - p(nonscaling delay) = 30.0%
# Year: 2220 - p(nonscaling delay) = 30.0%
# Year: 2221 - p(nonscaling delay) = 30.0%

# %% [markdown]
# ## Run Model

# %%
def run_model(initial_gdp_, tai_flop_size_, nonscaling_delay_, algo_doubling_rate_,
              possible_algo_reduction_, initial_flops_per_dollar_, flops_halving_rate_,
              max_flops_per_dollar_, initial_pay_, gdp_growth_, max_gdp_frac_,
              willingness_ramp_, spend_doubling_time_, initial_chance_of_nonscaling_issue_,
              final_chance_of_nonscaling_issue_, nonscaling_issue_bottom_year_,
              willingness_spend_horizon_, print_diagnostic):
    queue_tai_year = 99999
    plt.ioff()
    if print_diagnostic:
        cost_of_tai_collector = []
        willingness_collector = []
    
    if print_diagnostic:
        print('It takes {} log FLOPs (~{}) for transformative capabilities.'.format(np.round(tai_flop_size_, 1),
                                                                                    numerize(10 ** tai_flop_size_)))
        print('Every {} years algorithms get 2x better, with {} log reductions possible.'.format(np.round(algo_doubling_rate_, 1),
                                                                                                 np.round(possible_algo_reduction_, 1)))
        print(('FLOPs start at a cost of {} log FLOPs (~{}) per 2022$USD. Every {} years they get ' +
               '2x cheaper, to a maximum of {} log FLOPs (~{}) per 2022$USD.').format(np.round(math.log10(initial_flops_per_dollar_), 1),
                                                                               numerize(initial_flops_per_dollar_),
                                                                               np.round(flops_halving_rate_, 1),
                                                                               np.round(math.log10(max_flops_per_dollar_), 1),
                                                                               numerize(max_flops_per_dollar_)))
        print(('We are willing to pay {} log 2022$USD (~{}) and this increases by {}x per year to a max of {}% of GDP. ' +
               'GDP grows at a rate of {}x per year.').format(np.round(math.log10(initial_pay_), 1),
                                                              numerize(initial_pay_),
                                                              np.round(spend_doubling_time_, 1),
                                                              np.round(max_gdp_frac_, 4),
                                                              np.round(gdp_growth_, 3)))
        if willingness_ramp_ < 1:
            print('In this simulation, if we are {}% of the way to paying for TAI, we will ramp to paying for TAI.'.format(np.round(willingness_ramp_ * 100)))

        if willingness_spend_horizon_ > 1:
            print('We are willing to spend over {} years to make TAI'.format(willingness_spend_horizon_))
            
        print(('If a non-scaling delay happens, it will take an additional {} years to produce TAI due' +
               ' to issues unrelated to scaling FLOP').format(np.round(nonscaling_delay_, 1)))
        print('---')
    
    tai_created = False
    is_nonscaling_issue = None
    for y in years:
        if not tai_created:
            flops_needed_ = flops_needed(initial_flops=10 ** tai_flop_size_,
                                         doubling_rate=algo_doubling_rate_,
                                         possible_reduction=10 ** possible_algo_reduction_,
                                         year=(y - CURRENT_YEAR))
            
            flops_per_dollar_ = flops_per_dollar(initial_flops_per_dollar=initial_flops_per_dollar_,
                                                 max_flops_per_dollar=max_flops_per_dollar_,
                                                 halving_rate=flops_halving_rate_,
                                                 year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200 or flops_needed_ > 10 ** 200:
                flops_needed_ = int(flops_needed_)
                flops_per_dollar_ = int(flops_per_dollar_)
                cost_of_tai_ = flops_needed_ // flops_per_dollar_
            else:
                cost_of_tai_ = flops_needed_ / flops_per_dollar_
            
            willingness_ = willingness_to_pay(initial_gdp=initial_gdp_,
                                              gdp_growth=gdp_growth_,
                                              initial_pay=initial_pay_,
                                              spend_doubling_time=spend_doubling_time_,
                                              max_gdp_frac=max_gdp_frac_,
                                              year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200:
                willingness_ = int(willingness_)
            if willingness_ > 10 ** 200:
                flops_per_dollar_ = int(flops_per_dollar_)
            
            if print_diagnostic:
                cost_of_tai_collector.append(cost_of_tai_)
                willingness_collector.append(willingness_)
            
            total_compute_ = willingness_ * flops_per_dollar_
            
            if print_diagnostic:
                out_str = ('Year: {} - {} max log FLOP ({}) available - TAI takes {} log FLOP ({}) - ' +
                           'log $ {} to buy TAI ({}) vs. willingness to pay log $ {} ({}) - {} log FLOPS per $ ({})')
                print(out_str.format(y,
                                     np.round(math.log10(total_compute_), 1),
                                     numerize(total_compute_),
                                     np.round(math.log10(flops_needed_), 1),
                                     numerize(flops_needed_),
                                     np.round(math.log10(cost_of_tai_), 1),
                                     numerize(cost_of_tai_),
                                     np.round(math.log10(willingness_), 1),
                                     numerize(willingness_),
                                     np.round(math.log10(flops_per_dollar_), 1),
                                     numerize(flops_per_dollar_)))
            
            if cost_of_tai_ > 10 ** 200:
                spend_tai_years = int(cost_of_tai_) // int(willingness_)
            else:
                spend_tai_years = cost_of_tai_ / willingness_
                
            if not is_nonscaling_issue and queue_tai_year < 99999 and print_diagnostic:
                print('-$- {}/{}'.format(y, queue_tai_year))
            if (cost_of_tai_ * willingness_ramp_) <= willingness_ or y >= queue_tai_year:
                if is_nonscaling_issue is None:
                    p_nonscaling_delay_ = p_nonscaling_delay(initial_chance_of_nonscaling_issue_,
                                                             final_chance_of_nonscaling_issue_,
                                                             year=y,
                                                             max_year=nonscaling_issue_bottom_year_)
                    is_nonscaling_issue = sq.event(p_nonscaling_delay_)
                    nonscaling_countdown = nonscaling_delay_
                    if print_diagnostic:
                        print('-- {} p_nonscaling_issue={}'.format('Nonscaling delay occured' if is_nonscaling_issue else 'Nonscaling issue did not occur',
                                                                   np.round(p_nonscaling_delay_, 4)))
                
                if not is_nonscaling_issue or nonscaling_countdown <= 0.1:
                    if print_diagnostic:
                        print('--- /!\ TAI CREATED in {}'.format(y))
                        plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
                    return y
                else:
                    if print_diagnostic:
                        print('/!\ FLOPs for TAI sufficient but needs {} more years to solve non-scaling issues'.format(np.round(nonscaling_countdown, 1)))
                    nonscaling_countdown -= 1
            elif (not is_nonscaling_issue and willingness_spend_horizon_ > 1 and
                  spend_tai_years <= willingness_spend_horizon_ and y + math.ceil(spend_tai_years) < queue_tai_year):
                queue_tai_year = y + math.ceil(spend_tai_years)
                if print_diagnostic:
                    print('-$- We have enough spend to make TAI in {} years (in {}) if sustained.'.format(math.ceil(spend_tai_years),
                                                                                                          queue_tai_year))
                
    if not tai_created:
        if print_diagnostic:
            print('--- :/ TAI NOT CREATED BEFORE {}'.format(MAX_YEAR + 1))
            plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
        return MAX_YEAR + 1
    
    
def define_event(verbose=False):
    tai_flop_size_ = sq.sample(sq.discrete(variables['tai_flop_size']))

    if tai_flop_size_ > 300:
        tai_flop_size_ = int(tai_flop_size_) # Handle overflow errors
    
    algo_doubling_rate_ = algo_halving_fn(sq.sample(variables['algo_doubling_rate_min']),
                                          sq.sample(variables['algo_doubling_rate_max']),
                                          tai_flop_size_)
    
    possible_algo_reduction_ = possible_algo_reduction_fn(sq.sample(variables['min_reduction']),
                                                          sq.sample(variables['max_reduction']),
                                                          tai_flop_size_)
    
    initial_flops_per_dollar_ = 10 ** sq.sample(variables['initial_flops_per_dollar'])
    flops_halving_rate_ = sq.sample(variables['flops_halving_rate'])
    max_flops_per_dollar_ = 10 ** sq.sample(variables['max_flops_per_dollar'])
    initial_pay_ = 10 ** sq.sample(variables['initial_pay'])
    gdp_growth_ = sq.sample(variables['gdp_growth'])
    max_gdp_frac_ = sq.sample(variables['max_gdp_frac'])
    
    willingness_ramp_happens = sq.event_occurs(variables.get('p_willingness_ramp', 0))
    if willingness_ramp_happens:
        willingness_ramp_ = sq.sample(variables.get('willingness_ramp', 1))
    else:
        willingness_ramp_ = 1
    
    initial_gdp_ = variables['initial_gdp']
    spend_doubling_time_ = sq.sample(variables['spend_doubling_time'])
    nonscaling_delay_ = sq.sample(variables.get('nonscaling_delay', sq.const(0)))
    initial_chance_of_nonscaling_issue_ = variables.get('initial_chance_of_nonscaling_issue', 0)
    final_chance_of_nonscaling_issue_ = variables.get('final_chance_of_nonscaling_issue', 0)
    nonscaling_issue_bottom_year_ = variables.get('nonscaling_issue_bottom_year', 0)
    willingness_spend_horizon_ = int(sq.sample(variables.get('willingness_spend_horizon', sq.const(1))))
    
    tai_year = run_model(initial_gdp_=initial_gdp_,
                         tai_flop_size_=tai_flop_size_,
                         nonscaling_delay_=nonscaling_delay_,
                         algo_doubling_rate_=algo_doubling_rate_,
                         possible_algo_reduction_=possible_algo_reduction_,
                         initial_flops_per_dollar_=initial_flops_per_dollar_,
                         flops_halving_rate_=flops_halving_rate_,
                         max_flops_per_dollar_=max_flops_per_dollar_,
                         initial_pay_=initial_pay_,
                         gdp_growth_=gdp_growth_,
                         max_gdp_frac_=max_gdp_frac_,
                         willingness_ramp_=willingness_ramp_,
                         spend_doubling_time_=spend_doubling_time_,
                         initial_chance_of_nonscaling_issue_=initial_chance_of_nonscaling_issue_,
                         final_chance_of_nonscaling_issue_=final_chance_of_nonscaling_issue_,
                         nonscaling_issue_bottom_year_=nonscaling_issue_bottom_year_,
                         willingness_spend_horizon_=willingness_spend_horizon_,
                         print_diagnostic=verbose)
    
    return {'tai_year': tai_year,
            'initial_gdp': initial_gdp_,
            'tai_flop_size': tai_flop_size_,
            'nonscaling_delay': nonscaling_delay_,
            'algo_doubling_rte': algo_doubling_rate_,
            'possible_algo_reduction': possible_algo_reduction_,
            'initial_flops_per_dollar': initial_flops_per_dollar_,
            'flops_halving_rate': flops_halving_rate_,
            'max_flops_per_dollar': max_flops_per_dollar_,
            'initial_pay': initial_pay_,
            'gdp_growth': gdp_growth_,
            'max_gdp_frac': max_gdp_frac_,
            'willingness_ramp_': willingness_ramp_,
            'spend_doubling_time_': spend_doubling_time_,
            'initial_chance_of_nonscaling_issue': initial_chance_of_nonscaling_issue_,
            'final_chance_of_nonscaling_issue': final_chance_of_nonscaling_issue_,
            'nonscaling_issue_bottom_year': nonscaling_issue_bottom_year_,
            'willingness_spend_horizon_': willingness_spend_horizon_}

print('Loaded')
# Out:
# Loaded

# %%
define_event(verbose=True)
# Out:
# It takes 42.8 log FLOPs (~7 billion decillion) for transformative capabilities.
# Every 1.7 years algorithms get 2x better, with 5 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 3.8 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 4.9x per year to a max of 0.0007% of GDP. GDP grows at a rate of 1.019x per year.
# If a non-scaling delay happens, it will take an additional 10.4 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (13 septillion) available - TAI takes 42.8 log FLOP (7 billion decillion) - log $ 24.8 to buy TAI (7 septillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.2 max log FLOP (17 septillion) available - TAI takes 42.7 log FLOP (5 billion decillion) - log $ 24.6 to buy TAI (4 septillion) vs. willingness to pay log $ 7.2 (14 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.4 max log FLOP (24 septillion) available - TAI takes 42.5 log FLOP (3 billion decillion) - log $ 24.3 to buy TAI (2 septillion) vs. willingness to pay log $ 7.2 (17 million) - 18.2 log FLOPS per $ (1 quintillion)
# Year: 2025 - 25.5 max log FLOP (33 septillion) available - TAI takes 42.3 log FLOP (2 billion decillion) - log $ 24.1 to buy TAI (1 septillion) vs. willingness to pay log $ 7.3 (19 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 25.7 max log FLOP (46 septillion) available - TAI takes 42.1 log FLOP (1 billion decillion) - log $ 23.8 to buy TAI (660 sextillion) vs. willingness to pay log $ 7.3 (22 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2027 - 25.8 max log FLOP (64 septillion) available - TAI takes 42.0 log FLOP (923 million decillion) - log $ 23.6 to buy TAI (368 sextillion) vs. willingness to pay log $ 7.4 (26 million) - 18.4 log FLOPS per $ (3 quintillion)
# Year: 2028 - 25.9 max log FLOP (89 septillion) available - TAI takes 41.8 log FLOP (619 million decillion) - log $ 23.3 to buy TAI (205 sextillion) vs. willingness to pay log $ 7.5 (29 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2029 - 26.1 max log FLOP (123 septillion) available - TAI takes 41.6 log FLOP (414 million decillion) - log $ 23.1 to buy TAI (114 sextillion) vs. willingness to pay log $ 7.5 (34 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2030 - 26.2 max log FLOP (170 septillion) available - TAI takes 41.4 log FLOP (278 million decillion) - log $ 22.8 to buy TAI (64 sextillion) vs. willingness to pay log $ 7.6 (39 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2031 - 26.4 max log FLOP (236 septillion) available - TAI takes 41.3 log FLOP (186 million decillion) - log $ 22.5 to buy TAI (35 sextillion) vs. willingness to pay log $ 7.7 (45 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2032 - 26.5 max log FLOP (327 septillion) available - TAI takes 41.1 log FLOP (125 million decillion) - log $ 22.3 to buy TAI (20 sextillion) vs. willingness to pay log $ 7.7 (52 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2033 - 26.7 max log FLOP (452 septillion) available - TAI takes 40.9 log FLOP (84 million decillion) - log $ 22.0 to buy TAI (11 sextillion) vs. willingness to pay log $ 7.8 (60 million) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2034 - 26.8 max log FLOP (626 septillion) available - TAI takes 40.7 log FLOP (56 million decillion) - log $ 21.8 to buy TAI (6 sextillion) vs. willingness to pay log $ 7.8 (69 million) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2035 - 26.9 max log FLOP (867 septillion) available - TAI takes 40.6 log FLOP (38 million decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 7.9 (79 million) - 19.0 log FLOPS per $ (11 quintillion)
# Year: 2036 - 27.1 max log FLOP (1 octillion) available - TAI takes 40.4 log FLOP (25 million decillion) - log $ 21.3 to buy TAI (2 sextillion) vs. willingness to pay log $ 8.0 (91 million) - 19.1 log FLOPS per $ (13 quintillion)
# Year: 2037 - 27.2 max log FLOP (2 octillion) available - TAI takes 40.2 log FLOP (17 million decillion) - log $ 21.0 to buy TAI (1 sextillion) vs. willingness to pay log $ 8.0 (105 million) - 19.2 log FLOPS per $ (16 quintillion)
# Year: 2038 - 27.4 max log FLOP (2 octillion) available - TAI takes 40.1 log FLOP (11 million decillion) - log $ 20.8 to buy TAI (595 quintillion) vs. willingness to pay log $ 8.1 (121 million) - 19.3 log FLOPS per $ (19 quintillion)
# Year: 2039 - 27.5 max log FLOP (3 octillion) available - TAI takes 39.9 log FLOP (8 million decillion) - log $ 20.5 to buy TAI (333 quintillion) vs. willingness to pay log $ 8.1 (139 million) - 19.4 log FLOPS per $ (23 quintillion)
# Year: 2040 - 27.6 max log FLOP (4 octillion) available - TAI takes 39.7 log FLOP (5 million decillion) - log $ 20.3 to buy TAI (186 quintillion) vs. willingness to pay log $ 8.2 (160 million) - 19.4 log FLOPS per $ (28 quintillion)
# Year: 2041 - 27.8 max log FLOP (6 octillion) available - TAI takes 39.5 log FLOP (3 million decillion) - log $ 20.0 to buy TAI (104 quintillion) vs. willingness to pay log $ 8.3 (184 million) - 19.5 log FLOPS per $ (33 quintillion)
# Year: 2042 - 27.9 max log FLOP (8 octillion) available - TAI takes 39.4 log FLOP (2 million decillion) - log $ 19.8 to buy TAI (59 quintillion) vs. willingness to pay log $ 8.3 (212 million) - 19.6 log FLOPS per $ (40 quintillion)
# Year: 2043 - 28.1 max log FLOP (12 octillion) available - TAI takes 39.2 log FLOP (2 million decillion) - log $ 19.5 to buy TAI (33 quintillion) vs. willingness to pay log $ 8.4 (244 million) - 19.7 log FLOPS per $ (48 quintillion)
# Year: 2044 - 28.2 max log FLOP (16 octillion) available - TAI takes 39.0 log FLOP (1 million decillion) - log $ 19.3 to buy TAI (19 quintillion) vs. willingness to pay log $ 8.4 (281 million) - 19.8 log FLOPS per $ (57 quintillion)
# Year: 2045 - 28.3 max log FLOP (22 octillion) available - TAI takes 38.9 log FLOP (751 thousand decillion) - log $ 19.0 to buy TAI (11 quintillion) vs. willingness to pay log $ 8.5 (323 million) - 19.8 log FLOPS per $ (69 quintillion)
# Year: 2046 - 28.5 max log FLOP (31 octillion) available - TAI takes 38.7 log FLOP (525 thousand decillion) - log $ 18.8 to buy TAI (6 quintillion) vs. willingness to pay log $ 8.6 (372 million) - 19.9 log FLOPS per $ (83 quintillion)
# Year: 2047 - 28.6 max log FLOP (43 octillion) available - TAI takes 38.6 log FLOP (375 thousand decillion) - log $ 18.6 to buy TAI (4 quintillion) vs. willingness to pay log $ 8.6 (427 million) - 20.0 log FLOPS per $ (100 quintillion)
# Year: 2048 - 28.8 max log FLOP (59 octillion) available - TAI takes 38.4 log FLOP (274 thousand decillion) - log $ 18.4 to buy TAI (2 quintillion) vs. willingness to pay log $ 8.7 (491 million) - 20.1 log FLOPS per $ (120 quintillion)
# Year: 2049 - 28.9 max log FLOP (81 octillion) available - TAI takes 38.3 log FLOP (206 thousand decillion) - log $ 18.2 to buy TAI (1 quintillion) vs. willingness to pay log $ 8.8 (564 million) - 20.2 log FLOPS per $ (144 quintillion)
# Year: 2050 - 29.1 max log FLOP (112 octillion) available - TAI takes 38.2 log FLOP (160 thousand decillion) - log $ 18.0 to buy TAI (925 quadrillion) vs. willingness to pay log $ 8.8 (648 million) - 20.2 log FLOPS per $ (173 quintillion)
# Year: 2051 - 29.2 max log FLOP (155 octillion) available - TAI takes 38.1 log FLOP (130 thousand decillion) - log $ 17.8 to buy TAI (624 quadrillion) vs. willingness to pay log $ 8.9 (744 million) - 20.3 log FLOPS per $ (209 quintillion)
# Year: 2052 - 29.3 max log FLOP (214 octillion) available - TAI takes 38.0 log FLOP (110 thousand decillion) - log $ 17.6 to buy TAI (438 quadrillion) vs. willingness to pay log $ 8.9 (854 million) - 20.4 log FLOPS per $ (251 quintillion)
# Year: 2053 - 29.5 max log FLOP (295 octillion) available - TAI takes 38.0 log FLOP (96 thousand decillion) - log $ 17.5 to buy TAI (319 quadrillion) vs. willingness to pay log $ 9.0 (980 million) - 20.5 log FLOPS per $ (301 quintillion)
# Year: 2054 - 29.6 max log FLOP (407 octillion) available - TAI takes 37.9 log FLOP (87 thousand decillion) - log $ 17.4 to buy TAI (240 quadrillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.6 log FLOPS per $ (362 quintillion)
# Year: 2055 - 29.7 max log FLOP (561 octillion) available - TAI takes 37.9 log FLOP (81 thousand decillion) - log $ 17.3 to buy TAI (186 quadrillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.6 log FLOPS per $ (436 quintillion)
# Year: 2056 - 29.9 max log FLOP (772 octillion) available - TAI takes 37.9 log FLOP (77 thousand decillion) - log $ 17.2 to buy TAI (147 quadrillion) vs. willingness to pay log $ 9.2 (1 billion) - 20.7 log FLOPS per $ (524 quintillion)
# Year: 2057 - 30.0 max log FLOP (1 nonillion) available - TAI takes 37.9 log FLOP (74 thousand decillion) - log $ 17.1 to buy TAI (118 quadrillion) vs. willingness to pay log $ 9.2 (2 billion) - 20.8 log FLOPS per $ (629 quintillion)
# Year: 2058 - 30.2 max log FLOP (1 nonillion) available - TAI takes 37.9 log FLOP (72 thousand decillion) - log $ 17.0 to buy TAI (95 quadrillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.9 log FLOPS per $ (757 quintillion)
# Year: 2059 - 30.3 max log FLOP (2 nonillion) available - TAI takes 37.9 log FLOP (71 thousand decillion) - log $ 16.9 to buy TAI (78 quadrillion) vs. willingness to pay log $ 9.3 (2 billion) - 21.0 log FLOPS per $ (909 quintillion)
# Year: 2060 - 30.4 max log FLOP (3 nonillion) available - TAI takes 37.8 log FLOP (70 thousand decillion) - log $ 16.8 to buy TAI (64 quadrillion) vs. willingness to pay log $ 9.4 (3 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2061 - 30.6 max log FLOP (4 nonillion) available - TAI takes 37.8 log FLOP (70 thousand decillion) - log $ 16.7 to buy TAI (53 quadrillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2062 - 30.7 max log FLOP (5 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.6 to buy TAI (44 quadrillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2063 - 30.8 max log FLOP (7 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.6 to buy TAI (36 quadrillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2064 - 31.0 max log FLOP (10 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.5 to buy TAI (30 quadrillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.4 log FLOPS per $ (2 sextillion)
# Year: 2065 - 31.1 max log FLOP (13 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.4 to buy TAI (25 quadrillion) vs. willingness to pay log $ 9.7 (5 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2066 - 31.2 max log FLOP (18 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.3 to buy TAI (21 quadrillion) vs. willingness to pay log $ 9.7 (5 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2067 - 31.4 max log FLOP (24 nonillion) available - TAI takes 37.8 log FLOP (69 thousand decillion) - log $ 16.2 to buy TAI (17 quadrillion) vs. willingness to pay log $ 9.8 (6 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2068 - 31.5 max log FLOP (32 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 16.2 to buy TAI (14 quadrillion) vs. willingness to pay log $ 9.8 (7 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2069 - 31.6 max log FLOP (44 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 16.1 to buy TAI (12 quadrillion) vs. willingness to pay log $ 9.9 (8 billion) - 21.8 log FLOPS per $ (6 sextillion)
# Year: 2070 - 31.8 max log FLOP (59 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 16.0 to buy TAI (10 quadrillion) vs. willingness to pay log $ 9.9 (9 billion) - 21.8 log FLOPS per $ (7 sextillion)
# Year: 2071 - 31.9 max log FLOP (79 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.9 to buy TAI (8 quadrillion) vs. willingness to pay log $ 10.0 (10 billion) - 21.9 log FLOPS per $ (8 sextillion)
# Year: 2072 - 32.0 max log FLOP (106 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.8 to buy TAI (7 quadrillion) vs. willingness to pay log $ 10.0 (11 billion) - 22.0 log FLOPS per $ (10 sextillion)
# Year: 2073 - 32.1 max log FLOP (141 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.8 to buy TAI (6 quadrillion) vs. willingness to pay log $ 10.1 (12 billion) - 22.1 log FLOPS per $ (12 sextillion)
# Year: 2074 - 32.3 max log FLOP (187 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.7 to buy TAI (5 quadrillion) vs. willingness to pay log $ 10.1 (13 billion) - 22.2 log FLOPS per $ (14 sextillion)
# Year: 2075 - 32.4 max log FLOP (247 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 10.2 (15 billion) - 22.2 log FLOPS per $ (17 sextillion)
# Year: 2076 - 32.5 max log FLOP (325 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 10.2 (16 billion) - 22.3 log FLOPS per $ (20 sextillion)
# Year: 2077 - 32.6 max log FLOP (427 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.4 to buy TAI (3 quadrillion) vs. willingness to pay log $ 10.2 (17 billion) - 22.4 log FLOPS per $ (24 sextillion)
# Year: 2078 - 32.7 max log FLOP (557 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.4 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.3 (19 billion) - 22.5 log FLOPS per $ (29 sextillion)
# Year: 2079 - 32.9 max log FLOP (723 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.3 (21 billion) - 22.5 log FLOPS per $ (35 sextillion)
# Year: 2080 - 33.0 max log FLOP (935 nonillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.2 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.4 (22 billion) - 22.6 log FLOPS per $ (42 sextillion)
# Year: 2081 - 33.1 max log FLOP (1 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 10.4 (24 billion) - 22.7 log FLOPS per $ (50 sextillion)
# Year: 2082 - 33.2 max log FLOP (2 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 10.4 (26 billion) - 22.8 log FLOPS per $ (59 sextillion)
# Year: 2083 - 33.3 max log FLOP (2 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 15.0 to buy TAI (973 trillion) vs. willingness to pay log $ 10.4 (28 billion) - 22.8 log FLOPS per $ (70 sextillion)
# Year: 2084 - 33.4 max log FLOP (2 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.9 to buy TAI (821 trillion) vs. willingness to pay log $ 10.5 (30 billion) - 22.9 log FLOPS per $ (83 sextillion)
# Year: 2085 - 33.5 max log FLOP (3 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.8 to buy TAI (694 trillion) vs. willingness to pay log $ 10.5 (32 billion) - 23.0 log FLOPS per $ (99 sextillion)
# Year: 2086 - 33.6 max log FLOP (4 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.8 to buy TAI (589 trillion) vs. willingness to pay log $ 10.5 (33 billion) - 23.1 log FLOPS per $ (116 sextillion)
# Year: 2087 - 33.7 max log FLOP (5 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.7 to buy TAI (501 trillion) vs. willingness to pay log $ 10.5 (35 billion) - 23.1 log FLOPS per $ (136 sextillion)
# Year: 2088 - 33.8 max log FLOP (6 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.6 to buy TAI (429 trillion) vs. willingness to pay log $ 10.6 (37 billion) - 23.2 log FLOPS per $ (160 sextillion)
# Year: 2089 - 33.9 max log FLOP (7 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.6 to buy TAI (368 trillion) vs. willingness to pay log $ 10.6 (39 billion) - 23.3 log FLOPS per $ (186 sextillion)
# Year: 2090 - 33.9 max log FLOP (9 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.5 to buy TAI (318 trillion) vs. willingness to pay log $ 10.6 (41 billion) - 23.3 log FLOPS per $ (215 sextillion)
# Year: 2091 - 34.0 max log FLOP (11 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.4 to buy TAI (276 trillion) vs. willingness to pay log $ 10.6 (43 billion) - 23.4 log FLOPS per $ (248 sextillion)
# Year: 2092 - 34.1 max log FLOP (13 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.4 to buy TAI (241 trillion) vs. willingness to pay log $ 10.6 (45 billion) - 23.5 log FLOPS per $ (284 sextillion)
# Year: 2093 - 34.2 max log FLOP (15 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.3 to buy TAI (212 trillion) vs. willingness to pay log $ 10.7 (46 billion) - 23.5 log FLOPS per $ (323 sextillion)
# Year: 2094 - 34.2 max log FLOP (18 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.3 to buy TAI (188 trillion) vs. willingness to pay log $ 10.7 (48 billion) - 23.6 log FLOPS per $ (364 sextillion)
# Year: 2095 - 34.3 max log FLOP (20 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.2 to buy TAI (168 trillion) vs. willingness to pay log $ 10.7 (50 billion) - 23.6 log FLOPS per $ (408 sextillion)
# Year: 2096 - 34.4 max log FLOP (23 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.2 to buy TAI (151 trillion) vs. willingness to pay log $ 10.7 (51 billion) - 23.7 log FLOPS per $ (453 sextillion)
# Year: 2097 - 34.4 max log FLOP (27 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.1 to buy TAI (137 trillion) vs. willingness to pay log $ 10.7 (53 billion) - 23.7 log FLOPS per $ (499 sextillion)
# Year: 2098 - 34.5 max log FLOP (30 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.1 to buy TAI (126 trillion) vs. willingness to pay log $ 10.7 (55 billion) - 23.7 log FLOPS per $ (545 sextillion)
# Year: 2099 - 34.5 max log FLOP (33 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.1 to buy TAI (116 trillion) vs. willingness to pay log $ 10.8 (56 billion) - 23.8 log FLOPS per $ (590 sextillion)
# Year: 2100 - 34.6 max log FLOP (37 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.0 to buy TAI (108 trillion) vs. willingness to pay log $ 10.8 (58 billion) - 23.8 log FLOPS per $ (634 sextillion)
# Year: 2101 - 34.6 max log FLOP (40 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.0 to buy TAI (101 trillion) vs. willingness to pay log $ 10.8 (60 billion) - 23.8 log FLOPS per $ (675 sextillion)
# Year: 2102 - 34.6 max log FLOP (44 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.0 to buy TAI (96 trillion) vs. willingness to pay log $ 10.8 (61 billion) - 23.9 log FLOPS per $ (714 sextillion)
# Year: 2103 - 34.7 max log FLOP (47 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 14.0 to buy TAI (91 trillion) vs. willingness to pay log $ 10.8 (63 billion) - 23.9 log FLOPS per $ (750 sextillion)
# Year: 2104 - 34.7 max log FLOP (50 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (87 trillion) vs. willingness to pay log $ 10.8 (64 billion) - 23.9 log FLOPS per $ (783 sextillion)
# Year: 2105 - 34.7 max log FLOP (54 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (84 trillion) vs. willingness to pay log $ 10.8 (66 billion) - 23.9 log FLOPS per $ (813 sextillion)
# Year: 2106 - 34.8 max log FLOP (57 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (81 trillion) vs. willingness to pay log $ 10.8 (67 billion) - 23.9 log FLOPS per $ (839 sextillion)
# Year: 2107 - 34.8 max log FLOP (60 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (79 trillion) vs. willingness to pay log $ 10.8 (69 billion) - 23.9 log FLOPS per $ (863 sextillion)
# Year: 2108 - 34.8 max log FLOP (62 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (77 trillion) vs. willingness to pay log $ 10.8 (71 billion) - 23.9 log FLOPS per $ (883 sextillion)
# Year: 2109 - 34.8 max log FLOP (65 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (76 trillion) vs. willingness to pay log $ 10.9 (72 billion) - 24.0 log FLOPS per $ (901 sextillion)
# Year: 2110 - 34.8 max log FLOP (68 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (75 trillion) vs. willingness to pay log $ 10.9 (74 billion) - 24.0 log FLOPS per $ (916 sextillion)
# Year: 2111 - 34.8 max log FLOP (70 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (74 trillion) vs. willingness to pay log $ 10.9 (75 billion) - 24.0 log FLOPS per $ (929 sextillion)
# Year: 2112 - 34.9 max log FLOP (72 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (73 trillion) vs. willingness to pay log $ 10.9 (77 billion) - 24.0 log FLOPS per $ (940 sextillion)
# Year: 2113 - 34.9 max log FLOP (75 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (72 trillion) vs. willingness to pay log $ 10.9 (79 billion) - 24.0 log FLOPS per $ (950 sextillion)
# Year: 2114 - 34.9 max log FLOP (77 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (71 trillion) vs. willingness to pay log $ 10.9 (80 billion) - 24.0 log FLOPS per $ (958 sextillion)
# Year: 2115 - 34.9 max log FLOP (79 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.9 to buy TAI (71 trillion) vs. willingness to pay log $ 10.9 (82 billion) - 24.0 log FLOPS per $ (965 sextillion)
# Year: 2116 - 34.9 max log FLOP (81 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 10.9 (83 billion) - 24.0 log FLOPS per $ (971 sextillion)
# Year: 2117 - 34.9 max log FLOP (83 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 10.9 (85 billion) - 24.0 log FLOPS per $ (975 sextillion)
# Year: 2118 - 34.9 max log FLOP (85 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 10.9 (87 billion) - 24.0 log FLOPS per $ (979 sextillion)
# Year: 2119 - 34.9 max log FLOP (87 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 10.9 (89 billion) - 24.0 log FLOPS per $ (983 sextillion)
# Year: 2120 - 34.9 max log FLOP (89 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (90 billion) - 24.0 log FLOPS per $ (986 sextillion)
# Year: 2121 - 35.0 max log FLOP (91 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (92 billion) - 24.0 log FLOPS per $ (988 sextillion)
# Year: 2122 - 35.0 max log FLOP (93 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (94 billion) - 24.0 log FLOPS per $ (990 sextillion)
# Year: 2123 - 35.0 max log FLOP (95 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (96 billion) - 24.0 log FLOPS per $ (992 sextillion)
# Year: 2124 - 35.0 max log FLOP (97 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (98 billion) - 24.0 log FLOPS per $ (993 sextillion)
# Year: 2125 - 35.0 max log FLOP (99 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (99 billion) - 24.0 log FLOPS per $ (994 sextillion)
# Year: 2126 - 35.0 max log FLOP (101 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (101 billion) - 24.0 log FLOPS per $ (995 sextillion)
# Year: 2127 - 35.0 max log FLOP (103 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (103 billion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2128 - 35.0 max log FLOP (105 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (105 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2129 - 35.0 max log FLOP (107 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (107 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2130 - 35.0 max log FLOP (109 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (109 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2131 - 35.0 max log FLOP (111 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.0 (111 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2132 - 35.1 max log FLOP (113 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (69 trillion) vs. willingness to pay log $ 11.1 (114 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2133 - 35.1 max log FLOP (116 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (116 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2134 - 35.1 max log FLOP (118 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (118 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2135 - 35.1 max log FLOP (120 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (120 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2136 - 35.1 max log FLOP (122 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (122 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2137 - 35.1 max log FLOP (125 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (125 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2138 - 35.1 max log FLOP (127 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (127 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2139 - 35.1 max log FLOP (130 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (130 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2140 - 35.1 max log FLOP (132 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (132 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2141 - 35.1 max log FLOP (134 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (135 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2142 - 35.1 max log FLOP (137 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (137 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2143 - 35.1 max log FLOP (140 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.1 (140 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2144 - 35.2 max log FLOP (142 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (142 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2145 - 35.2 max log FLOP (145 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (145 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2146 - 35.2 max log FLOP (148 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (148 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2147 - 35.2 max log FLOP (150 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (151 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2148 - 35.2 max log FLOP (153 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (153 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2149 - 35.2 max log FLOP (156 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (156 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2150 - 35.2 max log FLOP (159 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (159 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2151 - 35.2 max log FLOP (162 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (162 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2152 - 35.2 max log FLOP (165 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (165 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2153 - 35.2 max log FLOP (168 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (168 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2154 - 35.2 max log FLOP (172 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (172 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2155 - 35.2 max log FLOP (175 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.2 (175 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2156 - 35.3 max log FLOP (178 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (178 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2157 - 35.3 max log FLOP (181 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (181 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2158 - 35.3 max log FLOP (185 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (185 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2159 - 35.3 max log FLOP (188 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (188 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2160 - 35.3 max log FLOP (192 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (192 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2161 - 35.3 max log FLOP (196 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (196 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2162 - 35.3 max log FLOP (199 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (199 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2163 - 35.3 max log FLOP (203 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (203 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2164 - 35.3 max log FLOP (207 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (207 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2165 - 35.3 max log FLOP (211 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (211 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2166 - 35.3 max log FLOP (215 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (215 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2167 - 35.3 max log FLOP (219 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (219 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2168 - 35.3 max log FLOP (223 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.3 (223 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2169 - 35.4 max log FLOP (227 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (227 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2170 - 35.4 max log FLOP (231 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (231 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2171 - 35.4 max log FLOP (236 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (236 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2172 - 35.4 max log FLOP (240 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (240 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2173 - 35.4 max log FLOP (245 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (245 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2174 - 35.4 max log FLOP (249 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (249 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2175 - 35.4 max log FLOP (254 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (254 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2176 - 35.4 max log FLOP (259 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (259 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2177 - 35.4 max log FLOP (264 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (264 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2178 - 35.4 max log FLOP (269 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (269 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2179 - 35.4 max log FLOP (274 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (274 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2180 - 35.4 max log FLOP (279 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.4 (279 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2181 - 35.5 max log FLOP (284 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (284 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2182 - 35.5 max log FLOP (289 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (289 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2183 - 35.5 max log FLOP (295 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (295 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2184 - 35.5 max log FLOP (300 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (300 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2185 - 35.5 max log FLOP (306 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (306 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2186 - 35.5 max log FLOP (312 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (312 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2187 - 35.5 max log FLOP (318 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (318 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2188 - 35.5 max log FLOP (324 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (324 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2189 - 35.5 max log FLOP (330 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (330 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2190 - 35.5 max log FLOP (336 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (336 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2191 - 35.5 max log FLOP (342 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (342 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2192 - 35.5 max log FLOP (349 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.5 (349 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2193 - 35.6 max log FLOP (355 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (355 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2194 - 35.6 max log FLOP (362 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (362 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2195 - 35.6 max log FLOP (369 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (369 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2196 - 35.6 max log FLOP (376 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (376 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2197 - 35.6 max log FLOP (383 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (383 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2198 - 35.6 max log FLOP (390 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (390 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2199 - 35.6 max log FLOP (398 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (398 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2200 - 35.6 max log FLOP (405 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (405 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2201 - 35.6 max log FLOP (413 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (413 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2202 - 35.6 max log FLOP (421 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (421 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2203 - 35.6 max log FLOP (428 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (428 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2204 - 35.6 max log FLOP (437 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (437 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2205 - 35.6 max log FLOP (445 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.6 (445 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2206 - 35.7 max log FLOP (453 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (453 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2207 - 35.7 max log FLOP (462 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (462 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2208 - 35.7 max log FLOP (470 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (470 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2209 - 35.7 max log FLOP (479 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (479 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2210 - 35.7 max log FLOP (488 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (488 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2211 - 35.7 max log FLOP (498 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (498 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2212 - 35.7 max log FLOP (507 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (507 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2213 - 35.7 max log FLOP (516 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (516 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2214 - 35.7 max log FLOP (526 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (526 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2215 - 35.7 max log FLOP (536 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (536 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2216 - 35.7 max log FLOP (546 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (546 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2217 - 35.7 max log FLOP (557 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.7 (557 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2218 - 35.8 max log FLOP (567 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.8 (567 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2219 - 35.8 max log FLOP (578 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.8 (578 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2220 - 35.8 max log FLOP (589 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.8 (589 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2221 - 35.8 max log FLOP (600 decillion) available - TAI takes 37.8 log FLOP (68 thousand decillion) - log $ 13.8 to buy TAI (68 trillion) vs. willingness to pay log $ 11.8 (600 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# --- :/ TAI NOT CREATED BEFORE 2223
# {'tai_year': 2223,
#  'initial_gdp': 21300000000000.0,
#  'tai_flop_size': 42.83508341492279,
#  'nonscaling_delay': 10.39443690013324,
#  'algo_doubling_rte': 1.7304279531970073,
#  'possible_algo_reduction': 5,
#  'initial_flops_per_dollar': 1000000000000000000,
#  'flops_halving_rate': 3.763940556807063,
#  'max_flops_per_dollar': 1000000000000000000000000,
#  'initial_pay': 12589254.117941663,
#  'gdp_growth': 1.0188542443846964,
#  'max_gdp_frac': 0.0006843582489996313,
#  'willingness_ramp_': 1,
#  'spend_doubling_time_': 4.891008385045784,
#  'initial_chance_of_nonscaling_issue': 0.95,
#  'final_chance_of_nonscaling_issue': 0.3,
#  'nonscaling_issue_bottom_year': 2050,
#  'willingness_spend_horizon_': 1}

# %%
for i in range(5):
    print('## RUN {} ##'.format(i + 1))
    define_event(verbose=True)
# Out:
# ## RUN 1 ##
# It takes 38.2 log FLOPs (~146 thousand decillion) for transformative capabilities.
# Every 2.0 years algorithms get 2x better, with 4 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 3.6x per year to a max of 0.0005% of GDP. GDP grows at a rate of 1.038x per year.
# If a non-scaling delay happens, it will take an additional 3.2 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (13 septillion) available - TAI takes 38.2 log FLOP (146 thousand decillion) - log $ 20.2 to buy TAI (146 quintillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.3 max log FLOP (20 septillion) available - TAI takes 38.0 log FLOP (103 thousand decillion) - log $ 19.9 to buy TAI (78 quintillion) vs. willingness to pay log $ 7.2 (15 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.5 max log FLOP (32 septillion) available - TAI takes 37.9 log FLOP (73 thousand decillion) - log $ 19.6 to buy TAI (42 quintillion) vs. willingness to pay log $ 7.3 (18 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2025 - 25.7 max log FLOP (51 septillion) available - TAI takes 37.7 log FLOP (51 thousand decillion) - log $ 19.4 to buy TAI (23 quintillion) vs. willingness to pay log $ 7.3 (22 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2026 - 25.9 max log FLOP (81 septillion) available - TAI takes 37.6 log FLOP (36 thousand decillion) - log $ 19.1 to buy TAI (12 quintillion) vs. willingness to pay log $ 7.4 (27 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2027 - 26.1 max log FLOP (128 septillion) available - TAI takes 37.4 log FLOP (26 thousand decillion) - log $ 18.8 to buy TAI (7 quintillion) vs. willingness to pay log $ 7.5 (33 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2028 - 26.3 max log FLOP (204 septillion) available - TAI takes 37.3 log FLOP (18 thousand decillion) - log $ 18.5 to buy TAI (4 quintillion) vs. willingness to pay log $ 7.6 (40 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2029 - 26.5 max log FLOP (325 septillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 18.3 to buy TAI (2 quintillion) vs. willingness to pay log $ 7.7 (48 million) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2030 - 26.7 max log FLOP (518 septillion) available - TAI takes 37.0 log FLOP (9 thousand decillion) - log $ 18.0 to buy TAI (1 quintillion) vs. willingness to pay log $ 7.8 (58 million) - 18.9 log FLOPS per $ (9 quintillion)
# Year: 2031 - 26.9 max log FLOP (823 septillion) available - TAI takes 36.8 log FLOP (6 thousand decillion) - log $ 17.7 to buy TAI (547 quadrillion) vs. willingness to pay log $ 7.8 (70 million) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2032 - 27.1 max log FLOP (1 octillion) available - TAI takes 36.7 log FLOP (5 thousand decillion) - log $ 17.5 to buy TAI (295 quadrillion) vs. willingness to pay log $ 7.9 (85 million) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2033 - 27.3 max log FLOP (2 octillion) available - TAI takes 36.5 log FLOP (3 thousand decillion) - log $ 17.2 to buy TAI (159 quadrillion) vs. willingness to pay log $ 8.0 (103 million) - 19.3 log FLOPS per $ (20 quintillion)
# Year: 2034 - 27.5 max log FLOP (3 octillion) available - TAI takes 36.4 log FLOP (2 thousand decillion) - log $ 16.9 to buy TAI (85 quadrillion) vs. willingness to pay log $ 8.1 (125 million) - 19.4 log FLOPS per $ (27 quintillion)
# Year: 2035 - 27.7 max log FLOP (5 octillion) available - TAI takes 36.2 log FLOP (2 thousand decillion) - log $ 16.7 to buy TAI (46 quadrillion) vs. willingness to pay log $ 8.2 (151 million) - 19.5 log FLOPS per $ (35 quintillion)
# Year: 2036 - 27.9 max log FLOP (8 octillion) available - TAI takes 36.1 log FLOP (1 thousand decillion) - log $ 16.4 to buy TAI (25 quadrillion) vs. willingness to pay log $ 8.3 (182 million) - 19.7 log FLOPS per $ (46 quintillion)
# Year: 2037 - 28.1 max log FLOP (13 octillion) available - TAI takes 35.9 log FLOP (811 decillion) - log $ 16.1 to buy TAI (13 quadrillion) vs. willingness to pay log $ 8.3 (220 million) - 19.8 log FLOPS per $ (60 quintillion)
# Year: 2038 - 28.3 max log FLOP (21 octillion) available - TAI takes 35.8 log FLOP (577 decillion) - log $ 15.9 to buy TAI (7 quadrillion) vs. willingness to pay log $ 8.4 (266 million) - 19.9 log FLOPS per $ (79 quintillion)
# Year: 2039 - 28.5 max log FLOP (34 octillion) available - TAI takes 35.6 log FLOP (412 decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 8.5 (322 million) - 20.0 log FLOPS per $ (104 quintillion)
# Year: 2040 - 28.7 max log FLOP (53 octillion) available - TAI takes 35.5 log FLOP (296 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 8.6 (389 million) - 20.1 log FLOPS per $ (137 quintillion)
# Year: 2041 - 28.9 max log FLOP (85 octillion) available - TAI takes 35.3 log FLOP (213 decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 8.7 (469 million) - 20.3 log FLOPS per $ (180 quintillion)
# Year: 2042 - 29.1 max log FLOP (134 octillion) available - TAI takes 35.2 log FLOP (155 decillion) - log $ 14.8 to buy TAI (654 trillion) vs. willingness to pay log $ 8.8 (566 million) - 20.4 log FLOPS per $ (237 quintillion)
# Year: 2043 - 29.3 max log FLOP (213 octillion) available - TAI takes 35.1 log FLOP (114 decillion) - log $ 14.6 to buy TAI (365 trillion) vs. willingness to pay log $ 8.8 (683 million) - 20.5 log FLOPS per $ (311 quintillion)
# Year: 2044 - 29.5 max log FLOP (337 octillion) available - TAI takes 34.9 log FLOP (85 decillion) - log $ 14.3 to buy TAI (207 trillion) vs. willingness to pay log $ 8.9 (823 million) - 20.6 log FLOPS per $ (409 quintillion)
# Year: 2045 - 29.7 max log FLOP (533 octillion) available - TAI takes 34.8 log FLOP (64 decillion) - log $ 14.1 to buy TAI (119 trillion) vs. willingness to pay log $ 9.0 (990 million) - 20.7 log FLOPS per $ (538 quintillion)
# Year: 2046 - 29.9 max log FLOP (842 octillion) available - TAI takes 34.7 log FLOP (50 decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.8 log FLOPS per $ (707 quintillion)
# Year: 2047 - 30.1 max log FLOP (1 nonillion) available - TAI takes 34.6 log FLOP (39 decillion) - log $ 13.6 to buy TAI (42 trillion) vs. willingness to pay log $ 9.2 (1 billion) - 21.0 log FLOPS per $ (929 quintillion)
# Year: 2048 - 30.3 max log FLOP (2 nonillion) available - TAI takes 34.5 log FLOP (32 decillion) - log $ 13.4 to buy TAI (26 trillion) vs. willingness to pay log $ 9.2 (2 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2049 - 30.5 max log FLOP (3 nonillion) available - TAI takes 34.4 log FLOP (27 decillion) - log $ 13.2 to buy TAI (17 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2050 - 30.7 max log FLOP (5 nonillion) available - TAI takes 34.4 log FLOP (23 decillion) - log $ 13.0 to buy TAI (11 trillion) vs. willingness to pay log $ 9.4 (2 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2051 - 30.9 max log FLOP (8 nonillion) available - TAI takes 34.3 log FLOP (21 decillion) - log $ 12.9 to buy TAI (7 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2052 - 31.1 max log FLOP (13 nonillion) available - TAI takes 34.3 log FLOP (19 decillion) - log $ 12.7 to buy TAI (5 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2053 - 31.3 max log FLOP (20 nonillion) available - TAI takes 34.2 log FLOP (18 decillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2054 - 31.5 max log FLOP (31 nonillion) available - TAI takes 34.2 log FLOP (17 decillion) - log $ 12.4 to buy TAI (3 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 21.8 log FLOPS per $ (6 sextillion)
# Year: 2055 - 31.7 max log FLOP (48 nonillion) available - TAI takes 34.2 log FLOP (16 decillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 21.9 log FLOPS per $ (8 sextillion)
# Year: 2056 - 31.9 max log FLOP (74 nonillion) available - TAI takes 34.2 log FLOP (16 decillion) - log $ 12.2 to buy TAI (1 trillion) vs. willingness to pay log $ 9.8 (7 billion) - 22.0 log FLOPS per $ (11 sextillion)
# Year: 2057 - 32.1 max log FLOP (113 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 12.0 to buy TAI (1 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 22.1 log FLOPS per $ (14 sextillion)
# Year: 2058 - 32.2 max log FLOP (173 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.9 to buy TAI (818 billion) vs. willingness to pay log $ 10.0 (9 billion) - 22.3 log FLOPS per $ (18 sextillion)
# Year: 2059 - 32.4 max log FLOP (263 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.8 to buy TAI (619 billion) vs. willingness to pay log $ 10.0 (11 billion) - 22.4 log FLOPS per $ (24 sextillion)
# Year: 2060 - 32.6 max log FLOP (397 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.7 to buy TAI (471 billion) vs. willingness to pay log $ 10.1 (13 billion) - 22.5 log FLOPS per $ (31 sextillion)
# Year: 2061 - 32.8 max log FLOP (594 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.6 to buy TAI (360 billion) vs. willingness to pay log $ 10.2 (15 billion) - 22.6 log FLOPS per $ (41 sextillion)
# Year: 2062 - 32.9 max log FLOP (883 nonillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.4 to buy TAI (276 billion) vs. willingness to pay log $ 10.2 (17 billion) - 22.7 log FLOPS per $ (53 sextillion)
# Year: 2063 - 33.1 max log FLOP (1 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.3 to buy TAI (213 billion) vs. willingness to pay log $ 10.3 (19 billion) - 22.8 log FLOPS per $ (69 sextillion)
# Year: 2064 - 33.3 max log FLOP (2 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.2 to buy TAI (165 billion) vs. willingness to pay log $ 10.3 (21 billion) - 22.9 log FLOPS per $ (88 sextillion)
# Year: 2065 - 33.4 max log FLOP (3 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.1 to buy TAI (129 billion) vs. willingness to pay log $ 10.4 (24 billion) - 23.1 log FLOPS per $ (113 sextillion)
# Year: 2066 - 33.6 max log FLOP (4 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 11.0 to buy TAI (102 billion) vs. willingness to pay log $ 10.4 (27 billion) - 23.2 log FLOPS per $ (144 sextillion)
# Year: 2067 - 33.7 max log FLOP (5 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.9 to buy TAI (81 billion) vs. willingness to pay log $ 10.5 (30 billion) - 23.3 log FLOPS per $ (180 sextillion)
# Year: 2068 - 33.9 max log FLOP (7 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.8 to buy TAI (65 billion) vs. willingness to pay log $ 10.5 (33 billion) - 23.4 log FLOPS per $ (224 sextillion)
# Year: 2069 - 34.0 max log FLOP (10 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.7 to buy TAI (53 billion) vs. willingness to pay log $ 10.6 (36 billion) - 23.4 log FLOPS per $ (276 sextillion)
# Year: 2070 - 34.1 max log FLOP (13 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.6 to buy TAI (44 billion) vs. willingness to pay log $ 10.6 (40 billion) - 23.5 log FLOPS per $ (333 sextillion)
# Year: 2071 - 34.2 max log FLOP (17 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.6 to buy TAI (37 billion) vs. willingness to pay log $ 10.6 (43 billion) - 23.6 log FLOPS per $ (397 sextillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.3
# /!\ FLOPs for TAI sufficient but needs 3.2 more years to solve non-scaling issues
# Year: 2072 - 34.3 max log FLOP (22 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.5 to buy TAI (31 billion) vs. willingness to pay log $ 10.7 (47 billion) - 23.7 log FLOPS per $ (464 sextillion)
# /!\ FLOPs for TAI sufficient but needs 2.2 more years to solve non-scaling issues
# Year: 2073 - 34.4 max log FLOP (27 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.4 to buy TAI (27 billion) vs. willingness to pay log $ 10.7 (50 billion) - 23.7 log FLOPS per $ (532 sextillion)
# /!\ FLOPs for TAI sufficient but needs 1.2 more years to solve non-scaling issues
# Year: 2074 - 34.5 max log FLOP (32 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.4 to buy TAI (24 billion) vs. willingness to pay log $ 10.7 (54 billion) - 23.8 log FLOPS per $ (599 sextillion)
# /!\ FLOPs for TAI sufficient but needs 0.2 more years to solve non-scaling issues
# Year: 2075 - 34.6 max log FLOP (38 decillion) available - TAI takes 34.2 log FLOP (15 decillion) - log $ 10.3 to buy TAI (22 billion) vs. willingness to pay log $ 10.8 (58 billion) - 23.8 log FLOPS per $ (662 sextillion)
# --- /!\ TAI CREATED in 2075
# ## RUN 2 ##
# It takes 39.5 log FLOPs (~3 million decillion) for transformative capabilities.
# Every 2.0 years algorithms get 2x better, with 4 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 4.6 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 5.0x per year to a max of 0.0% of GDP. GDP grows at a rate of 1.03x per year.
# If a non-scaling delay happens, it will take an additional 17.2 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (12 septillion) available - TAI takes 39.5 log FLOP (3 million decillion) - log $ 21.5 to buy TAI (3 sextillion) vs. willingness to pay log $ 7.1 (12 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.2 max log FLOP (16 septillion) available - TAI takes 39.3 log FLOP (2 million decillion) - log $ 21.2 to buy TAI (2 sextillion) vs. willingness to pay log $ 7.2 (14 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.3 max log FLOP (22 septillion) available - TAI takes 39.2 log FLOP (1 million decillion) - log $ 21.0 to buy TAI (1 sextillion) vs. willingness to pay log $ 7.2 (16 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2025 - 25.5 max log FLOP (29 septillion) available - TAI takes 39.0 log FLOP (1 million decillion) - log $ 20.8 to buy TAI (651 quintillion) vs. willingness to pay log $ 7.3 (19 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 25.6 max log FLOP (39 septillion) available - TAI takes 38.9 log FLOP (724 thousand decillion) - log $ 20.6 to buy TAI (399 quintillion) vs. willingness to pay log $ 7.3 (21 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2027 - 25.7 max log FLOP (52 septillion) available - TAI takes 38.7 log FLOP (515 thousand decillion) - log $ 20.4 to buy TAI (244 quintillion) vs. willingness to pay log $ 7.4 (24 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2028 - 25.8 max log FLOP (68 septillion) available - TAI takes 38.6 log FLOP (366 thousand decillion) - log $ 20.2 to buy TAI (149 quintillion) vs. willingness to pay log $ 7.4 (28 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2029 - 26.0 max log FLOP (91 septillion) available - TAI takes 38.4 log FLOP (260 thousand decillion) - log $ 20.0 to buy TAI (92 quintillion) vs. willingness to pay log $ 7.5 (32 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2030 - 26.1 max log FLOP (121 septillion) available - TAI takes 38.3 log FLOP (185 thousand decillion) - log $ 19.7 to buy TAI (56 quintillion) vs. willingness to pay log $ 7.6 (37 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2031 - 26.2 max log FLOP (160 septillion) available - TAI takes 38.1 log FLOP (132 thousand decillion) - log $ 19.5 to buy TAI (34 quintillion) vs. willingness to pay log $ 7.6 (42 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2032 - 26.3 max log FLOP (213 septillion) available - TAI takes 38.0 log FLOP (94 thousand decillion) - log $ 19.3 to buy TAI (21 quintillion) vs. willingness to pay log $ 7.7 (48 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2033 - 26.4 max log FLOP (282 septillion) available - TAI takes 37.8 log FLOP (67 thousand decillion) - log $ 19.1 to buy TAI (13 quintillion) vs. willingness to pay log $ 7.7 (55 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2034 - 26.6 max log FLOP (373 septillion) available - TAI takes 37.7 log FLOP (48 thousand decillion) - log $ 18.9 to buy TAI (8 quintillion) vs. willingness to pay log $ 7.8 (62 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2035 - 26.7 max log FLOP (495 septillion) available - TAI takes 37.5 log FLOP (34 thousand decillion) - log $ 18.7 to buy TAI (5 quintillion) vs. willingness to pay log $ 7.9 (71 million) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2036 - 26.8 max log FLOP (655 septillion) available - TAI takes 37.4 log FLOP (24 thousand decillion) - log $ 18.5 to buy TAI (3 quintillion) vs. willingness to pay log $ 7.9 (81 million) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2037 - 26.9 max log FLOP (866 septillion) available - TAI takes 37.2 log FLOP (17 thousand decillion) - log $ 18.3 to buy TAI (2 quintillion) vs. willingness to pay log $ 8.0 (92 million) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2038 - 27.1 max log FLOP (1 octillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 18.1 to buy TAI (1 quintillion) vs. willingness to pay log $ 8.0 (105 million) - 19.0 log FLOPS per $ (11 quintillion)
# Year: 2039 - 27.2 max log FLOP (2 octillion) available - TAI takes 36.9 log FLOP (9 thousand decillion) - log $ 17.8 to buy TAI (700 quadrillion) vs. willingness to pay log $ 8.1 (119 million) - 19.1 log FLOPS per $ (13 quintillion)
# Year: 2040 - 27.3 max log FLOP (2 octillion) available - TAI takes 36.8 log FLOP (6 thousand decillion) - log $ 17.6 to buy TAI (434 quadrillion) vs. willingness to pay log $ 8.1 (136 million) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2041 - 27.4 max log FLOP (3 octillion) available - TAI takes 36.7 log FLOP (5 thousand decillion) - log $ 17.4 to buy TAI (271 quadrillion) vs. willingness to pay log $ 8.2 (154 million) - 19.2 log FLOPS per $ (17 quintillion)
# Year: 2042 - 27.5 max log FLOP (3 octillion) available - TAI takes 36.5 log FLOP (3 thousand decillion) - log $ 17.2 to buy TAI (170 quadrillion) vs. willingness to pay log $ 8.2 (175 million) - 19.3 log FLOPS per $ (20 quintillion)
# Year: 2043 - 27.7 max log FLOP (5 octillion) available - TAI takes 36.4 log FLOP (2 thousand decillion) - log $ 17.0 to buy TAI (108 quadrillion) vs. willingness to pay log $ 8.3 (198 million) - 19.4 log FLOPS per $ (23 quintillion)
# Year: 2044 - 27.8 max log FLOP (6 octillion) available - TAI takes 36.3 log FLOP (2 thousand decillion) - log $ 16.8 to buy TAI (69 quadrillion) vs. willingness to pay log $ 8.3 (224 million) - 19.4 log FLOPS per $ (27 quintillion)
# Year: 2045 - 27.9 max log FLOP (8 octillion) available - TAI takes 36.1 log FLOP (1 thousand decillion) - log $ 16.7 to buy TAI (45 quadrillion) vs. willingness to pay log $ 8.4 (252 million) - 19.5 log FLOPS per $ (31 quintillion)
# Year: 2046 - 28.0 max log FLOP (10 octillion) available - TAI takes 36.0 log FLOP (1 thousand decillion) - log $ 16.5 to buy TAI (30 quadrillion) vs. willingness to pay log $ 8.5 (285 million) - 19.6 log FLOPS per $ (36 quintillion)
# Year: 2047 - 28.1 max log FLOP (13 octillion) available - TAI takes 35.9 log FLOP (843 decillion) - log $ 16.3 to buy TAI (20 quadrillion) vs. willingness to pay log $ 8.5 (320 million) - 19.6 log FLOPS per $ (42 quintillion)
# Year: 2048 - 28.2 max log FLOP (17 octillion) available - TAI takes 35.8 log FLOP (681 decillion) - log $ 16.1 to buy TAI (14 quadrillion) vs. willingness to pay log $ 8.6 (360 million) - 19.7 log FLOPS per $ (49 quintillion)
# Year: 2049 - 28.4 max log FLOP (23 octillion) available - TAI takes 35.8 log FLOP (566 decillion) - log $ 16.0 to buy TAI (10 quadrillion) vs. willingness to pay log $ 8.6 (404 million) - 19.8 log FLOPS per $ (56 quintillion)
# Year: 2050 - 28.5 max log FLOP (30 octillion) available - TAI takes 35.7 log FLOP (485 decillion) - log $ 15.9 to buy TAI (7 quadrillion) vs. willingness to pay log $ 8.7 (452 million) - 19.8 log FLOPS per $ (65 quintillion)
# Year: 2051 - 28.6 max log FLOP (38 octillion) available - TAI takes 35.6 log FLOP (426 decillion) - log $ 15.7 to buy TAI (6 quadrillion) vs. willingness to pay log $ 8.7 (505 million) - 19.9 log FLOPS per $ (76 quintillion)
# Year: 2052 - 28.7 max log FLOP (50 octillion) available - TAI takes 35.6 log FLOP (385 decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 8.8 (563 million) - 19.9 log FLOPS per $ (88 quintillion)
# Year: 2053 - 28.8 max log FLOP (64 octillion) available - TAI takes 35.6 log FLOP (356 decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 8.8 (626 million) - 20.0 log FLOPS per $ (102 quintillion)
# Year: 2054 - 28.9 max log FLOP (82 octillion) available - TAI takes 35.5 log FLOP (335 decillion) - log $ 15.4 to buy TAI (3 quadrillion) vs. willingness to pay log $ 8.8 (694 million) - 20.1 log FLOPS per $ (119 quintillion)
# Year: 2055 - 29.0 max log FLOP (106 octillion) available - TAI takes 35.5 log FLOP (320 decillion) - log $ 15.4 to buy TAI (2 quadrillion) vs. willingness to pay log $ 8.9 (768 million) - 20.1 log FLOPS per $ (138 quintillion)
# Year: 2056 - 29.1 max log FLOP (136 octillion) available - TAI takes 35.5 log FLOP (309 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 8.9 (847 million) - 20.2 log FLOPS per $ (160 quintillion)
# Year: 2057 - 29.2 max log FLOP (173 octillion) available - TAI takes 35.5 log FLOP (302 decillion) - log $ 15.2 to buy TAI (2 quadrillion) vs. willingness to pay log $ 9.0 (932 million) - 20.3 log FLOPS per $ (186 quintillion)
# Year: 2058 - 29.3 max log FLOP (221 octillion) available - TAI takes 35.5 log FLOP (297 decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 9.0 (1 billion) - 20.3 log FLOPS per $ (216 quintillion)
# Year: 2059 - 29.4 max log FLOP (280 octillion) available - TAI takes 35.5 log FLOP (293 decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 9.0 (1 billion) - 20.4 log FLOPS per $ (251 quintillion)
# Year: 2060 - 29.6 max log FLOP (355 octillion) available - TAI takes 35.5 log FLOP (290 decillion) - log $ 15.0 to buy TAI (997 trillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.5 log FLOPS per $ (291 quintillion)
# Year: 2061 - 29.7 max log FLOP (448 octillion) available - TAI takes 35.5 log FLOP (288 decillion) - log $ 14.9 to buy TAI (853 trillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.5 log FLOPS per $ (338 quintillion)
# Year: 2062 - 29.8 max log FLOP (564 octillion) available - TAI takes 35.5 log FLOP (287 decillion) - log $ 14.9 to buy TAI (731 trillion) vs. willingness to pay log $ 9.2 (1 billion) - 20.6 log FLOPS per $ (392 quintillion)
# Year: 2063 - 29.9 max log FLOP (708 octillion) available - TAI takes 35.5 log FLOP (286 decillion) - log $ 14.8 to buy TAI (628 trillion) vs. willingness to pay log $ 9.2 (2 billion) - 20.7 log FLOPS per $ (455 quintillion)
# Year: 2064 - 29.9 max log FLOP (886 octillion) available - TAI takes 35.5 log FLOP (285 decillion) - log $ 14.7 to buy TAI (539 trillion) vs. willingness to pay log $ 9.2 (2 billion) - 20.7 log FLOPS per $ (529 quintillion)
# Year: 2065 - 30.0 max log FLOP (1 nonillion) available - TAI takes 35.5 log FLOP (285 decillion) - log $ 14.7 to buy TAI (464 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.8 log FLOPS per $ (614 quintillion)
# Year: 2066 - 30.1 max log FLOP (1 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.6 to buy TAI (399 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.9 log FLOPS per $ (712 quintillion)
# Year: 2067 - 30.2 max log FLOP (2 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.5 to buy TAI (343 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.9 log FLOPS per $ (827 quintillion)
# Year: 2068 - 30.3 max log FLOP (2 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.5 to buy TAI (296 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 21.0 log FLOPS per $ (960 quintillion)
# Year: 2069 - 30.4 max log FLOP (3 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.4 to buy TAI (255 trillion) vs. willingness to pay log $ 9.4 (2 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2070 - 30.5 max log FLOP (3 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.3 to buy TAI (219 trillion) vs. willingness to pay log $ 9.4 (2 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2071 - 30.6 max log FLOP (4 nonillion) available - TAI takes 35.5 log FLOP (284 decillion) - log $ 14.3 to buy TAI (189 trillion) vs. willingness to pay log $ 9.4 (3 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2072 - 30.7 max log FLOP (5 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 14.2 to buy TAI (163 trillion) vs. willingness to pay log $ 9.4 (3 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2073 - 30.8 max log FLOP (6 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 14.1 to buy TAI (140 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2074 - 30.9 max log FLOP (7 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 14.1 to buy TAI (121 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.4 log FLOPS per $ (2 sextillion)
# Year: 2075 - 30.9 max log FLOP (9 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 14.0 to buy TAI (104 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2076 - 31.0 max log FLOP (11 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 14.0 to buy TAI (90 trillion) vs. willingness to pay log $ 9.5 (3 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2077 - 31.1 max log FLOP (13 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.9 to buy TAI (77 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2078 - 31.2 max log FLOP (16 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.8 to buy TAI (67 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2079 - 31.3 max log FLOP (19 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.8 to buy TAI (57 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2080 - 31.4 max log FLOP (23 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.7 to buy TAI (49 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.8 log FLOPS per $ (6 sextillion)
# Year: 2081 - 31.4 max log FLOP (28 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.6 to buy TAI (43 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.8 log FLOPS per $ (7 sextillion)
# Year: 2082 - 31.5 max log FLOP (34 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.6 to buy TAI (37 trillion) vs. willingness to pay log $ 9.6 (4 billion) - 21.9 log FLOPS per $ (8 sextillion)
# Year: 2083 - 31.6 max log FLOP (41 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.5 to buy TAI (32 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.0 log FLOPS per $ (9 sextillion)
# Year: 2084 - 31.7 max log FLOP (49 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.4 to buy TAI (27 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.0 log FLOPS per $ (10 sextillion)
# Year: 2085 - 31.8 max log FLOP (59 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.4 to buy TAI (24 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.1 log FLOPS per $ (12 sextillion)
# Year: 2086 - 31.9 max log FLOP (71 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.3 to buy TAI (20 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.1 log FLOPS per $ (14 sextillion)
# Year: 2087 - 31.9 max log FLOP (85 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.2 to buy TAI (18 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.2 log FLOPS per $ (16 sextillion)
# Year: 2088 - 32.0 max log FLOP (102 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.2 to buy TAI (15 trillion) vs. willingness to pay log $ 9.7 (5 billion) - 22.3 log FLOPS per $ (19 sextillion)
# Year: 2089 - 32.1 max log FLOP (123 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 22.3 log FLOPS per $ (22 sextillion)
# Year: 2090 - 32.2 max log FLOP (147 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.1 to buy TAI (11 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 22.4 log FLOPS per $ (25 sextillion)
# Year: 2091 - 32.2 max log FLOP (176 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 13.0 to buy TAI (10 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 22.5 log FLOPS per $ (29 sextillion)
# Year: 2092 - 32.3 max log FLOP (210 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.9 to buy TAI (8 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 22.5 log FLOPS per $ (33 sextillion)
# Year: 2093 - 32.4 max log FLOP (251 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.9 to buy TAI (7 trillion) vs. willingness to pay log $ 9.8 (6 billion) - 22.6 log FLOPS per $ (39 sextillion)
# Year: 2094 - 32.5 max log FLOP (299 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.8 to buy TAI (6 trillion) vs. willingness to pay log $ 9.8 (7 billion) - 22.6 log FLOPS per $ (45 sextillion)
# Year: 2095 - 32.6 max log FLOP (356 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.7 to buy TAI (6 trillion) vs. willingness to pay log $ 9.8 (7 billion) - 22.7 log FLOPS per $ (51 sextillion)
# Year: 2096 - 32.6 max log FLOP (423 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.7 to buy TAI (5 trillion) vs. willingness to pay log $ 9.9 (7 billion) - 22.8 log FLOPS per $ (59 sextillion)
# Year: 2097 - 32.7 max log FLOP (502 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 9.9 (7 billion) - 22.8 log FLOPS per $ (68 sextillion)
# Year: 2098 - 32.8 max log FLOP (595 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 22.9 log FLOPS per $ (78 sextillion)
# Year: 2099 - 32.8 max log FLOP (704 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.5 to buy TAI (3 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 23.0 log FLOPS per $ (90 sextillion)
# Year: 2100 - 32.9 max log FLOP (831 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.4 to buy TAI (3 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 23.0 log FLOPS per $ (102 sextillion)
# Year: 2101 - 33.0 max log FLOP (979 nonillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.4 to buy TAI (2 trillion) vs. willingness to pay log $ 9.9 (8 billion) - 23.1 log FLOPS per $ (117 sextillion)
# Year: 2102 - 33.1 max log FLOP (1 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 9.9 (9 billion) - 23.1 log FLOPS per $ (133 sextillion)
# Year: 2103 - 33.1 max log FLOP (1 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 9.9 (9 billion) - 23.2 log FLOPS per $ (152 sextillion)
# Year: 2104 - 33.2 max log FLOP (2 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.2 to buy TAI (2 trillion) vs. willingness to pay log $ 10.0 (9 billion) - 23.2 log FLOPS per $ (172 sextillion)
# Year: 2105 - 33.3 max log FLOP (2 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.2 to buy TAI (1 trillion) vs. willingness to pay log $ 10.0 (9 billion) - 23.3 log FLOPS per $ (194 sextillion)
# Year: 2106 - 33.3 max log FLOP (2 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 10.0 (10 billion) - 23.3 log FLOPS per $ (219 sextillion)
# Year: 2107 - 33.4 max log FLOP (2 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 10.0 (10 billion) - 23.4 log FLOPS per $ (245 sextillion)
# Year: 2108 - 33.5 max log FLOP (3 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.0 to buy TAI (1 trillion) vs. willingness to pay log $ 10.0 (10 billion) - 23.4 log FLOPS per $ (274 sextillion)
# Year: 2109 - 33.5 max log FLOP (3 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 12.0 to buy TAI (931 billion) vs. willingness to pay log $ 10.0 (11 billion) - 23.5 log FLOPS per $ (304 sextillion)
# Year: 2110 - 33.6 max log FLOP (4 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.9 to buy TAI (841 billion) vs. willingness to pay log $ 10.0 (11 billion) - 23.5 log FLOPS per $ (337 sextillion)
# Year: 2111 - 33.6 max log FLOP (4 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.9 to buy TAI (764 billion) vs. willingness to pay log $ 10.1 (11 billion) - 23.6 log FLOPS per $ (371 sextillion)
# Year: 2112 - 33.7 max log FLOP (5 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.8 to buy TAI (697 billion) vs. willingness to pay log $ 10.1 (12 billion) - 23.6 log FLOPS per $ (407 sextillion)
# Year: 2113 - 33.7 max log FLOP (5 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.8 to buy TAI (640 billion) vs. willingness to pay log $ 10.1 (12 billion) - 23.6 log FLOPS per $ (443 sextillion)
# Year: 2114 - 33.8 max log FLOP (6 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.8 to buy TAI (590 billion) vs. willingness to pay log $ 10.1 (12 billion) - 23.7 log FLOPS per $ (480 sextillion)
# Year: 2115 - 33.8 max log FLOP (7 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.7 to buy TAI (548 billion) vs. willingness to pay log $ 10.1 (13 billion) - 23.7 log FLOPS per $ (517 sextillion)
# Year: 2116 - 33.9 max log FLOP (7 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.7 to buy TAI (511 billion) vs. willingness to pay log $ 10.1 (13 billion) - 23.7 log FLOPS per $ (554 sextillion)
# Year: 2117 - 33.9 max log FLOP (8 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.7 to buy TAI (480 billion) vs. willingness to pay log $ 10.1 (14 billion) - 23.8 log FLOPS per $ (591 sextillion)
# Year: 2118 - 33.9 max log FLOP (9 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.7 to buy TAI (452 billion) vs. willingness to pay log $ 10.1 (14 billion) - 23.8 log FLOPS per $ (627 sextillion)
# Year: 2119 - 34.0 max log FLOP (10 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.6 to buy TAI (429 billion) vs. willingness to pay log $ 10.2 (14 billion) - 23.8 log FLOPS per $ (661 sextillion)
# Year: 2120 - 34.0 max log FLOP (10 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.6 to buy TAI (409 billion) vs. willingness to pay log $ 10.2 (15 billion) - 23.8 log FLOPS per $ (693 sextillion)
# Year: 2121 - 34.0 max log FLOP (11 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.6 to buy TAI (391 billion) vs. willingness to pay log $ 10.2 (15 billion) - 23.9 log FLOPS per $ (724 sextillion)
# Year: 2122 - 34.1 max log FLOP (12 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.6 to buy TAI (376 billion) vs. willingness to pay log $ 10.2 (16 billion) - 23.9 log FLOPS per $ (753 sextillion)
# Year: 2123 - 34.1 max log FLOP (13 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.6 to buy TAI (363 billion) vs. willingness to pay log $ 10.2 (16 billion) - 23.9 log FLOPS per $ (780 sextillion)
# Year: 2124 - 34.1 max log FLOP (13 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (352 billion) vs. willingness to pay log $ 10.2 (17 billion) - 23.9 log FLOPS per $ (804 sextillion)
# Year: 2125 - 34.2 max log FLOP (14 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (343 billion) vs. willingness to pay log $ 10.2 (17 billion) - 23.9 log FLOPS per $ (827 sextillion)
# Year: 2126 - 34.2 max log FLOP (15 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (335 billion) vs. willingness to pay log $ 10.2 (18 billion) - 23.9 log FLOPS per $ (847 sextillion)
# Year: 2127 - 34.2 max log FLOP (16 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (327 billion) vs. willingness to pay log $ 10.3 (18 billion) - 23.9 log FLOPS per $ (865 sextillion)
# Year: 2128 - 34.2 max log FLOP (17 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (321 billion) vs. willingness to pay log $ 10.3 (19 billion) - 23.9 log FLOPS per $ (882 sextillion)
# Year: 2129 - 34.2 max log FLOP (17 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (316 billion) vs. willingness to pay log $ 10.3 (19 billion) - 24.0 log FLOPS per $ (897 sextillion)
# Year: 2130 - 34.3 max log FLOP (18 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (312 billion) vs. willingness to pay log $ 10.3 (20 billion) - 24.0 log FLOPS per $ (910 sextillion)
# Year: 2131 - 34.3 max log FLOP (19 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (308 billion) vs. willingness to pay log $ 10.3 (21 billion) - 24.0 log FLOPS per $ (921 sextillion)
# Year: 2132 - 34.3 max log FLOP (20 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (304 billion) vs. willingness to pay log $ 10.3 (21 billion) - 24.0 log FLOPS per $ (931 sextillion)
# Year: 2133 - 34.3 max log FLOP (20 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (301 billion) vs. willingness to pay log $ 10.3 (22 billion) - 24.0 log FLOPS per $ (940 sextillion)
# Year: 2134 - 34.3 max log FLOP (21 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (299 billion) vs. willingness to pay log $ 10.4 (22 billion) - 24.0 log FLOPS per $ (948 sextillion)
# Year: 2135 - 34.3 max log FLOP (22 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (297 billion) vs. willingness to pay log $ 10.4 (23 billion) - 24.0 log FLOPS per $ (955 sextillion)
# Year: 2136 - 34.4 max log FLOP (23 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (295 billion) vs. willingness to pay log $ 10.4 (24 billion) - 24.0 log FLOPS per $ (961 sextillion)
# Year: 2137 - 34.4 max log FLOP (24 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (293 billion) vs. willingness to pay log $ 10.4 (25 billion) - 24.0 log FLOPS per $ (966 sextillion)
# Year: 2138 - 34.4 max log FLOP (25 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (292 billion) vs. willingness to pay log $ 10.4 (25 billion) - 24.0 log FLOPS per $ (971 sextillion)
# Year: 2139 - 34.4 max log FLOP (25 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (291 billion) vs. willingness to pay log $ 10.4 (26 billion) - 24.0 log FLOPS per $ (975 sextillion)
# Year: 2140 - 34.4 max log FLOP (26 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (290 billion) vs. willingness to pay log $ 10.4 (27 billion) - 24.0 log FLOPS per $ (978 sextillion)
# Year: 2141 - 34.4 max log FLOP (27 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (289 billion) vs. willingness to pay log $ 10.4 (28 billion) - 24.0 log FLOPS per $ (981 sextillion)
# Year: 2142 - 34.4 max log FLOP (28 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (288 billion) vs. willingness to pay log $ 10.5 (28 billion) - 24.0 log FLOPS per $ (984 sextillion)
# Year: 2143 - 34.5 max log FLOP (29 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (287 billion) vs. willingness to pay log $ 10.5 (29 billion) - 24.0 log FLOPS per $ (986 sextillion)
# Year: 2144 - 34.5 max log FLOP (30 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (287 billion) vs. willingness to pay log $ 10.5 (30 billion) - 24.0 log FLOPS per $ (988 sextillion)
# Year: 2145 - 34.5 max log FLOP (31 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (286 billion) vs. willingness to pay log $ 10.5 (31 billion) - 24.0 log FLOPS per $ (990 sextillion)
# Year: 2146 - 34.5 max log FLOP (32 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (286 billion) vs. willingness to pay log $ 10.5 (32 billion) - 24.0 log FLOPS per $ (991 sextillion)
# Year: 2147 - 34.5 max log FLOP (33 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (286 billion) vs. willingness to pay log $ 10.5 (33 billion) - 24.0 log FLOPS per $ (992 sextillion)
# Year: 2148 - 34.5 max log FLOP (34 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (285 billion) vs. willingness to pay log $ 10.5 (34 billion) - 24.0 log FLOPS per $ (993 sextillion)
# Year: 2149 - 34.5 max log FLOP (35 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (285 billion) vs. willingness to pay log $ 10.5 (35 billion) - 24.0 log FLOPS per $ (994 sextillion)
# Year: 2150 - 34.6 max log FLOP (36 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (285 billion) vs. willingness to pay log $ 10.6 (36 billion) - 24.0 log FLOPS per $ (995 sextillion)
# Year: 2151 - 34.6 max log FLOP (37 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (285 billion) vs. willingness to pay log $ 10.6 (37 billion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2152 - 34.6 max log FLOP (38 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (38 billion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2153 - 34.6 max log FLOP (39 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (39 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2154 - 34.6 max log FLOP (40 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (41 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2155 - 34.6 max log FLOP (42 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (42 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2156 - 34.6 max log FLOP (43 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (43 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2157 - 34.6 max log FLOP (44 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.6 (44 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2158 - 34.7 max log FLOP (46 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (46 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2159 - 34.7 max log FLOP (47 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (47 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2160 - 34.7 max log FLOP (48 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (48 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2161 - 34.7 max log FLOP (50 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (50 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2162 - 34.7 max log FLOP (51 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (51 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2163 - 34.7 max log FLOP (53 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (53 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2164 - 34.7 max log FLOP (54 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (54 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2165 - 34.7 max log FLOP (56 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.7 (56 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2166 - 34.8 max log FLOP (58 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (284 billion) vs. willingness to pay log $ 10.8 (58 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2167 - 34.8 max log FLOP (59 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (59 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2168 - 34.8 max log FLOP (61 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (61 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2169 - 34.8 max log FLOP (63 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (63 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2170 - 34.8 max log FLOP (65 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (65 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2171 - 34.8 max log FLOP (67 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (67 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2172 - 34.8 max log FLOP (69 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.8 (69 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2173 - 34.9 max log FLOP (71 decillion) available - TAI takes 35.5 log FLOP (283 decillion) - log $ 11.5 to buy TAI (283 billion) vs. willingness to pay log $ 10.9 (71 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# ...
# Year: 2029 - 26.2 max log FLOP (164 septillion) available - TAI takes 34.1 log FLOP (12 decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 7.7 (46 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2030 - 26.4 max log FLOP (237 septillion) available - TAI takes 33.9 log FLOP (8 decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 7.7 (55 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2031 - 26.5 max log FLOP (342 septillion) available - TAI takes 33.8 log FLOP (6 decillion) - log $ 15.0 to buy TAI (1 quadrillion) vs. willingness to pay log $ 7.8 (66 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2032 - 26.7 max log FLOP (494 septillion) available - TAI takes 33.6 log FLOP (4 decillion) - log $ 14.8 to buy TAI (633 trillion) vs. willingness to pay log $ 7.9 (80 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2033 - 26.9 max log FLOP (712 septillion) available - TAI takes 33.4 log FLOP (3 decillion) - log $ 14.6 to buy TAI (364 trillion) vs. willingness to pay log $ 8.0 (96 million) - 18.9 log FLOPS per $ (7 quintillion)
# Year: 2034 - 27.0 max log FLOP (1 octillion) available - TAI takes 33.3 log FLOP (2 decillion) - log $ 14.3 to buy TAI (211 trillion) vs. willingness to pay log $ 8.1 (116 million) - 18.9 log FLOPS per $ (9 quintillion)
# Year: 2035 - 27.2 max log FLOP (1 octillion) available - TAI takes 33.1 log FLOP (1 decillion) - log $ 14.1 to buy TAI (124 trillion) vs. willingness to pay log $ 8.1 (139 million) - 19.0 log FLOPS per $ (11 quintillion)
# Year: 2036 - 27.3 max log FLOP (2 octillion) available - TAI takes 33.0 log FLOP (956 nonillion) - log $ 13.9 to buy TAI (75 trillion) vs. willingness to pay log $ 8.2 (167 million) - 19.1 log FLOPS per $ (13 quintillion)
# Year: 2037 - 27.5 max log FLOP (3 octillion) available - TAI takes 32.8 log FLOP (707 nonillion) - log $ 13.7 to buy TAI (46 trillion) vs. willingness to pay log $ 8.3 (201 million) - 19.2 log FLOPS per $ (15 quintillion)
# Year: 2038 - 27.6 max log FLOP (4 octillion) available - TAI takes 32.7 log FLOP (540 nonillion) - log $ 13.5 to buy TAI (29 trillion) vs. willingness to pay log $ 8.4 (242 million) - 19.3 log FLOPS per $ (18 quintillion)
# Year: 2039 - 27.8 max log FLOP (6 octillion) available - TAI takes 32.6 log FLOP (427 nonillion) - log $ 13.3 to buy TAI (19 trillion) vs. willingness to pay log $ 8.5 (291 million) - 19.3 log FLOPS per $ (22 quintillion)
# Year: 2040 - 28.0 max log FLOP (9 octillion) available - TAI takes 32.5 log FLOP (351 nonillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 8.5 (349 million) - 19.4 log FLOPS per $ (26 quintillion)
# Year: 2041 - 28.1 max log FLOP (13 octillion) available - TAI takes 32.5 log FLOP (300 nonillion) - log $ 13.0 to buy TAI (9 trillion) vs. willingness to pay log $ 8.6 (419 million) - 19.5 log FLOPS per $ (32 quintillion)
# Year: 2042 - 28.3 max log FLOP (19 octillion) available - TAI takes 32.4 log FLOP (266 nonillion) - log $ 12.8 to buy TAI (7 trillion) vs. willingness to pay log $ 8.7 (503 million) - 19.6 log FLOPS per $ (38 quintillion)
# Year: 2043 - 28.4 max log FLOP (28 octillion) available - TAI takes 32.4 log FLOP (243 nonillion) - log $ 12.7 to buy TAI (5 trillion) vs. willingness to pay log $ 8.8 (604 million) - 19.7 log FLOPS per $ (46 quintillion)
# Year: 2044 - 28.6 max log FLOP (40 octillion) available - TAI takes 32.4 log FLOP (227 nonillion) - log $ 12.6 to buy TAI (4 trillion) vs. willingness to pay log $ 8.9 (725 million) - 19.7 log FLOPS per $ (55 quintillion)
# Year: 2045 - 28.8 max log FLOP (57 octillion) available - TAI takes 32.3 log FLOP (217 nonillion) - log $ 12.5 to buy TAI (3 trillion) vs. willingness to pay log $ 8.9 (869 million) - 19.8 log FLOPS per $ (66 quintillion)
# Year: 2046 - 28.9 max log FLOP (82 octillion) available - TAI takes 32.3 log FLOP (210 nonillion) - log $ 12.4 to buy TAI (3 trillion) vs. willingness to pay log $ 9.0 (1 billion) - 19.9 log FLOPS per $ (79 quintillion)
# Year: 2047 - 29.1 max log FLOP (118 octillion) available - TAI takes 32.3 log FLOP (205 nonillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 9.1 (1 billion) - 20.0 log FLOPS per $ (95 quintillion)
# Year: 2048 - 29.2 max log FLOP (169 octillion) available - TAI takes 32.3 log FLOP (202 nonillion) - log $ 12.2 to buy TAI (2 trillion) vs. willingness to pay log $ 9.2 (1 billion) - 20.1 log FLOPS per $ (114 quintillion)
# Year: 2049 - 29.4 max log FLOP (243 octillion) available - TAI takes 32.3 log FLOP (199 nonillion) - log $ 12.2 to buy TAI (1 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.1 log FLOPS per $ (136 quintillion)
# Year: 2050 - 29.5 max log FLOP (348 octillion) available - TAI takes 32.3 log FLOP (198 nonillion) - log $ 12.1 to buy TAI (1 trillion) vs. willingness to pay log $ 9.3 (2 billion) - 20.2 log FLOPS per $ (163 quintillion)
# Year: 2051 - 29.7 max log FLOP (498 octillion) available - TAI takes 32.3 log FLOP (197 nonillion) - log $ 12.0 to buy TAI (1 trillion) vs. willingness to pay log $ 9.4 (3 billion) - 20.3 log FLOPS per $ (196 quintillion)
# Year: 2052 - 29.9 max log FLOP (712 octillion) available - TAI takes 32.3 log FLOP (196 nonillion) - log $ 11.9 to buy TAI (835 billion) vs. willingness to pay log $ 9.5 (3 billion) - 20.4 log FLOPS per $ (235 quintillion)
# Year: 2053 - 30.0 max log FLOP (1 nonillion) available - TAI takes 32.3 log FLOP (196 nonillion) - log $ 11.8 to buy TAI (695 billion) vs. willingness to pay log $ 9.6 (4 billion) - 20.5 log FLOPS per $ (282 quintillion)
# Year: 2054 - 30.2 max log FLOP (1 nonillion) available - TAI takes 32.3 log FLOP (196 nonillion) - log $ 11.8 to buy TAI (578 billion) vs. willingness to pay log $ 9.6 (4 billion) - 20.5 log FLOPS per $ (338 quintillion)
# Year: 2055 - 30.3 max log FLOP (2 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.7 to buy TAI (481 billion) vs. willingness to pay log $ 9.7 (5 billion) - 20.6 log FLOPS per $ (406 quintillion)
# Year: 2056 - 30.5 max log FLOP (3 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.6 to buy TAI (401 billion) vs. willingness to pay log $ 9.8 (6 billion) - 20.7 log FLOPS per $ (487 quintillion)
# Year: 2057 - 30.6 max log FLOP (4 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.5 to buy TAI (334 billion) vs. willingness to pay log $ 9.8 (7 billion) - 20.8 log FLOPS per $ (584 quintillion)
# Year: 2058 - 30.8 max log FLOP (6 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.4 to buy TAI (279 billion) vs. willingness to pay log $ 9.9 (8 billion) - 20.8 log FLOPS per $ (701 quintillion)
# Year: 2059 - 30.9 max log FLOP (8 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.4 to buy TAI (232 billion) vs. willingness to pay log $ 10.0 (10 billion) - 20.9 log FLOPS per $ (840 quintillion)
# Year: 2060 - 31.1 max log FLOP (11 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.3 to buy TAI (194 billion) vs. willingness to pay log $ 10.1 (11 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2061 - 31.2 max log FLOP (16 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.2 to buy TAI (161 billion) vs. willingness to pay log $ 10.1 (13 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2062 - 31.3 max log FLOP (22 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.1 to buy TAI (135 billion) vs. willingness to pay log $ 10.2 (15 billion) - 21.2 log FLOPS per $ (1 sextillion)
# Year: 2063 - 31.5 max log FLOP (30 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.0 to buy TAI (112 billion) vs. willingness to pay log $ 10.2 (18 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2064 - 31.6 max log FLOP (42 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 11.0 to buy TAI (94 billion) vs. willingness to pay log $ 10.3 (20 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2065 - 31.8 max log FLOP (57 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.9 to buy TAI (78 billion) vs. willingness to pay log $ 10.4 (23 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2066 - 31.9 max log FLOP (78 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.8 to buy TAI (65 billion) vs. willingness to pay log $ 10.4 (26 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2067 - 32.0 max log FLOP (105 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.7 to buy TAI (54 billion) vs. willingness to pay log $ 10.5 (29 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2068 - 32.1 max log FLOP (141 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.7 to buy TAI (45 billion) vs. willingness to pay log $ 10.5 (33 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2069 - 32.3 max log FLOP (189 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.6 to buy TAI (38 billion) vs. willingness to pay log $ 10.6 (37 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2070 - 32.4 max log FLOP (250 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.5 to buy TAI (32 billion) vs. willingness to pay log $ 10.6 (40 billion) - 21.8 log FLOPS per $ (6 sextillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.3
# /!\ FLOPs for TAI sufficient but needs 5.0 more years to solve non-scaling issues
# Year: 2071 - 32.5 max log FLOP (330 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.4 to buy TAI (26 billion) vs. willingness to pay log $ 10.6 (44 billion) - 21.9 log FLOPS per $ (7 sextillion)
# /!\ FLOPs for TAI sufficient but needs 4.0 more years to solve non-scaling issues
# Year: 2072 - 32.6 max log FLOP (433 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.3 to buy TAI (22 billion) vs. willingness to pay log $ 10.7 (49 billion) - 21.9 log FLOPS per $ (9 sextillion)
# /!\ FLOPs for TAI sufficient but needs 3.0 more years to solve non-scaling issues
# Year: 2073 - 32.8 max log FLOP (564 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.3 to buy TAI (18 billion) vs. willingness to pay log $ 10.7 (53 billion) - 22.0 log FLOPS per $ (11 sextillion)
# /!\ FLOPs for TAI sufficient but needs 2.0 more years to solve non-scaling issues
# Year: 2074 - 32.9 max log FLOP (731 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.2 to buy TAI (15 billion) vs. willingness to pay log $ 10.8 (57 billion) - 22.1 log FLOPS per $ (13 sextillion)
# /!\ FLOPs for TAI sufficient but needs 1.0 more years to solve non-scaling issues
# Year: 2075 - 33.0 max log FLOP (942 nonillion) available - TAI takes 32.3 log FLOP (195 nonillion) - log $ 10.1 to buy TAI (13 billion) vs. willingness to pay log $ 10.8 (62 billion) - 22.2 log FLOPS per $ (15 sextillion)
# --- /!\ TAI CREATED in 2075
# ## RUN 5 ##
# It takes 28.5 log FLOPs (~33 octillion) for transformative capabilities.
# Every 2.0 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 3.2 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 4.6x per year to a max of 0.0004% of GDP. GDP grows at a rate of 1.039x per year.
# If a non-scaling delay happens, it will take an additional 5.0 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (13 septillion) available - TAI takes 28.5 log FLOP (33 octillion) - log $ 10.5 to buy TAI (33 billion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.3 max log FLOP (18 septillion) available - TAI takes 28.4 log FLOP (24 octillion) - log $ 10.3 to buy TAI (19 billion) vs. willingness to pay log $ 7.2 (15 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.4 max log FLOP (26 septillion) available - TAI takes 28.2 log FLOP (17 octillion) - log $ 10.0 to buy TAI (11 billion) vs. willingness to pay log $ 7.2 (17 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2025 - 25.6 max log FLOP (38 septillion) available - TAI takes 28.1 log FLOP (12 octillion) - log $ 9.8 to buy TAI (6 billion) vs. willingness to pay log $ 7.3 (20 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2026 - 25.7 max log FLOP (54 septillion) available - TAI takes 27.9 log FLOP (9 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 7.4 (23 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2027 - 25.9 max log FLOP (78 septillion) available - TAI takes 27.8 log FLOP (6 octillion) - log $ 9.3 to buy TAI (2 billion) vs. willingness to pay log $ 7.4 (27 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2028 - 26.1 max log FLOP (113 septillion) available - TAI takes 27.7 log FLOP (4 octillion) - log $ 9.1 to buy TAI (1 billion) vs. willingness to pay log $ 7.5 (31 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2029 - 26.2 max log FLOP (163 septillion) available - TAI takes 27.5 log FLOP (3 octillion) - log $ 8.9 to buy TAI (733 million) vs. willingness to pay log $ 7.6 (36 million) - 18.7 log FLOPS per $ (4 quintillion)
# Year: 2030 - 26.4 max log FLOP (235 septillion) available - TAI takes 27.4 log FLOP (2 octillion) - log $ 8.6 to buy TAI (436 million) vs. willingness to pay log $ 7.6 (42 million) - 18.7 log FLOPS per $ (6 quintillion)
# Year: 2031 - 26.5 max log FLOP (339 septillion) available - TAI takes 27.3 log FLOP (2 octillion) - log $ 8.4 to buy TAI (263 million) vs. willingness to pay log $ 7.7 (49 million) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2032 - 26.7 max log FLOP (489 septillion) available - TAI takes 27.1 log FLOP (1 octillion) - log $ 8.2 to buy TAI (162 million) vs. willingness to pay log $ 7.8 (57 million) - 18.9 log FLOPS per $ (9 quintillion)
# Year: 2033 - 26.8 max log FLOP (705 septillion) available - TAI takes 27.0 log FLOP (1 octillion) - log $ 8.0 to buy TAI (102 million) vs. willingness to pay log $ 7.8 (67 million) - 19.0 log FLOPS per $ (11 quintillion)
# Year: 2034 - 27.0 max log FLOP (1 octillion) available - TAI takes 26.9 log FLOP (854 septillion) - log $ 7.8 to buy TAI (65 million) vs. willingness to pay log $ 7.9 (78 million) - 19.1 log FLOPS per $ (13 quintillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.7527
# /!\ FLOPs for TAI sufficient but needs 5.0 more years to solve non-scaling issues
# Year: 2035 - 27.2 max log FLOP (1 octillion) available - TAI takes 26.8 log FLOP (702 septillion) - log $ 7.6 to buy TAI (43 million) vs. willingness to pay log $ 8.0 (91 million) - 19.2 log FLOPS per $ (16 quintillion)
# /!\ FLOPs for TAI sufficient but needs 4.0 more years to solve non-scaling issues
# Year: 2036 - 27.3 max log FLOP (2 octillion) available - TAI takes 26.8 log FLOP (594 septillion) - log $ 7.5 to buy TAI (30 million) vs. willingness to pay log $ 8.0 (105 million) - 19.3 log FLOPS per $ (20 quintillion)
# /!\ FLOPs for TAI sufficient but needs 3.0 more years to solve non-scaling issues
# Year: 2037 - 27.5 max log FLOP (3 octillion) available - TAI takes 26.7 log FLOP (517 septillion) - log $ 7.3 to buy TAI (21 million) vs. willingness to pay log $ 8.1 (123 million) - 19.4 log FLOPS per $ (25 quintillion)
# /!\ FLOPs for TAI sufficient but needs 2.0 more years to solve non-scaling issues
# Year: 2038 - 27.6 max log FLOP (4 octillion) available - TAI takes 26.7 log FLOP (463 septillion) - log $ 7.2 to buy TAI (15 million) vs. willingness to pay log $ 8.2 (143 million) - 19.5 log FLOPS per $ (31 quintillion)
# /!\ FLOPs for TAI sufficient but needs 1.0 more years to solve non-scaling issues
# Year: 2039 - 27.8 max log FLOP (6 octillion) available - TAI takes 26.6 log FLOP (425 septillion) - log $ 7.0 to buy TAI (11 million) vs. willingness to pay log $ 8.2 (166 million) - 19.6 log FLOPS per $ (38 quintillion)
# --- /!\ TAI CREATED in 2039

# %%
tai_years = bayes.bayesnet(define_event,
                           find=lambda e: e['tai_year'],
                           verbose=True,
                           raw=True,
                           dump_cache_file='caches/tai_years',
                           cores=6,
                           n=RUNS)
# Out:
# Loading from in-memory cache...
# ...Loaded
# Writing cache to file `caches/tai_years.sqcache.pkl`...
# ...Cached
# ...Finding

# %%
out = sq.get_percentiles(tai_years)
[str(o[0]) + '%: ' + (str(int(o[1])) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR)) for o in out.items()]

# NOTE: Ajeya's numbers should output something very close to:
# '5%': 2027,
# '10%: 2031',
# '20%: 2037',
# '30%: 2042',
# '40%: 2047',
# '50%: 2053',
# '60%: 2061',
# '70%: 2073',
# '80%: >2100',
# '90%: >2100',
# '95%: >2100'

# My latest numbers (2022 Aug 27 8:43PM CT):
# '1%: 2024',
# '5%: 2027',
# '10%: 2029',
# '20%: 2033',
# '30%: 2038',
# '40%: 2045',
# '50%: 2054',
# '60%: 2064',
# '70%: 2079',
# '80%: 2116',
# '90%: >2222',
# '95%: >2222',
# '99%: >2222']
# Out:
# ['1%: 2024',
#  '5%: 2027',
#  '10%: 2029',
#  '20%: 2034',
#  '30%: 2040',
#  '40%: 2047',
#  '50%: 2055',
#  '60%: 2066',
#  '70%: 2083',
#  '80%: 2152',
#  '90%: >2222',
#  '95%: >2222',
#  '99%: >2222']

# %%
[str(o[0]) + '%: ' + (str(int(o[1]) - CURRENT_YEAR) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR - CURRENT_YEAR)) + ' years from now' for o in out.items()]
# Out:
# ['1%: 2 years from now',
#  '5%: 5 years from now',
#  '10%: 7 years from now',
#  '20%: 12 years from now',
#  '30%: 18 years from now',
#  '40%: 25 years from now',
#  '50%: 33 years from now',
#  '60%: 44 years from now',
#  '70%: 61 years from now',
#  '80%: 130 years from now',
#  '90%: >200 years from now',
#  '95%: >200 years from now',
#  '99%: >200 years from now']

# %%
tai_years_ = np.array([MAX_YEAR + 1 if t > MAX_YEAR else t for t in tai_years])
count, bins_count = np.histogram(tai_years_, bins=(MAX_YEAR - CURRENT_YEAR))
bins = np.round(np.array([b for b in bins_count[1:] if b <= MAX_YEAR]))
pdf = count / sum(count)
cdf = np.cumsum(pdf)

plt.plot(bins, cdf[:len(bins)], label='CDF')
plt.legend()
plt.show()

# %%
d_ = dict(zip(years, cdf[:len(bins)]))

def bin_tai_yrs(low=None, hi=None):
    low = CURRENT_YEAR if low is None else low
    out = 1 - d_[low] if hi is None else d_[hi] - d_[low]
    return round(out * 100, 1)

print('<2024: {}%'.format(bin_tai_yrs(hi=2024)))
print('2025-2029: {}%'.format(bin_tai_yrs(2025, 2029)))
print('2030-2039: {}%'.format(bin_tai_yrs(2030, 2039)))
print('2040-2049: {}%'.format(bin_tai_yrs(2040, 2049)))
print('2050-2059: {}%'.format(bin_tai_yrs(2050, 2059)))
print('2060-2069: {}%'.format(bin_tai_yrs(2060, 2069)))
print('2070-2079: {}%'.format(bin_tai_yrs(2070, 2079)))
print('2080-2089: {}%'.format(bin_tai_yrs(2080, 2089)))
print('2090-2099: {}%'.format(bin_tai_yrs(2090, 2099)))
print('2100-2149: {}%'.format(bin_tai_yrs(2100, 2149)))
print('2149-2199: {}%'.format(bin_tai_yrs(2149, 2199)))
print('>2200: {}%'.format(bin_tai_yrs(low=2220)))
# Out:
# <2024: 1.9%
# 2025-2029: 8.5%
# 2030-2039: 15.9%
# 2040-2049: 12.1%
# 2050-2059: 9.5%
# 2060-2069: 7.2%
# 2070-2079: 5.6%
# 2080-2089: 3.5%
# 2090-2099: 2.1%
# 2100-2149: 4.2%
# 2149-2199: 1.9%
# >2200: 17.5%

# %%
def print_chance_tai_by_year(data, year_target):
    return '{}% chance of TAI by EOY {}'.format(int(np.round(sum([1 if y <= year_target else 0 for y in data]) / len(data) * 100, 0)),
                                                year_target)
    
print('## Within <1 years')
print_chance_tai_by_year(tai_years, 2022)
# Out:
# ## Within <1 years
# '1% chance of TAI by EOY 2022'

# %%
print('## Within <1 years')
print_chance_tai_by_year(tai_years, 2023)
# Out:
# ## Within <1 years
# '1% chance of TAI by EOY 2023'

# %%
print_chance_tai_by_year(tai_years, 2024)
# Out:
# '1% chance of TAI by EOY 2024'

# %%
print_chance_tai_by_year(tai_years, 2025)
# Out:
# '3% chance of TAI by EOY 2025'

# %%
print('## Within 5 years')
print_chance_tai_by_year(tai_years, 2027)
# Out:
# ## Within 5 years
# '6% chance of TAI by EOY 2027'

# %%
print_chance_tai_by_year(tai_years, 2029)
# Out:
# '10% chance of TAI by EOY 2029'

# %%
print_chance_tai_by_year(tai_years, 2030)
# Out:
# '13% chance of TAI by EOY 2030'

# %%
print('## Within 10 years')
print_chance_tai_by_year(tai_years, 2032)
# Out:
# ## Within 10 years
# '17% chance of TAI by EOY 2032'

# %%
# Holden benchmarks from https://www.cold-takes.com/biological-anchors-is-about-bounding-not-pinpointing-ai-timelines/#bio-anchors-as-a-way-of-bounding-ai-timelines
print('## Within 14 years (Holden benchmark - 10%-50%, Holden: 10%)')
print_chance_tai_by_year(tai_years, 2036)
# Out:
# ## Within 14 years (Holden benchmark - 10%-50%, Holden: 10%)
# '24% chance of TAI by EOY 2036'

# %%
print('## Within 15 years')
print_chance_tai_by_year(tai_years, 2037)
# Out:
# ## Within 15 years
# '26% chance of TAI by EOY 2037'

# %%
print_chance_tai_by_year(tai_years, 2040)
# Out:
# '31% chance of TAI by EOY 2040'

# %%
print('## Within 20 years')
print_chance_tai_by_year(tai_years, 2042)
# Out:
# ## Within 20 years
# '34% chance of TAI by EOY 2042'

# %%
print('## Within 25 years')
print_chance_tai_by_year(tai_years, 2047)
# Out:
# ## Within 25 years
# '41% chance of TAI by EOY 2047'

# %%
print_chance_tai_by_year(tai_years, 2050)
# Out:
# '44% chance of TAI by EOY 2050'

# %%
print('## Within 38 years (Holden benchmark - 25%-75%, Holden: 50%)')
print_chance_tai_by_year(tai_years, 2060)
# Out:
# ## Within 38 years (Holden benchmark - 25%-75%, Holden: 50%)
# '55% chance of TAI by EOY 2060'

# %%
print('## Within 48 years (Carlsmith benchmark - Carlsmith: 50%)')
print_chance_tai_by_year(tai_years, 2070)
# Out:
# ## Within 48 years (Carlsmith benchmark - Carlsmith: 50%)
# '63% chance of TAI by EOY 2070'

# %%
print('## Within 50 years')
print_chance_tai_by_year(tai_years, 2072)
# Out:
# ## Within 50 years
# '64% chance of TAI by EOY 2072'

# %%
print('## Within my personal expected lifespan')
print_chance_tai_by_year(tai_years, 2078)
# Out:
# ## Within my personal expected lifespan
# '68% chance of TAI by EOY 2078'

# %%
print('## Within 75 years')
print_chance_tai_by_year(tai_years, 2097)
# Out:
# ## Within 75 years
# '75% chance of TAI by EOY 2097'

# %%
print('## Within 78 years (Holden benchmark - 33%-90%, Holden: 66%)')
print_chance_tai_by_year(tai_years, 2100)
# Out:
# ## Within 78 years (Holden benchmark - 33%-90%, Holden: 66%)
# '76% chance of TAI by EOY 2100'

# %%
print('## Within 100 years')
print_chance_tai_by_year(tai_years, 2122)
# Out:
# ## Within 100 years
# '79% chance of TAI by EOY 2122'

# %%
print('## Within 200 years')
print_chance_tai_by_year(tai_years, 2222)
# Out:
# ## Within 200 years
# '83% chance of TAI by EOY 2222'

# %%
pdf_smoothed = savitzky_golay(pdf[:len(bins)], 51, 3)
plt.plot(bins, pdf_smoothed, label='PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
cdf[:len(bins)]
# Out:
# array([0.0084, 0.0132, 0.0272, 0.0427, 0.0592, 0.0822, 0.1041, 0.1274,
#        0.1492, 0.166 , 0.186 , 0.2013, 0.2202, 0.2393, 0.257 , 0.275 ,
#        0.2918, 0.3078, 0.3206, 0.3362, 0.3515, 0.3661, 0.3802, 0.3935,
#        0.4073, 0.4181, 0.4309, 0.4419, 0.4538, 0.4657, 0.4764, 0.4892,
#        0.5001, 0.5054, 0.517 , 0.5278, 0.5403, 0.5486, 0.5578, 0.5675,
#        0.5792, 0.586 , 0.5955, 0.604 , 0.6109, 0.6171, 0.6239, 0.6298,
#        0.6371, 0.6437, 0.652 , 0.6586, 0.667 , 0.6738, 0.6785, 0.6844,
#        0.6899, 0.6927, 0.6965, 0.6994, 0.7029, 0.7088, 0.7128, 0.7152,
#        0.7186, 0.7209, 0.7252, 0.7313, 0.7353, 0.7377, 0.7388, 0.7414,
#        0.7434, 0.7467, 0.7493, 0.752 , 0.7544, 0.7562, 0.7572, 0.7587,
#        0.7597, 0.7622, 0.7639, 0.766 , 0.7678, 0.7689, 0.77  , 0.7704,
#        0.7711, 0.7721, 0.7733, 0.7746, 0.7751, 0.7762, 0.7776, 0.7791,
#        0.7802, 0.7812, 0.783 , 0.7859, 0.7864, 0.7871, 0.7878, 0.7889,
#        0.7899, 0.7899, 0.7902, 0.7911, 0.7915, 0.7921, 0.7927, 0.7934,
#        0.794 , 0.7946, 0.7948, 0.7951, 0.7959, 0.797 , 0.797 , 0.7973,
#        0.7979, 0.7979, 0.798 , 0.798 , 0.798 , 0.7981, 0.7982, 0.7989,
#        0.7998, 0.8003, 0.8012, 0.8013, 0.8026, 0.8035, 0.8035, 0.8039,
#        0.8046, 0.8056, 0.8061, 0.8061, 0.8066, 0.807 , 0.807 , 0.8078,
#        0.8082, 0.8084, 0.8089, 0.8089, 0.8098, 0.8098, 0.8109, 0.8109,
#        0.8109, 0.8113, 0.8118, 0.8118, 0.8121, 0.8121, 0.8122, 0.8124,
#        0.8125, 0.8127, 0.8133, 0.8137, 0.8145, 0.8146, 0.8147, 0.8147,
#        0.8148, 0.8155, 0.8156, 0.816 , 0.8166, 0.8168, 0.8172, 0.8172,
#        0.8174, 0.8179, 0.8181, 0.8183, 0.819 , 0.8192, 0.8196, 0.8203,
#        0.8207, 0.8207, 0.8215, 0.8219, 0.822 , 0.822 , 0.8231, 0.8237,
#        0.824 , 0.8241, 0.8245, 0.8247, 0.8248, 0.8249, 0.8252])

# %%
pdf[:len(bins)]
# Out:
# array([0.0084, 0.0048, 0.014 , 0.0155, 0.0165, 0.023 , 0.0219, 0.0233,
#        0.0218, 0.0168, 0.02  , 0.0153, 0.0189, 0.0191, 0.0177, 0.018 ,
#        0.0168, 0.016 , 0.0128, 0.0156, 0.0153, 0.0146, 0.0141, 0.0133,
#        0.0138, 0.0108, 0.0128, 0.011 , 0.0119, 0.0119, 0.0107, 0.0128,
#        0.0109, 0.0053, 0.0116, 0.0108, 0.0125, 0.0083, 0.0092, 0.0097,
#        0.0117, 0.0068, 0.0095, 0.0085, 0.0069, 0.0062, 0.0068, 0.0059,
#        0.0073, 0.0066, 0.0083, 0.0066, 0.0084, 0.0068, 0.0047, 0.0059,
#        0.0055, 0.0028, 0.0038, 0.0029, 0.0035, 0.0059, 0.004 , 0.0024,
#        0.0034, 0.0023, 0.0043, 0.0061, 0.004 , 0.0024, 0.0011, 0.0026,
#        0.002 , 0.0033, 0.0026, 0.0027, 0.0024, 0.0018, 0.001 , 0.0015,
#        0.001 , 0.0025, 0.0017, 0.0021, 0.0018, 0.0011, 0.0011, 0.0004,
#        0.0007, 0.001 , 0.0012, 0.0013, 0.0005, 0.0011, 0.0014, 0.0015,
#        0.0011, 0.001 , 0.0018, 0.0029, 0.0005, 0.0007, 0.0007, 0.0011,
#        0.001 , 0.    , 0.0003, 0.0009, 0.0004, 0.0006, 0.0006, 0.0007,
#        0.0006, 0.0006, 0.0002, 0.0003, 0.0008, 0.0011, 0.    , 0.0003,
#        0.0006, 0.    , 0.0001, 0.    , 0.    , 0.0001, 0.0001, 0.0007,
#        0.0009, 0.0005, 0.0009, 0.0001, 0.0013, 0.0009, 0.    , 0.0004,
#        0.0007, 0.001 , 0.0005, 0.    , 0.0005, 0.0004, 0.    , 0.0008,
#        0.0004, 0.0002, 0.0005, 0.    , 0.0009, 0.    , 0.0011, 0.    ,
#        0.    , 0.0004, 0.0005, 0.    , 0.0003, 0.    , 0.0001, 0.0002,
#        0.0001, 0.0002, 0.0006, 0.0004, 0.0008, 0.0001, 0.0001, 0.    ,
#        0.0001, 0.0007, 0.0001, 0.0004, 0.0006, 0.0002, 0.0004, 0.    ,
#        0.0002, 0.0005, 0.0002, 0.0002, 0.0007, 0.0002, 0.0004, 0.0007,
#        0.0004, 0.    , 0.0008, 0.0004, 0.0001, 0.    , 0.0011, 0.0006,
#        0.0003, 0.0001, 0.0004, 0.0002, 0.0001, 0.0001, 0.0003])

# %%
## TODO: Update all

cotra_2020_cdf = [0.0214, 0.0272, 0.0328, 0.0385, 0.0458, 0.0551, 0.0641, 0.0721,
       0.0827, 0.0923, 0.1061, 0.1199, 0.1343, 0.1574, 0.175 , 0.1917,
       0.2108, 0.2321, 0.251 , 0.2825, 0.3001, 0.3177, 0.3317, 0.3531,
       0.3829, 0.4089, 0.4372, 0.4606, 0.4829, 0.4944, 0.504 , 0.5147,
       0.5243, 0.5335, 0.5423, 0.5521, 0.5608, 0.5719, 0.5826, 0.5922,
       0.6011, 0.6096, 0.6209, 0.6379, 0.6524, 0.6682, 0.682 , 0.6948,
       0.7084, 0.7207, 0.7314, 0.7362, 0.7407, 0.7456, 0.7506, 0.755 ,
       0.7594, 0.7626, 0.7668, 0.7698, 0.7725, 0.7745, 0.7765, 0.7775,
       0.7793, 0.7801, 0.781 , 0.7818, 0.7827, 0.7833, 0.7843, 0.7847,
       0.7852, 0.7858, 0.7861, 0.7868, 0.7874, 0.7882, 0.7887, 0.7891,
       0.7895, 0.7908, 0.7916, 0.7918, 0.7926, 0.7929, 0.7933, 0.7936,
       0.7941, 0.7949, 0.795 , 0.7954, 0.7957, 0.7962, 0.7969, 0.7976,
       0.7981, 0.7987, 0.7996, 0.8002, 0.8004, 0.801 , 0.8015, 0.8021,
       0.8025, 0.8029, 0.8034, 0.8041, 0.8045, 0.8052, 0.8059, 0.806 ,
       0.8066, 0.8071, 0.8079, 0.8087, 0.8089, 0.8093, 0.8093, 0.8095,
       0.8105, 0.8109, 0.8114, 0.8118, 0.8128, 0.8132, 0.8139, 0.8139,
       0.8144, 0.8149, 0.8154, 0.8162, 0.8167, 0.8173, 0.8177, 0.8185,
       0.8196, 0.82  , 0.821 , 0.8217, 0.8224, 0.8233, 0.8244, 0.8247,
       0.8254, 0.8262, 0.8267, 0.8274, 0.8277, 0.8288, 0.8294, 0.8298,
       0.8305, 0.8318, 0.8328, 0.8335, 0.8343, 0.8347, 0.8351, 0.8361,
       0.837 , 0.8376, 0.8385, 0.8398, 0.8404, 0.8413, 0.8419, 0.8427,
       0.8437, 0.8448, 0.8458, 0.8462, 0.8471, 0.8482, 0.8487, 0.8491,
       0.8498, 0.8505, 0.8507, 0.8511, 0.8519, 0.8526, 0.8534, 0.8542,
       0.855 , 0.8554, 0.8559, 0.8565, 0.857 , 0.8575, 0.8581, 0.8587,
       0.8592, 0.86  , 0.8605, 0.861 , 0.8615, 0.862 , 0.8629]
cotra_2020_pdf = np.append(np.array(cotra_2020_cdf[0]), np.diff(cotra_2020_cdf[:len(bins)]))
cotra_2020_pdf_smoothed = savitzky_golay(cotra_2020_pdf[:len(bins)], 51, 3)

cotra_2022_cdf = [0.0616, 0.0747, 0.0873, 0.1015, 0.118 , 0.1365, 0.1564, 0.1758,
       0.1981, 0.2188, 0.2531, 0.2768, 0.2975, 0.3193, 0.3481, 0.3728,
       0.4124, 0.433 , 0.4557, 0.4742, 0.4981, 0.5348, 0.569 , 0.6032,
       0.627 , 0.6404, 0.6507, 0.6611, 0.6701, 0.6801, 0.6893, 0.697 ,
       0.7051, 0.7115, 0.7186, 0.7252, 0.7331, 0.7411, 0.749 , 0.7577,
       0.7691, 0.7785, 0.7881, 0.799 , 0.807 , 0.8161, 0.8233, 0.8303,
       0.8348, 0.839 , 0.8429, 0.8462, 0.8494, 0.8517, 0.8532, 0.8553,
       0.8566, 0.8588, 0.8602, 0.862 , 0.8633, 0.864 , 0.8648, 0.8654,
       0.8662, 0.867 , 0.8672, 0.8677, 0.8683, 0.8686, 0.8689, 0.8689,
       0.8692, 0.8695, 0.8699, 0.8703, 0.8709, 0.8711, 0.8713, 0.8715,
       0.8719, 0.8721, 0.8727, 0.873 , 0.8736, 0.8739, 0.8742, 0.8746,
       0.875 , 0.8751, 0.8754, 0.8757, 0.8763, 0.8764, 0.8768, 0.8772,
       0.8775, 0.8775, 0.8776, 0.8779, 0.878 , 0.8781, 0.8783, 0.8789,
       0.8792, 0.8794, 0.8795, 0.8798, 0.8805, 0.8808, 0.8814, 0.8819,
       0.8822, 0.8826, 0.8827, 0.8828, 0.8832, 0.8834, 0.8837, 0.8839,
       0.8842, 0.8848, 0.8857, 0.8859, 0.8861, 0.8863, 0.8866, 0.8869,
       0.8869, 0.8873, 0.8878, 0.8889, 0.8896, 0.8904, 0.8906, 0.8911,
       0.8915, 0.892 , 0.8929, 0.8934, 0.8937, 0.8942, 0.8946, 0.8954,
       0.8959, 0.8963, 0.8969, 0.8972, 0.8975, 0.8984, 0.8988, 0.8993,
       0.8999, 0.9004, 0.9007, 0.9015, 0.9019, 0.9021, 0.9026, 0.9031,
       0.9037, 0.9041, 0.9048, 0.9054, 0.9057, 0.9062, 0.9067, 0.9075,
       0.9084, 0.9088, 0.909 , 0.9101, 0.9106, 0.9108, 0.9114, 0.9116,
       0.9121, 0.9127, 0.913 , 0.9137, 0.9144, 0.9147, 0.9154, 0.9159,
       0.9161, 0.9166, 0.9173, 0.9177, 0.9185, 0.9189, 0.9193, 0.9195,
       0.9195, 0.9198, 0.9204, 0.9205, 0.921 , 0.9216, 0.9221]
cotra_2022_pdf = np.append(np.array(cotra_2022_cdf[0]), np.diff(cotra_2022_cdf[:len(bins)]))
cotra_2022_pdf_smoothed = savitzky_golay(cotra_2022_pdf[:len(bins)], 51, 3)

peter_cdf = [0.0024, 0.0045, 0.0106, 0.0179, 0.0258, 0.0345, 0.0423, 0.0522,
       0.0638, 0.076 , 0.0885, 0.1028, 0.1165, 0.1332, 0.1498, 0.1669,
       0.1835, 0.2004, 0.2162, 0.2369, 0.2551, 0.2711, 0.2861, 0.3021,
       0.3184, 0.3314, 0.347 , 0.3589, 0.3729, 0.3882, 0.4022, 0.4142,
       0.4268, 0.4394, 0.4498, 0.4614, 0.471 , 0.4828, 0.4929, 0.5014,
       0.5097, 0.5179, 0.5275, 0.5359, 0.5456, 0.5545, 0.5634, 0.5711,
       0.5808, 0.5891, 0.5949, 0.6039, 0.6125, 0.6198, 0.6257, 0.6331,
       0.6392, 0.6453, 0.6503, 0.6571, 0.6629, 0.6684, 0.674 , 0.6803,
       0.6858, 0.6904, 0.6956, 0.7006, 0.7052, 0.7099, 0.7146, 0.7179,
       0.7209, 0.7253, 0.7293, 0.7325, 0.7352, 0.7388, 0.7421, 0.7448,
       0.7482, 0.7503, 0.7523, 0.7539, 0.7566, 0.7591, 0.7616, 0.7632,
       0.7667, 0.7685, 0.7699, 0.7714, 0.7729, 0.7749, 0.7769, 0.779 ,
       0.7808, 0.7829, 0.7849, 0.787 , 0.7878, 0.7895, 0.7902, 0.792 ,
       0.7931, 0.794 , 0.7952, 0.7967, 0.7981, 0.7993, 0.8003, 0.8021,
       0.8031, 0.8044, 0.8049, 0.8058, 0.8063, 0.8072, 0.8079, 0.8083,
       0.8091, 0.8096, 0.8101, 0.8111, 0.8116, 0.8126, 0.8131, 0.8142,
       0.815 , 0.8157, 0.8161, 0.817 , 0.8178, 0.8192, 0.8194, 0.8206,
       0.8209, 0.8211, 0.8217, 0.8221, 0.823 , 0.8234, 0.8237, 0.8245,
       0.825 , 0.8253, 0.8259, 0.8265, 0.8273, 0.8279, 0.8285, 0.8287,
       0.8294, 0.8297, 0.8302, 0.8302, 0.8311, 0.8315, 0.8316, 0.8318,
       0.832 , 0.8321, 0.8324, 0.8327, 0.8331, 0.8335, 0.8337, 0.8341,
       0.8342, 0.8344, 0.8347, 0.8349, 0.8353, 0.8359, 0.8365, 0.8371,
       0.8373, 0.8374, 0.8375, 0.8379, 0.8382, 0.8385, 0.8391, 0.8395,
       0.8398, 0.84  , 0.8406, 0.841 , 0.8413, 0.8417, 0.8419, 0.842 ,
       0.8426, 0.8427, 0.8432, 0.8434, 0.8439, 0.8444, 0.8448]
peter_pdf = np.append(np.array(peter_cdf[0]), np.diff(peter_cdf[:len(bins)]))
peter_pdf_smoothed = savitzky_golay(peter_pdf[:len(bins)], 51, 3)

plt.plot(bins[:99], cotra_2020_cdf[:99], label='Cotra 2020 CDF')
plt.plot(bins[:99], cotra_2022_cdf[:99], label='Cotra 2022 CDF (guess)')
plt.plot(bins[:99], peter_cdf[:99], label='Wildeford CDF')
plt.legend()
plt.show()

plt.plot(bins[:99], cotra_2020_pdf_smoothed[:99], label='Cotra 2020 PDF (smoothed)')
plt.plot(bins[:99], cotra_2022_pdf_smoothed[:99], label='Cotra 2022 PDF (guess, smoothed)')
plt.plot(bins[:99], peter_pdf_smoothed[:99], label='Wildeford PDF (smoothed)')
plt.legend()
plt.show()
# Out:
# <string>:111: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <string>:112: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## Sensitivity Analysis

# %%
print('## Default ##')
results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                      tai_flop_size_=36,
                                      nonscaling_delay_=0,
                                      algo_doubling_rate_=2,
                                      possible_algo_reduction_=2,
                                      initial_flops_per_dollar_=10 ** 18,
                                      flops_halving_rate_=2.5,
                                      max_flops_per_dollar_=10 ** 24,
                                      initial_pay_=10*M,
                                      gdp_growth_=1.03,
                                      max_gdp_frac_=1/1600,
                                      willingness_ramp_=1,
                                      spend_doubling_time_=2.5,
                                      initial_chance_of_nonscaling_issue_=0,
                                      final_chance_of_nonscaling_issue_=0,
                                      nonscaling_issue_bottom_year_=0,
                                      willingness_spend_horizon_=1,
                                      print_diagnostic=False), n=1000)
print('{}: {}'.format(t,
                      ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                       '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                       '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Default ##
# 59: [2067, 2067, 2067]

# %%
print('## TAI FLOP Size ##')
for t in range(20, 43):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=t,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(t,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## TAI FLOP Size ##
# 20: [2022, 2022, 2022]
# 21: [2022, 2022, 2022]
# 22: [2022, 2022, 2022]
# 23: [2022, 2022, 2022]
# 24: [2022, 2022, 2022]
# 25: [2023, 2023, 2023]
# 26: [2025, 2025, 2025]
# 27: [2028, 2028, 2028]
# 28: [2030, 2030, 2030]
# 29: [2033, 2033, 2033]
# 30: [2036, 2036, 2036]
# 31: [2040, 2040, 2040]
# 32: [2044, 2044, 2044]
# 33: [2048, 2048, 2048]
# 34: [2053, 2053, 2053]
# 35: [2060, 2060, 2060]
# 36: [2067, 2067, 2067]
# 37: [2091, 2091, 2091]
# 38: [2169, 2169, 2169]
# 39: ['>2222', '>2222', '>2222']
# 40: ['>2222', '>2222', '>2222']
# 41: ['>2222', '>2222', '>2222']
# 42: ['>2222', '>2222', '>2222']

# %%
print('## GDP Growth ##')
for g in range(0, 5):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1 + g/100,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + g / 100,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## GDP Growth ##
# 1.0: [2077, 2077, 2077]
# 1.01: [2072, 2072, 2072]
# 1.02: [2069, 2069, 2069]
# 1.03: [2067, 2067, 2067]
# 1.04: [2066, 2066, 2066]

# %%
print('## Max GDP Frac ##')
for g in [1/(500*K), 1/(250*K), 1/(100*K), 1/(50*K), 1/(10*K), 5/(10*K),
          1/2000, 1/1500, 1/1000, 2/1000, 3/1000, 4/1000, 5/1000, 1/100,
          2/100, 3/100, 4/100]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=g,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(g,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Max GDP Frac ##
# 2e-06: [2208, 2208, 2208]
# 4e-06: [2184, 2184, 2184]
# 1e-05: [2153, 2153, 2153]
# 2e-05: [2130, 2130, 2130]
# 0.0001: [2080, 2080, 2080]
# 0.0005: [2068, 2068, 2068]
# 0.0005: [2068, 2068, 2068]
# 0.0006666666666666666: [2067, 2067, 2067]
# 0.001: [2066, 2066, 2066]
# 0.002: [2064, 2064, 2064]
# 0.003: [2063, 2063, 2063]
# 0.004: [2062, 2062, 2062]
# 0.005: [2062, 2062, 2062]
# 0.01: [2061, 2061, 2061]
# 0.02: [2060, 2060, 2060]
# 0.03: [2060, 2060, 2060]
# 0.04: [2060, 2060, 2060]

# %%
print('## Spend Doubling Time ##')
for d in range(0, 50):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=1 + d / 10,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Spend Doubling Time ##
# 1.0: [2067, 2067, 2067]
# 1.1: [2067, 2067, 2067]
# 1.2: [2067, 2067, 2067]
# 1.3: [2067, 2067, 2067]
# 1.4: [2067, 2067, 2067]
# 1.5: [2067, 2067, 2067]
# 1.6: [2067, 2067, 2067]
# 1.7: [2067, 2067, 2067]
# 1.8: [2067, 2067, 2067]
# 1.9: [2067, 2067, 2067]
# 2.0: [2067, 2067, 2067]
# 2.1: [2067, 2067, 2067]
# 2.2: [2067, 2067, 2067]
# 2.3: [2067, 2067, 2067]
# 2.4: [2067, 2067, 2067]
# 2.5: [2067, 2067, 2067]
# 2.6: [2067, 2067, 2067]
# 2.7: [2068, 2068, 2068]
# 2.8: [2068, 2068, 2068]
# 2.9: [2068, 2068, 2068]
# 3.0: [2068, 2068, 2068]
# 3.1: [2068, 2068, 2068]
# 3.2: [2068, 2068, 2068]
# 3.3: [2069, 2069, 2069]
# 3.4: [2069, 2069, 2069]
# 3.5: [2069, 2069, 2069]
# 3.6: [2069, 2069, 2069]
# 3.7: [2070, 2070, 2070]
# 3.8: [2070, 2070, 2070]
# 3.9: [2071, 2071, 2071]
# 4.0: [2071, 2071, 2071]
# 4.1: [2071, 2071, 2071]
# 4.2: [2072, 2072, 2072]
# 4.3: [2072, 2072, 2072]
# 4.4: [2073, 2073, 2073]
# 4.5: [2073, 2073, 2073]
# 4.6: [2074, 2074, 2074]
# 4.7: [2074, 2074, 2074]
# 4.8: [2075, 2075, 2075]
# 4.9: [2076, 2076, 2076]
# 5.0: [2076, 2076, 2076]
# 5.1: [2077, 2077, 2077]
# 5.2: [2077, 2077, 2077]
# 5.3: [2078, 2078, 2078]
# 5.4: [2079, 2079, 2079]
# 5.5: [2080, 2080, 2080]
# 5.6: [2080, 2080, 2080]
# 5.7: [2081, 2081, 2081]
# 5.8: [2082, 2082, 2082]
# 5.9: [2083, 2083, 2083]

# %%
print('## Initial FLOPs per dollar ##')
for d in [17, 17.5, 18]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** d,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Initial FLOPs per dollar ##
# 17: [2075, 2075, 2075]
# 17.5: [2071, 2071, 2071]
# 18: [2067, 2067, 2067]

# %%
print('## Initial pay ##')
for p in range(70, 91):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10 ** (p / 10),
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('${}: {}'.format(numerize(10 ** (p / 10)),
                           ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                            '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                            '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Initial pay ##
# $10 million: [2067, 2067, 2067]
# $13 million: [2067, 2067, 2067]
# $16 million: [2067, 2067, 2067]
# $20 million: [2067, 2067, 2067]
# $25 million: [2067, 2067, 2067]
# $32 million: [2067, 2067, 2067]
# $40 million: [2067, 2067, 2067]
# $50 million: [2067, 2067, 2067]
# $63 million: [2067, 2067, 2067]
# $79 million: [2067, 2067, 2067]
# $100 million: [2067, 2067, 2067]
# $126 million: [2067, 2067, 2067]
# $158 million: [2067, 2067, 2067]
# $200 million: [2067, 2067, 2067]
# $251 million: [2067, 2067, 2067]
# $316 million: [2067, 2067, 2067]
# $398 million: [2067, 2067, 2067]
# $501 million: [2067, 2067, 2067]
# $631 million: [2067, 2067, 2067]
# $794 million: [2067, 2067, 2067]
# $1 billion: [2067, 2067, 2067]

# %%
print('## FLOPs halving rate ##')
for f in range(5, 41):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=f / 10,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## FLOPs halving rate ##
# 0.5: [2049, 2049, 2049]
# 0.6: [2049, 2049, 2049]
# 0.7: [2049, 2049, 2049]
# 0.8: [2049, 2049, 2049]
# 0.9: [2049, 2049, 2049]
# 1.0: [2049, 2049, 2049]
# 1.1: [2049, 2049, 2049]
# 1.2: [2050, 2050, 2050]
# 1.3: [2051, 2051, 2051]
# 1.4: [2052, 2052, 2052]
# 1.5: [2053, 2053, 2053]
# 1.6: [2054, 2054, 2054]
# 1.7: [2055, 2055, 2055]
# 1.8: [2057, 2057, 2057]
# 1.9: [2058, 2058, 2058]
# 2.0: [2060, 2060, 2060]
# 2.1: [2061, 2061, 2061]
# 2.2: [2063, 2063, 2063]
# 2.3: [2064, 2064, 2064]
# 2.4: [2066, 2066, 2066]
# 2.5: [2067, 2067, 2067]
# 2.6: [2069, 2069, 2069]
# 2.7: [2071, 2071, 2071]
# 2.8: [2072, 2072, 2072]
# 2.9: [2074, 2074, 2074]
# 3.0: [2075, 2075, 2075]
# 3.1: [2077, 2077, 2077]
# 3.2: [2078, 2078, 2078]
# 3.3: [2080, 2080, 2080]
# 3.4: [2081, 2081, 2081]
# 3.5: [2083, 2083, 2083]
# 3.6: [2084, 2084, 2084]
# 3.7: [2086, 2086, 2086]
# 3.8: [2087, 2087, 2087]
# 3.9: [2088, 2088, 2088]
# 4.0: [2090, 2090, 2090]

# %%
print('## Max FLOPs per dollar ##')
for f in range(20, 31):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** f,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Max FLOPs per dollar ##
# 20: ['>2222', '>2222', '>2222']
# 21: ['>2222', '>2222', '>2222']
# 22: [2169, 2169, 2169]
# 23: [2091, 2091, 2091]
# 24: [2067, 2067, 2067]
# 25: [2067, 2067, 2067]
# 26: [2067, 2067, 2067]
# 27: [2067, 2067, 2067]
# 28: [2067, 2067, 2067]
# 29: [2067, 2067, 2067]
# 30: [2067, 2067, 2067]

# %%
print('## Willingness ramp ##')
for r in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=r / 10,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Willingness ramp ##
# 0.1: [2060, 2060, 2060]
# 0.2: [2062, 2062, 2062]
# 0.3: [2063, 2063, 2063]
# 0.4: [2064, 2064, 2064]
# 0.5: [2065, 2065, 2065]
# 0.6: [2066, 2066, 2066]
# 0.7: [2066, 2066, 2066]
# 0.8: [2067, 2067, 2067]
# 0.9: [2067, 2067, 2067]
# 1.0: [2067, 2067, 2067]

# %%
print('## Willingness to spend horizon ##')
for y in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(y,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Willingness to spend horizon ##
# 1: [2067, 2067, 2067]
# 2: [2067, 2067, 2067]
# 3: [2066, 2066, 2066]
# 4: [2066, 2066, 2066]
# 5: [2066, 2066, 2066]
# 6: [2066, 2066, 2066]
# 7: [2066, 2066, 2066]
# 8: [2066, 2066, 2066]
# 9: [2066, 2066, 2066]
# 10: [2066, 2066, 2066]

# %%
print('## Algo doubling rate ##')
for d in range(10, 41, 2):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=d / 10,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Algo doubling rate ##
# 1.0: [2066, 2066, 2066]
# 1.2: [2066, 2066, 2066]
# 1.4: [2066, 2066, 2066]
# 1.6: [2066, 2066, 2066]
# 1.8: [2066, 2066, 2066]
# 2.0: [2066, 2066, 2066]
# 2.2: [2066, 2066, 2066]
# 2.4: [2066, 2066, 2066]
# 2.6: [2066, 2066, 2066]
# 2.8: [2067, 2067, 2067]
# 3.0: [2067, 2067, 2067]
# 3.2: [2067, 2067, 2067]
# 3.4: [2067, 2067, 2067]
# 3.6: [2067, 2067, 2067]
# 3.8: [2067, 2067, 2067]
# 4.0: [2067, 2067, 2067]

# %%
print('## Possible algo reduction ##')
for r in range(0, 13):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=r,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))
# Out:
# ## Possible algo reduction ##
# 0: [2101, 2101, 2101]
# 1: [2075, 2075, 2075]
# 2: [2066, 2066, 2066]
# 3: [2059, 2059, 2059]
# 4: [2054, 2054, 2054]
# 5: [2052, 2052, 2052]
# 6: [2051, 2051, 2051]
# 7: [2051, 2051, 2051]
# 8: [2051, 2051, 2051]
# 9: [2051, 2051, 2051]
# 10: [2051, 2051, 2051]
# 11: [2051, 2051, 2051]
# 12: [2051, 2051, 2051]

# %%
# TODO: Wildeford meta anchor horizon length
# TODO: Wildeford meta anchor efficiency w/ efficiency-based algorithmic reduction
# TODO: efficiency-based algorithmic reduction vs. regular algorithmic reduction

# %%
get_question(11558)
# Out:
# 11558 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates?
# 6192 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 1, 2031)
# Me -
# * Min: 1800
# * <Min: 0
# * Q1: 482363.462
# * Mid: 4955454.895
# * Q3: 14696518.042
# * >Max: 0.02200000000000002
# * Max: 10000000000
# Metaculus -
# * Min: 1800
# * <Min: 0.0
# * Q1: 3109866.189
# * Mid: 31948526.063
# * Q3: 281004112.704
# * >Max: 0.07401999999999997
# * Max: 10000000000
# -
# 6559 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 1, 2026)
# Me -
# * Min: 3640
# * <Min: 0
# * Q1: 330449.338
# * Mid: 899946.671
# * Q3: 1310339.199
# * >Max: 0.010000000000000009
# * Max: 1000000000
# Metaculus -
# * Min: 3640
# * <Min: 0.0
# * Q1: 618087.295
# * Mid: 5195921.5
# * Q3: 49506740.334
# * >Max: 0.12192999999999998
# * Max: 1000000000
# -
# 6517 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (February 14, 2023)
# Metaculus -
# * Min: 3640
# * <Min: 0.0
# * Q1: 17623.15
# * Mid: 51507.61
# * Q3: 150542.549
# * >Max: 0.029410000000000047
# * Max: 2000000
# -
# 6148 What will be the maximum compute (in petaFLOPS-days) ever used in training an AI experiment by the following dates? (January 14, 2022)
# Resolved as 320532.1027084993
# -

# %%
# https://www.metaculus.com/questions/11558/maximum-compute-used-in-ai-training/
# TODO: Fetch from Metaculus, look side by side
# TODO: Be able to predict back
for y in [2022, 2025, 2030]:
    print('-')
    print('## {} ##'.format(y))
    for i in range(3):
        flops_at_max_ = flops_at_max(initial_gdp=variables['initial_gdp'],
                                     gdp_growth=[1.02, 1.025, 1.03][i],
                                     initial_pay=[10*M, 100*M, 1*B][i],
                                     spend_doubling_time=[1, 2, 3][i],
                                     max_gdp_frac=[1/1000, 4/1000, 1/100][i],
                                     initial_flops_per_dollar=10 ** 18,
                                     max_flops_per_dollar=10 ** 24,
                                     flops_halving_rate=[2, 2.5, 3][i],
                                     year=(y - CURRENT_YEAR))

        print('{}: {} max log FLOPs / ~{} petaFLOP/s-days)'.format(['25th', 'mean', '75th'][i],
                                                                   np.round(np.log10(flops_at_max_), 1),
                                                                   log_flop_to_petaflop_sdays(np.log10(flops_at_max_))))
# Out:
# -
# ## 2022 ##
# 25th: 25.0 max log FLOPs / ~115686 petaFLOP/s-days)
# mean: 26.0 max log FLOPs / ~1156049 petaFLOP/s-days)
# 75th: 27.0 max log FLOPs / ~11519978 petaFLOP/s-days)
# -
# ## 2025 ##
# 25th: 26.4 max log FLOPs / ~2609670 petaFLOP/s-days)
# mean: 26.8 max log FLOPs / ~7497725 petaFLOP/s-days)
# 75th: 27.6 max log FLOPs / ~45901775 petaFLOP/s-days)
# -
# ## 2030 ##
# 25th: 28.6 max log FLOPs / ~429961423 petaFLOP/s-days)
# mean: 28.2 max log FLOPs / ~167592848 petaFLOP/s-days)
# 75th: 28.6 max log FLOPs / ~455905830 petaFLOP/s-days)
