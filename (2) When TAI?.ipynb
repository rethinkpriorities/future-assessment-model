# %% [markdown]
# ## Library

# %%
import math
import random

import numpy as np
import matplotlib.pyplot as plt

import squigglepy as sq
from squigglepy import bayes
from squigglepy.numbers import K, M, B, T

from copy import copy, deepcopy
from scipy import stats
from pprint import pprint
print('Loaded 1')

exec(open('utils.py').read())
print('Loaded 2')

exec(open('/Users/peterhurford/dev/forecastflow/library.py').read()) # TODO: Package?
print('Loaded 3')
# Out:
# Loaded 1
# Loaded 2
# Loaded 3

# %% [markdown]
# ## Variables (customize these)

# %%
# Customize these!!!

# Global variables - probably don't want to change these but you could.
RUNS = 10000                                      # Number of runs to do (default 1000)
CURRENT_YEAR = 2022                               # What year to start the run on? (default: 2022)
MAX_YEAR = 2222                                   # What year to end the run on? (default: 2100)
USE_NUMBERS = 'Wildeford'                         # Which variable set (see below) to use?
GRAPH_P = 50                                      # What percentile to graph on the graphs below? (default: 50)
VARIABLE_SETS = {}


VARIABLE_SETS['Cotra2020'] = {
    'initial_gdp': 21.3*T, # GDP in `CURRENT_YEAR` of country that will develop TAI (default: 21.3 trillion)
    'tai_flop_size': sq.sample(load_cache_file='caches/cotra_2020'),  # Cache generated in "Anchors" notebook
    # 90% CI, it takes 10^X FLOPs to run a transformative AI at inference.
    # Note: A petaflop/s-day (pfs-day) consists of performing 10^15 neural net operations per second for one day,
    # or a total of about 10^20 operations
    'algo_doubling_rate_max': 3.5,        # 90% CI, algorithms get twice as efficient every X years (maximum)
    'algo_doubling_rate_min': 2,          # 90% CI, algorithms get twice as efficient every X years (minimum)
    'min_reduction': 2,                   # 90% CI, the minimum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'max_reduction': 5,                   # 90% CI, the maximum amount of OOMs of reduction in TAI size algorithm improvements could acheive
    'initial_flops_per_dollar': 17,       # 90% CI, as of today, we can buy 10^X FLOPs per $
    'flops_halving_rate': 2.5,            # 90% CI, the cost of FLOPs per $ halves every X years
    'max_flops_per_dollar': 24,           # 90% CI, the cheapest FLOPs will get is 10^X FLOPs per $
    'initial_pay': 8.7,                   # 90% CI, as of today the maximum we would pay for TAI is $10^X
    'gdp_growth': 1.03,                   # 90% CI, GDP will increase by a factor of X each year
    'max_gdp_frac': 0.01,                 # 90% CI, the maximum % of GDP that would be spent on TAI is $10^X
    'spend_doubling_time': 2.5            # 90% CI, our willingness to spend on TAI doubles every X years
}


VARIABLE_SETS['Cotra2022'] = deepcopy(VARIABLE_SETS['Cotra2020'])
VARIABLE_SETS['Cotra2022']['tai_flop_size'] = sq.sample(load_cache_file='caches/cotra_2022')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Cotra2022']['initial_flops_per_dollar'] = sq.const(18)


def wildeford_max_gdp_frac():
    small_project = sq.lognorm(1 / (250*K), 1 / (3*K))
    modern_megaproject = sq.lognorm(1/K, 1/600)
    old_form_megaproject = sq.lognorm(1/500, 1/150)
    gigaproject = sq.lognorm(1/150, 1/50)
    
    r_ = random.random()
    if r_ < 0.1:
        gdp_frac = small_project
        percent_spent_on_compute = sq.lognorm(0.2,0.6, lclip=0.1, rclip=0.9)
    elif r_ < 0.8:
        gdp_frac = modern_megaproject
        percent_spent_on_compute = sq.lognorm(0.4,0.7, lclip=0.1, rclip=0.9)
    elif r_ < 0.95:
        gdp_frac = old_form_megaproject
        percent_spent_on_compute = sq.lognorm(0.5,0.9, lclip=0.1, rclip=0.9)
    else:
        gdp_frac = gigaproject
        percent_spent_on_compute = sq.lognorm(0.6,0.9, lclip=0.1, rclip=0.9)

    return ~gdp_frac * ~percent_spent_on_compute

VARIABLE_SETS['Wildeford'] = deepcopy(VARIABLE_SETS['Cotra2022'])
VARIABLE_SETS['Wildeford']['tai_flop_size'] = sq.sample(load_cache_file='caches/meta_anchor')  # Cache generated in "Anchors" notebook
VARIABLE_SETS['Wildeford']['flops_halving_rate'] = sq.lognorm(2, 5)
VARIABLE_SETS['Wildeford']['initial_pay'] = sq.mixture([[0.8, sq.const(7.1)],
                                                        [0.2, sq.lognorm(7.1,9, lclip=7.1)]]) #NEW
VARIABLE_SETS['Wildeford']['gdp_growth'] = sq.lognorm(1.015, 1.035) #NEW
VARIABLE_SETS['Wildeford']['max_gdp_frac'] = wildeford_max_gdp_frac #NEW
VARIABLE_SETS['Wildeford']['spend_doubling_time'] = sq.mixture([[0.8, sq.lognorm(3,6)],
                                                                [0.2, sq.lognorm(1,2, lclip=1)]]) #NEW
# TODO: Willingness to spend connected to commercialization
VARIABLE_SETS['Wildeford']['initial_chance_of_nonscaling_issue'] = 0.95 #NEW
VARIABLE_SETS['Wildeford']['final_chance_of_nonscaling_issue'] = 0.3 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_issue_bottom_year'] = 2050 #NEW
VARIABLE_SETS['Wildeford']['nonscaling_delay'] = sq.mixture([[0.7, sq.lognorm(2,10)],
                                                             [0.3, sq.lognorm(5,40)]]) #NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_max'] = sq.norm(1,3) # NEW
VARIABLE_SETS['Wildeford']['algo_doubling_rate_min'] = sq.norm(1,2) # NEW
VARIABLE_SETS['Wildeford']['min_reduction'] = 2 # TODO: Connect to efficiency within tai_flop_size / should correlate with tai_flop_size
VARIABLE_SETS['Wildeford']['max_reduction'] = 5


# These equations define how variables change over time or in relationship to other variables.
def gdp(initial_gdp, gdp_growth, year):
    return initial_gdp * (gdp_growth ** year)


def willingness_to_pay(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac, year):
    gdp_ = gdp(initial_gdp=initial_gdp, gdp_growth=gdp_growth, year=year)
    x = (np.log(2) / spend_doubling_time) * year
    if x < 650:
        y = math.log10(initial_pay) + math.log10(math.exp(x)) - math.log10(1 + initial_pay / (gdp_ * max_gdp_frac) * math.exp(x))
        if y > 300:
            y = int(y) # Handle overflow errors
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_pay) + (year/spend_doubling_time)/3.3)
    

def algo_halving_fn(min_speed, max_speed, tai_flop_size):
    if max_speed < min_speed:
        max_speed = min_speed
    if min_speed > max_speed:
        min_speed = max_speed
    return min(max(max_speed - (round((tai_flop_size - 29) / 2) / 2), min_speed), max_speed)


def flops_needed(initial_flops, possible_reduction, doubling_rate, year):
    x = (np.log(2) / doubling_rate) * year
    if x < 650:
        y = (math.log10(initial_flops) - max(math.log10(math.exp(x)) - math.log10(1 + (1/possible_reduction) * math.exp(x)), 0))
        if y > 300:
            y = int(y) # Handle overflow errors        
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops) - (1/possible_reduction))

    
def flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, halving_rate, year):
    x = (np.log(2) / halving_rate) * year
    if x < 650:
        y = (math.log10(initial_flops_per_dollar) + math.log10(math.exp(x)) - math.log10(1 + initial_flops_per_dollar / max_flops_per_dollar * math.exp(x)))
        if y > 300:
            y = int(y) # Handle overflow errors                
        return 10 ** y
    else: # Handle math.exp and math.log10 overflow errors
        return 10 ** int(math.log10(initial_flops_per_dollar) + (year/halving_rate)/3.3)

    
def cost_of_tai(initial_flops, possible_reduction, algo_doubling_rate, initial_flops_per_dollar, max_flops_per_dollar,
                flops_halving_rate, year):
    return (flops_needed(initial_flops, possible_reduction, algo_doubling_rate, year) /
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def flops_at_max(initial_gdp, gdp_growth, initial_pay, spend_doubling_time, max_gdp_frac,
                 initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year):
    return (willingness_to_pay(initial_gdp=initial_gdp,
                               gdp_growth=gdp_growth,
                               initial_pay=initial_pay,
                               spend_doubling_time=spend_doubling_time,
                               max_gdp_frac=max_gdp_frac,
                               year=year) *
            flops_per_dollar(initial_flops_per_dollar, max_flops_per_dollar, flops_halving_rate, year))


def possible_algo_reduction_fn(min_reduction, max_reduction, tai_flop_size):
    if max_reduction < min_reduction:
        max_reduction = min_reduction
    if min_reduction > max_reduction:
        min_reduction = max_reduction
    return min(max(min_reduction + round((tai_flop_size - 32) / 4), min_reduction), max_reduction)


# NEW
def p_nonscaling_delay(initial_p, final_p, year, max_year):
    return generalized_logistic_curve(x=year - CURRENT_YEAR,
                                      slope=0.3,
                                      shift=3 * (max_year - CURRENT_YEAR),
                                      push=1,
                                      maximum=final_p,
                                      minimum=initial_p)
    

# ------------- Ignore below here ------------
years = list(range(CURRENT_YEAR, MAX_YEAR))
variables = VARIABLE_SETS[USE_NUMBERS]
print('Loaded')
# Out:
# Loaded

# %%
initial_flop_size_s = variables['tai_flop_size']
initial_flops_p = sq.get_percentiles(initial_flop_size_s)
plt.hist(initial_flop_size_s, bins = 200)
pprint(initial_flops_p)
# Out:
# {1: 20.045682037721935,
#  5: 24.060911735587453,
#  10: 25.292763406013908,
#  20: 26.905575948274755,
#  30: 28.730688119443748,
#  40: 30.73025347871559,
#  50: 32.54306015655732,
#  60: 34.48093681248623,
#  70: 36.63812523525167,
#  80: 39.209648394722635,
#  90: 42.86429739184473,
#  95: 45.79532218086243,
#  99: 52.376143622331945}

# %%
min_reduction_p = sq.get_percentiles(sq.sample(variables['min_reduction'], n=1000))
min_reduction_p
# Out:
# {1: 2.0,
#  5: 2.0,
#  10: 2.0,
#  20: 2.0,
#  30: 2.0,
#  40: 2.0,
#  50: 2.0,
#  60: 2.0,
#  70: 2.0,
#  80: 2.0,
#  90: 2.0,
#  95: 2.0,
#  99: 2.0}

# %%
max_reduction_p = sq.get_percentiles(sq.sample(variables['max_reduction'], n=1000), reverse=True)
max_reduction_p
# Out:
# {99: 5.0,
#  95: 5.0,
#  90: 5.0,
#  80: 5.0,
#  70: 5.0,
#  60: 5.0,
#  50: 5.0,
#  40: 5.0,
#  30: 5.0,
#  20: 5.0,
#  10: 5.0,
#  5: 5.0,
#  1: 5.0}

# %%
algo_doubling_rate_min_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_min'], n=1000), reverse=True)
algo_doubling_rate_min_p
# Out:
# {99: 0.8212246775387119,
#  95: 1.0007230556057085,
#  90: 1.1063065093266076,
#  80: 1.2347571303431857,
#  70: 1.3282852926586879,
#  60: 1.4173630581761771,
#  50: 1.501484662219296,
#  40: 1.5845260665223044,
#  30: 1.6699456937016168,
#  20: 1.7584379423862941,
#  10: 1.9003216440614634,
#  5: 2.0005605883335926,
#  1: 2.238745235325454}

# %%
algo_doubling_rate_max_p = sq.get_percentiles(sq.sample(variables['algo_doubling_rate_max'], n=1000), reverse=True)
algo_doubling_rate_max_p
# Out:
# {99: 0.5927358516425412,
#  95: 0.9801465152453736,
#  90: 1.196309073994382,
#  80: 1.4908576673480476,
#  70: 1.6938014788737397,
#  60: 1.8467229344540643,
#  50: 1.9670238438944077,
#  40: 2.1212675995543866,
#  30: 2.3097932553870315,
#  20: 2.516123688021767,
#  10: 2.774211209926692,
#  5: 3.0025515988037617,
#  1: 3.501657150038087}

# %%
initial_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['initial_flops_per_dollar'], n=1000))
initial_flops_per_dollar_p
# Out:
# {1: 18.0,
#  5: 18.0,
#  10: 18.0,
#  20: 18.0,
#  30: 18.0,
#  40: 18.0,
#  50: 18.0,
#  60: 18.0,
#  70: 18.0,
#  80: 18.0,
#  90: 18.0,
#  95: 18.0,
#  99: 18.0}

# %%
flops_halving_rate_p = sq.get_percentiles(sq.sample(variables['flops_halving_rate'], n=1000), reverse=True)
flops_halving_rate_p
# Out:
# {99: 1.6802445350873034,
#  95: 2.065177563264124,
#  90: 2.2542340735157587,
#  80: 2.490816569390878,
#  70: 2.7285738022590196,
#  60: 2.932244630538737,
#  50: 3.158387333982081,
#  40: 3.3934687786114237,
#  30: 3.682584870655728,
#  20: 4.031486665492008,
#  10: 4.529394817531632,
#  5: 5.025727327406026,
#  1: 5.890877824975541}

# %%
max_flops_per_dollar_p = sq.get_percentiles(sq.sample(variables['max_flops_per_dollar'], n=1000))
max_flops_per_dollar_p
# Out:
# {1: 24.0,
#  5: 24.0,
#  10: 24.0,
#  20: 24.0,
#  30: 24.0,
#  40: 24.0,
#  50: 24.0,
#  60: 24.0,
#  70: 24.0,
#  80: 24.0,
#  90: 24.0,
#  95: 24.0,
#  99: 24.0}

# %%
initial_pay_p = sq.get_percentiles(sq.sample(variables['initial_pay'], n=1000))
initial_pay_p
# Out:
# {1: 7.1,
#  5: 7.1,
#  10: 7.1,
#  20: 7.1,
#  30: 7.1,
#  40: 7.1,
#  50: 7.1,
#  60: 7.1,
#  70: 7.1,
#  80: 7.12761149479101,
#  90: 8.166100935824327,
#  95: 8.536469166603194,
#  99: 9.141191175078916}

# %%
gdp_growth_p = sq.get_percentiles(sq.sample(variables['gdp_growth'], n=1000))
gdp_growth_p
# Out:
# {1: 1.0111827291920965,
#  5: 1.0152677841034503,
#  10: 1.0178004891208268,
#  20: 1.0199345449404438,
#  30: 1.0217560724839263,
#  40: 1.0233814018194063,
#  50: 1.0248715544577378,
#  60: 1.0264200915035369,
#  70: 1.0278883780902097,
#  80: 1.03001107137573,
#  90: 1.032781025064811,
#  95: 1.0345784547212307,
#  99: 1.0375761087050035}

# %%
max_gdp_frac_p = sq.get_percentiles(sq.sample(variables['max_gdp_frac'], n=1000))
max_gdp_frac_p
# Out:
# {1: 2.035670935278237e-06,
#  5: 1.1047634653515157e-05,
#  10: 0.0003253857611472698,
#  20: 0.0005198164096757356,
#  30: 0.0005913226701700817,
#  40: 0.0006498147311590085,
#  50: 0.000700227804330728,
#  60: 0.0007630069588189971,
#  70: 0.0008695906305743532,
#  80: 0.001137557081089475,
#  90: 0.002541644307269019,
#  95: 0.00453898001482202,
#  99: 0.011925923023734764}

# %%
willingness_ramp = variables.get('willingness_ramp', 0)
if willingness_ramp != 0:
    willingness_ramp_p = sq.get_percentiles(sq.sample(willingness_ramp), n=1000)
    pprint(willingness_ramp_p)
else:
    print(0)
# Out:
# 0

# %%
spend_doubling_time_p = sq.get_percentiles(sq.sample(variables['spend_doubling_time'], n=1000), reverse=True)
spend_doubling_time_p
# Out:
# {99: 1.0275716208785515,
#  95: 1.2440132512066708,
#  90: 1.3835319467563314,
#  80: 2.3035680428716563,
#  70: 3.406850370137363,
#  60: 3.730200263084487,
#  50: 4.019523959400935,
#  40: 4.280285040299074,
#  30: 4.585106882931971,
#  20: 4.9555844019148285,
#  10: 5.49858393903104,
#  5: 5.969229369584842,
#  1: 6.8071035280500665}

# %%
nonscaling_delay = variables.get('nonscaling_delay', 0)
if nonscaling_delay != 0:
    nonscaling_delay_p = sq.get_percentiles(np.ceil(sq.sample(nonscaling_delay, n=1000)), reverse=True)
    pprint(nonscaling_delay_p)
else:
    print(0)
# Out:
# {1: 48.00999999999999,
#  5: 28.0,
#  10: 21.0,
#  20: 12.0,
#  30: 9.0,
#  40: 7.0,
#  50: 6.0,
#  60: 5.0,
#  70: 5.0,
#  80: 4.0,
#  90: 3.0,
#  95: 3.0,
#  99: 2.0}

# %%
willingness_spend_horizon = variables.get('willingness_spend_horizon', 1)
if willingness_spend_horizon != 1:
    willingness_spend_horizon_p = sq.get_percentiles(sq.sample(willingness_spend_horizon, n=1000))
    pprint(willingness_spend_horizon_p)
else:
    print(1)
# Out:
# 1

# %% [markdown]
# ## GDP Over Time

# %%
gdp_ = np.array([gdp(initial_gdp=variables['initial_gdp'],
                     gdp_growth=gdp_growth_p[GRAPH_P],
                     year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(gdp_))
                                               spend_doubling_time=spend_doubling_time_p[p],
                                               max_gdp_frac=max_gdp_frac_p[p],
                                               year=(y - CURRENT_YEAR)) for y in years])
    for y in years:
        print('Year: {} - willingness log 2022$USD per year {} (~{})'.format(y,
                                                                             np.round(np.log10(willingness[y - CURRENT_YEAR]), 1),
                                                                             numerize(willingness[y - CURRENT_YEAR])))


    plt.plot(years, np.log10(willingness))
plt.ylabel('log 2022$USD/yr willing to spend on TAI')
plt.show()
# Out:
# -
# -
# ## 20 ##
# Year: 2022 - willingness log 2022$USD per year 7.1 (~13 million)
# Year: 2023 - willingness log 2022$USD per year 7.2 (~14 million)
# Year: 2024 - willingness log 2022$USD per year 7.2 (~17 million)
# Year: 2025 - willingness log 2022$USD per year 7.3 (~19 million)
# Year: 2026 - willingness log 2022$USD per year 7.3 (~22 million)
# Year: 2027 - willingness log 2022$USD per year 7.4 (~25 million)
# Year: 2028 - willingness log 2022$USD per year 7.5 (~29 million)
# Year: 2029 - willingness log 2022$USD per year 7.5 (~33 million)
# Year: 2030 - willingness log 2022$USD per year 7.6 (~38 million)
# Year: 2031 - willingness log 2022$USD per year 7.6 (~44 million)
# Year: 2032 - willingness log 2022$USD per year 7.7 (~51 million)
# Year: 2033 - willingness log 2022$USD per year 7.8 (~58 million)
# Year: 2034 - willingness log 2022$USD per year 7.8 (~67 million)
# Year: 2035 - willingness log 2022$USD per year 7.9 (~77 million)
# Year: 2036 - willingness log 2022$USD per year 7.9 (~89 million)
# Year: 2037 - willingness log 2022$USD per year 8.0 (~102 million)
# Year: 2038 - willingness log 2022$USD per year 8.1 (~117 million)
# Year: 2039 - willingness log 2022$USD per year 8.1 (~135 million)
# Year: 2040 - willingness log 2022$USD per year 8.2 (~155 million)
# Year: 2041 - willingness log 2022$USD per year 8.2 (~178 million)
# Year: 2042 - willingness log 2022$USD per year 8.3 (~204 million)
# Year: 2043 - willingness log 2022$USD per year 8.4 (~234 million)
# Year: 2044 - willingness log 2022$USD per year 8.4 (~269 million)
# Year: 2045 - willingness log 2022$USD per year 8.5 (~309 million)
# Year: 2046 - willingness log 2022$USD per year 8.5 (~354 million)
# Year: 2047 - willingness log 2022$USD per year 8.6 (~406 million)
# Year: 2048 - willingness log 2022$USD per year 8.7 (~466 million)
# Year: 2049 - willingness log 2022$USD per year 8.7 (~534 million)
# Year: 2050 - willingness log 2022$USD per year 8.8 (~612 million)
# Year: 2051 - willingness log 2022$USD per year 8.8 (~701 million)
# Year: 2052 - willingness log 2022$USD per year 8.9 (~803 million)
# Year: 2053 - willingness log 2022$USD per year 9.0 (~919 million)
# Year: 2054 - willingness log 2022$USD per year 9.0 (~1 billion)
# Year: 2055 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2056 - willingness log 2022$USD per year 9.1 (~1 billion)
# Year: 2057 - willingness log 2022$USD per year 9.2 (~2 billion)
# Year: 2058 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2059 - willingness log 2022$USD per year 9.3 (~2 billion)
# Year: 2060 - willingness log 2022$USD per year 9.4 (~2 billion)
# Year: 2061 - willingness log 2022$USD per year 9.4 (~3 billion)
# Year: 2062 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2063 - willingness log 2022$USD per year 9.5 (~3 billion)
# Year: 2064 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2065 - willingness log 2022$USD per year 9.6 (~4 billion)
# Year: 2066 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2067 - willingness log 2022$USD per year 9.7 (~5 billion)
# Year: 2068 - willingness log 2022$USD per year 9.8 (~6 billion)
# Year: 2069 - willingness log 2022$USD per year 9.8 (~7 billion)
# Year: 2070 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 2071 - willingness log 2022$USD per year 9.9 (~8 billion)
# Year: 
- willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2169 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2170 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2171 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2172 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2173 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2174 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2175 - willingness log 2022$USD per year 12.3 (~2 trillion)
# Year: 2176 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2177 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2178 - willingness log 2022$USD per year 12.4 (~2 trillion)
# Year: 2179 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2180 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2181 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2182 - willingness log 2022$USD per year 12.4 (~3 trillion)
# Year: 2183 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2184 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2185 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2186 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2187 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2188 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2189 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2190 - willingness log 2022$USD per year 12.5 (~3 trillion)
# Year: 2191 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2192 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2193 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2194 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2195 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2196 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2197 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2198 - willingness log 2022$USD per year 12.6 (~4 trillion)
# Year: 2199 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2200 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2201 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2202 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2203 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2204 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2205 - willingness log 2022$USD per year 12.7 (~5 trillion)
# Year: 2206 - willingness log 2022$USD per year 12.7 (~6 trillion)
# Year: 2207 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2208 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2209 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2210 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2211 - willingness log 2022$USD per year 12.8 (~6 trillion)
# Year: 2212 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2213 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2214 - willingness log 2022$USD per year 12.8 (~7 trillion)
# Year: 2215 - willingness log 2022$USD per year 12.9 (~7 trillion)
# Year: 2216 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2217 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2218 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2219 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2220 - willingness log 2022$USD per year 12.9 (~8 trillion)
# Year: 2221 - willingness log 2022$USD per year 12.9 (~9 trillion)

# %% [markdown]
# ## FLOPs Needed to Make TAI (Given Algorithmic Progress)

# %%
flops_ = np.array([flops_needed(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                              algo_doubling_rate_max_p[GRAPH_P],
                                                              initial_flops_p[GRAPH_P]),
                                possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                    max_reduction_p[GRAPH_P],
                                                                                    initial_flops_p[GRAPH_P]),
                                year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_))
plt.ylabel('log FLOPs needed to make TAI')
# Out:
# Text(0, 0.5, 'log FLOPs needed to make TAI')

# %%
for y in years:
    print('Year: {} - log FLOPs needed for TAI {} (~{})'.format(y,
                                                                np.round(np.log10(flops_[y - CURRENT_YEAR]), 1),
                                                                numerize(flops_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log FLOPs needed for TAI 32.5 (~349 nonillion)
# Year: 2023 - log FLOPs needed for TAI 32.3 (~224 nonillion)
# Year: 2024 - log FLOPs needed for TAI 32.2 (~142 nonillion)
# Year: 2025 - log FLOPs needed for TAI 32.0 (~91 nonillion)
# Year: 2026 - log FLOPs needed for TAI 31.8 (~59 nonillion)
# Year: 2027 - log FLOPs needed for TAI 31.6 (~38 nonillion)
# Year: 2028 - log FLOPs needed for TAI 31.4 (~25 nonillion)
# Year: 2029 - log FLOPs needed for TAI 31.2 (~17 nonillion)
# Year: 2030 - log FLOPs needed for TAI 31.1 (~12 nonillion)
# Year: 2031 - log FLOPs needed for TAI 31.0 (~9 nonillion)
# Year: 2032 - log FLOPs needed for TAI 30.8 (~7 nonillion)
# Year: 2033 - log FLOPs needed for TAI 30.8 (~6 nonillion)
# Year: 2034 - log FLOPs needed for TAI 30.7 (~5 nonillion)
# Year: 2035 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2036 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2037 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2038 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2039 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2040 - log FLOPs needed for TAI 30.6 (~4 nonillion)
# Year: 2041 - log FLOPs needed for TAI 30.5 (~4 nonillion)
# Year: 2042 - log FLOPs needed for TAI 30.5 (~4 nonillion)
# Year: 2043 - log FLOPs needed for TAI 30.5 (~4 nonillion)
# Year: 2044 - log FLOPs needed for TAI 30.5 (~4 nonillion)
# Year: 2045 - log FLOPs needed for TAI 30.5 (~4 nonillion)
# Year: 2046 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2047 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2048 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2049 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2050 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2051 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2052 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2053 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2054 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2055 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2056 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2057 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2058 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2059 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2060 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2061 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2062 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2063 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2064 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2065 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2066 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2067 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2068 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2069 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2070 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2071 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2072 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2073 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2074 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2075 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2076 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2077 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2078 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2079 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2080 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2081 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2082 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2083 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2084 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2085 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2086 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2087 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2088 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2089 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2090 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2091 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2092 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2093 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2094 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2095 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2096 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2097 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2098 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2099 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2100 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2101 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2102 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2103 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2104 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2105 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2106 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2107 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2108 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2109 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2110 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2111 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2112 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2113 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2114 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2115 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2116 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2117 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2118 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2119 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2120 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2121 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2122 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2123 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2124 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2125 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2126 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2127 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2128 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2129 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2130 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2131 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2132 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2133 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2134 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2135 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2136 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2137 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2138 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2139 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2140 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2141 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2142 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2143 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2144 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2145 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2146 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2147 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2148 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2149 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2150 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2151 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2152 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2153 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2154 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2155 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2156 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2157 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2158 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2159 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2160 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2161 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2162 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2163 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2164 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2165 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2166 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2167 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2168 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2169 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2170 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2171 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2172 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2173 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2174 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2175 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2176 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2177 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2178 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2179 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2180 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2181 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2182 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2183 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2184 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2185 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2186 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2187 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2188 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2189 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2190 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2191 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2192 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2193 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2194 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2195 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2196 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2197 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2198 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2199 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2200 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2201 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2202 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2203 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2204 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2205 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2206 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2207 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2208 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2209 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2210 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2211 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2212 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2213 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2214 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2215 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2216 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2217 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2218 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2219 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2220 - log FLOPs needed for TAI 30.5 (~3 nonillion)
# Year: 2221 - log FLOPs needed for TAI 30.5 (~3 nonillion)

# %% [markdown]
# ## FLOPs per Dollar (Given Declining Costs)

# %%
flops_per_dollar_ = np.array([flops_per_dollar(initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                               max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                               halving_rate=flops_halving_rate_p[GRAPH_P],
                                               year=(y - CURRENT_YEAR)) for y in years])
plt.plot(years, np.log10(flops_per_dollar_))
plt.ylabel('log FLOPs per $1')
# Out:
# Text(0, 0.5, 'log FLOPs per $1')

# %%
for y in years:
    print('Year: {} - log {} FLOPs per $ (~{})'.format(y,
                                                       np.round(np.log10(flops_per_dollar_[y - CURRENT_YEAR]), 1),
                                                       numerize(flops_per_dollar_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log 18.0 FLOPs per $ (~1000 quadrillion)
# Year: 2023 - log 18.1 FLOPs per $ (~1 quintillion)
# Year: 2024 - log 18.2 FLOPs per $ (~2 quintillion)
# Year: 2025 - log 18.3 FLOPs per $ (~2 quintillion)
# Year: 2026 - log 18.4 FLOPs per $ (~2 quintillion)
# Year: 2027 - log 18.5 FLOPs per $ (~3 quintillion)
# Year: 2028 - log 18.6 FLOPs per $ (~4 quintillion)
# Year: 2029 - log 18.7 FLOPs per $ (~5 quintillion)
# Year: 2030 - log 18.8 FLOPs per $ (~6 quintillion)
# Year: 2031 - log 18.9 FLOPs per $ (~7 quintillion)
# Year: 2032 - log 19.0 FLOPs per $ (~9 quintillion)
# Year: 2033 - log 19.0 FLOPs per $ (~11 quintillion)
# Year: 2034 - log 19.1 FLOPs per $ (~14 quintillion)
# Year: 2035 - log 19.2 FLOPs per $ (~17 quintillion)
# Year: 2036 - log 19.3 FLOPs per $ (~22 quintillion)
# Year: 2037 - log 19.4 FLOPs per $ (~27 quintillion)
# Year: 2038 - log 19.5 FLOPs per $ (~33 quintillion)
# Year: 2039 - log 19.6 FLOPs per $ (~42 quintillion)
# Year: 2040 - log 19.7 FLOPs per $ (~52 quintillion)
# Year: 2041 - log 19.8 FLOPs per $ (~65 quintillion)
# Year: 2042 - log 19.9 FLOPs per $ (~81 quintillion)
# Year: 2043 - log 20.0 FLOPs per $ (~100 quintillion)
# Year: 2044 - log 20.1 FLOPs per $ (~125 quintillion)
# Year: 2045 - log 20.2 FLOPs per $ (~156 quintillion)
# Year: 2046 - log 20.3 FLOPs per $ (~194 quintillion)
# Year: 2047 - log 20.4 FLOPs per $ (~241 quintillion)
# Year: 2048 - log 20.5 FLOPs per $ (~301 quintillion)
# Year: 2049 - log 20.6 FLOPs per $ (~374 quintillion)
# Year: 2050 - log 20.7 FLOPs per $ (~466 quintillion)
# Year: 2051 - log 20.8 FLOPs per $ (~580 quintillion)
# Year: 2052 - log 20.9 FLOPs per $ (~723 quintillion)
# Year: 2053 - log 21.0 FLOPs per $ (~900 quintillion)
# Year: 2054 - log 21.0 FLOPs per $ (~1 sextillion)
# Year: 2055 - log 21.1 FLOPs per $ (~1 sextillion)
# Year: 2056 - log 21.2 FLOPs per $ (~2 sextillion)
# Year: 2057 - log 21.3 FLOPs per $ (~2 sextillion)
# Year: 2058 - log 21.4 FLOPs per $ (~3 sextillion)
# Year: 2059 - log 21.5 FLOPs per $ (~3 sextillion)
# Year: 2060 - log 21.6 FLOPs per $ (~4 sextillion)
# Year: 2061 - log 21.7 FLOPs per $ (~5 sextillion)
# Year: 2062 - log 21.8 FLOPs per $ (~6 sextillion)
# Year: 2063 - log 21.9 FLOPs per $ (~8 sextillion)
# Year: 2064 - log 22.0 FLOPs per $ (~10 sextillion)
# Year: 2065 - log 22.1 FLOPs per $ (~12 sextillion)
# Year: 2066 - log 22.2 FLOPs per $ (~15 sextillion)
# Year: 2067 - log 22.3 FLOPs per $ (~19 sextillion)
# Year: 2068 - log 22.4 FLOPs per $ (~24 sextillion)
# Year: 2069 - log 22.5 FLOPs per $ (~29 sextillion)
# Year: 2070 - log 22.6 FLOPs per $ (~36 sextillion)
# Year: 2071 - log 22.7 FLOPs per $ (~45 sextillion)
# Year: 2072 - log 22.7 FLOPs per $ (~55 sextillion)
# Year: 2073 - log 22.8 FLOPs per $ (~68 sextillion)
# Year: 2074 - log 22.9 FLOPs per $ (~83 sextillion)
# Year: 2075 - log 23.0 FLOPs per $ (~101 sextillion)
# Year: 2076 - log 23.1 FLOPs per $ (~123 sextillion)
# Year: 2077 - log 23.2 FLOPs per $ (~149 sextillion)
# Year: 2078 - log 23.3 FLOPs per $ (~179 sextillion)
# Year: 2079 - log 23.3 FLOPs per $ (~213 sextillion)
# Year: 2080 - log 23.4 FLOPs per $ (~252 sextillion)
# Year: 2081 - log 23.5 FLOPs per $ (~296 sextillion)
# Year: 2082 - log 23.5 FLOPs per $ (~343 sextillion)
# Year: 2083 - log 23.6 FLOPs per $ (~395 sextillion)
# Year: 2084 - log 23.7 FLOPs per $ (~448 sextillion)
# Year: 2085 - log 23.7 FLOPs per $ (~503 sextillion)
# Year: 2086 - log 23.7 FLOPs per $ (~557 sextillion)
# Year: 2087 - log 23.8 FLOPs per $ (~611 sextillion)
# Year: 2088 - log 23.8 FLOPs per $ (~661 sextillion)
# Year: 2089 - log 23.9 FLOPs per $ (~709 sextillion)
# Year: 2090 - log 23.9 FLOPs per $ (~752 sextillion)
# Year: 2091 - log 23.9 FLOPs per $ (~790 sextillion)
# Year: 2092 - log 23.9 FLOPs per $ (~824 sextillion)
# Year: 2093 - log 23.9 FLOPs per $ (~854 sextillion)
# Year: 2094 - log 23.9 FLOPs per $ (~879 sextillion)
# Year: 2095 - log 24.0 FLOPs per $ (~901 sextillion)
# Year: 2096 - log 24.0 FLOPs per $ (~919 sextillion)
# Year: 2097 - log 24.0 FLOPs per $ (~934 sextillion)
# Year: 2098 - log 24.0 FLOPs per $ (~946 sextillion)
# Year: 2099 - log 24.0 FLOPs per $ (~956 sextillion)
# Year: 2100 - log 24.0 FLOPs per $ (~965 sextillion)
# Year: 2101 - log 24.0 FLOPs per $ (~971 sextillion)
# Year: 2102 - log 24.0 FLOPs per $ (~977 sextillion)
# Year: 2103 - log 24.0 FLOPs per $ (~981 sextillion)
# Year: 2104 - log 24.0 FLOPs per $ (~985 sextillion)
# Year: 2105 - log 24.0 FLOPs per $ (~988 sextillion)
# Year: 2106 - log 24.0 FLOPs per $ (~990 sextillion)
# Year: 2107 - log 24.0 FLOPs per $ (~992 sextillion)
# Year: 2108 - log 24.0 FLOPs per $ (~994 sextillion)
# Year: 2109 - log 24.0 FLOPs per $ (~995 sextillion)
# Year: 2110 - log 24.0 FLOPs per $ (~996 sextillion)
# Year: 2111 - log 24.0 FLOPs per $ (~997 sextillion)
# Year: 2112 - log 24.0 FLOPs per $ (~997 sextillion)
# Year: 2113 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2114 - log 24.0 FLOPs per $ (~998 sextillion)
# Year: 2115 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2116 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2117 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2118 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2119 - log 24.0 FLOPs per $ (~999 sextillion)
# Year: 2120 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2121 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2122 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2123 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2124 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2125 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2126 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2127 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2128 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2129 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2130 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2131 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2132 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2133 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2134 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2135 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2136 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2137 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2138 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2139 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2140 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2141 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2142 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2143 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2144 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2145 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2146 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2147 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2148 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2149 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2150 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2151 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2152 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2153 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2154 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2155 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2156 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2157 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2158 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2159 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2160 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2161 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2162 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2163 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2164 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2165 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2166 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2167 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2168 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2169 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2170 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2171 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2172 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2173 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2174 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2175 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2176 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2177 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2178 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2179 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2180 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2181 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2182 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2183 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2184 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2185 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2186 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2187 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2188 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2189 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2190 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2191 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2192 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2193 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2194 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2195 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2196 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2197 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2198 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2199 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2200 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2201 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2202 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2203 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2204 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2205 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2206 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2207 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2208 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2209 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2210 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2211 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2212 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2213 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2214 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2215 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2216 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2217 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2218 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2219 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2220 - log 24.0 FLOPs per $ (~1000 sextillion)
# Year: 2221 - log 24.0 FLOPs per $ (~1000 sextillion)

# %% [markdown]
# ## Max Possible OOM Reduction in TAI FLOP Size

# %%
# TODO: Update to include efficiency based
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                         max_reduction_p[GRAPH_P], t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('max OOM reduction')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> {} OOM reductions possible'.format(t,
                                                                 round(possible_algo_reduction_fn(min_reduction_p[GRAPH_P],
                                                                                                  max_reduction_p[GRAPH_P],
                                                                                                  t), 2)))
# Out:
# TAI log FLOP 24 -> 2.0 OOM reductions possible
# TAI log FLOP 25 -> 2.0 OOM reductions possible
# TAI log FLOP 26 -> 2.0 OOM reductions possible
# TAI log FLOP 27 -> 2.0 OOM reductions possible
# TAI log FLOP 28 -> 2.0 OOM reductions possible
# TAI log FLOP 29 -> 2.0 OOM reductions possible
# TAI log FLOP 30 -> 2.0 OOM reductions possible
# TAI log FLOP 31 -> 2.0 OOM reductions possible
# TAI log FLOP 32 -> 2.0 OOM reductions possible
# TAI log FLOP 33 -> 2.0 OOM reductions possible
# TAI log FLOP 34 -> 2.0 OOM reductions possible
# TAI log FLOP 35 -> 3.0 OOM reductions possible
# TAI log FLOP 36 -> 3.0 OOM reductions possible
# TAI log FLOP 37 -> 3.0 OOM reductions possible
# TAI log FLOP 38 -> 4.0 OOM reductions possible
# TAI log FLOP 39 -> 4.0 OOM reductions possible
# TAI log FLOP 40 -> 4.0 OOM reductions possible
# TAI log FLOP 41 -> 4.0 OOM reductions possible
# TAI log FLOP 42 -> 4.0 OOM reductions possible
# TAI log FLOP 43 -> 5.0 OOM reductions possible
# TAI log FLOP 44 -> 5.0 OOM reductions possible
# TAI log FLOP 45 -> 5.0 OOM reductions possible
# TAI log FLOP 46 -> 5.0 OOM reductions possible
# TAI log FLOP 47 -> 5.0 OOM reductions possible
# TAI log FLOP 48 -> 5.0 OOM reductions possible
# TAI log FLOP 49 -> 5.0 OOM reductions possible
# TAI log FLOP 50 -> 5.0 OOM reductions possible
# TAI log FLOP 51 -> 5.0 OOM reductions possible
# TAI log FLOP 52 -> 5.0 OOM reductions possible
# TAI log FLOP 53 -> 5.0 OOM reductions possible
# TAI log FLOP 54 -> 5.0 OOM reductions possible
# TAI log FLOP 55 -> 5.0 OOM reductions possible
# TAI log FLOP 56 -> 5.0 OOM reductions possible
# TAI log FLOP 57 -> 5.0 OOM reductions possible
# TAI log FLOP 58 -> 5.0 OOM reductions possible
# TAI log FLOP 59 -> 5.0 OOM reductions possible

# %% [markdown]
# ## Halving time (years) of compute requirements

# %%
tai_sizes = range(24, 60)
flops_per_dollar_ = np.array([algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                              algo_doubling_rate_max_p[GRAPH_P],
                                              t) for t in tai_sizes])
plt.plot(tai_sizes, flops_per_dollar_)
plt.ylabel('number of years for compute requirements to halve')
plt.xlabel('initial FLOP needed for TAI prior to any reduction')
# Out:
# Text(0.5, 0, 'initial FLOP needed for TAI prior to any reduction')

# %%
for t in tai_sizes:
    print('TAI log FLOP {} -> algo doubling rate {}yrs'.format(t,
                                                               round(algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                                     algo_doubling_rate_max_p[GRAPH_P],
                                                                                     t), 2)))
# Out:
# TAI log FLOP 24 -> algo doubling rate 1.97yrs
# TAI log FLOP 25 -> algo doubling rate 1.97yrs
# TAI log FLOP 26 -> algo doubling rate 1.97yrs
# TAI log FLOP 27 -> algo doubling rate 1.97yrs
# TAI log FLOP 28 -> algo doubling rate 1.97yrs
# TAI log FLOP 29 -> algo doubling rate 1.97yrs
# TAI log FLOP 30 -> algo doubling rate 1.97yrs
# TAI log FLOP 31 -> algo doubling rate 1.5yrs
# TAI log FLOP 32 -> algo doubling rate 1.5yrs
# TAI log FLOP 33 -> algo doubling rate 1.5yrs
# TAI log FLOP 34 -> algo doubling rate 1.5yrs
# TAI log FLOP 35 -> algo doubling rate 1.5yrs
# TAI log FLOP 36 -> algo doubling rate 1.5yrs
# TAI log FLOP 37 -> algo doubling rate 1.5yrs
# TAI log FLOP 38 -> algo doubling rate 1.5yrs
# TAI log FLOP 39 -> algo doubling rate 1.5yrs
# TAI log FLOP 40 -> algo doubling rate 1.5yrs
# TAI log FLOP 41 -> algo doubling rate 1.5yrs
# TAI log FLOP 42 -> algo doubling rate 1.5yrs
# TAI log FLOP 43 -> algo doubling rate 1.5yrs
# TAI log FLOP 44 -> algo doubling rate 1.5yrs
# TAI log FLOP 45 -> algo doubling rate 1.5yrs
# TAI log FLOP 46 -> algo doubling rate 1.5yrs
# TAI log FLOP 47 -> algo doubling rate 1.5yrs
# TAI log FLOP 48 -> algo doubling rate 1.5yrs
# TAI log FLOP 49 -> algo doubling rate 1.5yrs
# TAI log FLOP 50 -> algo doubling rate 1.5yrs
# TAI log FLOP 51 -> algo doubling rate 1.5yrs
# TAI log FLOP 52 -> algo doubling rate 1.5yrs
# TAI log FLOP 53 -> algo doubling rate 1.5yrs
# TAI log FLOP 54 -> algo doubling rate 1.5yrs
# TAI log FLOP 55 -> algo doubling rate 1.5yrs
# TAI log FLOP 56 -> algo doubling rate 1.5yrs
# TAI log FLOP 57 -> algo doubling rate 1.5yrs
# TAI log FLOP 58 -> algo doubling rate 1.5yrs
# TAI log FLOP 59 -> algo doubling rate 1.5yrs

# %% [markdown]
# ## Dollars Needed to Buy TAI (Given Algorithmic Progress and Decline in Cost per FLOP)

# %%
cost_of_tai_ = np.array([cost_of_tai(initial_flops=10 ** initial_flops_p[GRAPH_P],
                                     possible_reduction=10 ** possible_algo_reduction_fn(min_reduction_p[GRAPH_P], max_reduction_p[GRAPH_P], initial_flops_p[GRAPH_P]),
                                     algo_doubling_rate=algo_halving_fn(algo_doubling_rate_min_p[GRAPH_P],
                                                                        algo_doubling_rate_max_p[GRAPH_P],
                                                                        initial_flops_p[GRAPH_P]),
                                     initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                     max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                     flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                     year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(cost_of_tai_))
plt.ylabel('log $ needed to buy TAI')
# Out:
# Text(0, 0.5, 'log $ needed to buy TAI')

# %%
for y in years:
    print('Year: {} - log $ {} to buy TAI (~{})'.format(y,
                                                        np.round(np.log10(cost_of_tai_[y - CURRENT_YEAR]), 1),
                                                        numerize(cost_of_tai_[y - CURRENT_YEAR])))
# Out:
# Year: 2022 - log $ 14.5 to buy TAI (~349 trillion)
# Year: 2023 - log $ 14.3 to buy TAI (~180 trillion)
# Year: 2024 - log $ 14.0 to buy TAI (~92 trillion)
# Year: 2025 - log $ 13.7 to buy TAI (~47 trillion)
# Year: 2026 - log $ 13.4 to buy TAI (~24 trillion)
# Year: 2027 - log $ 13.1 to buy TAI (~13 trillion)
# Year: 2028 - log $ 12.8 to buy TAI (~7 trillion)
# Year: 2029 - log $ 12.6 to buy TAI (~4 trillion)
# Year: 2030 - log $ 12.3 to buy TAI (~2 trillion)
# Year: 2031 - log $ 12.1 to buy TAI (~1 trillion)
# Year: 2032 - log $ 11.9 to buy TAI (~774 billion)
# Year: 2033 - log $ 11.7 to buy TAI (~507 billion)
# Year: 2034 - log $ 11.5 to buy TAI (~349 billion)
# Year: 2035 - log $ 11.4 to buy TAI (~251 billion)
# Year: 2036 - log $ 11.3 to buy TAI (~187 billion)
# Year: 2037 - log $ 11.2 to buy TAI (~143 billion)
# Year: 2038 - log $ 11.0 to buy TAI (~111 billion)
# Year: 2039 - log $ 10.9 to buy TAI (~87 billion)
# Year: 2040 - log $ 10.8 to buy TAI (~69 billion)
# Year: 2041 - log $ 10.7 to buy TAI (~55 billion)
# Year: 2042 - log $ 10.6 to buy TAI (~44 billion)
# Year: 2043 - log $ 10.5 to buy TAI (~35 billion)
# Year: 2044 - log $ 10.4 to buy TAI (~28 billion)
# Year: 2045 - log $ 10.4 to buy TAI (~22 billion)
# Year: 2046 - log $ 10.3 to buy TAI (~18 billion)
# Year: 2047 - log $ 10.2 to buy TAI (~14 billion)
# Year: 2048 - log $ 10.1 to buy TAI (~12 billion)
# Year: 2049 - log $ 10.0 to buy TAI (~9 billion)
# Year: 2050 - log $ 9.9 to buy TAI (~7 billion)
# Year: 2051 - log $ 9.8 to buy TAI (~6 billion)
# Year: 2052 - log $ 9.7 to buy TAI (~5 billion)
# Year: 2205 - log $ 6.5 to buy TAI (~3 million)
# Year: 2206 - log $ 6.5 to buy TAI (~3 million)
# Year: 2207 - log $ 6.5 to buy TAI (~3 million)
# Year: 2208 - log $ 6.5 to buy TAI (~3 million)
# Year: 2209 - log $ 6.5 to buy TAI (~3 million)
# Year: 2210 - log $ 6.5 to buy TAI (~3 million)
# Year: 2211 - log $ 6.5 to buy TAI (~3 million)
# Year: 2212 - log $ 6.5 to buy TAI (~3 million)
# Year: 2213 - log $ 6.5 to buy TAI (~3 million)
# Year: 2214 - log $ 6.5 to buy TAI (~3 million)
# Year: 2215 - log $ 6.5 to buy TAI (~3 million)
# Year: 2216 - log $ 6.5 to buy TAI (~3 million)
# Year: 2217 - log $ 6.5 to buy TAI (~3 million)
# Year: 2218 - log $ 6.5 to buy TAI (~3 million)
# Year: 2219 - log $ 6.5 to buy TAI (~3 million)
# Year: 2220 - log $ 6.5 to buy TAI (~3 million)
# Year: 2221 - log $ 6.5 to buy TAI (~3 million)

# %% [markdown]
# ## FLOPs at Max Spend

# %%
flops_at_max_ = np.array([flops_at_max(initial_gdp=variables['initial_gdp'],
                                       gdp_growth=gdp_growth_p[GRAPH_P],
                                       initial_pay=10 ** initial_pay_p[GRAPH_P],
                                       spend_doubling_time=spend_doubling_time_p[GRAPH_P],
                                       max_gdp_frac=max_gdp_frac_p[GRAPH_P],
                                       initial_flops_per_dollar=10 ** initial_flops_per_dollar_p[GRAPH_P],
                                       max_flops_per_dollar=10 ** max_flops_per_dollar_p[GRAPH_P],
                                       flops_halving_rate=flops_halving_rate_p[GRAPH_P],
                                       year=(y - CURRENT_YEAR)) for y in years])

plt.plot(years, np.log10(flops_at_max_))
plt.ylabel('max log FLOPs bought given willingness to spend')
# Out:
# Text(0, 0.5, 'max log FLOPs bought given willingness to spend')

# %%
for y in years:
    print('Year: {} - max log FLOPs {} (~{} FLOP, ~{} petaFLOP/s-days)'.format(y,
                                                                               np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]), 1),
                                                                               numerize(flops_at_max_[y - CURRENT_YEAR]),
                                                                               log_flop_to_petaflop_sdays(np.log10(flops_at_max_[y - CURRENT_YEAR]))))
# Out:
# Year: 2022 - max log FLOPs 25.1 (~13 septillion FLOP, ~145586 petaFLOP/s-days)
# Year: 2023 - max log FLOPs 25.3 (~19 septillion FLOP, ~215409 petaFLOP/s-days)
# Year: 2024 - max log FLOPs 25.4 (~28 septillion FLOP, ~318713 petaFLOP/s-days)
# Year: 2025 - max log FLOPs 25.6 (~41 septillion FLOP, ~471546 petaFLOP/s-days)
# Year: 2026 - max log FLOPs 25.8 (~60 septillion FLOP, ~697648 petaFLOP/s-days)
# Year: 2027 - max log FLOPs 26.0 (~89 septillion FLOP, ~1032129 petaFLOP/s-days)
# Year: 2028 - max log FLOPs 26.1 (~132 septillion FLOP, ~1526915 petaFLOP/s-days)
# Year: 2029 - max log FLOPs 26.3 (~195 septillion FLOP, ~2258791 petaFLOP/s-days)
# Year: 2030 - max log FLOPs 26.5 (~289 septillion FLOP, ~3341295 petaFLOP/s-days)
# Year: 2031 - max log FLOPs 26.6 (~427 septillion FLOP, ~4942279 petaFLOP/s-days)
# Year: 2032 - max log FLOPs 26.8 (~632 septillion FLOP, ~7309866 petaFLOP/s-days)
# Year: 2033 - max log FLOPs 27.0 (~934 septillion FLOP, ~10810765 petaFLOP/s-days)
# Year: 2034 - max log FLOPs 27.1 (~1 octillion FLOP, ~15986842 petaFLOP/s-days)
# Year: 2035 - max log FLOPs 27.3 (~2 octillion FLOP, ~23638599 petaFLOP/s-days)
# Year: 2036 - max log FLOPs 27.5 (~3 octillion FLOP, ~34948308 petaFLOP/s-days)
# Year: 2037 - max log FLOPs 27.6 (~4 octillion FLOP, ~51661535 petaFLOP/s-days)
# Year: 2038 - max log FLOPs 27.8 (~7 octillion FLOP, ~76354604 petaFLOP/s-days)
# Year: 2039 - max log FLOPs 28.0 (~10 octillion FLOP, ~112828392 petaFLOP/s-days)
# Year: 2040 - max log FLOPs 28.2 (~14 octillion FLOP, ~166687693 petaFLOP/s-days)
# Year: 2041 - max log FLOPs 28.3 (~21 octillion FLOP, ~246192778 petaFLOP/s-days)
# Year: 2042 - max log FLOPs 28.5 (~31 octillion FLOP, ~363509742 petaFLOP/s-days)
# Year: 2043 - max log FLOPs 28.7 (~46 octillion FLOP, ~536544116 petaFLOP/s-days)
# Year: 2044 - max log FLOPs 28.8 (~68 octillion FLOP, ~791626042 petaFLOP/s-days)
# Year: 2045 - max log FLOPs 29.0 (~101 octillion FLOP, ~1167436084 petaFLOP/s-days)
# Year: 2046 - max log FLOPs 29.2 (~149 octillion FLOP, ~1720734136 petaFLOP/s-days)
# Year: 2047 - max log FLOPs 29.3 (~219 octillion FLOP, ~2534701555 petaFLOP/s-days)
# Year: 2048 - max log FLOPs 29.5 (~322 octillion FLOP, ~3731058494 petaFLOP/s-days)
# Year: 2049 - max log FLOPs 29.7 (~474 octillion FLOP, ~5487614956 petaFLOP/s-days)
# Year: 2050 - max log FLOPs 29.8 (~697 octillion FLOP, ~8063609711 petaFLOP/s-days)
# Year: 2051 - max log FLOPs 30.0 (~1 nonillion FLOP, ~11836157226 petaFLOP/s-days)
# Year: 2052 - max log FLOPs 30.2 (~1 nonillion FLOP, ~17352450898 petaFLOP/s-days)
# Year: 2053 - max log FLOPs 30.3 (~2 nonillion FLOP, ~25404175914 petaFLOP/s-days)
# Year: 2054 - max log FLOPs 30.5 (~3 nonillion FLOP, ~37133005283 petaFLOP/s-days)
# Year: 2055 - max log FLOPs 30.7 (~5 nonillion FLOP, ~54179247803 petaFLOP/s-days)
# Year: 2056 - max log FLOPs 30.8 (~7 nonillion FLOP, ~78889859281 petaFLOP/s-days)
# Year: 2057 - max log FLOPs 31.0 (~10 nonillion FLOP, ~114607287304 petaFLOP/s-days)
# Year: 2058 - max log FLOPs 31.2 (~14 nonillion FLOP, ~166067133223 petaFLOP/s-days)
# Year: 2059 - max log FLOPs 31.3 (~21 nonillion FLOP, ~239940449586 petaFLOP/s-days)
# Year: 2060 - max log FLOPs 31.5 (~30 nonillion FLOP, ~345565588521 petaFLOP/s-days)
# Year: 2061 - max log FLOPs 31.6 (~43 nonillion FLOP, ~495924626590 petaFLOP/s-days)
# Year: 2062 - max log FLOPs 31.8 (~61 nonillion FLOP, ~708929997464 petaFLOP/s-days)
# Year: 2063 - max log FLOPs 31.9 (~87 nonillion FLOP, ~1009097196687 petaFLOP/s-days)
# Year: 2064 - max log FLOPs 32.1 (~124 nonillion FLOP, ~1429687961350 petaFLOP/s-days)
# Year: 2065 - max log FLOPs 32.2 (~174 nonillion FLOP, ~2015413252887 petaFLOP/s-days)
# Year: 2066 - max log FLOPs 32.4 (~244 nonillion FLOP, ~2825783924789 petaFLOP/s-days)
# Year: 2067 - max log FLOPs 32.5 (~340 nonillion FLOP, ~3939185118071 petaFLOP/s-days)
# Year: 2068 - max log FLOPs 32.7 (~472 nonillion FLOP, ~5457722227948 petaFLOP/s-days)
# Year: 2069 - max log FLOPs 32.8 (~649 nonillion FLOP, ~7512832844492 petaFLOP/s-days)
# Year: 2070 - max log FLOPs 32.9 (~887 nonillion FLOP, ~10271567517462 petaFLOP/s-days)
# Year: 2071 - max log FLOPs 33.1 (~1 decillion FLOP, ~13943295012392 petaFLOP/s-days)
# Year: 2072 - max log FLOPs 33.2 (~2 decillion FLOP, ~18786363605912 petaFLOP/s-days)
# Year: 2073 - max log FLOPs 33.3 (~2 decillion FLOP, ~25113928044044 petaFLOP/s-days)
# Year: 2074 - max log FLOPs 33.5 (~3 decillion FLOP, ~33297721792701 petaFLOP/s-days)
# Year: 2075 - max log FLOPs 33.6 (~4 decillion FLOP, ~43768035350843 petaFLOP/s-days)
# Year: 2076 - max log FLOPs 33.7 (~5 decillion FLOP, ~57007631078858 petaFLOP/s-days)
# Year: 2077 - max log FLOPs 33.8 (~6 decillion FLOP, ~73536953105851 petaFLOP/s-days)
# Year: 2078 - max log FLOPs 33.9 (~8 decillion FLOP, ~93888063726133 petaFLOP/s-days)
# Year: 2079 - max log FLOPs 34.0 (~10 decillion FLOP, ~118565638296739 petaFLOP/s-days)
# Year: 2080 - max log FLOPs 34.1 (~13 decillion FLOP, ~147995447906850 petaFLOP/s-days)
# Year: 2081 - max log FLOPs 34.2 (~16 decillion FLOP, ~182464170963908 petaFLOP/s-days)
# Year: 2082 - max log FLOPs 34.3 (~19 decillion FLOP, ~222058643021339 petaFLOP/s-days)
# Year: 2083 - max log FLOPs 34.4 (~23 decillion FLOP, ~266616507498304 petaFLOP/s-days)
# Year: 2084 - max log FLOPs 34.4 (~27 decillion FLOP, ~315701741443778 petaFLOP/s-days)
# Year: 2085 - max log FLOPs 34.5 (~32 decillion FLOP, ~368615902216241 petaFLOP/s-days)
# Year: 2086 - max log FLOPs 34.6 (~37 decillion FLOP, ~424448730843337 petaFLOP/s-days)
# Year: 2087 - max log FLOPs 34.6 (~42 decillion FLOP, ~482161763998274 petaFLOP/s-days)
# Year: 2088 - max log FLOPs 34.7 (~47 decillion FLOP, ~540689537225268 petaFLOP/s-days)
# Year: 2089 - max log FLOPs 34.7 (~52 decillion FLOP, ~599038573636063 petaFLOP/s-days)
# Year: 2090 - max log FLOPs 34.8 (~57 decillion FLOP, ~656366339136046 petaFLOP/s-days)
# Year: 2091 - max log FLOPs 34.8 (~62 decillion FLOP, ~712029413409962 petaFLOP/s-days)
# Year: 2092 - max log FLOPs 34.8 (~66 decillion FLOP, ~765598959311836 petaFLOP/s-days)
# Year: 2093 - max log FLOPs 34.8 (~71 decillion FLOP, ~816848825290158 petaFLOP/s-days)
# Year: 2094 - max log FLOPs 34.9 (~75 decillion FLOP, ~865725456904076 petaFLOP/s-days)
# Year: 2095 - max log FLOPs 34.9 (~79 decillion FLOP, ~912309220049144 petaFLOP/s-days)
# Year: 2096 - max log FLOPs 34.9 (~83 decillion FLOP, ~956774896287542 petaFLOP/s-days)
# Year: 2097 - max log FLOPs 34.9 (~86 decillion FLOP, ~999356386989336 petaFLOP/s-days)
# Year: 2098 - max log FLOPs 35.0 (~90 decillion FLOP, ~1040318089518126 petaFLOP/s-days)
# Year: 2099 - max log FLOPs 35.0 (~93 decillion FLOP, ~1079933493719523 petaFLOP/s-days)
# Year: 2100 - max log FLOPs 35.0 (~97 decillion FLOP, ~1118470383330670 petaFLOP/s-days)
# Year: 2101 - max log FLOPs 35.0 (~100 decillion FLOP, ~1156181482156818 petaFLOP/s-days)
# Year: 2102 - max log FLOPs 35.0 (~103 decillion FLOP, ~1193299257022469 petaFLOP/s-days)
# Year: 2103 - max log FLOPs 35.0 (~106 decillion FLOP, ~1230033695279739 petaFLOP/s-days)
# Year: 2104 - max log FLOPs 35.0 (~109 decillion FLOP, ~1266572081696416 petaFLOP/s-days)
# Year: 2105 - max log FLOPs 35.1 (~113 decillion FLOP, ~1303080026938685 petaFLOP/s-days)
# Year: 2106 - max log FLOPs 35.1 (~116 decillion FLOP, ~1339703205946900 petaFLOP/s-days)
# Year: 2107 - max log FLOPs 35.1 (~119 decillion FLOP, ~1376569432953835 petaFLOP/s-days)
# Year: 2108 - max log FLOPs 35.1 (~122 decillion FLOP, ~1413790828563638 petaFLOP/s-days)
# Year: 2109 - max log FLOPs 35.1 (~125 decillion FLOP, ~1451465927755502 petaFLOP/s-days)
# Year: 2110 - max log FLOPs 35.1 (~129 decillion FLOP, ~1489681642749169 petaFLOP/s-days)
# Year: 2111 - max log FLOPs 35.1 (~132 decillion FLOP, ~1528515038252764 petaFLOP/s-days)
# Year: 2112 - max log FLOPs 35.1 (~135 decillion FLOP, ~1568034904623576 petaFLOP/s-days)
# Year: 2113 - max log FLOPs 35.1 (~139 decillion FLOP, ~1608303131596911 petaFLOP/s-days)
# Year: 2114 - max log FLOPs 35.2 (~143 decillion FLOP, ~1649375894992122 petaFLOP/s-days)
# Year: 2115 - max log FLOPs 35.2 (~146 decillion FLOP, ~1691304673718579 petaFLOP/s-days)
# Year: 2116 - max log FLOPs 35.2 (~150 decillion FLOP, ~1734137116252730 petaFLOP/s-days)
# Year: 2117 - max log FLOPs 35.2 (~154 decillion FLOP, ~1777917775744470 petaFLOP/s-days)
# Year: 2118 - max log FLOPs 35.2 (~157 decillion FLOP, ~1822688731840235 petaFLOP/s-days)
# Year: 2119 - max log FLOPs 35.2 (~161 decillion FLOP, ~1868490115697602 petaFLOP/s-days)
# Year: 2120 - max log FLOPs 35.2 (~165 decillion FLOP, ~1915360552842086 petaFLOP/s-days)
# Year: 2121 - max log FLOPs 35.2 (~170 decillion FLOP, ~1963337536670731 petaFLOP/s-days)
# Year: 2122 - max log FLOPs 35.2 (~174 decillion FLOP, ~2012457743659146 petaFLOP/s-days)
# Year: 2123 - max log FLOPs 35.3 (~178 decillion FLOP, ~2062757299728019 petaFLOP/s-days)
# Year: 2124 - max log FLOPs 35.3 (~183 decillion FLOP, ~2114272005802840 petaFLOP/s-days)
# Year: 2125 - max log FLOPs 35.3 (~187 decillion FLOP, ~2167037529353749 petaFLOP/s-days)
# Year: 2126 - max log FLOPs 35.3 (~192 decillion FLOP, ~2221089567627794 petaFLOP/s-days)
# Year: 2127 - max log FLOPs 35.3 (~197 decillion FLOP, ~2276463987365118 petaFLOP/s-days)
# Year: 2128 - max log FLOPs 35.3 (~202 decillion FLOP, ~2333196945009586 petaFLOP/s-days)
# Year: 2129 - max log FLOPs 35.3 (~207 decillion FLOP, ~2391324990765185 petaFLOP/s-days)
# Year: 2130 - max log FLOPs 35.3 (~212 decillion FLOP, ~2450885159293687 petaFLOP/s-days)
# Year: 2131 - max log FLOPs 35.3 (~217 decillion FLOP, ~2511915049385746 petaFLOP/s-days)
# Year: 2132 - max log FLOPs 35.3 (~222 decillion FLOP, ~2574452894547288 petaFLOP/s-days)
# Year: 2133 - max log FLOPs 35.4 (~228 decillion FLOP, ~2638537626120656 petaFLOP/s-days)
# Year: 2134 - max log FLOPs 35.4 (~234 decillion FLOP, ~2704208930288298 petaFLOP/s-days)
# Year: 2135 - max log FLOPs 35.4 (~239 decillion FLOP, ~2771507300083812 petaFLOP/s-days)
# Year: 2136 - max log FLOPs 35.4 (~245 decillion FLOP, ~2840474083346658 petaFLOP/s-days)
# Year: 2137 - max log FLOPs 35.4 (~252 decillion FLOP, ~2911151527402840 petaFLOP/s-days)
# Year: 2138 - max log FLOPs 35.4 (~258 decillion FLOP, ~2983582821125730 petaFLOP/s-days)
# Year: 2139 - max log FLOPs 35.4 (~264 decillion FLOP, ~3057812134922348 petaFLOP/s-days)
# Year: 2140 - max log FLOPs 35.4 (~271 decillion FLOP, ~3133884659102986 petaFLOP/s-days)
# Year: 2141 - max log FLOPs 35.4 (~278 decillion FLOP, ~3211846641019261 petaFLOP/s-days)
# Year: 2142 - max log FLOPs 35.5 (~284 decillion FLOP, ~3291745421292462 petaFLOP/s-days)
# Year: 2143 - max log FLOPs 35.5 (~291 decillion FLOP, ~3373629469405998 petaFLOP/s-days)
# Year: 2144 - max log FLOPs 35.5 (~299 decillion FLOP, ~3457548418890871 petaFLOP/s-days)
# Year: 2145 - max log FLOPs 35.5 (~306 decillion FLOP, ~3543553102301381 petaFLOP/s-days)
# Year: 2146 - max log FLOPs 35.5 (~314 decillion FLOP, ~3631695586147128 petaFLOP/s-days)
# Year: 2147 - max log FLOPs 35.5 (~322 decillion FLOP, ~3722029205923865 petaFLOP/s-days)
# Year: 2148 - max log FLOPs 35.5 (~330 decillion FLOP, ~3814608601367118 petaFLOP/s-days)
# Year: 2149 - max log FLOPs 35.5 (~338 decillion FLOP, ~3909489752034284 petaFLOP/s-days)
# Year: 2150 - max log FLOPs 35.5 (~346 decillion FLOP, ~4006730013307948 petaFLOP/s-days)
# Year: 2151 - max log FLOPs 35.5 (~355 decillion FLOP, ~4106388152904075 petaFLOP/s-days)
# Year: 2152 - max log FLOPs 35.6 (~364 decillion FLOP, ~4208524387953914 petaFLOP/s-days)
# Year: 2153 - max log FLOPs 35.6 (~373 decillion FLOP, ~4313200422728240 petaFLOP/s-days)
# Year: 2154 - max log FLOPs 35.6 (~382 decillion FLOP, ~4420479487059322 petaFLOP/s-days)
# Year: 2155 - max log FLOPs 35.6 (~391 decillion FLOP, ~4530426375514691 petaFLOP/s-days)
# Year: 2156 - max log FLOPs 35.6 (~401 decillion FLOP, ~4643107487372459 petaFLOP/s-days)
# Year: 2157 - max log FLOPs 35.6 (~411 decillion FLOP, ~4758590867442973 petaFLOP/s-days)
# Year: 2158 - max log FLOPs 35.6 (~421 decillion FLOP, ~4876946247778225 petaFLOP/s-days)
# Year: 2159 - max log FLOPs 35.6 (~432 decillion FLOP, ~4998245090312926 petaFLOP/s-days)
# Year: 2160 - max log FLOPs 35.6 (~443 decillion FLOP, ~5122560630470970 petaFLOP/s-days)
# Year: 2161 - max log FLOPs 35.7 (~454 decillion FLOP, ~5249967921779966 petaFLOP/s-days)
# Year: 2162 - max log FLOPs 35.7 (~465 decillion FLOP, ~5380543881525395 petaFLOP/s-days)
# Year: 2163 - max log FLOPs 35.7 (~476 decillion FLOP, ~5514367337482800 petaFLOP/s-days)
# Year: 2164 - max log FLOPs 35.7 (~488 decillion FLOP, ~5651519075762058 petaFLOP/s-days)
# Year: 2165 - max log FLOPs 35.7 (~500 decillion FLOP, ~5792081889797946 petaFLOP/s-days)
# Year: 2166 - max log FLOPs 35.7 (~513 decillion FLOP, ~5936140630522202 petaFLOP/s-days)
# Year: 2167 - max log FLOPs 35.7 (~526 decillion FLOP, ~6083782257750864 petaFLOP/s-days)
# Year: 2168 - max log FLOPs 35.7 (~539 decillion FLOP, ~6235095892822326 petaFLOP/s-days)
# Year: 2169 - max log FLOPs 35.7 (~552 decillion FLOP, ~6390172872520873 petaFLOP/s-days)
# Year: 2170 - max log FLOPs 35.8 (~566 decillion FLOP, ~6549106804318399 petaFLOP/s-days)
# Year: 2171 - max log FLOPs 35.8 (~580 decillion FLOP, ~6711993622975094 petaFLOP/s-days)
# Year: 2172 - max log FLOPs 35.8 (~594 decillion FLOP, ~6878931648529606 petaFLOP/s-days)
# Year: 2173 - max log FLOPs 35.8 (~609 decillion FLOP, ~7050021645719507 petaFLOP/s-days)
# Year: 2174 - max log FLOPs 35.8 (~624 decillion FLOP, ~7225366884866772 petaFLOP/s-days)
# Year: 2175 - max log FLOPs 35.8 (~640 decillion FLOP, ~7405073204267581 petaFLOP/s-days)
# Year: 2176 - max log FLOPs 35.8 (~656 decillion FLOP, ~7589249074125561 petaFLOP/s-days)
# Year: 2177 - max log FLOPs 35.8 (~672 decillion FLOP, ~7778005662066049 petaFLOP/s-days)
# Year: 2178 - max log FLOPs 35.8 (~689 decillion FLOP, ~7971456900273610 petaFLOP/s-days)
# Year: 2179 - max log FLOPs 35.8 (~706 decillion FLOP, ~8169719554293887 petaFLOP/s-days)
# Year: 2180 - max log FLOPs 35.9 (~723 decillion FLOP, ~8372913293540295 petaFLOP/s-days)
# Year: 2181 - max log FLOPs 35.9 (~741 decillion FLOP, ~8581160763551284 petaFLOP/s-days)
# Year: 2182 - max log FLOPs 35.9 (~760 decillion FLOP, ~8794587660039193 petaFLOP/s-days)
# Year: 2183 - max log FLOPs 35.9 (~779 decillion FLOP, ~9013322804778012 petaFLOP/s-days)
# Year: 2184 - max log FLOPs 35.9 (~798 decillion FLOP, ~9237498223376094 petaFLOP/s-days)
# Year: 2185 - max log FLOPs 35.9 (~818 decillion FLOP, ~9467249224979830 petaFLOP/s-days)
# Year: 2186 - max log FLOPs 35.9 (~838 decillion FLOP, ~9702714483957004 petaFLOP/s-days)
# Year: 2187 - max log FLOPs 35.9 (~859 decillion FLOP, ~9944036123611134 petaFLOP/s-days)
# Year: 2188 - max log FLOPs 35.9 (~881 decillion FLOP, ~10191359801973596 petaFLOP/s-days)
# Year: 2189 - max log FLOPs 36.0 (~902 decillion FLOP, ~10444834799730778 petaFLOP/s-days)
# Year: 2190 - max log FLOPs 36.0 (~925 decillion FLOP, ~10704614110335792 petaFLOP/s-days)
# Year: 2191 - max log FLOPs 36.0 (~948 decillion FLOP, ~10970854532357976 petaFLOP/s-days)
# Year: 2192 - max log FLOPs 36.0 (~971 decillion FLOP, ~11243716764131900 petaFLOP/s-days)
# Year: 2193 - max log FLOPs 36.0 (~996 decillion FLOP, ~11523365500756296 petaFLOP/s-days)
# Year: 2194 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~11809969533506690 petaFLOP/s-days)
# Year: 2195 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~12103701851719472 petaFLOP/s-days)
# Year: 2196 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~12404739747207794 petaFLOP/s-days)
# Year: 2197 - max log FLOPs 36.0 (~1 thousand decillion FLOP, ~12713264921276674 petaFLOP/s-days)
# Year: 2198 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~13029463594396044 petaFLOP/s-days)
# Year: 2199 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~13353526618603794 petaFLOP/s-days)
# Year: 2200 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~13685649592702534 petaFLOP/s-days)
# Year: 2201 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~14026032980321968 petaFLOP/s-days)
# Year: 2202 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~14374882230917504 petaFLOP/s-days)
# Year: 2203 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~14732407903774906 petaFLOP/s-days)
# Year: 2204 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~15098825795104896 petaFLOP/s-days)
# Year: 2205 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~15474357068292720 petaFLOP/s-days)
# Year: 2206 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~15859228387390568 petaFLOP/s-days)
# Year: 2207 - max log FLOPs 36.1 (~1 thousand decillion FLOP, ~16253672053929246 petaFLOP/s-days)
# Year: 2208 - max log FLOPs 36.2 (~1 thousand decillion FLOP, ~16657926147131178 petaFLOP/s-days)
# Year: 2209 - max log FLOPs 36.2 (~1 thousand decillion FLOP, ~17072234667611962 petaFLOP/s-days)
# Year: 2210 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~17496847684654770 petaFLOP/s-days)
# Year: 2211 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~17932021487150438 petaFLOP/s-days)
# Year: 2212 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~18378018738286960 petaFLOP/s-days)
# Year: 2213 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~18835108634089836 petaFLOP/s-days)
# Year: 2214 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19303567065904288 petaFLOP/s-days)
# Year: 2215 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~19783676786919024 petaFLOP/s-days)
# Year: 2216 - max log FLOPs 36.2 (~2 thousand decillion FLOP, ~20275727582830492 petaFLOP/s-days)
# Year: 2217 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~20780016446754232 petaFLOP/s-days)
# Year: 2218 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~21296847758482560 petaFLOP/s-days)
# Year: 2219 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~21826533468205816 petaFLOP/s-days)
# Year: 2220 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~22369393284796532 petaFLOP/s-days)
# Year: 2221 - max log FLOPs 36.3 (~2 thousand decillion FLOP, ~22925754868784312 petaFLOP/s-days)

# %% [markdown]
# ## Parameters at Max Spend

# %%
for y in years:
    print('Year: {} - max log parameters {} (~{} parameters)'.format(y,
                                                                     np.round(np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12, 1),
                                                                     numerize(10 ** (np.log10(flops_at_max_[y - CURRENT_YEAR]) - 12))))
# Out:
# Year: 2022 - max log parameters 13.1 (~13 trillion parameters)
# Year: 2023 - max log parameters 13.3 (~19 trillion parameters)
# Year: 2024 - max log parameters 13.4 (~28 trillion parameters)
# Year: 2025 - max log parameters 13.6 (~41 trillion parameters)
# Year: 2026 - max log parameters 13.8 (~60 trillion parameters)
# Year: 2027 - max log parameters 14.0 (~89 trillion parameters)
# Year: 2028 - max log parameters 14.1 (~132 trillion parameters)
# Year: 2029 - max log parameters 14.3 (~195 trillion parameters)
# Year: 2030 - max log parameters 14.5 (~289 trillion parameters)
# Year: 2031 - max log parameters 14.6 (~427 trillion parameters)
# Year: 2032 - max log parameters 14.8 (~632 trillion parameters)
# Year: 2033 - max log parameters 15.0 (~934 trillion parameters)
# Year: 2034 - max log parameters 15.1 (~1 quadrillion parameters)
# Year: 2035 - max log parameters 15.3 (~2 quadrillion parameters)
# Year: 2036 - max log parameters 15.5 (~3 quadrillion parameters)
# Year: 2037 - max log parameters 15.6 (~4 quadrillion parameters)
# Year: 2038 - max log parameters 15.8 (~7 quadrillion parameters)
# Year: 2039 - max log parameters 16.0 (~10 quadrillion parameters)
# Year: 2040 - max log parameters 16.2 (~14 quadrillion parameters)
# Year: 2041 - max log parameters 16.3 (~21 quadrillion parameters)
# Year: 2042 - max log parameters 16.5 (~31 quadrillion parameters)
# Year: 2043 - max log parameters 16.7 (~46 quadrillion parameters)
# Year: 2044 - max log parameters 16.8 (~68 quadrillion parameters)
# Year: 2045 - max log parameters 17.0 (~101 quadrillion parameters)
# Year: 2046 - max log parameters 17.2 (~149 quadrillion parameters)
# Year: 2047 - max log parameters 17.3 (~219 quadrillion parameters)
# Year: 2048 - max log parameters 17.5 (~322 quadrillion parameters)
# Year: 2049 - max log parameters 17.7 (~474 quadrillion parameters)
# Year: 2050 - max log parameters 17.8 (~697 quadrillion parameters)
# Year: 2051 - max log parameters 18.0 (~1 quintillion parameters)
# Year: 2052 - max log parameters 18.2 (~1 quintillion parameters)
# Year: 2053 - max log parameters 18.3 (~2 quintillion parameters)
# Year: 2054 - max log parameters 18.5 (~3 quintillion parameters)
# Year: 2055 - max log parameters 18.7 (~5 quintillion parameters)
# Year: 2056 - max log parameters 18.8 (~7 quintillion parameters)
# Year: 2057 - max log parameters 19.0 (~10 quintillion parameters)
# Year: 2058 - max log parameters 19.2 (~14 quintillion parameters)
# Year: 2059 - max log parameters 19.3 (~21 quintillion parameters)
# Year: 2060 - max log parameters 19.5 (~30 quintillion parameters)
# Year: 2061 - max log parameters 19.6 (~43 quintillion parameters)
# Year: 2062 - max log parameters 19.8 (~61 quintillion parameters)
# Year: 2063 - max log parameters 19.9 (~87 quintillion parameters)
# Year: 2064 - max log parameters 20.1 (~124 quintillion parameters)
# Year: 2065 - max log parameters 20.2 (~174 quintillion parameters)
# Year: 2066 - max log parameters 20.4 (~244 quintillion parameters)
# Year: 2067 - max log parameters 20.5 (~340 quintillion parameters)
# Year: 2068 - max log parameters 20.7 (~472 quintillion parameters)
# Year: 2069 - max log parameters 20.8 (~649 quintillion parameters)
# Year: 2070 - max log parameters 20.9 (~887 quintillion parameters)
# Year: 2071 - max log parameters 21.1 (~1 sextillion parameters)
# Year: 2072 - max log parameters 21.2 (~2 sextillion parameters)
# Year: 2073 - max log parameters 21.3 (~2 sextillion parameters)
# Year: 2074 - max log parameters 21.5 (~3 sextillion parameters)
# Year: 2075 - max log parameters 21.6 (~4 sextillion parameters)
# Year: 2076 - max log parameters 21.7 (~5 sextillion parameters)
# Year: 2077 - max log parameters 21.8 (~6 sextillion parameters)
# Year: 2078 - max log parameters 21.9 (~8 sextillion parameters)
# Year: 2079 - max log parameters 22.0 (~10 sextillion parameters)
# Year: 2080 - max log parameters 22.1 (~13 sextillion parameters)
# Year: 2081 - max log parameters 22.2 (~16 sextillion parameters)
# Year: 2082 - max log parameters 22.3 (~19 sextillion parameters)
# Year: 2083 - max log parameters 22.4 (~23 sextillion parameters)
# Year: 2084 - max log parameters 22.4 (~27 sextillion parameters)
# Year: 2085 - max log parameters 22.5 (~32 sextillion parameters)
# Year: 2086 - max log parameters 22.6 (~37 sextillion parameters)
# Year: 2087 - max log parameters 22.6 (~42 sextillion parameters)
# Year: 2088 - max log parameters 22.7 (~47 sextillion parameters)
# Year: 2089 - max log parameters 22.7 (~52 sextillion parameters)
# Year: 2090 - max log parameters 22.8 (~57 sextillion parameters)
# Year: 2091 - max log parameters 22.8 (~62 sextillion parameters)
# Year: 2092 - max log parameters 22.8 (~66 sextillion parameters)
# Year: 2093 - max log parameters 22.8 (~71 sextillion parameters)
- max log parameters 24.0 (~1 septillion parameters)
# Year: 2195 - max log parameters 24.0 (~1 septillion parameters)
# Year: 2196 - max log parameters 24.0 (~1 septillion parameters)
# Year: 2197 - max log parameters 24.0 (~1 septillion parameters)
# Year: 2198 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2199 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2200 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2201 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2202 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2203 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2204 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2205 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2206 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2207 - max log parameters 24.1 (~1 septillion parameters)
# Year: 2208 - max log parameters 24.2 (~1 septillion parameters)
# Year: 2209 - max log parameters 24.2 (~1 septillion parameters)
# Year: 2210 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2211 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2212 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2213 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2214 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2215 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2216 - max log parameters 24.2 (~2 septillion parameters)
# Year: 2217 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2218 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2219 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2220 - max log parameters 24.3 (~2 septillion parameters)
# Year: 2221 - max log parameters 24.3 (~2 septillion parameters)

# %% [markdown]
# ## Chance of Non-scaling Delay

# %%
p_nonscaling_delay_ = np.array([p_nonscaling_delay(variables.get('initial_chance_of_nonscaling_issue', 0),
                                                   variables.get('final_chance_of_nonscaling_issue', 0),
                                                   year=y,
                                                   max_year=variables.get('nonscaling_issue_bottom_year', 0)) for y in years])

plt.plot(years[:60], p_nonscaling_delay_[:60])
plt.ylabel('chance of non-scaling delay by year')
# Out:
# Text(0, 0.5, 'chance of non-scaling delay by year')

# %%
for y in years:
    print('Year: {} - p(nonscaling delay) = {}%'.format(y,
                                                        np.round(p_nonscaling_delay_[y - CURRENT_YEAR] * 100, 1)))
# Out:
# Year: 2022 - p(nonscaling delay) = 94.2%
# Year: 2023 - p(nonscaling delay) = 94.0%
# Year: 2024 - p(nonscaling delay) = 93.6%
# Year: 2025 - p(nonscaling delay) = 93.2%
# Year: 2026 - p(nonscaling delay) = 92.5%
# Year: 2027 - p(nonscaling delay) = 91.7%
# Year: 2028 - p(nonscaling delay) = 90.6%
# Year: 2029 - p(nonscaling delay) = 89.2%
# Year: 2030 - p(nonscaling delay) = 87.5%
# Year: 2031 - p(nonscaling delay) = 85.2%
# Year: 2032 - p(nonscaling delay) = 82.5%
# Year: 2033 - p(nonscaling delay) = 79.1%
# Year: 2034 - p(nonscaling delay) = 75.3%
# Year: 2035 - p(nonscaling delay) = 70.9%
# Year: 2036 - p(nonscaling delay) = 66.2%
# Year: 2037 - p(nonscaling delay) = 61.4%
# Year: 2038 - p(nonscaling delay) = 56.6%
# Year: 2039 - p(nonscaling delay) = 52.0%
# Year: 2040 - p(nonscaling delay) = 47.9%
# Year: 2041 - p(nonscaling delay) = 44.3%
# Year: 2042 - p(nonscaling delay) = 41.2%
# Year: 2043 - p(nonscaling delay) = 38.7%
# Year: 2044 - p(nonscaling delay) = 36.7%
# Year: 2045 - p(nonscaling delay) = 35.1%
# Year: 2046 - p(nonscaling delay) = 33.8%
# Year: 2047 - p(nonscaling delay) = 32.9%
# Year: 2048 - p(nonscaling delay) = 32.2%
# Year: 2049 - p(nonscaling delay) = 31.6%
# Year: 2050 - p(nonscaling delay) = 31.2%
# Year: 2051 - p(nonscaling delay) = 30.9%
# Year: 2052 - p(nonscaling delay) = 30.7%
# Year: 2053 - p(nonscaling delay) = 30.5%
# Year: 2054 - p(nonscaling delay) = 30.4%
# Year: 2055 - p(nonscaling delay) = 30.3%
# Year: 2056 - p(nonscaling delay) = 30.2%
# Year: 2057 - p(nonscaling delay) = 30.2%
# Year: 2058 - p(nonscaling delay) = 30.1%
# Year: 2059 - p(nonscaling delay) = 30.1%
# Year: 2060 - p(nonscaling delay) = 30.1%
# Year: 2061 - p(nonscaling delay) = 30.0%
# Year: 2062 - p(nonscaling delay) = 30.0%
# Year: 2063 - p(nonscaling delay) = 30.0%
# Year: 2064 - p(nonscaling delay) = 30.0%
# Year: 2065 - p(nonscaling delay) = 30.0%
# Year: 2066 - p(nonscaling delay) = 30.0%
# Year: 2067 - p(nonscaling delay) = 30.0%
# Year: 2068 - p(nonscaling delay) = 30.0%
# Year: 2069 - p(nonscaling delay) = 30.0%
# Year: 2070 - p(nonscaling delay) = 30.0%
# Year: 2071 - p(nonscaling delay) = 30.0%
# Year: 2072 - p(nonscaling delay) = 30.0%
# Year: 2073 - p(nonscaling delay) = 30.0%
# Year: 2074 - p(nonscaling delay) = 30.0%
# Year: 2075 - p(nonscaling delay) = 30.0%
# Year: 2076 - p(nonscaling delay) = 30.0%
# Year: 2077 - p(nonscaling delay) = 30.0%
# Year: 2078 - p(nonscaling delay) = 30.0%
# Year: 2079 - p(nonscaling delay) = 30.0%
# Year: 2080 - p(nonscaling delay) = 30.0%
# Year: 2081 - p(nonscaling delay) = 30.0%
# Year: 2082 - p(nonscaling delay) = 30.0%
# Year: 2083 - p(nonscaling delay) = 30.0%
# Year: 2084 - p(nonscaling delay) = 30.0%
# Year: 2085 - p(nonscaling delay) = 30.0%
# Year: 2086 - p(nonscaling delay) = 30.0%
# Year: 2087 - p(nonscaling delay) = 30.0%
# Year: 2088 - p(nonscaling delay) = 30.0%
# Year: 2089 - p(nonscaling delay) = 30.0%
# Year: 2090 - p(nonscaling delay) = 30.0%
# Year: 2091 - p(nonscaling delay) = 30.0%
# Year: 2092 - p(nonscaling delay) = 30.0%
# Year: 2093 - p(nonscaling delay) = 30.0%
# Year: 2094 - p(nonscaling delay) = 30.0%
# Year: 2095 - p(nonscaling delay) = 30.0%
# Year: 2096 - p(nonscaling delay) = 30.0%
# Year: 2097 - p(nonscaling delay) = 30.0%
# Year: 2098 - p(nonscaling delay) = 30.0%
# Year: 2099 - p(nonscaling delay) = 30.0%
# Year: 2100 - p(nonscaling delay) = 30.0%
# Year: 2101 - p(nonscaling delay) = 30.0%
# Year: 2102 - p(nonscaling delay) = 30.0%
# Year: 2103 - p(nonscaling delay) = 30.0%
# Year: 2104 - p(nonscaling delay) = 30.0%
# Year: 2105 - p(nonscaling delay) = 30.0%
# Year: 2106 - p(nonscaling delay) = 30.0%
# Year: 2107 - p(nonscaling delay) = 30.0%
# Year: 2108 - p(nonscaling delay) = 30.0%
# Year: 2109 - p(nonscaling delay) = 30.0%
# Year: 2110 - p(nonscaling delay) = 30.0%
# Year: 2111 - p(nonscaling delay) = 30.0%
# Year: 2112 - p(nonscaling delay) = 30.0%
# Year: 2113 - p(nonscaling delay) = 30.0%
# Year: 2114 - p(nonscaling delay) = 30.0%
# Year: 2115 - p(nonscaling delay) = 30.0%
# Year: 2116 - p(nonscaling delay) = 30.0%
# Year: 2117 - p(nonscaling delay) = 30.0%
# Year: 2118 - p(nonscaling delay) = 30.0%
# Year: 2119 - p(nonscaling delay) = 30.0%
# Year: 2120 - p(nonscaling delay) = 30.0%
# Year: 2121 - p(nonscaling delay) = 30.0%
# Year: 2122 - p(nonscaling delay) = 30.0%
# Year: 2123 - p(nonscaling delay) = 30.0%
# Year: 2124 - p(nonscaling delay) = 30.0%
# Year: 2125 - p(nonscaling delay) = 30.0%
# Year: 2126 - p(nonscaling delay) = 30.0%
# Year: 2127 - p(nonscaling delay) = 30.0%
# Year: 2128 - p(nonscaling delay) = 30.0%
# Year: 2129 - p(nonscaling delay) = 30.0%
# Year: 2130 - p(nonscaling delay) = 30.0%
# Year: 2131 - p(nonscaling delay) = 30.0%
# Year: 2132 - p(nonscaling delay) = 30.0%
# Year: 2133 - p(nonscaling delay) = 30.0%
# Year: 2134 - p(nonscaling delay) = 30.0%
# Year: 2135 - p(nonscaling delay) = 30.0%
# Year: 2136 - p(nonscaling delay) = 30.0%
# Year: 2137 - p(nonscaling delay) = 30.0%
# Year: 2138 - p(nonscaling delay) = 30.0%
# Year: 2139 - p(nonscaling delay) = 30.0%
# Year: 2140 - p(nonscaling delay) = 30.0%
# Year: 2141 - p(nonscaling delay) = 30.0%
# Year: 2142 - p(nonscaling delay) = 30.0%
# Year: 2143 - p(nonscaling delay) = 30.0%
# Year: 2144 - p(nonscaling delay) = 30.0%
# Year: 2145 - p(nonscaling delay) = 30.0%
# Year: 2146 - p(nonscaling delay) = 30.0%
# Year: 2147 - p(nonscaling delay) = 30.0%
# Year: 2148 - p(nonscaling delay) = 30.0%
# Year: 2149 - p(nonscaling delay) = 30.0%
# Year: 2150 - p(nonscaling delay) = 30.0%
# Year: 2151 - p(nonscaling delay) = 30.0%
# Year: 2152 - p(nonscaling delay) = 30.0%
# Year: 2153 - p(nonscaling delay) = 30.0%
# Year: 2154 - p(nonscaling delay) = 30.0%
# Year: 2155 - p(nonscaling delay) = 30.0%
# Year: 2156 - p(nonscaling delay) = 30.0%
# Year: 2157 - p(nonscaling delay) = 30.0%
# Year: 2158 - p(nonscaling delay) = 30.0%
# Year: 2159 - p(nonscaling delay) = 30.0%
# Year: 2160 - p(nonscaling delay) = 30.0%
# Year: 2161 - p(nonscaling delay) = 30.0%
# Year: 2162 - p(nonscaling delay) = 30.0%
# Year: 2163 - p(nonscaling delay) = 30.0%
# Year: 2164 - p(nonscaling delay) = 30.0%
# Year: 2165 - p(nonscaling delay) = 30.0%
# Year: 2166 - p(nonscaling delay) = 30.0%
# Year: 2167 - p(nonscaling delay) = 30.0%
# Year: 2168 - p(nonscaling delay) = 30.0%
# Year: 2169 - p(nonscaling delay) = 30.0%
# Year: 2170 - p(nonscaling delay) = 30.0%
# Year: 2171 - p(nonscaling delay) = 30.0%
# Year: 2172 - p(nonscaling delay) = 30.0%
# Year: 2173 - p(nonscaling delay) = 30.0%
# Year: 2174 - p(nonscaling delay) = 30.0%
# Year: 2175 - p(nonscaling delay) = 30.0%
# Year: 2176 - p(nonscaling delay) = 30.0%
# Year: 2177 - p(nonscaling delay) = 30.0%
# Year: 2178 - p(nonscaling delay) = 30.0%
# Year: 2179 - p(nonscaling delay) = 30.0%
# Year: 2180 - p(nonscaling delay) = 30.0%
# Year: 2181 - p(nonscaling delay) = 30.0%
# Year: 2182 - p(nonscaling delay) = 30.0%
# Year: 2183 - p(nonscaling delay) = 30.0%
# Year: 2184 - p(nonscaling delay) = 30.0%
# Year: 2185 - p(nonscaling delay) = 30.0%
# Year: 2186 - p(nonscaling delay) = 30.0%
# Year: 2187 - p(nonscaling delay) = 30.0%
# Year: 2188 - p(nonscaling delay) = 30.0%
# Year: 2189 - p(nonscaling delay) = 30.0%
# Year: 2190 - p(nonscaling delay) = 30.0%
# Year: 2191 - p(nonscaling delay) = 30.0%
# Year: 2192 - p(nonscaling delay) = 30.0%
# Year: 2193 - p(nonscaling delay) = 30.0%
# Year: 2194 - p(nonscaling delay) = 30.0%
# Year: 2195 - p(nonscaling delay) = 30.0%
# Year: 2196 - p(nonscaling delay) = 30.0%
# Year: 2197 - p(nonscaling delay) = 30.0%
# Year: 2198 - p(nonscaling delay) = 30.0%
# Year: 2199 - p(nonscaling delay) = 30.0%
# Year: 2200 - p(nonscaling delay) = 30.0%
# Year: 2201 - p(nonscaling delay) = 30.0%
# Year: 2202 - p(nonscaling delay) = 30.0%
# Year: 2203 - p(nonscaling delay) = 30.0%
# Year: 2204 - p(nonscaling delay) = 30.0%
# Year: 2205 - p(nonscaling delay) = 30.0%
# Year: 2206 - p(nonscaling delay) = 30.0%
# Year: 2207 - p(nonscaling delay) = 30.0%
# Year: 2208 - p(nonscaling delay) = 30.0%
# Year: 2209 - p(nonscaling delay) = 30.0%
# Year: 2210 - p(nonscaling delay) = 30.0%
# Year: 2211 - p(nonscaling delay) = 30.0%
# Year: 2212 - p(nonscaling delay) = 30.0%
# Year: 2213 - p(nonscaling delay) = 30.0%
# Year: 2214 - p(nonscaling delay) = 30.0%
# Year: 2215 - p(nonscaling delay) = 30.0%
# Year: 2216 - p(nonscaling delay) = 30.0%
# Year: 2217 - p(nonscaling delay) = 30.0%
# Year: 2218 - p(nonscaling delay) = 30.0%
# Year: 2219 - p(nonscaling delay) = 30.0%
# Year: 2220 - p(nonscaling delay) = 30.0%
# Year: 2221 - p(nonscaling delay) = 30.0%

# %% [markdown]
# ## Run Model

# %%
def run_model(initial_gdp_, tai_flop_size_, nonscaling_delay_, algo_doubling_rate_,
              possible_algo_reduction_, initial_flops_per_dollar_, flops_halving_rate_,
              max_flops_per_dollar_, initial_pay_, gdp_growth_, max_gdp_frac_,
              willingness_ramp_, spend_doubling_time_, initial_chance_of_nonscaling_issue_,
              final_chance_of_nonscaling_issue_, nonscaling_issue_bottom_year_,
              willingness_spend_horizon_, print_diagnostic):
    queue_tai_year = 99999
    plt.ioff()
    if print_diagnostic:
        cost_of_tai_collector = []
        willingness_collector = []
    
    if print_diagnostic:
        print('It takes {} log FLOPs (~{}) for transformative capabilities.'.format(np.round(tai_flop_size_, 1),
                                                                                    numerize(10 ** tai_flop_size_)))
        print('Every {} years algorithms get 2x better, with {} log reductions possible.'.format(np.round(algo_doubling_rate_, 1),
                                                                                                 np.round(possible_algo_reduction_, 1)))
        print(('FLOPs start at a cost of {} log FLOPs (~{}) per 2022$USD. Every {} years they get ' +
               '2x cheaper, to a maximum of {} log FLOPs (~{}) per 2022$USD.').format(np.round(math.log10(initial_flops_per_dollar_), 1),
                                                                               numerize(initial_flops_per_dollar_),
                                                                               np.round(flops_halving_rate_, 1),
                                                                               np.round(math.log10(max_flops_per_dollar_), 1),
                                                                               numerize(max_flops_per_dollar_)))
        print(('We are willing to pay {} log 2022$USD (~{}) and this increases by {}x per year to a max of {}% of GDP. ' +
               'GDP grows at a rate of {}x per year.').format(np.round(math.log10(initial_pay_), 1),
                                                              numerize(initial_pay_),
                                                              np.round(spend_doubling_time_, 1),
                                                              np.round(max_gdp_frac_, 4),
                                                              np.round(gdp_growth_, 3)))
        if willingness_ramp_ < 1:
            print('In this simulation, if we are {}% of the way to paying for TAI, we will ramp to paying for TAI.'.format(np.round(willingness_ramp_ * 100)))

        if willingness_spend_horizon_ > 1:
            print('We are willing to spend over {} years to make TAI'.format(willingness_spend_horizon_))
            
        print(('If a non-scaling delay happens, it will take an additional {} years to produce TAI due' +
               ' to issues unrelated to scaling FLOP').format(np.round(nonscaling_delay_, 1)))
        print('---')
    
    tai_created = False
    is_nonscaling_issue = None
    for y in years:
        if not tai_created:
            flops_needed_ = flops_needed(initial_flops=10 ** tai_flop_size_,
                                         doubling_rate=algo_doubling_rate_,
                                         possible_reduction=10 ** possible_algo_reduction_,
                                         year=(y - CURRENT_YEAR))
            
            flops_per_dollar_ = flops_per_dollar(initial_flops_per_dollar=initial_flops_per_dollar_,
                                                 max_flops_per_dollar=max_flops_per_dollar_,
                                                 halving_rate=flops_halving_rate_,
                                                 year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200 or flops_needed_ > 10 ** 200:
                flops_needed_ = int(flops_needed_)
                flops_per_dollar_ = int(flops_per_dollar_)
                cost_of_tai_ = flops_needed_ // flops_per_dollar_
            else:
                cost_of_tai_ = flops_needed_ / flops_per_dollar_
            
            willingness_ = willingness_to_pay(initial_gdp=initial_gdp_,
                                              gdp_growth=gdp_growth_,
                                              initial_pay=initial_pay_,
                                              spend_doubling_time=spend_doubling_time_,
                                              max_gdp_frac=max_gdp_frac_,
                                              year=(y - CURRENT_YEAR))
            
            if flops_per_dollar_ > 10 ** 200:
                willingness_ = int(willingness_)
            if willingness_ > 10 ** 200:
                flops_per_dollar_ = int(flops_per_dollar_)
            
            if print_diagnostic:
                cost_of_tai_collector.append(cost_of_tai_)
                willingness_collector.append(willingness_)
            
            total_compute_ = willingness_ * flops_per_dollar_
            
            if print_diagnostic:
                out_str = ('Year: {} - {} max log FLOP ({}) available - TAI takes {} log FLOP ({}) - ' +
                           'log $ {} to buy TAI ({}) vs. willingness to pay log $ {} ({}) - {} log FLOPS per $ ({})')
                print(out_str.format(y,
                                     np.round(math.log10(total_compute_), 1),
                                     numerize(total_compute_),
                                     np.round(math.log10(flops_needed_), 1),
                                     numerize(flops_needed_),
                                     np.round(math.log10(cost_of_tai_), 1),
                                     numerize(cost_of_tai_),
                                     np.round(math.log10(willingness_), 1),
                                     numerize(willingness_),
                                     np.round(math.log10(flops_per_dollar_), 1),
                                     numerize(flops_per_dollar_)))
            
            if cost_of_tai_ > 10 ** 200:
                spend_tai_years = int(cost_of_tai_) // int(willingness_)
            else:
                spend_tai_years = cost_of_tai_ / willingness_
                
            if not is_nonscaling_issue and queue_tai_year < 99999 and print_diagnostic:
                print('-$- {}/{}'.format(y, queue_tai_year))
            if (cost_of_tai_ * willingness_ramp_) <= willingness_ or y >= queue_tai_year:
                if is_nonscaling_issue is None:
                    p_nonscaling_delay_ = p_nonscaling_delay(initial_chance_of_nonscaling_issue_,
                                                             final_chance_of_nonscaling_issue_,
                                                             year=y,
                                                             max_year=nonscaling_issue_bottom_year_)
                    is_nonscaling_issue = sq.event(p_nonscaling_delay_)
                    nonscaling_countdown = nonscaling_delay_
                    if print_diagnostic:
                        print('-- {} p_nonscaling_issue={}'.format('Nonscaling delay occured' if is_nonscaling_issue else 'Nonscaling issue did not occur',
                                                                   np.round(p_nonscaling_delay_, 4)))
                
                if not is_nonscaling_issue or nonscaling_countdown <= 0.1:
                    if print_diagnostic:
                        print('--- /!\ TAI CREATED in {}'.format(y))
                        plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
                    return y
                else:
                    if print_diagnostic:
                        print('/!\ FLOPs for TAI sufficient but needs {} more years to solve non-scaling issues'.format(np.round(nonscaling_countdown, 1)))
                    nonscaling_countdown -= 1
            elif (not is_nonscaling_issue and willingness_spend_horizon_ > 1 and
                  spend_tai_years <= willingness_spend_horizon_ and y + math.ceil(spend_tai_years) < queue_tai_year):
                queue_tai_year = y + math.ceil(spend_tai_years)
                if print_diagnostic:
                    print('-$- We have enough spend to make TAI in {} years (in {}) if sustained.'.format(math.ceil(spend_tai_years),
                                                                                                          queue_tai_year))
                
    if not tai_created:
        if print_diagnostic:
            print('--- :/ TAI NOT CREATED BEFORE {}'.format(MAX_YEAR + 1))
            plot_tai(plt, years, cost_of_tai_collector, willingness_collector).show()
        return MAX_YEAR + 1
    
    
def define_event(verbose=False):
    tai_flop_size_ = sq.sample(sq.discrete(variables['tai_flop_size']))

    if tai_flop_size_ > 300:
        tai_flop_size_ = int(tai_flop_size_) # Handle overflow errors
    
    algo_doubling_rate_ = algo_halving_fn(sq.sample(variables['algo_doubling_rate_min']),
                                          sq.sample(variables['algo_doubling_rate_max']),
                                          tai_flop_size_)
    
    possible_algo_reduction_ = possible_algo_reduction_fn(sq.sample(variables['min_reduction']),
                                                          sq.sample(variables['max_reduction']),
                                                          tai_flop_size_)
    
    initial_flops_per_dollar_ = 10 ** sq.sample(variables['initial_flops_per_dollar'])
    flops_halving_rate_ = sq.sample(variables['flops_halving_rate'])
    max_flops_per_dollar_ = 10 ** sq.sample(variables['max_flops_per_dollar'])
    initial_pay_ = 10 ** sq.sample(variables['initial_pay'])
    gdp_growth_ = sq.sample(variables['gdp_growth'])
    max_gdp_frac_ = sq.sample(variables['max_gdp_frac'])
    
    willingness_ramp_happens = sq.event_occurs(variables.get('p_willingness_ramp', 0))
    if willingness_ramp_happens:
        willingness_ramp_ = sq.sample(variables.get('willingness_ramp', 1))
    else:
        willingness_ramp_ = 1
    
    initial_gdp_ = variables['initial_gdp']
    spend_doubling_time_ = sq.sample(variables['spend_doubling_time'])
    nonscaling_delay_ = sq.sample(variables.get('nonscaling_delay', sq.const(0)))
    initial_chance_of_nonscaling_issue_ = variables.get('initial_chance_of_nonscaling_issue', 0)
    final_chance_of_nonscaling_issue_ = variables.get('final_chance_of_nonscaling_issue', 0)
    nonscaling_issue_bottom_year_ = variables.get('nonscaling_issue_bottom_year', 0)
    willingness_spend_horizon_ = int(sq.sample(variables.get('willingness_spend_horizon', sq.const(1))))
    
    tai_year = run_model(initial_gdp_=initial_gdp_,
                         tai_flop_size_=tai_flop_size_,
                         nonscaling_delay_=nonscaling_delay_,
                         algo_doubling_rate_=algo_doubling_rate_,
                         possible_algo_reduction_=possible_algo_reduction_,
                         initial_flops_per_dollar_=initial_flops_per_dollar_,
                         flops_halving_rate_=flops_halving_rate_,
                         max_flops_per_dollar_=max_flops_per_dollar_,
                         initial_pay_=initial_pay_,
                         gdp_growth_=gdp_growth_,
                         max_gdp_frac_=max_gdp_frac_,
                         willingness_ramp_=willingness_ramp_,
                         spend_doubling_time_=spend_doubling_time_,
                         initial_chance_of_nonscaling_issue_=initial_chance_of_nonscaling_issue_,
                         final_chance_of_nonscaling_issue_=final_chance_of_nonscaling_issue_,
                         nonscaling_issue_bottom_year_=nonscaling_issue_bottom_year_,
                         willingness_spend_horizon_=willingness_spend_horizon_,
                         print_diagnostic=verbose)
    
    return {'tai_year': tai_year,
            'initial_gdp': initial_gdp_,
            'tai_flop_size': tai_flop_size_,
            'nonscaling_delay': nonscaling_delay_,
            'algo_doubling_rte': algo_doubling_rate_,
            'possible_algo_reduction': possible_algo_reduction_,
            'initial_flops_per_dollar': float(initial_flops_per_dollar_),
            'flops_halving_rate': flops_halving_rate_,
            'max_flops_per_dollar': float(max_flops_per_dollar_),
            'initial_pay': initial_pay_,
            'gdp_growth': gdp_growth_,
            'max_gdp_frac': max_gdp_frac_,
            'willingness_ramp_': willingness_ramp_,
            'spend_doubling_time_': spend_doubling_time_,
            'initial_chance_of_nonscaling_issue': initial_chance_of_nonscaling_issue_,
            'final_chance_of_nonscaling_issue': final_chance_of_nonscaling_issue_,
            'nonscaling_issue_bottom_year': nonscaling_issue_bottom_year_,
            'willingness_spend_horizon_': willingness_spend_horizon_}

print('Loaded')
# Out:
# Loaded

# %%
define_event(verbose=True)
# Out:
# It takes 31.5 log FLOPs (~28 nonillion) for transformative capabilities.
# Every 2.2 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.5 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 5.5x per year to a max of 0.0007% of GDP. GDP grows at a rate of 1.027x per year.
# If a non-scaling delay happens, it will take an additional 5.2 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (13 septillion) available - TAI takes 31.5 log FLOP (28 nonillion) - log $ 13.5 to buy TAI (28 trillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.3 max log FLOP (19 septillion) available - TAI takes 31.3 log FLOP (21 nonillion) - log $ 13.2 to buy TAI (16 trillion) vs. willingness to pay log $ 7.2 (14 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.5 max log FLOP (28 septillion) available - TAI takes 31.2 log FLOP (15 nonillion) - log $ 12.9 to buy TAI (9 trillion) vs. willingness to pay log $ 7.2 (16 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2025 - 25.6 max log FLOP (43 septillion) available - TAI takes 31.1 log FLOP (11 nonillion) - log $ 12.7 to buy TAI (5 trillion) vs. willingness to pay log $ 7.3 (18 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2026 - 25.8 max log FLOP (64 septillion) available - TAI takes 30.9 log FLOP (8 nonillion) - log $ 12.4 to buy TAI (3 trillion) vs. willingness to pay log $ 7.3 (21 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2027 - 26.0 max log FLOP (96 septillion) available - TAI takes 30.8 log FLOP (6 nonillion) - log $ 12.2 to buy TAI (2 trillion) vs. willingness to pay log $ 7.4 (24 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2028 - 26.2 max log FLOP (144 septillion) available - TAI takes 30.7 log FLOP (5 nonillion) - log $ 11.9 to buy TAI (853 billion) vs. willingness to pay log $ 7.4 (27 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2029 - 26.3 max log FLOP (217 septillion) available - TAI takes 30.5 log FLOP (3 nonillion) - log $ 11.7 to buy TAI (481 billion) vs. willingness to pay log $ 7.5 (30 million) - 18.9 log FLOPS per $ (7 quintillion)
# Year: 2030 - 26.5 max log FLOP (326 septillion) available - TAI takes 30.4 log FLOP (3 nonillion) - log $ 11.4 to buy TAI (273 billion) vs. willingness to pay log $ 7.5 (35 million) - 19.0 log FLOPS per $ (9 quintillion)
# Year: 2031 - 26.7 max log FLOP (489 septillion) available - TAI takes 30.3 log FLOP (2 nonillion) - log $ 11.2 to buy TAI (157 billion) vs. willingness to pay log $ 7.6 (39 million) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2032 - 26.9 max log FLOP (735 septillion) available - TAI takes 30.2 log FLOP (2 nonillion) - log $ 11.0 to buy TAI (91 billion) vs. willingness to pay log $ 7.6 (45 million) - 19.2 log FLOPS per $ (17 quintillion)
# Year: 2033 - 27.0 max log FLOP (1 octillion) available - TAI takes 30.1 log FLOP (1 nonillion) - log $ 10.7 to buy TAI (54 billion) vs. willingness to pay log $ 7.7 (51 million) - 19.3 log FLOPS per $ (22 quintillion)
# Year: 2034 - 27.2 max log FLOP (2 octillion) available - TAI takes 30.0 log FLOP (935 octillion) - log $ 10.5 to buy TAI (32 billion) vs. willingness to pay log $ 7.8 (57 million) - 19.5 log FLOPS per $ (29 quintillion)
# Year: 2035 - 27.4 max log FLOP (2 octillion) available - TAI takes 29.9 log FLOP (759 octillion) - log $ 10.3 to buy TAI (20 billion) vs. willingness to pay log $ 7.8 (65 million) - 19.6 log FLOPS per $ (38 quintillion)
# Year: 2036 - 27.6 max log FLOP (4 octillion) available - TAI takes 29.8 log FLOP (631 octillion) - log $ 10.1 to buy TAI (12 billion) vs. willingness to pay log $ 7.9 (74 million) - 19.7 log FLOPS per $ (51 quintillion)
# Year: 2037 - 27.7 max log FLOP (6 octillion) available - TAI takes 29.7 log FLOP (537 octillion) - log $ 9.9 to buy TAI (8 billion) vs. willingness to pay log $ 7.9 (84 million) - 19.8 log FLOPS per $ (67 quintillion)
# Year: 2038 - 27.9 max log FLOP (8 octillion) available - TAI takes 29.7 log FLOP (469 octillion) - log $ 9.7 to buy TAI (5 billion) vs. willingness to pay log $ 8.0 (95 million) - 19.9 log FLOPS per $ (89 quintillion)
# Year: 2039 - 28.1 max log FLOP (13 octillion) available - TAI takes 29.6 log FLOP (419 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 8.0 (108 million) - 20.1 log FLOPS per $ (117 quintillion)
# Year: 2040 - 28.3 max log FLOP (19 octillion) available - TAI takes 29.6 log FLOP (383 octillion) - log $ 9.4 to buy TAI (2 billion) vs. willingness to pay log $ 8.1 (122 million) - 20.2 log FLOPS per $ (155 quintillion)
# Year: 2041 - 28.5 max log FLOP (29 octillion) available - TAI takes 29.6 log FLOP (356 octillion) - log $ 9.2 to buy TAI (2 billion) vs. willingness to pay log $ 8.1 (139 million) - 20.3 log FLOPS per $ (206 quintillion)
# Year: 2042 - 28.6 max log FLOP (43 octillion) available - TAI takes 29.5 log FLOP (337 octillion) - log $ 9.1 to buy TAI (1 billion) vs. willingness to pay log $ 8.2 (157 million) - 20.4 log FLOPS per $ (272 quintillion)
# Year: 2043 - 28.8 max log FLOP (64 octillion) available - TAI takes 29.5 log FLOP (323 octillion) - log $ 9.0 to buy TAI (896 million) vs. willingness to pay log $ 8.3 (178 million) - 20.6 log FLOPS per $ (360 quintillion)
# Year: 2044 - 29.0 max log FLOP (96 octillion) available - TAI takes 29.5 log FLOP (313 octillion) - log $ 8.8 to buy TAI (655 million) vs. willingness to pay log $ 8.3 (202 million) - 20.7 log FLOPS per $ (477 quintillion)
# Year: 2045 - 29.2 max log FLOP (145 octillion) available - TAI takes 29.5 log FLOP (305 octillion) - log $ 8.7 to buy TAI (483 million) vs. willingness to pay log $ 8.4 (229 million) - 20.8 log FLOPS per $ (631 quintillion)
# Year: 2046 - 29.3 max log FLOP (217 octillion) available - TAI takes 29.5 log FLOP (299 octillion) - log $ 8.6 to buy TAI (359 million) vs. willingness to pay log $ 8.4 (260 million) - 20.9 log FLOPS per $ (835 quintillion)
# Year: 2047 - 29.5 max log FLOP (326 octillion) available - TAI takes 29.5 log FLOP (295 octillion) - log $ 8.4 to buy TAI (267 million) vs. willingness to pay log $ 8.5 (295 million) - 21.0 log FLOPS per $ (1 sextillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.3289
# --- /!\ TAI CREATED in 2047
# {'tai_year': 2047,
#  'initial_gdp': 21300000000000.0,
#  'tai_flop_size': 31.454250817694188,
#  'nonscaling_delay': 5.201932120925748,
#  'algo_doubling_rte': 2.2010908915880574,
#  'possible_algo_reduction': 2,
#  'initial_flops_per_dollar': 1e+18,
#  'flops_halving_rate': 2.4724263738309324,
#  'max_flops_per_dollar': 1e+24,
#  'initial_pay': 12589254.117941663,
#  'gdp_growth': 1.0270218213291435,
#  'max_gdp_frac': 0.0006679579291168332,
#  'willingness_ramp_': 1,
#  'spend_doubling_time_': 5.476684411409307,
#  'initial_chance_of_nonscaling_issue': 0.95,
#  'final_chance_of_nonscaling_issue': 0.3,
#  'nonscaling_issue_bottom_year': 2050,
#  'willingness_spend_horizon_': 1}

# %%
for i in range(5):
    print('## RUN {} ##'.format(i + 1))
    define_event(verbose=True)
# Out:
# ## RUN 1 ##
# It takes 30.3 log FLOPs (~2 nonillion) for transformative capabilities.
# Every 1.0 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.3 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 7.1 log 2022$USD (~13 million) and this increases by 1.3x per year to a max of 0.0007% of GDP. GDP grows at a rate of 1.038x per year.
# If a non-scaling delay happens, it will take an additional 5.2 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 25.1 max log FLOP (13 septillion) available - TAI takes 30.3 log FLOP (2 nonillion) - log $ 12.3 to buy TAI (2 trillion) vs. willingness to pay log $ 7.1 (13 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 25.5 max log FLOP (29 septillion) available - TAI takes 30.0 log FLOP (1 nonillion) - log $ 11.9 to buy TAI (743 billion) vs. willingness to pay log $ 7.3 (21 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 25.8 max log FLOP (65 septillion) available - TAI takes 29.7 log FLOP (525 octillion) - log $ 11.5 to buy TAI (285 billion) vs. willingness to pay log $ 7.5 (35 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2025 - 26.2 max log FLOP (148 septillion) available - TAI takes 29.4 log FLOP (278 octillion) - log $ 11.0 to buy TAI (111 billion) vs. willingness to pay log $ 7.8 (59 million) - 18.4 log FLOPS per $ (3 quintillion)
# Year: 2026 - 26.5 max log FLOP (335 septillion) available - TAI takes 29.2 log FLOP (152 octillion) - log $ 10.6 to buy TAI (45 billion) vs. willingness to pay log $ 8.0 (98 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2027 - 26.9 max log FLOP (760 septillion) available - TAI takes 28.9 log FLOP (87 octillion) - log $ 10.3 to buy TAI (19 billion) vs. willingness to pay log $ 8.2 (164 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2028 - 27.2 max log FLOP (2 octillion) available - TAI takes 28.7 log FLOP (54 octillion) - log $ 9.9 to buy TAI (9 billion) vs. willingness to pay log $ 8.4 (274 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2029 - 27.6 max log FLOP (4 octillion) available - TAI takes 28.6 log FLOP (37 octillion) - log $ 9.6 to buy TAI (4 billion) vs. willingness to pay log $ 8.7 (455 million) - 18.9 log FLOPS per $ (9 quintillion)
# Year: 2030 - 27.9 max log FLOP (9 octillion) available - TAI takes 28.5 log FLOP (28 octillion) - log $ 9.4 to buy TAI (2 billion) vs. willingness to pay log $ 8.9 (751 million) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2031 - 28.3 max log FLOP (19 octillion) available - TAI takes 28.4 log FLOP (24 octillion) - log $ 9.2 to buy TAI (2 billion) vs. willingness to pay log $ 9.1 (1 billion) - 19.2 log FLOPS per $ (16 quintillion)
# Year: 2032 - 28.6 max log FLOP (43 octillion) available - TAI takes 28.3 log FLOP (22 octillion) - log $ 9.0 to buy TAI (1 billion) vs. willingness to pay log $ 9.3 (2 billion) - 19.3 log FLOPS per $ (21 quintillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.8246
# /!\ FLOPs for TAI sufficient but needs 5.2 more years to solve non-scaling issues
# Year: 2033 - 29.0 max log FLOP (92 octillion) available - TAI takes 28.3 log FLOP (21 octillion) - log $ 8.9 to buy TAI (708 million) vs. willingness to pay log $ 9.5 (3 billion) - 19.5 log FLOPS per $ (29 quintillion)
# /!\ FLOPs for TAI sufficient but needs 4.2 more years to solve non-scaling issues
# Year: 2034 - 29.3 max log FLOP (193 octillion) available - TAI takes 28.3 log FLOP (20 octillion) - log $ 8.7 to buy TAI (506 million) vs. willingness to pay log $ 9.7 (5 billion) - 19.6 log FLOPS per $ (39 quintillion)
# /!\ FLOPs for TAI sufficient but needs 3.2 more years to solve non-scaling issues
# Year: 2035 - 29.6 max log FLOP (390 octillion) available - TAI takes 28.3 log FLOP (20 octillion) - log $ 8.6 to buy TAI (367 million) vs. willingness to pay log $ 9.9 (7 billion) - 19.7 log FLOPS per $ (54 quintillion)
# /!\ FLOPs for TAI sufficient but needs 2.2 more years to solve non-scaling issues
# Year: 2036 - 29.9 max log FLOP (753 octillion) available - TAI takes 28.3 log FLOP (20 octillion) - log $ 8.4 to buy TAI (268 million) vs. willingness to pay log $ 10.0 (10 billion) - 19.9 log FLOPS per $ (73 quintillion)
# /!\ FLOPs for TAI sufficient but needs 1.2 more years to solve non-scaling issues
# Year: 2037 - 30.1 max log FLOP (1 nonillion) available - TAI takes 28.3 log FLOP (19 octillion) - log $ 8.3 to buy TAI (197 million) vs. willingness to pay log $ 10.1 (14 billion) - 20.0 log FLOPS per $ (99 quintillion)
# /!\ FLOPs for TAI sufficient but needs 0.2 more years to solve non-scaling issues
# Year: 2038 - 30.4 max log FLOP (2 nonillion) available - TAI takes 28.3 log FLOP (19 octillion) - log $ 8.2 to buy TAI (144 million) vs. willingness to pay log $ 10.2 (18 billion) - 20.1 log FLOPS per $ (134 quintillion)
# --- /!\ TAI CREATED in 2038
# ## RUN 2 ##
# It takes 42.1 log FLOPs (~1 billion decillion) for transformative capabilities.
# Every 1.6 years algorithms get 2x better, with 5 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 4.0 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.3 log 2022$USD (~199 million) and this increases by 4.5x per year to a max of 0.0007% of GDP. GDP grows at a rate of 1.038x per year.
# If a non-scaling delay happens, it will take an additional 4.4 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 26.3 max log FLOP (196 septillion) available - TAI takes 42.1 log FLOP (1 billion decillion) - log $ 24.1 to buy TAI (1 septillion) vs. willingness to pay log $ 8.3 (196 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# Year: 2023 - 26.4 max log FLOP (272 septillion) available - TAI takes 41.9 log FLOP (758 million decillion) - log $ 23.8 to buy TAI (636 sextillion) vs. willingness to pay log $ 8.4 (229 million) - 18.1 log FLOPS per $ (1 quintillion)
# Year: 2024 - 26.6 max log FLOP (378 septillion) available - TAI takes 41.7 log FLOP (485 million decillion) - log $ 23.5 to buy TAI (342 sextillion) vs. willingness to pay log $ 8.4 (266 million) - 18.2 log FLOPS per $ (1 quintillion)
# Year: 2025 - 26.7 max log FLOP (524 septillion) available - TAI takes 41.5 log FLOP (311 million decillion) - log $ 23.3 to buy TAI (184 sextillion) vs. willingness to pay log $ 8.5 (310 million) - 18.2 log FLOPS per $ (2 quintillion)
# Year: 2026 - 26.9 max log FLOP (728 septillion) available - TAI takes 41.3 log FLOP (199 million decillion) - log $ 23.0 to buy TAI (99 sextillion) vs. willingness to pay log $ 8.6 (362 million) - 18.3 log FLOPS per $ (2 quintillion)
# Year: 2027 - 27.0 max log FLOP (1 octillion) available - TAI takes 41.1 log FLOP (128 million decillion) - log $ 22.7 to buy TAI (53 sextillion) vs. willingness to pay log $ 8.6 (421 million) - 18.4 log FLOPS per $ (2 quintillion)
# Year: 2028 - 27.1 max log FLOP (1 octillion) available - TAI takes 40.9 log FLOP (82 million decillion) - log $ 22.5 to buy TAI (29 sextillion) vs. willingness to pay log $ 8.7 (490 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2029 - 27.3 max log FLOP (2 octillion) available - TAI takes 40.7 log FLOP (52 million decillion) - log $ 22.2 to buy TAI (15 sextillion) vs. willingness to pay log $ 8.8 (571 million) - 18.5 log FLOPS per $ (3 quintillion)
# Year: 2030 - 27.4 max log FLOP (3 octillion) available - TAI takes 40.5 log FLOP (34 million decillion) - log $ 21.9 to buy TAI (8 sextillion) vs. willingness to pay log $ 8.8 (664 million) - 18.6 log FLOPS per $ (4 quintillion)
# Year: 2031 - 27.6 max log FLOP (4 octillion) available - TAI takes 40.3 log FLOP (21 million decillion) - log $ 21.6 to buy TAI (4 sextillion) vs. willingness to pay log $ 8.9 (772 million) - 18.7 log FLOPS per $ (5 quintillion)
# Year: 2032 - 27.7 max log FLOP (5 octillion) available - TAI takes 40.1 log FLOP (14 million decillion) - log $ 21.4 to buy TAI (2 sextillion) vs. willingness to pay log $ 9.0 (898 million) - 18.8 log FLOPS per $ (6 quintillion)
# Year: 2033 - 27.9 max log FLOP (7 octillion) available - TAI takes 39.9 log FLOP (9 million decillion) - log $ 21.1 to buy TAI (1 sextillion) vs. willingness to pay log $ 9.0 (1 billion) - 18.8 log FLOPS per $ (7 quintillion)
# Year: 2034 - 28.0 max log FLOP (10 octillion) available - TAI takes 39.8 log FLOP (6 million decillion) - log $ 20.8 to buy TAI (694 quintillion) vs. willingness to pay log $ 9.1 (1 billion) - 18.9 log FLOPS per $ (8 quintillion)
# Year: 2035 - 28.1 max log FLOP (14 octillion) available - TAI takes 39.6 log FLOP (4 million decillion) - log $ 20.6 to buy TAI (374 quintillion) vs. willingness to pay log $ 9.1 (1 billion) - 19.0 log FLOPS per $ (10 quintillion)
# Year: 2036 - 28.3 max log FLOP (19 octillion) available - TAI takes 39.4 log FLOP (2 million decillion) - log $ 20.3 to buy TAI (201 quintillion) vs. willingness to pay log $ 9.2 (2 billion) - 19.1 log FLOPS per $ (12 quintillion)
# Year: 2037 - 28.4 max log FLOP (26 octillion) available - TAI takes 39.2 log FLOP (1 million decillion) - log $ 20.0 to buy TAI (109 quintillion) vs. willingness to pay log $ 9.3 (2 billion) - 19.1 log FLOPS per $ (14 quintillion)
# Year: 2038 - 28.6 max log FLOP (36 octillion) available - TAI takes 39.0 log FLOP (960 thousand decillion) - log $ 19.8 to buy TAI (59 quintillion) vs. willingness to pay log $ 9.3 (2 billion) - 19.2 log FLOPS per $ (16 quintillion)
# Year: 2039 - 28.7 max log FLOP (49 octillion) available - TAI takes 38.8 log FLOP (619 thousand decillion) - log $ 19.5 to buy TAI (32 quintillion) vs. willingness to pay log $ 9.4 (3 billion) - 19.3 log FLOPS per $ (20 quintillion)
# Year: 2040 - 28.8 max log FLOP (68 octillion) available - TAI takes 38.6 log FLOP (401 thousand decillion) - log $ 19.2 to buy TAI (17 quintillion) vs. willingness to pay log $ 9.5 (3 billion) - 19.4 log FLOPS per $ (23 quintillion)
# Year: 2041 - 29.0 max log FLOP (93 octillion) available - TAI takes 38.4 log FLOP (261 thousand decillion) - log $ 19.0 to buy TAI (9 quintillion) vs. willingness to pay log $ 9.5 (3 billion) - 19.4 log FLOPS per $ (28 quintillion)
# Year: 2042 - 29.1 max log FLOP (128 octillion) available - TAI takes 38.2 log FLOP (171 thousand decillion) - log $ 18.7 to buy TAI (5 quintillion) vs. willingness to pay log $ 9.6 (4 billion) - 19.5 log FLOPS per $ (33 quintillion)
# Year: 2043 - 29.2 max log FLOP (175 octillion) available - TAI takes 38.1 log FLOP (114 thousand decillion) - log $ 18.5 to buy TAI (3 quintillion) vs. willingness to pay log $ 9.6 (4 billion) - 19.6 log FLOPS per $ (39 quintillion)
# Year: 2044 - 29.4 max log FLOP (239 octillion) available - TAI takes 37.9 log FLOP (77 thousand decillion) - log $ 18.2 to buy TAI (2 quintillion) vs. willingness to pay log $ 9.7 (5 billion) - 19.7 log FLOPS per $ (47 quintillion)
# Year: 2045 - 29.5 max log FLOP (326 octillion) available - TAI takes 37.7 log FLOP (54 thousand decillion) - log $ 18.0 to buy TAI (966 quadrillion) vs. willingness to pay log $ 9.8 (6 billion) - 19.7 log FLOPS per $ (56 quintillion)
# Year: 2046 - 29.6 max log FLOP (444 octillion) available - TAI takes 37.6 log FLOP (39 thousand decillion) - log $ 17.8 to buy TAI (584 quadrillion) vs. willingness to pay log $ 9.8 (7 billion) - 19.8 log FLOPS per $ (66 quintillion)
# Year: 2047 - 29.8 max log FLOP (603 octillion) available - TAI takes 37.5 log FLOP (29 thousand decillion) - log $ 17.6 to buy TAI (368 quadrillion) vs. willingness to pay log $ 9.9 (8 billion) - 19.9 log FLOPS per $ (79 quintillion)
# Year: 2048 - 29.9 max log FLOP (818 octillion) available - TAI takes 37.4 log FLOP (23 thousand decillion) - log $ 17.4 to buy TAI (243 quadrillion) vs. willingness to pay log $ 9.9 (9 billion) - 20.0 log FLOPS per $ (94 quintillion)
# Year: 2049 - 30.0 max log FLOP (1 nonillion) available - TAI takes 37.3 log FLOP (19 thousand decillion) - log $ 17.2 to buy TAI (169 quadrillion) vs. willingness to pay log $ 10.0 (10 billion) - 20.0 log FLOPS per $ (112 quintillion)
# Year: 2050 - 30.2 max log FLOP (1 nonillion) available - TAI takes 37.2 log FLOP (16 thousand decillion) - log $ 17.1 to buy TAI (123 quadrillion) vs. willingness to pay log $ 10.0 (11 billion) - 20.1 log FLOPS per $ (133 quintillion)
# Year: 2051 - 30.3 max log FLOP (2 nonillion) available - TAI takes 37.2 log FLOP (15 thousand decillion) - log $ 17.0 to buy TAI (93 quadrillion) vs. willingness to pay log $ 10.1 (13 billion) - 20.2 log FLOPS per $ (159 quintillion)
# Year: 2052 - 30.4 max log FLOP (3 nonillion) available - TAI takes 37.1 log FLOP (14 thousand decillion) - log $ 16.9 to buy TAI (72 quadrillion) vs. willingness to pay log $ 10.2 (14 billion) - 20.3 log FLOPS per $ (189 quintillion)
# Year: 2053 - 30.6 max log FLOP (4 nonillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 16.8 to buy TAI (58 quadrillion) vs. willingness to pay log $ 10.2 (16 billion) - 20.4 log FLOPS per $ (225 quintillion)
# Year: 2054 - 30.7 max log FLOP (5 nonillion) available - TAI takes 37.1 log FLOP (13 thousand decillion) - log $ 16.7 to buy TAI (47 quadrillion) vs. willingness to pay log $ 10.3 (18 billion) - 20.4 log FLOPS per $ (268 quintillion)
# Year: 2055 - 30.8 max log FLOP (6 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.6 to buy TAI (39 quadrillion) vs. willingness to pay log $ 10.3 (20 billion) - 20.5 log FLOPS per $ (319 quintillion)
# Year: 2056 - 30.9 max log FLOP (8 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.5 to buy TAI (32 quadrillion) vs. willingness to pay log $ 10.3 (22 billion) - 20.6 log FLOPS per $ (380 quintillion)
# Year: 2057 - 31.0 max log FLOP (11 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.4 to buy TAI (27 quadrillion) vs. willingness to pay log $ 10.4 (25 billion) - 20.7 log FLOPS per $ (453 quintillion)
# Year: 2058 - 31.2 max log FLOP (15 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.3 to buy TAI (22 quadrillion) vs. willingness to pay log $ 10.4 (27 billion) - 20.7 log FLOPS per $ (539 quintillion)
# Year: 2059 - 31.3 max log FLOP (19 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.3 to buy TAI (19 quadrillion) vs. willingness to pay log $ 10.5 (30 billion) - 20.8 log FLOPS per $ (642 quintillion)
# Year: 2060 - 31.4 max log FLOP (25 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.2 to buy TAI (16 quadrillion) vs. willingness to pay log $ 10.5 (33 billion) - 20.9 log FLOPS per $ (765 quintillion)
# Year: 2061 - 31.5 max log FLOP (33 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.1 to buy TAI (13 quadrillion) vs. willingness to pay log $ 10.6 (36 billion) - 21.0 log FLOPS per $ (910 quintillion)
# Year: 2062 - 31.6 max log FLOP (43 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.0 to buy TAI (11 quadrillion) vs. willingness to pay log $ 10.6 (39 billion) - 21.0 log FLOPS per $ (1 sextillion)
# Year: 2063 - 31.7 max log FLOP (55 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 16.0 to buy TAI (9 quadrillion) vs. willingness to pay log $ 10.6 (43 billion) - 21.1 log FLOPS per $ (1 sextillion)
# Year: 2064 - 31.9 max log FLOP (71 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.9 to buy TAI (8 quadrillion) vs. willingness to pay log $ 10.7 (46 billion) - 21.2 log FLOPS per $ (2 sextillion)
# Year: 2065 - 32.0 max log FLOP (92 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.8 to buy TAI (6 quadrillion) vs. willingness to pay log $ 10.7 (50 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2066 - 32.1 max log FLOP (117 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.7 to buy TAI (5 quadrillion) vs. willingness to pay log $ 10.7 (54 billion) - 21.3 log FLOPS per $ (2 sextillion)
# Year: 2067 - 32.2 max log FLOP (150 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.7 to buy TAI (5 quadrillion) vs. willingness to pay log $ 10.8 (58 billion) - 21.4 log FLOPS per $ (3 sextillion)
# Year: 2068 - 32.3 max log FLOP (191 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.6 to buy TAI (4 quadrillion) vs. willingness to pay log $ 10.8 (62 billion) - 21.5 log FLOPS per $ (3 sextillion)
# Year: 2069 - 32.4 max log FLOP (243 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.5 to buy TAI (3 quadrillion) vs. willingness to pay log $ 10.8 (66 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2070 - 32.5 max log FLOP (308 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.4 to buy TAI (3 quadrillion) vs. willingness to pay log $ 10.8 (70 billion) - 21.6 log FLOPS per $ (4 sextillion)
# Year: 2071 - 32.6 max log FLOP (389 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.4 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.9 (75 billion) - 21.7 log FLOPS per $ (5 sextillion)
# Year: 2072 - 32.7 max log FLOP (491 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.3 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.9 (79 billion) - 21.8 log FLOPS per $ (6 sextillion)
# Year: 2073 - 32.8 max log FLOP (618 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.2 to buy TAI (2 quadrillion) vs. willingness to pay log $ 10.9 (84 billion) - 21.9 log FLOPS per $ (7 sextillion)
# Year: 2074 - 32.9 max log FLOP (777 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 10.9 (89 billion) - 21.9 log FLOPS per $ (9 sextillion)
# Year: 2075 - 33.0 max log FLOP (974 nonillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.1 to buy TAI (1 quadrillion) vs. willingness to pay log $ 11.0 (94 billion) - 22.0 log FLOPS per $ (10 sextillion)
# Year: 2076 - 33.1 max log FLOP (1 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 15.0 to buy TAI (956 trillion) vs. willingness to pay log $ 11.0 (98 billion) - 22.1 log FLOPS per $ (12 sextillion)
# Year: 2077 - 33.2 max log FLOP (2 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.9 to buy TAI (805 trillion) vs. willingness to pay log $ 11.0 (104 billion) - 22.2 log FLOPS per $ (15 sextillion)
# Year: 2078 - 33.3 max log FLOP (2 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.8 to buy TAI (678 trillion) vs. willingness to pay log $ 11.0 (109 billion) - 22.2 log FLOPS per $ (17 sextillion)
# Year: 2079 - 33.4 max log FLOP (2 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.8 to buy TAI (571 trillion) vs. willingness to pay log $ 11.1 (114 billion) - 22.3 log FLOPS per $ (21 sextillion)
# Year: 2080 - 33.5 max log FLOP (3 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.7 to buy TAI (481 trillion) vs. willingness to pay log $ 11.1 (119 billion) - 22.4 log FLOPS per $ (25 sextillion)
# Year: 2081 - 33.6 max log FLOP (4 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.6 to buy TAI (406 trillion) vs. willingness to pay log $ 11.1 (125 billion) - 22.5 log FLOPS per $ (29 sextillion)
# Year: 2082 - 33.7 max log FLOP (5 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.5 to buy TAI (343 trillion) vs. willingness to pay log $ 11.1 (131 billion) - 22.5 log FLOPS per $ (35 sextillion)
# Year: 2083 - 33.7 max log FLOP (6 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.5 to buy TAI (290 trillion) vs. willingness to pay log $ 11.1 (137 billion) - 22.6 log FLOPS per $ (41 sextillion)
# Year: 2084 - 33.8 max log FLOP (7 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.4 to buy TAI (245 trillion) vs. willingness to pay log $ 11.2 (143 billion) - 22.7 log FLOPS per $ (48 sextillion)
# Year: 2085 - 33.9 max log FLOP (8 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.3 to buy TAI (208 trillion) vs. willingness to pay log $ 11.2 (149 billion) - 22.8 log FLOPS per $ (57 sextillion)
# Year: 2086 - 34.0 max log FLOP (10 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.2 to buy TAI (176 trillion) vs. willingness to pay log $ 11.2 (155 billion) - 22.8 log FLOPS per $ (67 sextillion)
# Year: 2087 - 34.1 max log FLOP (13 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.2 to buy TAI (150 trillion) vs. willingness to pay log $ 11.2 (162 billion) - 22.9 log FLOPS per $ (79 sextillion)
# Year: 2088 - 34.2 max log FLOP (16 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.1 to buy TAI (128 trillion) vs. willingness to pay log $ 11.2 (169 billion) - 23.0 log FLOPS per $ (93 sextillion)
# Year: 2089 - 34.3 max log FLOP (19 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.0 to buy TAI (109 trillion) vs. willingness to pay log $ 11.2 (176 billion) - 23.0 log FLOPS per $ (108 sextillion)
# Year: 2090 - 34.4 max log FLOP (23 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 14.0 to buy TAI (94 trillion) vs. willingness to pay log $ 11.3 (183 billion) - 23.1 log FLOPS per $ (126 sextillion)
# Year: 2091 - 34.4 max log FLOP (28 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.9 to buy TAI (81 trillion) vs. willingness to pay log $ 11.3 (191 billion) - 23.2 log FLOPS per $ (147 sextillion)
# Year: 2092 - 34.5 max log FLOP (34 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.8 to buy TAI (70 trillion) vs. willingness to pay log $ 11.3 (198 billion) - 23.2 log FLOPS per $ (170 sextillion)
# Year: 2093 - 34.6 max log FLOP (41 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.8 to buy TAI (60 trillion) vs. willingness to pay log $ 11.3 (206 billion) - 23.3 log FLOPS per $ (196 sextillion)
# Year: 2094 - 34.7 max log FLOP (48 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.7 to buy TAI (52 trillion) vs. willingness to pay log $ 11.3 (215 billion) - 23.4 log FLOPS per $ (225 sextillion)
# Year: 2095 - 34.8 max log FLOP (57 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.7 to buy TAI (46 trillion) vs. willingness to pay log $ 11.3 (223 billion) - 23.4 log FLOPS per $ (257 sextillion)
# Year: 2096 - 34.8 max log FLOP (68 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.6 to buy TAI (41 trillion) vs. willingness to pay log $ 11.4 (232 billion) - 23.5 log FLOPS per $ (292 sextillion)
# Year: 2097 - 34.9 max log FLOP (79 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.6 to buy TAI (36 trillion) vs. willingness to pay log $ 11.4 (241 billion) - 23.5 log FLOPS per $ (330 sextillion)
# Year: 2098 - 35.0 max log FLOP (93 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.5 to buy TAI (32 trillion) vs. willingness to pay log $ 11.4 (251 billion) - 23.6 log FLOPS per $ (369 sextillion)
# Year: 2099 - 35.0 max log FLOP (107 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.5 to buy TAI (29 trillion) vs. willingness to pay log $ 11.4 (260 billion) - 23.6 log FLOPS per $ (411 sextillion)
# Year: 2100 - 35.1 max log FLOP (123 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.4 to buy TAI (26 trillion) vs. willingness to pay log $ 11.4 (271 billion) - 23.7 log FLOPS per $ (454 sextillion)
# Year: 2101 - 35.1 max log FLOP (140 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.4 to buy TAI (24 trillion) vs. willingness to pay log $ 11.4 (281 billion) - 23.7 log FLOPS per $ (497 sextillion)
# Year: 2102 - 35.2 max log FLOP (158 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.3 to buy TAI (22 trillion) vs. willingness to pay log $ 11.5 (292 billion) - 23.7 log FLOPS per $ (541 sextillion)
# Year: 2103 - 35.2 max log FLOP (177 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.3 to buy TAI (20 trillion) vs. willingness to pay log $ 11.5 (303 billion) - 23.8 log FLOPS per $ (584 sextillion)
# Year: 2104 - 35.3 max log FLOP (197 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.3 to buy TAI (19 trillion) vs. willingness to pay log $ 11.5 (315 billion) - 23.8 log FLOPS per $ (626 sextillion)
# Year: 2105 - 35.3 max log FLOP (218 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (18 trillion) vs. willingness to pay log $ 11.5 (327 billion) - 23.8 log FLOPS per $ (665 sextillion)
# Year: 2106 - 35.4 max log FLOP (239 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (17 trillion) vs. willingness to pay log $ 11.5 (340 billion) - 23.8 log FLOPS per $ (703 sextillion)
# Year: 2107 - 35.4 max log FLOP (261 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (16 trillion) vs. willingness to pay log $ 11.5 (353 billion) - 23.9 log FLOPS per $ (738 sextillion)
# Year: 2108 - 35.5 max log FLOP (283 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (15 trillion) vs. willingness to pay log $ 11.6 (367 billion) - 23.9 log FLOPS per $ (771 sextillion)
# Year: 2109 - 35.5 max log FLOP (305 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (15 trillion) vs. willingness to pay log $ 11.6 (381 billion) - 23.9 log FLOPS per $ (800 sextillion)
# Year: 2110 - 35.5 max log FLOP (327 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.2 to buy TAI (14 trillion) vs. willingness to pay log $ 11.6 (395 billion) - 23.9 log FLOPS per $ (827 sextillion)
# Year: 2111 - 35.5 max log FLOP (349 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (14 trillion) vs. willingness to pay log $ 11.6 (411 billion) - 23.9 log FLOPS per $ (850 sextillion)
# Year: 2112 - 35.6 max log FLOP (371 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (14 trillion) vs. willingness to pay log $ 11.6 (426 billion) - 23.9 log FLOPS per $ (871 sextillion)
# Year: 2113 - 35.6 max log FLOP (394 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 11.6 (443 billion) - 23.9 log FLOPS per $ (890 sextillion)
# Year: 2114 - 35.6 max log FLOP (416 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 11.7 (460 billion) - 24.0 log FLOPS per $ (906 sextillion)
# Year: 2115 - 35.6 max log FLOP (439 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 11.7 (477 billion) - 24.0 log FLOPS per $ (919 sextillion)
# Year: 2116 - 35.7 max log FLOP (462 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 11.7 (495 billion) - 24.0 log FLOPS per $ (932 sextillion)
# Year: 2117 - 35.7 max log FLOP (484 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (13 trillion) vs. willingness to pay log $ 11.7 (514 billion) - 24.0 log FLOPS per $ (942 sextillion)
# Year: 2118 - 35.7 max log FLOP (508 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (534 billion) - 24.0 log FLOPS per $ (951 sextillion)
# Year: 2119 - 35.7 max log FLOP (531 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (554 billion) - 24.0 log FLOPS per $ (958 sextillion)
# Year: 2120 - 35.7 max log FLOP (555 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (576 billion) - 24.0 log FLOPS per $ (965 sextillion)
# Year: 2121 - 35.8 max log FLOP (580 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (598 billion) - 24.0 log FLOPS per $ (970 sextillion)
# Year: 2122 - 35.8 max log FLOP (605 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (620 billion) - 24.0 log FLOPS per $ (975 sextillion)
# Year: 2123 - 35.8 max log FLOP (630 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (644 billion) - 24.0 log FLOPS per $ (979 sextillion)
# Year: 2124 - 35.8 max log FLOP (657 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (669 billion) - 24.0 log FLOPS per $ (982 sextillion)
# Year: 2125 - 35.8 max log FLOP (684 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (694 billion) - 24.0 log FLOPS per $ (985 sextillion)
# Year: 2126 - 35.9 max log FLOP (712 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (721 billion) - 24.0 log FLOPS per $ (987 sextillion)
# Year: 2127 - 35.9 max log FLOP (740 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (748 billion) - 24.0 log FLOPS per $ (989 sextillion)
# Year: 2128 - 35.9 max log FLOP (770 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (777 billion) - 24.0 log FLOPS per $ (991 sextillion)
# Year: 2129 - 35.9 max log FLOP (800 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (806 billion) - 24.0 log FLOPS per $ (992 sextillion)
# Year: 2130 - 35.9 max log FLOP (832 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (837 billion) - 24.0 log FLOPS per $ (994 sextillion)
# Year: 2131 - 35.9 max log FLOP (864 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (869 billion) - 24.0 log FLOPS per $ (995 sextillion)
# Year: 2132 - 36.0 max log FLOP (898 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (902 billion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2133 - 36.0 max log FLOP (933 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (937 billion) - 24.0 log FLOPS per $ (996 sextillion)
# Year: 2134 - 36.0 max log FLOP (969 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (972 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2135 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2136 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2137 - 36.0 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (1 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2138 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2139 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2140 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2141 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2142 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2143 - 36.1 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.1 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2144 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2145 - 36.2 max log FLOP (1 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (1 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2146 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2147 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2148 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2149 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2150 - 36.2 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.2 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2151 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2152 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2153 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2154 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2155 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2156 - 36.3 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.3 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2157 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2158 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2159 - 36.4 max log FLOP (2 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (2 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2160 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2161 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2162 - 36.4 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.4 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2163 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2164 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2165 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2166 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2167 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2168 - 36.5 max log FLOP (3 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.5 (3 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2169 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2170 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2171 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2172 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2173 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2174 - 36.6 max log FLOP (4 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.6 (4 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2175 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2176 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2177 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2178 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2179 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2180 - 36.7 max log FLOP (5 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.7 (5 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2181 - 36.8 max log FLOP (6 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (6 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2182 - 36.8 max log FLOP (6 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (6 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2183 - 36.8 max log FLOP (6 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (6 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2184 - 36.8 max log FLOP (6 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (6 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2185 - 36.8 max log FLOP (7 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (7 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2186 - 36.8 max log FLOP (7 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (7 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2187 - 36.8 max log FLOP (7 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.8 (7 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2188 - 36.9 max log FLOP (7 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (7 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2189 - 36.9 max log FLOP (8 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (8 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2190 - 36.9 max log FLOP (8 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (8 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2191 - 36.9 max log FLOP (8 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (8 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2192 - 36.9 max log FLOP (9 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (9 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2193 - 36.9 max log FLOP (9 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.9 (9 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2194 - 37.0 max log FLOP (9 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (9 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2195 - 37.0 max log FLOP (10 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (10 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2196 - 37.0 max log FLOP (10 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (10 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2197 - 37.0 max log FLOP (10 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (10 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2198 - 37.0 max log FLOP (11 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (11 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2199 - 37.0 max log FLOP (11 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.0 (11 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2200 - 37.1 max log FLOP (11 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.1 (11 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2201 - 37.1 max log FLOP (12 thousand decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 13.1 (12 trillion) - 24.0 log FLOPS per $ (1000 sextillion)
# -- Nonscaling issue did not occur p_nonscaling_issue=0.3
# --- /!\ TAI CREATED in 2201
# ...
# Year: 2165 - 35.5 max log FLOP (294 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (295 billion) - 24.0 log FLOPS per $ (997 sextillion)
# Year: 2166 - 35.5 max log FLOP (300 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (301 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2167 - 35.5 max log FLOP (307 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (307 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2168 - 35.5 max log FLOP (313 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (314 billion) - 24.0 log FLOPS per $ (998 sextillion)
# Year: 2169 - 35.5 max log FLOP (320 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (320 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2170 - 35.5 max log FLOP (327 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (327 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2171 - 35.5 max log FLOP (334 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (334 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2172 - 35.5 max log FLOP (341 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (341 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2173 - 35.5 max log FLOP (348 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.5 (348 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2174 - 35.6 max log FLOP (355 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (355 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2175 - 35.6 max log FLOP (363 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (363 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2176 - 35.6 max log FLOP (370 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (371 billion) - 24.0 log FLOPS per $ (999 sextillion)
# Year: 2177 - 35.6 max log FLOP (378 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (378 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2178 - 35.6 max log FLOP (386 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (386 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2179 - 35.6 max log FLOP (394 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (394 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2180 - 35.6 max log FLOP (403 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (403 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2181 - 35.6 max log FLOP (411 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (411 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2182 - 35.6 max log FLOP (420 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (420 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2183 - 35.6 max log FLOP (429 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (429 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2184 - 35.6 max log FLOP (438 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.6 (438 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2185 - 35.7 max log FLOP (447 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (447 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2186 - 35.7 max log FLOP (456 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (456 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2187 - 35.7 max log FLOP (466 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (466 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2188 - 35.7 max log FLOP (476 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (476 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2189 - 35.7 max log FLOP (486 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (486 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2190 - 35.7 max log FLOP (496 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (496 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2191 - 35.7 max log FLOP (506 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (506 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2192 - 35.7 max log FLOP (517 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (517 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2193 - 35.7 max log FLOP (528 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (528 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2194 - 35.7 max log FLOP (539 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (539 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2195 - 35.7 max log FLOP (550 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (550 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2196 - 35.7 max log FLOP (562 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.7 (562 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2197 - 35.8 max log FLOP (573 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (574 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2198 - 35.8 max log FLOP (586 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (586 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2199 - 35.8 max log FLOP (598 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (598 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2200 - 35.8 max log FLOP (610 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (610 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2201 - 35.8 max log FLOP (623 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (623 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2202 - 35.8 max log FLOP (636 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (636 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2203 - 35.8 max log FLOP (650 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (650 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2204 - 35.8 max log FLOP (663 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (663 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2205 - 35.8 max log FLOP (677 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (677 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2206 - 35.8 max log FLOP (692 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (692 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2207 - 35.8 max log FLOP (706 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.8 (706 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2208 - 35.9 max log FLOP (721 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (721 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2209 - 35.9 max log FLOP (736 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (736 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2210 - 35.9 max log FLOP (752 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (752 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2211 - 35.9 max log FLOP (767 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (767 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2212 - 35.9 max log FLOP (783 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (783 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2213 - 35.9 max log FLOP (800 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (800 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2214 - 35.9 max log FLOP (817 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (817 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2215 - 35.9 max log FLOP (834 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (834 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2216 - 35.9 max log FLOP (851 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (851 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2217 - 35.9 max log FLOP (869 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (869 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2218 - 35.9 max log FLOP (888 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 11.9 (888 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2219 - 36.0 max log FLOP (906 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (906 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2220 - 36.0 max log FLOP (925 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (925 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# Year: 2221 - 36.0 max log FLOP (945 decillion) available - TAI takes 37.1 log FLOP (12 thousand decillion) - log $ 13.1 to buy TAI (12 trillion) vs. willingness to pay log $ 12.0 (945 billion) - 24.0 log FLOPS per $ (1000 sextillion)
# --- :/ TAI NOT CREATED BEFORE 2223
# ## RUN 5 ##
# It takes 16.2 log FLOPs (~15 quadrillion) for transformative capabilities.
# Every 1.9 years algorithms get 2x better, with 2 log reductions possible.
# FLOPs start at a cost of 18.0 log FLOPs (~1 quintillion) per 2022$USD. Every 2.9 years they get 2x cheaper, to a maximum of 24.0 log FLOPs (~1 septillion) per 2022$USD.
# We are willing to pay 8.2 log 2022$USD (~170 million) and this increases by 4.1x per year to a max of 0.0008% of GDP. GDP grows at a rate of 1.017x per year.
# If a non-scaling delay happens, it will take an additional 4.8 years to produce TAI due to issues unrelated to scaling FLOP
# ---
# Year: 2022 - 26.2 max log FLOP (168 septillion) available - TAI takes 16.2 log FLOP (15 quadrillion) - log $ -1.8 to buy TAI (0.014786049886547538) vs. willingness to pay log $ 8.2 (168 million) - 18.0 log FLOPS per $ (1000 quadrillion)
# -- Nonscaling delay occured p_nonscaling_issue=0.9424
# /!\ FLOPs for TAI sufficient but needs 4.8 more years to solve non-scaling issues
# Year: 2023 - 26.4 max log FLOP (252 septillion) available - TAI takes 16.0 log FLOP (10 quadrillion) - log $ -2.1 to buy TAI (0.008226538079290927) vs. willingness to pay log $ 8.3 (198 million) - 18.1 log FLOPS per $ (1 quintillion)
# /!\ FLOPs for TAI sufficient but needs 3.8 more years to solve non-scaling issues
# Year: 2024 - 26.6 max log FLOP (378 septillion) available - TAI takes 15.9 log FLOP (7 quadrillion) - log $ -2.3 to buy TAI (0.004539994606095198) vs. willingness to pay log $ 8.4 (234 million) - 18.2 log FLOPS per $ (2 quintillion)
# /!\ FLOPs for TAI sufficient but needs 2.8 more years to solve non-scaling issues
# Year: 2025 - 26.8 max log FLOP (567 septillion) available - TAI takes 15.7 log FLOP (5 quadrillion) - log $ -2.6 to buy TAI (0.0025119955465632724) vs. willingness to pay log $ 8.4 (276 million) - 18.3 log FLOPS per $ (2 quintillion)
# /!\ FLOPs for TAI sufficient but needs 1.8 more years to solve non-scaling issues
# Year: 2026 - 26.9 max log FLOP (850 septillion) available - TAI takes 15.6 log FLOP (4 quadrillion) - log $ -2.9 to buy TAI (0.00139497831995651) vs. willingness to pay log $ 8.5 (325 million) - 18.4 log FLOPS per $ (3 quintillion)
# /!\ FLOPs for TAI sufficient but needs 0.8 more years to solve non-scaling issues
# Year: 2027 - 27.1 max log FLOP (1 octillion) available - TAI takes 15.4 log FLOP (3 quadrillion) - log $ -3.1 to buy TAI (0.00077863163749036) vs. willingness to pay log $ 8.6 (383 million) - 18.5 log FLOPS per $ (3 quintillion)
# --- /!\ TAI CREATED in 2027

# %%
# %%time
tai_years = bayes.bayesnet(define_event,
                           find=lambda e: e['tai_year'],
                           verbose=True,
                           raw=True,
                           dump_cache_file='caches/tai_years',
                           reload_cache=True,
                           cores=7,
                           n=RUNS)
# Out:
# Reloading cache...
# Generating Bayes net with 7 cores...
#  42%|█████████████████████████▎                                  | 4214/10000 [01:35<01:35, 60.36it/s]

# %%
out = sq.get_percentiles(tai_years)
[str(o[0]) + '%: ' + (str(int(o[1])) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR)) for o in out.items()]

# NOTE: Ajeya's numbers should output something very close to:
# '5%': 2027,
# '10%: 2031',
# '20%: 2037',
# '30%: 2042',
# '40%: 2047',
# '50%: 2053',
# '60%: 2061',
# '70%: 2073',
# '80%: >2100',
# '90%: >2100',
# '95%: >2100'

# My latest numbers (2022 Aug 27 8:43PM CT):
# '1%: 2024',
# '5%: 2027',
# '10%: 2029',
# '20%: 2033',
# '30%: 2038',
# '40%: 2045',
# '50%: 2054',
# '60%: 2064',
# '70%: 2079',
# '80%: 2116',
# '90%: >2222',
# '95%: >2222',
# '99%: >2222']

# %%
[str(o[0]) + '%: ' + (str(int(o[1]) - CURRENT_YEAR) if o[1] < MAX_YEAR else '>' + str(MAX_YEAR - CURRENT_YEAR)) + ' years from now' for o in out.items()]

# %%
tai_years_ = np.array([MAX_YEAR + 1 if t > MAX_YEAR else t for t in tai_years])
count, bins_count = np.histogram(tai_years_, bins=(MAX_YEAR - CURRENT_YEAR))
bins = np.round(np.array([b for b in bins_count[1:] if b <= MAX_YEAR]))
pdf = count / sum(count)
cdf = np.cumsum(pdf)

plt.plot(bins, cdf[:len(bins)], label='CDF')
plt.legend()
plt.show()

# %%
d_ = dict(zip(years, cdf[:len(bins)]))

def bin_tai_yrs(low=None, hi=None):
    low = CURRENT_YEAR if low is None else low
    out = 1 - d_[low] if hi is None else d_[hi] - d_[low]
    return round(out * 100, 1)

print('<2024: {}%'.format(bin_tai_yrs(hi=2024)))
print('2025-2029: {}%'.format(bin_tai_yrs(2025, 2029)))
print('2030-2039: {}%'.format(bin_tai_yrs(2030, 2039)))
print('2040-2049: {}%'.format(bin_tai_yrs(2040, 2049)))
print('2050-2059: {}%'.format(bin_tai_yrs(2050, 2059)))
print('2060-2069: {}%'.format(bin_tai_yrs(2060, 2069)))
print('2070-2079: {}%'.format(bin_tai_yrs(2070, 2079)))
print('2080-2089: {}%'.format(bin_tai_yrs(2080, 2089)))
print('2090-2099: {}%'.format(bin_tai_yrs(2090, 2099)))
print('2100-2149: {}%'.format(bin_tai_yrs(2100, 2149)))
print('2149-2199: {}%'.format(bin_tai_yrs(2149, 2199)))
print('>2200: {}%'.format(bin_tai_yrs(low=2220)))

# %%
def print_chance_tai_by_year(data, year_target):
    return '{}% chance of TAI by EOY {}'.format(int(np.round(sum([1 if y <= year_target else 0 for y in data]) / len(data) * 100, 0)),
                                                year_target)
    
print('## Within <1 years')
print_chance_tai_by_year(tai_years, 2022)

# %%
print('## Within <1 years')
print_chance_tai_by_year(tai_years, 2023)

# %%
print_chance_tai_by_year(tai_years, 2024)

# %%
print_chance_tai_by_year(tai_years, 2025)

# %%
print('## Within 5 years')
print_chance_tai_by_year(tai_years, 2027)

# %%
print_chance_tai_by_year(tai_years, 2029)

# %%
print_chance_tai_by_year(tai_years, 2030)

# %%
print('## Within 10 years')
print_chance_tai_by_year(tai_years, 2032)

# %%
# Holden benchmarks from https://www.cold-takes.com/biological-anchors-is-about-bounding-not-pinpointing-ai-timelines/#bio-anchors-as-a-way-of-bounding-ai-timelines
print('## Within 14 years (Holden benchmark - 10%-50%, Holden: 10%)')
print_chance_tai_by_year(tai_years, 2036)

# %%
print('## Within 15 years')
print_chance_tai_by_year(tai_years, 2037)

# %%
print_chance_tai_by_year(tai_years, 2040)

# %%
print('## Within 20 years')
print_chance_tai_by_year(tai_years, 2042)

# %%
print('## Within 25 years')
print_chance_tai_by_year(tai_years, 2047)

# %%
print_chance_tai_by_year(tai_years, 2050)

# %%
print('## Within 38 years (Holden benchmark - 25%-75%, Holden: 50%)')
print_chance_tai_by_year(tai_years, 2060)

# %%
print('## Within 48 years (Carlsmith benchmark - Carlsmith: 50%)')
print_chance_tai_by_year(tai_years, 2070)

# %%
print('## Within 50 years')
print_chance_tai_by_year(tai_years, 2072)

# %%
print('## Within my personal expected lifespan')
print_chance_tai_by_year(tai_years, 2078)

# %%
print('## Within 75 years')
print_chance_tai_by_year(tai_years, 2097)

# %%
print('## Within 78 years (Holden benchmark - 33%-90%, Holden: 66%)')
print_chance_tai_by_year(tai_years, 2100)

# %%
print('## Within 100 years')
print_chance_tai_by_year(tai_years, 2122)

# %%
print('## Within 200 years')
print_chance_tai_by_year(tai_years, 2222)

# %%
pdf_smoothed = savitzky_golay(pdf[:len(bins)], 51, 3)
plt.plot(bins, pdf_smoothed, label='PDF (smoothed)')
plt.legend()
plt.show()

# %%
cdf[:len(bins)]

# %%
pdf[:len(bins)]

# %%
## TODO: Update all

cotra_2020_cdf = [0.0214, 0.0272, 0.0328, 0.0385, 0.0458, 0.0551, 0.0641, 0.0721,
       0.0827, 0.0923, 0.1061, 0.1199, 0.1343, 0.1574, 0.175 , 0.1917,
       0.2108, 0.2321, 0.251 , 0.2825, 0.3001, 0.3177, 0.3317, 0.3531,
       0.3829, 0.4089, 0.4372, 0.4606, 0.4829, 0.4944, 0.504 , 0.5147,
       0.5243, 0.5335, 0.5423, 0.5521, 0.5608, 0.5719, 0.5826, 0.5922,
       0.6011, 0.6096, 0.6209, 0.6379, 0.6524, 0.6682, 0.682 , 0.6948,
       0.7084, 0.7207, 0.7314, 0.7362, 0.7407, 0.7456, 0.7506, 0.755 ,
       0.7594, 0.7626, 0.7668, 0.7698, 0.7725, 0.7745, 0.7765, 0.7775,
       0.7793, 0.7801, 0.781 , 0.7818, 0.7827, 0.7833, 0.7843, 0.7847,
       0.7852, 0.7858, 0.7861, 0.7868, 0.7874, 0.7882, 0.7887, 0.7891,
       0.7895, 0.7908, 0.7916, 0.7918, 0.7926, 0.7929, 0.7933, 0.7936,
       0.7941, 0.7949, 0.795 , 0.7954, 0.7957, 0.7962, 0.7969, 0.7976,
       0.7981, 0.7987, 0.7996, 0.8002, 0.8004, 0.801 , 0.8015, 0.8021,
       0.8025, 0.8029, 0.8034, 0.8041, 0.8045, 0.8052, 0.8059, 0.806 ,
       0.8066, 0.8071, 0.8079, 0.8087, 0.8089, 0.8093, 0.8093, 0.8095,
       0.8105, 0.8109, 0.8114, 0.8118, 0.8128, 0.8132, 0.8139, 0.8139,
       0.8144, 0.8149, 0.8154, 0.8162, 0.8167, 0.8173, 0.8177, 0.8185,
       0.8196, 0.82  , 0.821 , 0.8217, 0.8224, 0.8233, 0.8244, 0.8247,
       0.8254, 0.8262, 0.8267, 0.8274, 0.8277, 0.8288, 0.8294, 0.8298,
       0.8305, 0.8318, 0.8328, 0.8335, 0.8343, 0.8347, 0.8351, 0.8361,
       0.837 , 0.8376, 0.8385, 0.8398, 0.8404, 0.8413, 0.8419, 0.8427,
       0.8437, 0.8448, 0.8458, 0.8462, 0.8471, 0.8482, 0.8487, 0.8491,
       0.8498, 0.8505, 0.8507, 0.8511, 0.8519, 0.8526, 0.8534, 0.8542,
       0.855 , 0.8554, 0.8559, 0.8565, 0.857 , 0.8575, 0.8581, 0.8587,
       0.8592, 0.86  , 0.8605, 0.861 , 0.8615, 0.862 , 0.8629]
cotra_2020_pdf = np.append(np.array(cotra_2020_cdf[0]), np.diff(cotra_2020_cdf[:len(bins)]))
cotra_2020_pdf_smoothed = savitzky_golay(cotra_2020_pdf[:len(bins)], 51, 3)

cotra_2022_cdf = [0.0616, 0.0747, 0.0873, 0.1015, 0.118 , 0.1365, 0.1564, 0.1758,
       0.1981, 0.2188, 0.2531, 0.2768, 0.2975, 0.3193, 0.3481, 0.3728,
       0.4124, 0.433 , 0.4557, 0.4742, 0.4981, 0.5348, 0.569 , 0.6032,
       0.627 , 0.6404, 0.6507, 0.6611, 0.6701, 0.6801, 0.6893, 0.697 ,
       0.7051, 0.7115, 0.7186, 0.7252, 0.7331, 0.7411, 0.749 , 0.7577,
       0.7691, 0.7785, 0.7881, 0.799 , 0.807 , 0.8161, 0.8233, 0.8303,
       0.8348, 0.839 , 0.8429, 0.8462, 0.8494, 0.8517, 0.8532, 0.8553,
       0.8566, 0.8588, 0.8602, 0.862 , 0.8633, 0.864 , 0.8648, 0.8654,
       0.8662, 0.867 , 0.8672, 0.8677, 0.8683, 0.8686, 0.8689, 0.8689,
       0.8692, 0.8695, 0.8699, 0.8703, 0.8709, 0.8711, 0.8713, 0.8715,
       0.8719, 0.8721, 0.8727, 0.873 , 0.8736, 0.8739, 0.8742, 0.8746,
       0.875 , 0.8751, 0.8754, 0.8757, 0.8763, 0.8764, 0.8768, 0.8772,
       0.8775, 0.8775, 0.8776, 0.8779, 0.878 , 0.8781, 0.8783, 0.8789,
       0.8792, 0.8794, 0.8795, 0.8798, 0.8805, 0.8808, 0.8814, 0.8819,
       0.8822, 0.8826, 0.8827, 0.8828, 0.8832, 0.8834, 0.8837, 0.8839,
       0.8842, 0.8848, 0.8857, 0.8859, 0.8861, 0.8863, 0.8866, 0.8869,
       0.8869, 0.8873, 0.8878, 0.8889, 0.8896, 0.8904, 0.8906, 0.8911,
       0.8915, 0.892 , 0.8929, 0.8934, 0.8937, 0.8942, 0.8946, 0.8954,
       0.8959, 0.8963, 0.8969, 0.8972, 0.8975, 0.8984, 0.8988, 0.8993,
       0.8999, 0.9004, 0.9007, 0.9015, 0.9019, 0.9021, 0.9026, 0.9031,
       0.9037, 0.9041, 0.9048, 0.9054, 0.9057, 0.9062, 0.9067, 0.9075,
       0.9084, 0.9088, 0.909 , 0.9101, 0.9106, 0.9108, 0.9114, 0.9116,
       0.9121, 0.9127, 0.913 , 0.9137, 0.9144, 0.9147, 0.9154, 0.9159,
       0.9161, 0.9166, 0.9173, 0.9177, 0.9185, 0.9189, 0.9193, 0.9195,
       0.9195, 0.9198, 0.9204, 0.9205, 0.921 , 0.9216, 0.9221]
cotra_2022_pdf = np.append(np.array(cotra_2022_cdf[0]), np.diff(cotra_2022_cdf[:len(bins)]))
cotra_2022_pdf_smoothed = savitzky_golay(cotra_2022_pdf[:len(bins)], 51, 3)

peter_cdf = [0.0024, 0.0045, 0.0106, 0.0179, 0.0258, 0.0345, 0.0423, 0.0522,
       0.0638, 0.076 , 0.0885, 0.1028, 0.1165, 0.1332, 0.1498, 0.1669,
       0.1835, 0.2004, 0.2162, 0.2369, 0.2551, 0.2711, 0.2861, 0.3021,
       0.3184, 0.3314, 0.347 , 0.3589, 0.3729, 0.3882, 0.4022, 0.4142,
       0.4268, 0.4394, 0.4498, 0.4614, 0.471 , 0.4828, 0.4929, 0.5014,
       0.5097, 0.5179, 0.5275, 0.5359, 0.5456, 0.5545, 0.5634, 0.5711,
       0.5808, 0.5891, 0.5949, 0.6039, 0.6125, 0.6198, 0.6257, 0.6331,
       0.6392, 0.6453, 0.6503, 0.6571, 0.6629, 0.6684, 0.674 , 0.6803,
       0.6858, 0.6904, 0.6956, 0.7006, 0.7052, 0.7099, 0.7146, 0.7179,
       0.7209, 0.7253, 0.7293, 0.7325, 0.7352, 0.7388, 0.7421, 0.7448,
       0.7482, 0.7503, 0.7523, 0.7539, 0.7566, 0.7591, 0.7616, 0.7632,
       0.7667, 0.7685, 0.7699, 0.7714, 0.7729, 0.7749, 0.7769, 0.779 ,
       0.7808, 0.7829, 0.7849, 0.787 , 0.7878, 0.7895, 0.7902, 0.792 ,
       0.7931, 0.794 , 0.7952, 0.7967, 0.7981, 0.7993, 0.8003, 0.8021,
       0.8031, 0.8044, 0.8049, 0.8058, 0.8063, 0.8072, 0.8079, 0.8083,
       0.8091, 0.8096, 0.8101, 0.8111, 0.8116, 0.8126, 0.8131, 0.8142,
       0.815 , 0.8157, 0.8161, 0.817 , 0.8178, 0.8192, 0.8194, 0.8206,
       0.8209, 0.8211, 0.8217, 0.8221, 0.823 , 0.8234, 0.8237, 0.8245,
       0.825 , 0.8253, 0.8259, 0.8265, 0.8273, 0.8279, 0.8285, 0.8287,
       0.8294, 0.8297, 0.8302, 0.8302, 0.8311, 0.8315, 0.8316, 0.8318,
       0.832 , 0.8321, 0.8324, 0.8327, 0.8331, 0.8335, 0.8337, 0.8341,
       0.8342, 0.8344, 0.8347, 0.8349, 0.8353, 0.8359, 0.8365, 0.8371,
       0.8373, 0.8374, 0.8375, 0.8379, 0.8382, 0.8385, 0.8391, 0.8395,
       0.8398, 0.84  , 0.8406, 0.841 , 0.8413, 0.8417, 0.8419, 0.842 ,
       0.8426, 0.8427, 0.8432, 0.8434, 0.8439, 0.8444, 0.8448]
peter_pdf = np.append(np.array(peter_cdf[0]), np.diff(peter_cdf[:len(bins)]))
peter_pdf_smoothed = savitzky_golay(peter_pdf[:len(bins)], 51, 3)

plt.plot(bins[:99], cotra_2020_cdf[:99], label='Cotra 2020 CDF')
plt.plot(bins[:99], cotra_2022_cdf[:99], label='Cotra 2022 CDF (guess)')
plt.plot(bins[:99], peter_cdf[:99], label='Wildeford CDF')
plt.legend()
plt.show()

plt.plot(bins[:99], cotra_2020_pdf_smoothed[:99], label='Cotra 2020 PDF (smoothed)')
plt.plot(bins[:99], cotra_2022_pdf_smoothed[:99], label='Cotra 2022 PDF (guess, smoothed)')
plt.plot(bins[:99], peter_pdf_smoothed[:99], label='Wildeford PDF (smoothed)')
plt.legend()
plt.show()

# %% [markdown]
# ## Sensitivity Analysis

# %%
print('## Default ##')
results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                      tai_flop_size_=36,
                                      nonscaling_delay_=0,
                                      algo_doubling_rate_=2,
                                      possible_algo_reduction_=2,
                                      initial_flops_per_dollar_=10 ** 18,
                                      flops_halving_rate_=2.5,
                                      max_flops_per_dollar_=10 ** 24,
                                      initial_pay_=10*M,
                                      gdp_growth_=1.03,
                                      max_gdp_frac_=1/1600,
                                      willingness_ramp_=1,
                                      spend_doubling_time_=2.5,
                                      initial_chance_of_nonscaling_issue_=0,
                                      final_chance_of_nonscaling_issue_=0,
                                      nonscaling_issue_bottom_year_=0,
                                      willingness_spend_horizon_=1,
                                      print_diagnostic=False), n=1000)
print('{}: {}'.format(t,
                      ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                       '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                       '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## TAI FLOP Size ##')
for t in range(20, 43):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=t,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(t,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## GDP Growth ##')
for g in range(0, 5):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1 + g/100,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + g / 100,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Max GDP Frac ##')
for g in [1/(500*K), 1/(250*K), 1/(100*K), 1/(50*K), 1/(10*K), 5/(10*K),
          1/2000, 1/1500, 1/1000, 2/1000, 3/1000, 4/1000, 5/1000, 1/100,
          2/100, 3/100, 4/100]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=g,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(g,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Spend Doubling Time ##')
for d in range(0, 50):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=1 + d / 10,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(1 + d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Initial FLOPs per dollar ##')
for d in [17, 17.5, 18]:
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** d,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Initial pay ##')
for p in range(70, 91):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10 ** (p / 10),
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('${}: {}'.format(numerize(10 ** (p / 10)),
                           ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                            '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                            '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## FLOPs halving rate ##')
for f in range(5, 41):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=f / 10,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Max FLOPs per dollar ##')
for f in range(20, 31):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** f,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(f,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Willingness ramp ##')
for r in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=r / 10,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=1,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Willingness to spend horizon ##')
for y in range(1, 11):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(y,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Algo doubling rate ##')
for d in range(10, 41, 2):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=d / 10,
                                          possible_algo_reduction_=2,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(d / 10,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
print('## Possible algo reduction ##')
for r in range(0, 13):
    results = sq.sample(lambda: run_model(initial_gdp_=21*T,
                                          tai_flop_size_=36,
                                          nonscaling_delay_=0,
                                          algo_doubling_rate_=2,
                                          possible_algo_reduction_=r,
                                          initial_flops_per_dollar_=10 ** 18,
                                          flops_halving_rate_=2.5,
                                          max_flops_per_dollar_=10 ** 24,
                                          initial_pay_=10*M,
                                          gdp_growth_=1.03,
                                          max_gdp_frac_=1/1600,
                                          willingness_ramp_=1,
                                          spend_doubling_time_=2.5,
                                          initial_chance_of_nonscaling_issue_=0,
                                          final_chance_of_nonscaling_issue_=0,
                                          nonscaling_issue_bottom_year_=0,
                                          willingness_spend_horizon_=y,
                                          print_diagnostic=False), n=1000)
    print('{}: {}'.format(r,
                          ['>2222' if int(sq.get_percentiles(results)[5]) > 2222 else int(sq.get_percentiles(results)[5]),
                           '>2222' if int(sq.get_percentiles(results)[50]) > 2222 else int(sq.get_percentiles(results)[50]),
                           '>2222' if int(sq.get_percentiles(results)[95]) > 2222 else int(sq.get_percentiles(results)[95])]))

# %%
# TODO: Wildeford meta anchor horizon length
# TODO: Wildeford meta anchor efficiency w/ efficiency-based algorithmic reduction
# TODO: efficiency-based algorithmic reduction vs. regular algorithmic reduction

# %%
get_question(11558)

# %%
# https://www.metaculus.com/questions/11558/maximum-compute-used-in-ai-training/
# TODO: Fetch from Metaculus, look side by side
# TODO: Be able to predict back
for y in [2022, 2025, 2030]:
    print('-')
    print('## {} ##'.format(y))
    for i in range(3):
        flops_at_max_ = flops_at_max(initial_gdp=variables['initial_gdp'],
                                     gdp_growth=[1.02, 1.025, 1.03][i],
                                     initial_pay=[10*M, 100*M, 1*B][i],
                                     spend_doubling_time=[1, 2, 3][i],
                                     max_gdp_frac=[1/1000, 4/1000, 1/100][i],
                                     initial_flops_per_dollar=10 ** 18,
                                     max_flops_per_dollar=10 ** 24,
                                     flops_halving_rate=[2, 2.5, 3][i],
                                     year=(y - CURRENT_YEAR))

        print('{}: {} max log FLOPs / ~{} petaFLOP/s-days)'.format(['25th', 'mean', '75th'][i],
                                                                   np.round(np.log10(flops_at_max_), 1),
                                                                   log_flop_to_petaflop_sdays(np.log10(flops_at_max_))))
